# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
#import consine_similarity
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Define the directory paths
directories = [
    ("..\\new_dataset\\eclipse", "..\\new_dataset\\eclipse"),
    #("..\\new_dataset\\eclipse_test", "..\\new_dataset\\eclipse_test"),
    #("..\\new_dataset\\firefox", "..\\new_dataset\\firefox"),
    #("..\\new_dataset\\netbeans", "..\\new_dataset\\netbeans"),
    #("..\\new_dataset\\openoffice", "..\\new_dataset\\openoffice")
]

# %%
# Initialize TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Concatenate preprocessed descriptions from all files in all directories
all_preprocessed_desc = []

# Iterate over each directory
for source_dir, target_dir in directories:
    # Iterate over each file in the directory
    for file_name in os.listdir(source_dir):
        print(file_name)

        # Check if the file is a CSV file        
        if file_name.endswith(".csv"):
            # Load the CSV file
            df = pd.read_csv(os.path.join(source_dir, file_name))
            
            # Check if the DataFrame is empty (end of file reached)
            if df.empty:
                print("End of file reached for:", file_name)
                continue

            # Get the data from the preprocessed_description column
            short_desc = df['preprocessed_description'].astype(str)

            # Concatenate the preprocessed descriptions
            all_preprocessed_desc.extend(short_desc)

    print("Preprocessing done for all files in:", source_dir)

# Fit TF-IDF vectorizer on combined data to build the vocabulary
tfidf_vectorizer.fit(all_preprocessed_desc)
# Out:
# eclipse_small_new.csv
# eclipse_small_new_updated.csv
# Preprocessing done for all files in: ..\new_dataset\eclipse
# TfidfVectorizer()

# %%
# Iterate over each directory
for source_dir, target_dir in directories:
    # Iterate over each file in the directory
    for file_name in os.listdir(source_dir):
        print(file_name)

        # Check if the file is a CSV file        
        if file_name.endswith(".csv"):
            # Load the CSV file
            df = pd.read_csv(os.path.join(source_dir, file_name))
            
            # Check if the DataFrame is empty (end of file reached)
            if df.empty:
                print("End of file reached for:", file_name)
                continue

            # loop over all the rows in the dataframe except the row with issue_id 214301
            for index, row in df.iterrows():
                if row['bug_id'] == 214990:
                    description1 = row['preprocessed_description']
                    continue

                description2 = row['preprocessed_description']

                # convert the two descriptions into a string
                description1 = str(description1)
                description2 = str(description2)
                
                # Transform the two descriptions into TF-IDF vectors
                desc1_tfidf = tfidf_vectorizer.transform([description1])
                desc2_tfidf = tfidf_vectorizer.transform([description2])

                # Compute cosine similarity between the two descriptions
                similarity_score = cosine_similarity(desc1_tfidf, desc2_tfidf)

                # write the outpur in text file in the target directory
                #with open(os.path.join(target_dir, file_name), 'a') as f:
                #    f.write(str(row['bug_id']) + "," + str(214990) + "," + str(similarity_score[0][0]) + "\n")

                if row['bug_id'] == 215040:
                    print("Target ================================================================================")
                # print the id of the two descriptions and the cosine similarity between them
                print("Bug ID1:", row['bug_id'])
                print("Bug ID2:", 214990)
                print("Cosine Similarity between the two descriptions:", similarity_score[0][0])


    print("Preprocessing done for all files in:", source_dir)
# Out:
# eclipse_small_new.csv
# Bug ID1: 214065.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020999547584819353
# Bug ID1: 214070.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01008495692578468
# Bug ID1: 214068.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214072.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.002708924458953911
# Bug ID1: 214071.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214069.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214066.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0257742119488214
# Bug ID1: 214067.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.055968262908647204
# Bug ID1: 214076.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.043271805303896294
# Bug ID1: 214075.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03412084665118001
# Bug ID1: 214078.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02902419604185098
# Bug ID1: 214073.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009354829435249935
# Bug ID1: 214080.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.026205445815060437
# Bug ID1: 214074.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009428638713580906
# Bug ID1: 214079.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04232390124147514
# Bug ID1: 214077.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020387984405222815
# Bug ID1: 214081.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.030636517363252742
# Bug ID1: 214083.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01695705329174908
# Bug ID1: 214082.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0018740604948184907
# Bug ID1: 214084.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023126465900641817
# Bug ID1: 214086.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.013770235018599175
# Bug ID1: 214087.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.017618736032006192
# Bug ID1: 214089.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04670237649695376
# Bug ID1: 214090.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214088.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05879182513975657
# Bug ID1: 214094.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005247540873131657
# Bug ID1: 214095.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.021655813313002956
# Bug ID1: 214097.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214093.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02331216564117854
# Bug ID1: 214092.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.055428655742499194
# Bug ID1: 214100.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214101.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214102.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.041087354521234964
# Bug ID1: 214099.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0014776223805602782
# Bug ID1: 214098.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02275690713690847
# Bug ID1: 214104.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.026650525182364864
# Bug ID1: 214106.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.046534153834772385
# Bug ID1: 214108.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214107.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214105.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025625968244508184
# Bug ID1: 214110.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005572478663334523
# Bug ID1: 214112.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0009103931447087477
# Bug ID1: 214111.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05399549183931488
# Bug ID1: 214113.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020475605254496838
# Bug ID1: 214114.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02464107549297999
# Bug ID1: 214115.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0380705610757336
# Bug ID1: 214118.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05217826385896142
# Bug ID1: 214121.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02863559485793524
# Bug ID1: 214122.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.037252616531727595
# Bug ID1: 214120.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0315145225187456
# Bug ID1: 214123.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.002641540989969492
# Bug ID1: 214119.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214116.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02800448306610702
# Bug ID1: 214124.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01563814646663108
# Bug ID1: 214125.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214126.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04363957109573255
# Bug ID1: 214128.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.026053198883664235
# Bug ID1: 214130.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012858230116346188
# Bug ID1: 214131.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007234363298984789
# Bug ID1: 214132.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214133.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0404513181792934
# Bug ID1: 214127.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008759030649996223
# Bug ID1: 214135.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.048968573999716235
# Bug ID1: 214136.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012112113098585259
# Bug ID1: 214137.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01896613790559448
# Bug ID1: 214143.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009318129087529149
# Bug ID1: 214139.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.030530275140718054
# Bug ID1: 214142.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214141.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008143846858406583
# Bug ID1: 214144.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0360553964703908
# Bug ID1: 214146.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214145.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.14313876720472096
# Bug ID1: 214147.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005050027451448005
# Bug ID1: 214149.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.057957721668882994
# Bug ID1: 214148.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10428186026799535
# Bug ID1: 214150.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.051309993214278385
# Bug ID1: 214154.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.013047271861819698
# Bug ID1: 214140.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04321905948224156
# Bug ID1: 214153.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.13413121385109814
# Bug ID1: 214152.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05350824596591175
# Bug ID1: 214138.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.036696579972655546
# Bug ID1: 214155.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.011698235902073674
# Bug ID1: 214157.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06046287013376337
# Bug ID1: 214156.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.036060801452081924
# Bug ID1: 214161.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214159.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05781277040535818
# Bug ID1: 214160.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.034415674671507
# Bug ID1: 214163.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015049912325750555
# Bug ID1: 214165.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.00817434755891825
# Bug ID1: 214164.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02748665964785903
# Bug ID1: 214167.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214169.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015241465330217255
# Bug ID1: 214168.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0038101346509043974
# Bug ID1: 214170.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.024647668832708712
# Bug ID1: 214171.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.003997136396887739
# Bug ID1: 214172.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0055106002457684196
# Bug ID1: 214173.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.011743358788774989
# Bug ID1: 214174.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.016993246032680622
# Bug ID1: 214176.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009497535620392206
# Bug ID1: 214175.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025268485362344308
# Bug ID1: 214177.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02846610242864339
# Bug ID1: 214178.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010718370706521903
# Bug ID1: 214180.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0427403197334344
# Bug ID1: 214181.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214179.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.028540602953406245
# Bug ID1: 214183.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020153911779966407
# Bug ID1: 214184.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025385209735254995
# Bug ID1: 214185.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214186.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01238954768268287
# Bug ID1: 214182.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06300097870239006
# Bug ID1: 214189.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.013008011645450557
# Bug ID1: 214187.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.00901213873633054
# Bug ID1: 214191.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214193.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0034364997120209695
# Bug ID1: 214190.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015518688072440208
# Bug ID1: 214192.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.07124338409525115
# Bug ID1: 214198.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01185372273633838
# Bug ID1: 214194.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10694215554763427
# Bug ID1: 214196.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010019154490936858
# Bug ID1: 214200.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007070729240464541
# Bug ID1: 214201.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214197.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214195.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.060385687415333816
# Bug ID1: 214199.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214204.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.013547196816108793
# Bug ID1: 214205.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03177961424996181
# Bug ID1: 214203.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.022641503846401883
# Bug ID1: 214206.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010994315074392325
# Bug ID1: 214208.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214202.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015553220429835002
# Bug ID1: 214211.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214212.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214214.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03187408329939974
# Bug ID1: 214217.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214216.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01183767118779679
# Bug ID1: 214209.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.00976467426583209
# Bug ID1: 214218.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023808353453143208
# Bug ID1: 214220.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.019672032574690128
# Bug ID1: 214219.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.029964466240548285
# Bug ID1: 214221.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05139778621278121
# Bug ID1: 214222.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06554701834224685
# Bug ID1: 214223.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214224.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.042049234585007554
# Bug ID1: 214228.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04493877586606035
# Bug ID1: 214229.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.046842197924958216
# Bug ID1: 214227.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04828363371267941
# Bug ID1: 214225.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.006954053197340756
# Bug ID1: 214230.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.042271727552588664
# Bug ID1: 214231.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0125201690220265
# Bug ID1: 214232.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012711970681746817
# Bug ID1: 214235.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.037572361320220245
# Bug ID1: 214233.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012180594137440263
# Bug ID1: 214236.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009919763796439182
# Bug ID1: 214237.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.004614013881096397
# Bug ID1: 214238.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01178442470259863
# Bug ID1: 214239.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.031109524734062928
# Bug ID1: 214240.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010662648493301868
# Bug ID1: 214241.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.019727989346578385
# Bug ID1: 214242.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.031074111867902002
# Bug ID1: 214243.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.022665682741612615
# Bug ID1: 214245.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214246.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06299093940992787
# Bug ID1: 214247.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05408860734504172
# Bug ID1: 214249.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01185512848536525
# Bug ID1: 214250.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0339183672374943
# Bug ID1: 214251.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214254.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03094590443830241
# Bug ID1: 214253.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03309431669785841
# Bug ID1: 214255.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01271558869759614
# Bug ID1: 214257.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009846090812161628
# Bug ID1: 214258.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023596901288199506
# Bug ID1: 214259.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214260.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214264.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008625562887688416
# Bug ID1: 214263.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214265.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214266.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.022480471750012367
# Bug ID1: 214262.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214261.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.021385476196717622
# Bug ID1: 214267.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03898742617457534
# Bug ID1: 214270.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.033720519249705525
# Bug ID1: 214268.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214269.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.11730861815873421
# Bug ID1: 214273.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04483747479232254
# Bug ID1: 214275.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214271.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025241460530268465
# Bug ID1: 214272.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.014497060062140774
# Bug ID1: 214279.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10740392461626361
# Bug ID1: 214274.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214280.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.019067238258107362
# Bug ID1: 214284.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.014447551080846673
# Bug ID1: 214285.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06322284565301362
# Bug ID1: 214288.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.006975962128415762
# Bug ID1: 214286.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0396656214886345
# Bug ID1: 214289.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010634118874306547
# Bug ID1: 214293.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015013042356042538
# Bug ID1: 214294.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03759754209801768
# Bug ID1: 214292.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.028350533805957524
# Bug ID1: 214290.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03180373690360203
# Bug ID1: 214291.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06546572648310565
# Bug ID1: 214295.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.011950953984675152
# Bug ID1: 214300.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009459848321141441
# Bug ID1: 214301.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.001939759788545378
# Bug ID1: 214296.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.021616625636080945
# Bug ID1: 214302.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.013113371455089428
# Bug ID1: 214298.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.08054114958010947
# Bug ID1: 214297.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02329883909432332
# Bug ID1: 214276.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05421222945665012
# Bug ID1: 214303.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.000435047229996396
# Bug ID1: 214304.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0014494987294846236
# Bug ID1: 214299.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02075797003586217
# Bug ID1: 214305.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0015613584259028474
# Bug ID1: 214306.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0015613377783110826
# Bug ID1: 214308.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023603277805871757
# Bug ID1: 214307.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.027693142883198
# Bug ID1: 214310.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03683528786070918
# Bug ID1: 214309.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05868110422288872
# Bug ID1: 214311.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10248398648975761
# Bug ID1: 214313.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008262813966572833
# Bug ID1: 214312.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.052266165964373265
# Bug ID1: 214314.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.039585008895112336
# Bug ID1: 214316.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01601429230745913
# Bug ID1: 214315.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010495928808531499
# Bug ID1: 214317.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.11354107943850994
# Bug ID1: 214319.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03256359605318193
# Bug ID1: 214322.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025131638496785853
# Bug ID1: 214320.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023372028005095136
# Bug ID1: 214325.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214318.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03447612081070313
# Bug ID1: 214323.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020560644493654728
# Bug ID1: 214326.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02630173792755163
# Bug ID1: 214327.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214331.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0068069133606921016
# Bug ID1: 214333.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0033636716297446084
# Bug ID1: 214334.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023866679593507398
# Bug ID1: 214335.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214328.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03933316048224078
# Bug ID1: 214337.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.003701780346519865
# Bug ID1: 214340.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.018062071798074415
# Bug ID1: 214336.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06797225517221019
# Bug ID1: 214341.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005228548701639356
# Bug ID1: 214345.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.033006550999577
# Bug ID1: 214346.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214347.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214342.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.021088008749424077
# Bug ID1: 214348.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020520362057762784
# Bug ID1: 214349.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.00743949894504137
# Bug ID1: 214350.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.12209895098710456
# Bug ID1: 214343.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01485838825005118
# Bug ID1: 214355.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214354.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05168497505598223
# Bug ID1: 214357.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214359.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.037865033245262844
# Bug ID1: 214358.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04790120147101084
# Bug ID1: 214360.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05741123127696789
# Bug ID1: 214362.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.018386400544261446
# Bug ID1: 214363.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02361026176159843
# Bug ID1: 214364.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0054014666060946265
# Bug ID1: 214366.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214365.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02849778635434269
# Bug ID1: 214367.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01602363598273835
# Bug ID1: 214369.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0812960660554462
# Bug ID1: 214368.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.014972464709493212
# Bug ID1: 214370.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.011805283179912448
# Bug ID1: 214356.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.055590379167481004
# Bug ID1: 214371.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010047952209164124
# Bug ID1: 214373.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023810633276540885
# Bug ID1: 214377.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0026341413881765035
# Bug ID1: 214376.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.026114385118051933
# Bug ID1: 214378.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007239374488886371
# Bug ID1: 214375.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03666956759137181
# Bug ID1: 214374.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0350719804061845
# Bug ID1: 214380.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214383.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214382.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06348128913412693
# Bug ID1: 214381.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04134323124475943
# Bug ID1: 214385.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214372.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0062697068817138355
# Bug ID1: 214384.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06062946657790312
# Bug ID1: 214379.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.09773747058659088
# Bug ID1: 214387.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03246610393333627
# Bug ID1: 214388.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.043264784109561555
# Bug ID1: 214390.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214391.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0144415292204251
# Bug ID1: 214392.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.059689918962959845
# Bug ID1: 214393.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03805199299214209
# Bug ID1: 214394.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02712362725827157
# Bug ID1: 214386.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.048560515565083534
# Bug ID1: 214395.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008084639617368192
# Bug ID1: 214389.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214396.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214399.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214401.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005716544852099274
# Bug ID1: 214405.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.011439727186312415
# Bug ID1: 214400.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.047566198552751904
# Bug ID1: 214404.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214397.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03709334634737056
# Bug ID1: 214407.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.00474460685437722
# Bug ID1: 214406.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.031325270333078
# Bug ID1: 214408.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05337779504995005
# Bug ID1: 214409.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0516884893616503
# Bug ID1: 214411.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.08146708833099853
# Bug ID1: 214412.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.033333619261495036
# Bug ID1: 214414.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.027864766034580053
# Bug ID1: 214415.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0025268939967204185
# Bug ID1: 214416.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214419.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214420.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06458554000924406
# Bug ID1: 214422.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214421.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010753674602038242
# Bug ID1: 214424.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214426.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214410.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04808774912410632
# Bug ID1: 214428.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0791591854626634
# Bug ID1: 214427.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020000019748954465
# Bug ID1: 214417.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012353493633772823
# Bug ID1: 214429.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015019585861126188
# Bug ID1: 214430.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.018184908559029066
# Bug ID1: 214431.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214434.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02623683732229705
# Bug ID1: 214435.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0242145849314899
# Bug ID1: 214433.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010153274536514484
# Bug ID1: 214432.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.046809603525495444
# Bug ID1: 214437.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0506930314221328
# Bug ID1: 214441.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04313459850893767
# Bug ID1: 214442.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007488168871327874
# Bug ID1: 214443.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015176582505158307
# Bug ID1: 214444.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007171716128482256
# Bug ID1: 214445.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10747019671304693
# Bug ID1: 214446.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.021203886578459716
# Bug ID1: 214436.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.13170121976568114
# Bug ID1: 214448.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03504001082049709
# Bug ID1: 214447.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214450.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.018481570764743535
# Bug ID1: 214449.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.040586134759213986
# Bug ID1: 214451.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.029266303207587524
# Bug ID1: 214452.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04748581771144565
# Bug ID1: 214458.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009938464654783423
# Bug ID1: 214457.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214459.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214455.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02239024968112317
# Bug ID1: 214453.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214460.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.07301434229572745
# Bug ID1: 214461.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020878655955737964
# Bug ID1: 214463.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02870392928007704
# Bug ID1: 214462.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214464.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0168519599979851
# Bug ID1: 214466.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008173802160579132
# Bug ID1: 214467.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05343450325626738
# Bug ID1: 214469.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214470.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01154646337331261
# Bug ID1: 214471.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.044986940328204585
# Bug ID1: 214474.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.027702393779681467
# Bug ID1: 214472.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.004672930472589758
# Bug ID1: 214476.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03127863020640884
# Bug ID1: 214478.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.019851393285903907
# Bug ID1: 214480.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.061981302474882205
# Bug ID1: 214479.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023325649055057466
# Bug ID1: 214482.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.060765025865961636
# Bug ID1: 214483.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214484.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023036856816195196
# Bug ID1: 214485.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.042571937903492674
# Bug ID1: 214487.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214492.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06977390419418894
# Bug ID1: 214493.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04705591934519297
# Bug ID1: 214494.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.054190927790647596
# Bug ID1: 214495.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03674608765731249
# Bug ID1: 214496.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214497.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214488.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025066361716438997
# Bug ID1: 214498.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214500.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214501.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214505.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214503.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0518341240048716
# Bug ID1: 214499.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.08073137617090917
# Bug ID1: 214506.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005660666060555235
# Bug ID1: 214507.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02565368295164311
# Bug ID1: 214502.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214509.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015612697847973818
# Bug ID1: 214510.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03963376847226101
# Bug ID1: 214512.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.039188537710431084
# Bug ID1: 214513.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214504.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214511.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04923838916826434
# Bug ID1: 214514.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214515.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020193519358456584
# Bug ID1: 214516.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.055214107365108636
# Bug ID1: 214518.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0401485154891872
# Bug ID1: 214520.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03556172086688812
# Bug ID1: 214517.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05112685586250273
# Bug ID1: 214523.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.020864517497000613
# Bug ID1: 214522.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10793017128678081
# Bug ID1: 214524.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.08238469048616255
# Bug ID1: 214519.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05330416313056314
# Bug ID1: 214525.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10557106021091543
# Bug ID1: 214526.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.05659925859616845
# Bug ID1: 214527.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.042280426562105886
# Bug ID1: 214530.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.07930790553580144
# Bug ID1: 214529.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214533.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214532.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06907746757750911
# Bug ID1: 214535.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.014810575896168935
# Bug ID1: 214537.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.028365803509380248
# Bug ID1: 214536.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.006112227774592985
# Bug ID1: 214538.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025838209982937475
# Bug ID1: 214539.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008051369878952108
# Bug ID1: 214534.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06778326465219243
# Bug ID1: 214540.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03891377440561278
# Bug ID1: 214521.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.09799351368392625
# Bug ID1: 214541.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0031206174587850364
# Bug ID1: 214543.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0007985528589097056
# Bug ID1: 214542.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214544.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214545.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01016987518187607
# Bug ID1: 214547.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.11075717697939787
# Bug ID1: 214546.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.018673382177845966
# Bug ID1: 214550.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.027424402197581393
# Bug ID1: 214549.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.019936230852522437
# Bug ID1: 214552.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214548.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.022037573367332905
# Bug ID1: 214551.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214554.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0741931937874073
# Bug ID1: 214556.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007980158758018514
# Bug ID1: 214555.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04252449382850099
# Bug ID1: 214557.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.1266007232392086
# Bug ID1: 214559.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.023390862166018093
# Bug ID1: 214560.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010106698296561006
# Bug ID1: 214558.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02139580209881433
# Bug ID1: 214563.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0582144956982832
# Bug ID1: 214561.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.013176910941644799
# Bug ID1: 214564.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.071711444407124
# Bug ID1: 214566.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02625330169094419
# Bug ID1: 214567.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012302310567062153
# Bug ID1: 214565.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.032536295079183486
# Bug ID1: 214570.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214571.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214572.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.017261887551834495
# Bug ID1: 214573.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.006989638012407553
# Bug ID1: 214574.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.07695775028981053
# Bug ID1: 214575.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.06022125216649761
# Bug ID1: 214576.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02028668835200007
# Bug ID1: 214577.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.062223431599000685
# Bug ID1: 214578.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0551667776265155
# Bug ID1: 214580.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04758273768203319
# Bug ID1: 214582.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.030739244566911503
# Bug ID1: 214585.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.008544445663943337
# Bug ID1: 214583.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.022769751742818787
# Bug ID1: 214584.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04635225831971304
# Bug ID1: 214586.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005916327496948383
# Bug ID1: 214587.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02398581634147693
# Bug ID1: 214588.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.10132408420418185
# Bug ID1: 214590.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.012469272237157015
# Bug ID1: 214589.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.024078946648678073
# Bug ID1: 214592.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.015148340814992377
# Bug ID1: 214591.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.025074444693908602
# Bug ID1: 214579.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.010796529512429456
# Bug ID1: 214581.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01690955127407727
# Bug ID1: 214595.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.01572987820302283
# Bug ID1: 214596.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.009418760524380747
# Bug ID1: 214597.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.014690829208676804
# Bug ID1: 214599.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.04144520095032915
# Bug ID1: 214600.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214603.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.005499833567256006
# Bug ID1: 214604.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03304848853186084
# Bug ID1: 214607.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0053178134392685246
# Bug ID1: 214606.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.09451198957739253
# Bug ID1: 214608.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214609.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.004337803717213248
# Bug ID1: 214601.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03678560531994213
# Bug ID1: 214611.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007047279602940954
# Bug ID1: 214610.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.061877163825929685
# Bug ID1: 214613.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214614.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.056810304052483024
# Bug ID1: 214605.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.058179462361804574
# Bug ID1: 214615.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.007449201917497739
# Bug ID1: 214616.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.03510045827856157
# Bug ID1: 214617.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.02941094527875817
# Bug ID1: 214621.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214619.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.019005335127668686
# Bug ID1: 214624.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: 214623.0
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.00994040851348128
# Bug ID1: 214622.0
# Bug ID2: 214990
# ...
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Bug ID1: nan
# Bug ID2: 214990
# Cosine Similarity between the two descriptions: 0.0
# Preprocessing done for all files in: ..\new_dataset\eclipse

# %%
# Choose two preprocessed descriptions for similarity comparison
description1= """
build id m step to reproduce my environment are a follow session eclipse buildid m java version java vendor sun microsystems inc bootloader constant o linux , arch x , w gtk , nl en u command line argument o linux w gtk arch x user import to import a new project , any project is ok , then open another project , usually in about five minute then open the eclipse again , the problem will repeat more information the hole log file a follow session eclipse buildid m java version java vendor sun microsystems inc bootloader constant o linux , arch x , w gtk , nl en u command line argument o linux w gtk arch x entry org eclipse osgi message while loading class org eclipse mylyn internal task ui itaskhighlighter , thread thread worker , ,main timed out waiting m for thread thread worker , ,main to finish starting bundle update plugins org eclipse mylyn task ui v jar to avoid deadlock , thread thread worker , ,main is proceeding but org eclipse mylyn internal task ui itaskhighlighter may not be fully initialized stack org osgi framework bundleexception state change in progress for bundle update plugins org eclipse mylyn task ui v jar by thread worker at org eclipse osgi framework internal core abstractbundle beginstatechange abstractbundle java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core singlesourcepackage loadclass singlesourcepackage java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at java lang classloader loadclassinternal classloader java at java lang class getdeclaredconstructors native method at java lang class privategetdeclaredconstructors class java at java lang class getconstructor class java at java lang class newinstance class java at java lang class newinstance class java at org eclipse osgi framework internal core abstractbundle loadbundleactivator abstractbundle java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at org eclipse osgi framework internal core bundleloader loadclass bundleloader java at org eclipse osgi framework internal core bundlehost loadclass bundlehost java at org eclipse osgi framework internal core abstractbundle loadclass abstractbundle java at org eclipse core internal registry osgi registrystrategyosgi createexecutableextension registrystrategyosgi java at org eclipse core internal registry extensionregistry createexecutableextension extensionregistry java at org eclipse core internal registry configurationelement createexecutableextension configurationelement java at org eclipse core internal registry configurationelementhandle createexecutableextension configurationelementhandle java at org eclipse ui internal workbenchplugin run workbenchplugin java at org eclipse swt custom busyindicator showwhile busyindicator java at org eclipse ui internal workbenchplugin createextension workbenchplugin java at org eclipse ui internal decorator lightweightdecoratordefinition run lightweightdecoratordefinition java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratordefinition internalgetdecorator lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratordefinition decorate lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratormanager lightweightrunnable run lightweightdecoratormanager java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratormanager decorate lightweightdecoratormanager java at org eclipse ui internal decorator lightweightdecoratormanager getdecorations lightweightdecoratormanager java at org eclipse ui internal decorator decorationscheduler ensureresultcached decorationscheduler java at org eclipse ui internal decorator decorationscheduler run decorationscheduler java at org eclipse core internal job worker run worker java caused by org eclipse osgi framework internal core abstractbundle bundlestatusexception more root exception org eclipse osgi framework internal core abstractbundle bundlestatusexception at org eclipse osgi framework internal core abstractbundle beginstatechange abstractbundle java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core singlesourcepackage loadclass singlesourcepackage java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at java lang classloader loadclassinternal classloader java at java lang class getdeclaredconstructors native method at java lang class privategetdeclaredconstructors class java at java lang class getconstructor class java at java lang class newinstance class java at java lang class newinstance class java at org eclipse osgi framework internal core abstractbundle loadbundleactivator abstractbundle java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at org eclipse osgi framework internal core bundleloader loadclass bundleloader java at org eclipse osgi framework internal core bundlehost loadclass bundlehost java at org eclipse osgi framework internal core abstractbundle loadclass abstractbundle java at org eclipse core internal registry osgi registrystrategyosgi createexecutableextension registrystrategyosgi java at org eclipse core internal registry extensionregistry createexecutableextension extensionregistry java at org eclipse core internal registry configurationelement createexecutableextension configurationelement java at org eclipse core internal registry configurationelementhandle createexecutableextension configurationelementhandle java at org eclipse ui internal workbenchplugin run workbenchplugin java at org eclipse swt custom busyindicator showwhile busyindicator java at org eclipse ui internal workbenchplugin createextension workbenchplugin java at org eclipse ui internal decorator lightweightdecoratordefinition run lightweightdecoratordefinition java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratordefinition internalgetdecorator lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratordefinition decorate lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratormanager lightweightrunnable run lightweightdecoratormanager java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratormanager decorate lightweightdecoratormanager java at org eclipse ui internal decorator lightweightdecoratormanager getdecorations lightweightdecoratormanager java at org eclipse ui internal decorator decorationscheduler ensureresultcached decorationscheduler java at org eclipse ui internal decorator decorationscheduler run decorationscheduler java at org eclipse core internal job worker run worker java
"""
description2 = """
error log date fri jan cet message could not load tasklist hyperlink detector extension severity info plugin id org eclipse mylyn stack trace org eclipse core runtime coreexception plug in org eclipse mylyn java ui wa unable to load class org eclipse mylyn internal java ui javastacktracehyperlinkdetector at org eclipse core internal registry osgi registrystrategyosgi throwexception registrystrategyosgi java at org eclipse core internal registry osgi registrystrategyosgi createexecutableextension registrystrategyosgi java at org eclipse core internal registry extensionregistry createexecutableextension extensionregistry java at org eclipse core internal registry configurationelement createexecutableextension configurationelement java at org eclipse core internal registry configurationelementhandle createexecutableextension configurationelementhandle java at org eclipse mylyn internal task ui util tasksuiextensionreader readhyperlinkdetector tasksuiextensionreader java at org eclipse mylyn internal task ui util tasksuiextensionreader initstartupextensions tasksuiextensionreader java at org eclipse mylyn task ui tasksuiplugin start tasksuiplugin java at org eclipse osgi framework internal core bundlecontextimpl run bundlecontextimpl java at java security accesscontroller doprivileged native method at org eclipse osgi framework internal core bundlecontextimpl startactivator bundlecontextimpl java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction run secureaction java at java security accesscontroller doprivileged native method at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core singlesourcepackage loadclass singlesourcepackage java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at java lang classloader loadclassinternal classloader java at java lang class getdeclaredconstructors native method at java lang class privategetdeclaredconstructors class java at java lang class getconstructor class java at java lang class newinstance class java at java lang class newinstance class java at org eclipse osgi framework internal core abstractbundle loadbundleactivator abstractbundle java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction run secureaction java at java security accesscontroller doprivileged native method at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at org eclipse osgi framework internal core bundleloader loadclass bundleloader java at org eclipse osgi framework internal core bundlehost loadclass bundlehost java at org eclipse osgi framework internal core abstractbundle loadclass abstractbundle java at org eclipse core internal registry osgi registrystrategyosgi createexecutableextension registrystrategyosgi java at org eclipse core internal registry extensionregistry createexecutableextension extensionregistry java at org eclipse core internal registry configurationelement createexecutableextension configurationelement java at org eclipse core internal registry configurationelementhandle createexecutableextension configurationelementhandle java at org eclipse ui internal workbenchplugin run workbenchplugin java at org eclipse swt custom busyindicator showwhile busyindicator java at org eclipse ui internal workbenchplugin createextension workbenchplugin java at org eclipse ui internal decorator lightweightdecoratordefinition run lightweightdecoratordefinition java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratordefinition internalgetdecorator lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratordefinition decorate lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratormanager lightweightrunnable run lightweightdecoratormanager java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratormanager decorate lightweightdecoratormanager java at org eclipse ui internal decorator lightweightdecoratormanager getdecorations lightweightdecoratormanager java at org eclipse ui internal decorator decorationscheduler ensureresultcached decorationscheduler java at org eclipse ui internal decorator decorationscheduler run decorationscheduler java at org eclipse core internal job worker run worker java org eclipse core runtime coreexception org eclipse core runtime internal adaptor eclipselazystarter terminatingclassnotfoundexception an error occurred while automatically activating bundle org eclipse mylyn java ui at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at org eclipse osgi framework internal core bundleloader loadclass bundleloader java at org eclipse osgi framework internal core bundlehost loadclass bundlehost java at org eclipse osgi framework internal core abstractbundle loadclass abstractbundle java at org eclipse core internal registry osgi registrystrategyosgi createexecutableextension registrystrategyosgi java at org eclipse core internal registry extensionregistry createexecutableextension extensionregistry java at org eclipse core internal registry configurationelement createexecutableextension configurationelement java at org eclipse core internal registry configurationelementhandle createexecutableextension configurationelementhandle java at org eclipse mylyn internal task ui util tasksuiextensionreader readhyperlinkdetector tasksuiextensionreader java at org eclipse mylyn internal task ui util tasksuiextensionreader initstartupextensions tasksuiextensionreader java at org eclipse mylyn task ui tasksuiplugin start tasksuiplugin java at org eclipse osgi framework internal core bundlecontextimpl run bundlecontextimpl java at java security accesscontroller doprivileged native method at org eclipse osgi framework internal core bundlecontextimpl startactivator bundlecontextimpl java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction run secureaction java at java security accesscontroller doprivileged native method at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core singlesourcepackage loadclass singlesourcepackage java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at java lang classloader loadclassinternal classloader java at java lang class getdeclaredconstructors native method at java lang class privategetdeclaredconstructors class java at java lang class getconstructor class java at java lang class newinstance class java at java lang class newinstance class java at org eclipse osgi framework internal core abstractbundle loadbundleactivator abstractbundle java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction run secureaction java at java security accesscontroller doprivileged native method at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at org eclipse osgi framework internal core bundleloader loadclass bundleloader java at org eclipse osgi framework internal core bundlehost loadclass bundlehost java at org eclipse osgi framework internal core abstractbundle loadclass abstractbundle java at org eclipse core internal registry osgi registrystrategyosgi createexecutableextension registrystrategyosgi java at org eclipse core internal registry extensionregistry createexecutableextension extensionregistry java at org eclipse core internal registry configurationelement createexecutableextension configurationelement java at org eclipse core internal registry configurationelementhandle createexecutableextension configurationelementhandle java at org eclipse ui internal workbenchplugin run workbenchplugin java at org eclipse swt custom busyindicator showwhile busyindicator java at org eclipse ui internal workbenchplugin createextension workbenchplugin java at org eclipse ui internal decorator lightweightdecoratordefinition run lightweightdecoratordefinition java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratordefinition internalgetdecorator lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratordefinition decorate lightweightdecoratordefinition java at org eclipse ui internal decorator lightweightdecoratormanager lightweightrunnable run lightweightdecoratormanager java at org eclipse core runtime saferunner run saferunner java at org eclipse core runtime platform run platform java at org eclipse ui internal decorator lightweightdecoratormanager decorate lightweightdecoratormanager java at org eclipse ui internal decorator lightweightdecoratormanager getdecorations lightweightdecoratormanager java at org eclipse ui internal decorator decorationscheduler ensureresultcached decorationscheduler java at org eclipse ui internal decorator decorationscheduler run decorationscheduler java at org eclipse core internal job worker run worker java caused by org osgi framework bundleexception the activator org eclipse mylyn internal java ui javauibridgeplugin for bundle org eclipse mylyn java ui is invalid at org eclipse osgi framework internal core abstractbundle loadbundleactivator abstractbundle java at org eclipse osgi framework internal core bundlecontextimpl start bundlecontextimpl java at org eclipse osgi framework internal core bundlehost startworker bundlehost java at org eclipse osgi framework internal core abstractbundle start abstractbundle java at org eclipse osgi framework util secureaction run secureaction java at java security accesscontroller doprivileged native method at org eclipse osgi framework util secureaction start secureaction java at org eclipse core runtime internal adaptor eclipselazystarter postfindlocalclass eclipselazystarter java more caused by java lang noclassdeffounderror org eclipse mylyn internal context ui abstractcontextuiplugin at java lang classloader defineclass native method at java lang classloader defineclass classloader java at org eclipse osgi internal baseadaptor defaultclassloader defineclass defaultclassloader java at org eclipse osgi baseadaptor loader classpathmanager defineclass classpathmanager java at org eclipse osgi baseadaptor loader classpathmanager findclassimpl classpathmanager java at org eclipse osgi baseadaptor loader classpathmanager findlocalclassimpl classpathmanager java at org eclipse osgi baseadaptor loader classpathmanager findlocalclass classpathmanager java at org eclipse osgi internal baseadaptor defaultclassloader findlocalclass defaultclassloader java at org eclipse osgi framework internal core bundleloader findlocalclass bundleloader java at org eclipse osgi framework internal core bundleloader findclassinternal bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi framework internal core bundleloader findclass bundleloader java at org eclipse osgi internal baseadaptor defaultclassloader loadclass defaultclassloader java at java lang classloader loadclass classloader java at org eclipse osgi framework internal core bundleloader loadclass bundleloader java at org eclipse osgi framework internal core bundlehost loadclass bundlehost java at org eclipse osgi framework internal core abstractbundle loadbundleactivator abstractbundle java more
"""
# Transform the two descriptions into TF-IDF vectors
desc1_tfidf = tfidf_vectorizer.transform([description1])
desc2_tfidf = tfidf_vectorizer.transform([description2])

# Compute cosine similarity between the two descriptions
similarity_score = cosine_similarity(desc1_tfidf, desc2_tfidf)

print("Cosine Similarity between the two descriptions:", similarity_score[0][0])
# Out:
# Cosine Similarity between the two descriptions: 0.9869365782431393
