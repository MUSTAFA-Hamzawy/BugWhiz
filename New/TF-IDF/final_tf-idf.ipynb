# %%
import pandas as pd
import os
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import csv
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
from sklearn.model_selection import train_test_split

# %%
# Remove the stop words from the preprocessed_description column using nltk
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Define the directory paths
directories = [
    ("..\\new_dataset\\eclipse", "..\\new_dataset\\eclipse"),
    #("..\\new_dataset\\eclipse_test", "..\\new_dataset\\eclipse_test"),
    #("..\\new_dataset\\firefox", "..\\new_dataset\\firefox"),
    #("..\\new_dataset\\netbeans", "..\\new_dataset\\netbeans"),
    #("..\\new_dataset\\openoffice", "..\\new_dataset\\openoffice")
]

# %%
# Read the file eclipse_new_updated.csv
df = pd.read_csv("..\\new_dataset\\eclipse\\eclipse_small_new_updated.csv")

# Print the first 5 rows of the dataframe (preprocessed_description column only)
print(df['preprocessed_description'].head())
# Out:
# 0    description regression group toc are created a...
# 1    output column page in data set editor used res...
# 2    description regression failed to preview chart...
# 3    description exception is thrown out when link ...
# 4    build id m step to reproduce start eclipse cli...
# Name: preprocessed_description, dtype: object

# %%
# Remove the stop words from the preprocessed_description column
df['preprocessed_description'] = df['preprocessed_description'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Print the first 5 rows of the dataframe (preprocessed_description column only)
print(df['preprocessed_description'].head())
# Out:
# 0    description regression group toc created autom...
# 1    output column page data set editor used result...
# 2    description regression failed preview chart vi...
# 3    description exception thrown link label anothe...
# 4    build id step reproduce start eclipse click he...
# Name: preprocessed_description, dtype: object

# %%
# Split the data into training and testing data
X_train, X_test = train_test_split(df, test_size=0.2, random_state=42)

# print the first 1 rows of the training data
print(X_train.head(1))

# print the first 1 rows of the testing data
print(X_test.head(1))
# Out:
#      bug_id bug_severity                                        description  \
# 762  214940       normal  If my memory don't fail me, content.xml and ar...
#
#     dup_id priority                              short_desc  \
# 762     []       P3  [prov] Use ECF to get repository files
#
#                               preprocessed_description
# 762  memory dont fail , content xml artifact xml cu...
#      bug_id bug_severity                                        description  \
# 394  214519  enhancement  It would be useful to allow SQL to be appended...
#
#     dup_id priority                                         short_desc  \
# 394     []       P5  Allow appending strings to CREATE TABLE statem...
#
#                               preprocessed_description
# 394  would useful allow sql appended end create tab...

# %%
# Use TF-IDF as a feature extraction technique
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train['preprocessed_description'])
X_test_tfidf = vectorizer.transform(X_test['preprocessed_description'])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# make a dictionary to store the test example bug_id as a key and the predicted duplicates as values
predicted_duplicates_dict = {}
# make a dictionary to store the test example bug_id as a key and the corrected duplicates as values
true_duplicates_dict = {}

# Iterate over each example of the test data
for i in range(X_test_tfidf.shape[0]):
    predicted_duplicates_dict[X_test['bug_id'].values[i]] = []
    true_duplicates_dict[X_test['bug_id'].values[i]] = []
    
    # Calculate the cosine similarity between the test example and all the training examples
    similarity = cosine_similarity(X_test_tfidf[i], X_train_tfidf)

    # Get the bug_ids of the training examples that have similarity greater than or equal to 0.9
    bug_ids = X_train['bug_id'].values[np.where(similarity >= 0.9)[1]]
    # if bug_ids is empty, replace it with -1
    if len(bug_ids) == 0:
        bug_ids = [-1]

    # Append the bug_ids to the predicted_duplicates list
    predicted_duplicates_dict[X_test['bug_id'].values[i]].extend(bug_ids)
    print ("Predicted Duplicates for Bug ID {}: {}".format(X_test['bug_id'].values[i], bug_ids))

    # Print the bug ID of the test example
    print("Test Bug ID:", X_test['bug_id'].values[i])

    # along with the bug_id of the training example
    print("Training Bug IDs:", X_train['bug_id'].values[np.where(similarity >= 0.9)[1]])

    # Get the dup_id of the test example and split it by semicolons
    dup_ids = X_test['dup_id'].values[i].split(';')

    # after splitting check if there is an empty string in the list and remove it
    if '' in dup_ids:
        dup_ids.remove('')

    # if the dup_ids list is  ['[]'] replace it with -1
    if dup_ids == ['[]']:
        dup_ids = [-1]
    # make the dup_ids list as integers
    dup_ids = [int(dup_id) for dup_id in dup_ids]

    # Append the dup_ids to the true_duplicates list
    true_duplicates_dict[X_test['bug_id'].values[i]].extend(dup_ids)
    print("True Duplicates for Bug ID {}: {}".format(X_test['bug_id'].values[i], dup_ids))

    print("\n")
    
# calculate the true_positive, false_positive, true_negative, false_negative
true_positive = 0
false_positive = 0
true_negative = 0
false_negative = 0

# There are 4 cases to consider:
# 1. The predicted duplicate is in the true duplicates list (true positive)
# 2. The predicted duplicate is not in the true duplicates list (false positive)
# 3. The true duplicate is not predicted as a duplicate (false negative)
# 4. The true duplicate is predicted as a duplicate (true negative)

# Note: if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains -1, and true_duplicates_dict[X_test['bug_id'].values[i]] contains -1, then it is a true negative
# if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains -1, and true_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, then it is a false negative
# if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, and true_duplicates_dict[X_test['bug_id'].values[i]] contains -1, then it is a false positive
# if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, and true_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, then it is a true positive

for key in predicted_duplicates_dict.keys():
    if -1 in predicted_duplicates_dict[key] and -1 in true_duplicates_dict[key]:
        true_negative += 1
    elif -1 in predicted_duplicates_dict[key] and -1 not in true_duplicates_dict[key]:
        false_negative += 1
    elif -1 not in predicted_duplicates_dict[key] and -1 in true_duplicates_dict[key]:
        false_positive += 1
    elif -1 not in predicted_duplicates_dict[key] and -1 not in true_duplicates_dict[key]:
        for bug_id in predicted_duplicates_dict[key]:
            if bug_id in true_duplicates_dict[key]:
                true_positive += 1

# calculate the precision, recall, and f1 score
precision = true_positive / (true_positive + false_positive)
recall = true_positive / (true_positive + false_negative)
f1 = 2 * precision * recall / (precision + recall)
accuracy_score = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy Score:", accuracy_score)

# confusion matrix
conf_matrix = [[true_negative, false_positive],
               [false_negative, true_positive]]

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Predicted Duplicates for Bug ID 214519: [-1]
# Test Bug ID: 214519
# Training Bug IDs: []
# True Duplicates for Bug ID 214519: [-1]
#
#
# Predicted Duplicates for Bug ID 214139: [-1]
# Test Bug ID: 214139
# Training Bug IDs: []
# True Duplicates for Bug ID 214139: [-1]
#
#
# Predicted Duplicates for Bug ID 214639: [-1]
# Test Bug ID: 214639
# Training Bug IDs: []
# True Duplicates for Bug ID 214639: [-1]
#
#
# Predicted Duplicates for Bug ID 214142: [-1]
# Test Bug ID: 214142
# Training Bug IDs: []
# True Duplicates for Bug ID 214142: [-1]
#
#
# Predicted Duplicates for Bug ID 215046: [-1]
# Test Bug ID: 215046
# Training Bug IDs: []
# True Duplicates for Bug ID 215046: [-1]
#
#
# Predicted Duplicates for Bug ID 214943: [-1]
# Test Bug ID: 214943
# Training Bug IDs: []
# True Duplicates for Bug ID 214943: [-1]
#
#
# Predicted Duplicates for Bug ID 214160: [-1]
# Test Bug ID: 214160
# Training Bug IDs: []
# True Duplicates for Bug ID 214160: [-1]
#
#
# Predicted Duplicates for Bug ID 214989: [214988 215040 214990]
# Test Bug ID: 214989
# Training Bug IDs: [214988 215040 214990]
# True Duplicates for Bug ID 214989: [214988, 214990, 214991, 215040]
#
#
# Predicted Duplicates for Bug ID 214764: [-1]
# Test Bug ID: 214764
# Training Bug IDs: []
# True Duplicates for Bug ID 214764: [-1]
#
#
# Predicted Duplicates for Bug ID 214608: [-1]
# Test Bug ID: 214608
# Training Bug IDs: []
# True Duplicates for Bug ID 214608: [-1]
#
#
# Predicted Duplicates for Bug ID 214381: [-1]
# Test Bug ID: 214381
# Training Bug IDs: []
# True Duplicates for Bug ID 214381: [-1]
#
#
# Predicted Duplicates for Bug ID 214555: [-1]
# Test Bug ID: 214555
# Training Bug IDs: []
# True Duplicates for Bug ID 214555: [-1]
#
#
# Predicted Duplicates for Bug ID 214449: [-1]
# Test Bug ID: 214449
# Training Bug IDs: []
# True Duplicates for Bug ID 214449: [214288]
#
#
# Predicted Duplicates for Bug ID 214387: [-1]
# Test Bug ID: 214387
# Training Bug IDs: []
# True Duplicates for Bug ID 214387: [-1]
#
#
# Predicted Duplicates for Bug ID 214617: [-1]
# Test Bug ID: 214617
# Training Bug IDs: []
# True Duplicates for Bug ID 214617: [-1]
#
#
# Predicted Duplicates for Bug ID 214299: [-1]
# Test Bug ID: 214299
# Training Bug IDs: []
# True Duplicates for Bug ID 214299: [-1]
#
#
# Predicted Duplicates for Bug ID 214557: [-1]
# Test Bug ID: 214557
# Training Bug IDs: []
# True Duplicates for Bug ID 214557: [-1]
#
#
# Predicted Duplicates for Bug ID 215061: [-1]
# Test Bug ID: 215061
# Training Bug IDs: []
# True Duplicates for Bug ID 215061: [-1]
#
#
# Predicted Duplicates for Bug ID 214394: [-1]
# Test Bug ID: 214394
# Training Bug IDs: []
# True Duplicates for Bug ID 214394: [-1]
#
#
# Predicted Duplicates for Bug ID 214693: [-1]
# Test Bug ID: 214693
# Training Bug IDs: []
# True Duplicates for Bug ID 214693: [-1]
#
#
# Predicted Duplicates for Bug ID 214255: [-1]
# Test Bug ID: 214255
# Training Bug IDs: []
# True Duplicates for Bug ID 214255: [-1]
#
#
# Predicted Duplicates for Bug ID 214479: [-1]
# Test Bug ID: 214479
# Training Bug IDs: []
# True Duplicates for Bug ID 214479: [-1]
#
#
# Predicted Duplicates for Bug ID 214429: [-1]
# Test Bug ID: 214429
# Training Bug IDs: []
# True Duplicates for Bug ID 214429: [-1]
#
#
# Predicted Duplicates for Bug ID 214644: [-1]
# Test Bug ID: 214644
# Training Bug IDs: []
# True Duplicates for Bug ID 214644: [-1]
#
#
# Predicted Duplicates for Bug ID 214607: [-1]
# Test Bug ID: 214607
# Training Bug IDs: []
# True Duplicates for Bug ID 214607: [-1]
#
#
# Predicted Duplicates for Bug ID 214421: [-1]
# Test Bug ID: 214421
# Training Bug IDs: []
# True Duplicates for Bug ID 214421: [-1]
#
#
# Predicted Duplicates for Bug ID 214090: [-1]
# Test Bug ID: 214090
# Training Bug IDs: []
# True Duplicates for Bug ID 214090: [-1]
#
#
# Predicted Duplicates for Bug ID 214100: [-1]
# Test Bug ID: 214100
# Training Bug IDs: []
# True Duplicates for Bug ID 214100: [-1]
#
#
# Predicted Duplicates for Bug ID 214114: [-1]
# Test Bug ID: 214114
# Training Bug IDs: []
# True Duplicates for Bug ID 214114: [-1]
#
#
# Predicted Duplicates for Bug ID 214971: [-1]
# Test Bug ID: 214971
# Training Bug IDs: []
# True Duplicates for Bug ID 214971: [-1]
#
#
# Predicted Duplicates for Bug ID 214889: [-1]
# Test Bug ID: 214889
# Training Bug IDs: []
# True Duplicates for Bug ID 214889: [-1]
#
#
# Predicted Duplicates for Bug ID 214492: [-1]
# Test Bug ID: 214492
# Training Bug IDs: []
# True Duplicates for Bug ID 214492: [-1]
#
#
# Predicted Duplicates for Bug ID 214857: [-1]
# Test Bug ID: 214857
# Training Bug IDs: []
# True Duplicates for Bug ID 214857: [-1]
#
#
# Predicted Duplicates for Bug ID 214848: [-1]
# Test Bug ID: 214848
# Training Bug IDs: []
# True Duplicates for Bug ID 214848: [-1]
#
#
# Predicted Duplicates for Bug ID 215008: [-1]
# Test Bug ID: 215008
# Training Bug IDs: []
# True Duplicates for Bug ID 215008: [-1]
#
#
# Predicted Duplicates for Bug ID 214589: [-1]
# Test Bug ID: 214589
# Training Bug IDs: []
# True Duplicates for Bug ID 214589: [-1]
#
#
# Predicted Duplicates for Bug ID 214942: [-1]
# Test Bug ID: 214942
# Training Bug IDs: []
# True Duplicates for Bug ID 214942: [-1]
#
#
# Predicted Duplicates for Bug ID 214147: [-1]
# Test Bug ID: 214147
# Training Bug IDs: []
# True Duplicates for Bug ID 214147: [-1]
#
#
# Predicted Duplicates for Bug ID 214864: [-1]
# Test Bug ID: 214864
# Training Bug IDs: []
# True Duplicates for Bug ID 214864: [-1]
#
#
# Predicted Duplicates for Bug ID 214679: [-1]
# Test Bug ID: 214679
# Training Bug IDs: []
# True Duplicates for Bug ID 214679: [-1]
#
#
# Predicted Duplicates for Bug ID 214897: [-1]
# Test Bug ID: 214897
# Training Bug IDs: []
# True Duplicates for Bug ID 214897: [-1]
#
#
# Predicted Duplicates for Bug ID 214952: [-1]
# Test Bug ID: 214952
# Training Bug IDs: []
# True Duplicates for Bug ID 214952: [-1]
#
#
# Predicted Duplicates for Bug ID 214625: [-1]
# Test Bug ID: 214625
# Training Bug IDs: []
# True Duplicates for Bug ID 214625: [-1]
#
#
# Predicted Duplicates for Bug ID 214146: [-1]
# Test Bug ID: 214146
# Training Bug IDs: []
# True Duplicates for Bug ID 214146: [-1]
#
#
# Predicted Duplicates for Bug ID 214806: [-1]
# Test Bug ID: 214806
# Training Bug IDs: []
# True Duplicates for Bug ID 214806: [-1]
#
#
# Predicted Duplicates for Bug ID 214399: [-1]
# Test Bug ID: 214399
# Training Bug IDs: []
# True Duplicates for Bug ID 214399: [-1]
#
#
# Predicted Duplicates for Bug ID 214401: [-1]
# Test Bug ID: 214401
# Training Bug IDs: []
# True Duplicates for Bug ID 214401: [-1]
#
#
# Predicted Duplicates for Bug ID 214671: [-1]
# Test Bug ID: 214671
# Training Bug IDs: []
# True Duplicates for Bug ID 214671: [-1]
#
#
# Predicted Duplicates for Bug ID 214876: [-1]
# Test Bug ID: 214876
# Training Bug IDs: []
# True Duplicates for Bug ID 214876: [-1]
#
#
# Predicted Duplicates for Bug ID 215001: [-1]
# Test Bug ID: 215001
# Training Bug IDs: []
# True Duplicates for Bug ID 215001: [-1]
#
#
# Predicted Duplicates for Bug ID 214360: [-1]
# Test Bug ID: 214360
# Training Bug IDs: []
# True Duplicates for Bug ID 214360: [-1]
#
#
# Predicted Duplicates for Bug ID 214999: [-1]
# Test Bug ID: 214999
# Training Bug IDs: []
# True Duplicates for Bug ID 214999: [-1]
#
#
# Predicted Duplicates for Bug ID 215011: [-1]
# Test Bug ID: 215011
# Training Bug IDs: []
# True Duplicates for Bug ID 215011: [-1]
#
#
# Predicted Duplicates for Bug ID 214928: [-1]
# Test Bug ID: 214928
# Training Bug IDs: []
# True Duplicates for Bug ID 214928: [-1]
#
#
# Predicted Duplicates for Bug ID 214218: [-1]
# Test Bug ID: 214218
# Training Bug IDs: []
# True Duplicates for Bug ID 214218: [-1]
#
#
# Predicted Duplicates for Bug ID 214881: [-1]
# Test Bug ID: 214881
# Training Bug IDs: []
# True Duplicates for Bug ID 214881: [-1]
#
#
# Predicted Duplicates for Bug ID 214771: [-1]
# Test Bug ID: 214771
# Training Bug IDs: []
# True Duplicates for Bug ID 214771: [-1]
#
#
# Predicted Duplicates for Bug ID 214263: [-1]
# Test Bug ID: 214263
# Training Bug IDs: []
# True Duplicates for Bug ID 214263: [-1]
#
#
# Predicted Duplicates for Bug ID 214659: [-1]
# Test Bug ID: 214659
# Training Bug IDs: []
# True Duplicates for Bug ID 214659: [-1]
#
#
# Predicted Duplicates for Bug ID 214408: [-1]
# Test Bug ID: 214408
# Training Bug IDs: []
# True Duplicates for Bug ID 214408: [-1]
#
#
# Predicted Duplicates for Bug ID 214726: [-1]
# Test Bug ID: 214726
# Training Bug IDs: []
# True Duplicates for Bug ID 214726: [-1]
#
#
# Predicted Duplicates for Bug ID 214173: [-1]
# Test Bug ID: 214173
# Training Bug IDs: []
# True Duplicates for Bug ID 214173: [-1]
#
#
# Predicted Duplicates for Bug ID 214105: [-1]
# Test Bug ID: 214105
# Training Bug IDs: []
# True Duplicates for Bug ID 214105: [-1]
#
#
# Predicted Duplicates for Bug ID 214855: [-1]
# Test Bug ID: 214855
# Training Bug IDs: []
# True Duplicates for Bug ID 214855: [-1]
#
#
# Predicted Duplicates for Bug ID 214738: [-1]
# Test Bug ID: 214738
# Training Bug IDs: []
# True Duplicates for Bug ID 214738: [-1]
#
#
# Predicted Duplicates for Bug ID 214956: [-1]
# Test Bug ID: 214956
# Training Bug IDs: []
# True Duplicates for Bug ID 214956: [-1]
#
#
# Predicted Duplicates for Bug ID 214426: [-1]
# Test Bug ID: 214426
# Training Bug IDs: []
# True Duplicates for Bug ID 214426: [-1]
#
#
# Predicted Duplicates for Bug ID 214696: [-1]
# Test Bug ID: 214696
# Training Bug IDs: []
# True Duplicates for Bug ID 214696: [-1]
#
#
# Predicted Duplicates for Bug ID 214483: [-1]
# Test Bug ID: 214483
# Training Bug IDs: []
# True Duplicates for Bug ID 214483: [-1]
#
#
# Predicted Duplicates for Bug ID 214664: [-1]
# Test Bug ID: 214664
# Training Bug IDs: []
# True Duplicates for Bug ID 214664: [-1]
#
#
# Predicted Duplicates for Bug ID 214220: [-1]
# Test Bug ID: 214220
# Training Bug IDs: []
# True Duplicates for Bug ID 214220: [-1]
#
#
# Predicted Duplicates for Bug ID 214847: [-1]
# Test Bug ID: 214847
# Training Bug IDs: []
# True Duplicates for Bug ID 214847: [-1]
#
#
# Predicted Duplicates for Bug ID 214201: [-1]
# Test Bug ID: 214201
# Training Bug IDs: []
# True Duplicates for Bug ID 214201: [-1]
#
#
# Predicted Duplicates for Bug ID 214890: [-1]
# Test Bug ID: 214890
# Training Bug IDs: []
# True Duplicates for Bug ID 214890: [-1]
#
#
# Predicted Duplicates for Bug ID 214154: [-1]
# Test Bug ID: 214154
# Training Bug IDs: []
# True Duplicates for Bug ID 214154: [-1]
#
#
# Predicted Duplicates for Bug ID 214367: [-1]
# Test Bug ID: 214367
# Training Bug IDs: []
# True Duplicates for Bug ID 214367: [-1]
#
#
# Predicted Duplicates for Bug ID 214799: [-1]
# Test Bug ID: 214799
# Training Bug IDs: []
# True Duplicates for Bug ID 214799: [-1]
#
#
# Predicted Duplicates for Bug ID 214373: [-1]
# Test Bug ID: 214373
# Training Bug IDs: []
# True Duplicates for Bug ID 214373: [-1]
#
#
# Predicted Duplicates for Bug ID 214325: [-1]
# Test Bug ID: 214325
# Training Bug IDs: []
# True Duplicates for Bug ID 214325: [-1]
#
#
# Predicted Duplicates for Bug ID 215047: [-1]
# Test Bug ID: 215047
# Training Bug IDs: []
# True Duplicates for Bug ID 215047: [-1]
#
#
# Predicted Duplicates for Bug ID 214437: [-1]
# Test Bug ID: 214437
# Training Bug IDs: []
# True Duplicates for Bug ID 214437: [-1]
#
#
# Predicted Duplicates for Bug ID 214740: [-1]
# Test Bug ID: 214740
# Training Bug IDs: []
# True Duplicates for Bug ID 214740: [-1]
#
#
# Predicted Duplicates for Bug ID 214878: [-1]
# Test Bug ID: 214878
# Training Bug IDs: []
# True Duplicates for Bug ID 214878: [-1]
#
#
# Predicted Duplicates for Bug ID 214294: [-1]
# Test Bug ID: 214294
# Training Bug IDs: []
# True Duplicates for Bug ID 214294: [-1]
#
#
# Predicted Duplicates for Bug ID 214464: [-1]
# Test Bug ID: 214464
# Training Bug IDs: []
# True Duplicates for Bug ID 214464: [-1]
#
#
# Predicted Duplicates for Bug ID 214885: [-1]
# Test Bug ID: 214885
# Training Bug IDs: []
# True Duplicates for Bug ID 214885: [-1]
#
#
# Predicted Duplicates for Bug ID 214484: [-1]
# Test Bug ID: 214484
# Training Bug IDs: []
# True Duplicates for Bug ID 214484: [-1]
#
#
# Predicted Duplicates for Bug ID 214763: [-1]
# Test Bug ID: 214763
# Training Bug IDs: []
# True Duplicates for Bug ID 214763: [-1]
#
#
# Predicted Duplicates for Bug ID 214388: [-1]
# Test Bug ID: 214388
# Training Bug IDs: []
# True Duplicates for Bug ID 214388: [-1]
#
#
# Predicted Duplicates for Bug ID 214305: [214304 214306 214301 214701]
# Test Bug ID: 214305
# Training Bug IDs: [214304 214306 214301 214701]
# True Duplicates for Bug ID 214305: [214301, 214303, 214304, 214306]
#
#
# Predicted Duplicates for Bug ID 214835: [-1]
# Test Bug ID: 214835
# Training Bug IDs: []
# True Duplicates for Bug ID 214835: [-1]
#
#
# Predicted Duplicates for Bug ID 214342: [-1]
# Test Bug ID: 214342
# Training Bug IDs: []
# True Duplicates for Bug ID 214342: [-1]
#
#
# Predicted Duplicates for Bug ID 214396: [-1]
# Test Bug ID: 214396
# Training Bug IDs: []
# True Duplicates for Bug ID 214396: [-1]
#
#
# Predicted Duplicates for Bug ID 214548: [-1]
# Test Bug ID: 214548
# Training Bug IDs: []
# True Duplicates for Bug ID 214548: [-1]
#
#
# Predicted Duplicates for Bug ID 214837: [-1]
# Test Bug ID: 214837
# Training Bug IDs: []
# True Duplicates for Bug ID 214837: [-1]
#
#
# Predicted Duplicates for Bug ID 214720: [-1]
# Test Bug ID: 214720
# Training Bug IDs: []
# True Duplicates for Bug ID 214720: [-1]
#
#
# Predicted Duplicates for Bug ID 214136: [-1]
# Test Bug ID: 214136
# Training Bug IDs: []
# True Duplicates for Bug ID 214136: [-1]
#
#
# Predicted Duplicates for Bug ID 214991: [214988 215040 214990]
# Test Bug ID: 214991
# Training Bug IDs: [214988 215040 214990]
# True Duplicates for Bug ID 214991: [214988, 214989, 214990, 215040]
#
#
# Predicted Duplicates for Bug ID 214790: [-1]
# Test Bug ID: 214790
# Training Bug IDs: []
# True Duplicates for Bug ID 214790: [-1]
#
#
# Predicted Duplicates for Bug ID 214820: [-1]
# Test Bug ID: 214820
# Training Bug IDs: []
# True Duplicates for Bug ID 214820: [-1]
#
#
# Predicted Duplicates for Bug ID 214143: [-1]
# Test Bug ID: 214143
# Training Bug IDs: []
# True Duplicates for Bug ID 214143: [-1]
#
#
# Predicted Duplicates for Bug ID 214416: [-1]
# Test Bug ID: 214416
# Training Bug IDs: []
# True Duplicates for Bug ID 214416: [-1]
#
#
# Predicted Duplicates for Bug ID 214800: [-1]
# Test Bug ID: 214800
# Training Bug IDs: []
# True Duplicates for Bug ID 214800: [-1]
#
#
# Predicted Duplicates for Bug ID 214937: [-1]
# Test Bug ID: 214937
# Training Bug IDs: []
# True Duplicates for Bug ID 214937: [-1]
#
#
# Predicted Duplicates for Bug ID 214153: [-1]
# Test Bug ID: 214153
# Training Bug IDs: []
# True Duplicates for Bug ID 214153: [-1]
#
#
# Predicted Duplicates for Bug ID 214931: [-1]
# Test Bug ID: 214931
# Training Bug IDs: []
# True Duplicates for Bug ID 214931: [-1]
#
#
# Predicted Duplicates for Bug ID 214574: [-1]
# Test Bug ID: 214574
# Training Bug IDs: []
# True Duplicates for Bug ID 214574: [-1]
#
#
# Predicted Duplicates for Bug ID 214694: [-1]
# Test Bug ID: 214694
# Training Bug IDs: []
# True Duplicates for Bug ID 214694: [-1]
#
#
# Predicted Duplicates for Bug ID 214954: [-1]
# Test Bug ID: 214954
# Training Bug IDs: []
# True Duplicates for Bug ID 214954: [-1]
#
#
# Predicted Duplicates for Bug ID 214189: [-1]
# Test Bug ID: 214189
# Training Bug IDs: []
# True Duplicates for Bug ID 214189: [-1]
#
#
# Predicted Duplicates for Bug ID 214536: [-1]
# Test Bug ID: 214536
# Training Bug IDs: []
# True Duplicates for Bug ID 214536: [-1]
#
#
# Predicted Duplicates for Bug ID 214965: [-1]
# Test Bug ID: 214965
# Training Bug IDs: []
# True Duplicates for Bug ID 214965: [-1]
#
#
# Predicted Duplicates for Bug ID 214714: [-1]
# Test Bug ID: 214714
# Training Bug IDs: []
# True Duplicates for Bug ID 214714: [-1]
#
#
# Predicted Duplicates for Bug ID 214584: [-1]
# Test Bug ID: 214584
# Training Bug IDs: []
# True Duplicates for Bug ID 214584: [-1]
#
#
# Predicted Duplicates for Bug ID 214588: [-1]
# Test Bug ID: 214588
# Training Bug IDs: []
# True Duplicates for Bug ID 214588: [-1]
#
#
# Predicted Duplicates for Bug ID 214460: [-1]
# Test Bug ID: 214460
# Training Bug IDs: []
# True Duplicates for Bug ID 214460: [-1]
#
#
# Predicted Duplicates for Bug ID 214120: [-1]
# Test Bug ID: 214120
# Training Bug IDs: []
# True Duplicates for Bug ID 214120: [-1]
#
#
# Predicted Duplicates for Bug ID 214221: [-1]
# Test Bug ID: 214221
# Training Bug IDs: []
# True Duplicates for Bug ID 214221: [-1]
#
#
# Predicted Duplicates for Bug ID 214783: [-1]
# Test Bug ID: 214783
# Training Bug IDs: []
# True Duplicates for Bug ID 214783: [-1]
#
#
# Predicted Duplicates for Bug ID 214791: [-1]
# Test Bug ID: 214791
# Training Bug IDs: []
# True Duplicates for Bug ID 214791: [-1]
#
#
# Predicted Duplicates for Bug ID 214670: [-1]
# Test Bug ID: 214670
# Training Bug IDs: []
# True Duplicates for Bug ID 214670: [-1]
#
#
# Predicted Duplicates for Bug ID 214944: [-1]
# Test Bug ID: 214944
# Training Bug IDs: []
# True Duplicates for Bug ID 214944: [-1]
#
#
# Predicted Duplicates for Bug ID 214542: [-1]
# Test Bug ID: 214542
# Training Bug IDs: []
# True Duplicates for Bug ID 214542: [-1]
#
#
# Predicted Duplicates for Bug ID 215063: [-1]
# Test Bug ID: 215063
# Training Bug IDs: []
# True Duplicates for Bug ID 215063: [-1]
#
#
# Predicted Duplicates for Bug ID 215057: [-1]
# Test Bug ID: 215057
# Training Bug IDs: []
# True Duplicates for Bug ID 215057: [-1]
#
#
# Predicted Duplicates for Bug ID 214335: [-1]
# Test Bug ID: 214335
# Training Bug IDs: []
# True Duplicates for Bug ID 214335: [-1]
#
#
# Predicted Duplicates for Bug ID 214623: [-1]
# Test Bug ID: 214623
# Training Bug IDs: []
# True Duplicates for Bug ID 214623: [-1]
#
#
# Predicted Duplicates for Bug ID 214099: [-1]
# Test Bug ID: 214099
# Training Bug IDs: []
# True Duplicates for Bug ID 214099: [-1]
#
#
# Predicted Duplicates for Bug ID 214101: [-1]
# Test Bug ID: 214101
# Training Bug IDs: []
# True Duplicates for Bug ID 214101: [-1]
#
#
# Predicted Duplicates for Bug ID 214327: [-1]
# Test Bug ID: 214327
# Training Bug IDs: []
# True Duplicates for Bug ID 214327: [-1]
#
#
# Predicted Duplicates for Bug ID 214923: [-1]
# Test Bug ID: 214923
# Training Bug IDs: []
# True Duplicates for Bug ID 214923: [-1]
#
#
# Predicted Duplicates for Bug ID 214632: [-1]
# Test Bug ID: 214632
# Training Bug IDs: []
# True Duplicates for Bug ID 214632: [-1]
#
#
# Predicted Duplicates for Bug ID 214308: [-1]
# Test Bug ID: 214308
# Training Bug IDs: []
# True Duplicates for Bug ID 214308: [-1]
#
#
# Predicted Duplicates for Bug ID 214182: [-1]
# Test Bug ID: 214182
# Training Bug IDs: []
# True Duplicates for Bug ID 214182: [-1]
#
#
# Predicted Duplicates for Bug ID 214140: [-1]
# Test Bug ID: 214140
# Training Bug IDs: []
# True Duplicates for Bug ID 214140: [-1]
#
#
# Predicted Duplicates for Bug ID 214365: [-1]
# Test Bug ID: 214365
# Training Bug IDs: []
# True Duplicates for Bug ID 214365: [-1]
#
#
# Predicted Duplicates for Bug ID 214157: [-1]
# Test Bug ID: 214157
# Training Bug IDs: []
# True Duplicates for Bug ID 214157: [-1]
#
#
# Predicted Duplicates for Bug ID 214406: [-1]
# Test Bug ID: 214406
# Training Bug IDs: []
# True Duplicates for Bug ID 214406: [-1]
#
#
# Predicted Duplicates for Bug ID 214571: [-1]
# Test Bug ID: 214571
# Training Bug IDs: []
# True Duplicates for Bug ID 214571: [-1]
#
#
# Predicted Duplicates for Bug ID 214290: [-1]
# Test Bug ID: 214290
# Training Bug IDs: []
# True Duplicates for Bug ID 214290: [-1]
#
#
# Predicted Duplicates for Bug ID 214288: [-1]
# Test Bug ID: 214288
# Training Bug IDs: []
# True Duplicates for Bug ID 214288: [-1]
#
#
# Predicted Duplicates for Bug ID 214635: [-1]
# Test Bug ID: 214635
# Training Bug IDs: []
# True Duplicates for Bug ID 214635: [-1]
#
#
# Predicted Duplicates for Bug ID 214478: [-1]
# Test Bug ID: 214478
# Training Bug IDs: []
# True Duplicates for Bug ID 214478: [-1]
#
#
# Predicted Duplicates for Bug ID 214069: [214068]
# Test Bug ID: 214069
# Training Bug IDs: [214068]
# True Duplicates for Bug ID 214069: [214068]
#
#
# Predicted Duplicates for Bug ID 214125: [-1]
# Test Bug ID: 214125
# Training Bug IDs: []
# True Duplicates for Bug ID 214125: [-1]
#
#
# Predicted Duplicates for Bug ID 214565: [-1]
# Test Bug ID: 214565
# Training Bug IDs: []
# True Duplicates for Bug ID 214565: [-1]
#
#
# Predicted Duplicates for Bug ID 214409: [-1]
# Test Bug ID: 214409
# Training Bug IDs: []
# True Duplicates for Bug ID 214409: [-1]
#
#
# Predicted Duplicates for Bug ID 214336: [-1]
# Test Bug ID: 214336
# Training Bug IDs: []
# True Duplicates for Bug ID 214336: [-1]
#
#
# Predicted Duplicates for Bug ID 214174: [-1]
# Test Bug ID: 214174
# Training Bug IDs: []
# True Duplicates for Bug ID 214174: [-1]
#
#
# Predicted Duplicates for Bug ID 214710: [-1]
# Test Bug ID: 214710
# Training Bug IDs: []
# True Duplicates for Bug ID 214710: [-1]
#
#
# Predicted Duplicates for Bug ID 215020: [-1]
# Test Bug ID: 215020
# Training Bug IDs: []
# True Duplicates for Bug ID 215020: [-1]
#
#
# Predicted Duplicates for Bug ID 214840: [-1]
# Test Bug ID: 214840
# Training Bug IDs: []
# True Duplicates for Bug ID 214840: [-1]
#
#
# Predicted Duplicates for Bug ID 214629: [-1]
# Test Bug ID: 214629
# Training Bug IDs: []
# True Duplicates for Bug ID 214629: [-1]
#
#
# Predicted Duplicates for Bug ID 214094: [-1]
# Test Bug ID: 214094
# Training Bug IDs: []
# True Duplicates for Bug ID 214094: [-1]
#
#
# Predicted Duplicates for Bug ID 214161: [-1]
# Test Bug ID: 214161
# Training Bug IDs: []
# True Duplicates for Bug ID 214161: [-1]
#
#
# Predicted Duplicates for Bug ID 214078: [-1]
# Test Bug ID: 214078
# Training Bug IDs: []
# True Duplicates for Bug ID 214078: [-1]
#
#
# Predicted Duplicates for Bug ID 214303: [214304 214306 214301 214701]
# Test Bug ID: 214303
# Training Bug IDs: [214304 214306 214301 214701]
# True Duplicates for Bug ID 214303: [214301, 214304, 214305, 214306, 214701]
#
#
# Predicted Duplicates for Bug ID 214487: [-1]
# Test Bug ID: 214487
# Training Bug IDs: []
# True Duplicates for Bug ID 214487: [-1]
#
#
# Predicted Duplicates for Bug ID 214968: [-1]
# Test Bug ID: 214968
# Training Bug IDs: []
# True Duplicates for Bug ID 214968: [-1]
#
#
# Predicted Duplicates for Bug ID 214496: [214497 214500 214498 214501]
# Test Bug ID: 214496
# Training Bug IDs: [214497 214500 214498 214501]
# True Duplicates for Bug ID 214496: [214497, 214498, 214500, 214501, 214504]
#
#
# Predicted Duplicates for Bug ID 214196: [-1]
# Test Bug ID: 214196
# Training Bug IDs: []
# True Duplicates for Bug ID 214196: [-1]
#
#
# Predicted Duplicates for Bug ID 214832: [-1]
# Test Bug ID: 214832
# Training Bug IDs: []
# True Duplicates for Bug ID 214832: [-1]
#
#
# Predicted Duplicates for Bug ID 214797: [-1]
# Test Bug ID: 214797
# Training Bug IDs: []
# True Duplicates for Bug ID 214797: [-1]
#
#
# Predicted Duplicates for Bug ID 214092: [-1]
# Test Bug ID: 214092
# Training Bug IDs: []
# True Duplicates for Bug ID 214092: [-1]
#
#
# Predicted Duplicates for Bug ID 214733: [214950]
# Test Bug ID: 214733
# Training Bug IDs: [214950]
# True Duplicates for Bug ID 214733: [-1]
#
#
# Predicted Duplicates for Bug ID 214695: [-1]
# Test Bug ID: 214695
# Training Bug IDs: []
# True Duplicates for Bug ID 214695: [-1]
#
#
# Predicted Duplicates for Bug ID 215012: [-1]
# Test Bug ID: 215012
# Training Bug IDs: []
# True Duplicates for Bug ID 215012: [-1]
#
#
# Predicted Duplicates for Bug ID 214753: [-1]
# Test Bug ID: 214753
# Training Bug IDs: []
# True Duplicates for Bug ID 214753: [-1]
#
#
# Predicted Duplicates for Bug ID 214463: [-1]
# Test Bug ID: 214463
# Training Bug IDs: []
# True Duplicates for Bug ID 214463: [-1]
#
#
# Predicted Duplicates for Bug ID 214155: [-1]
# Test Bug ID: 214155
# Training Bug IDs: []
# True Duplicates for Bug ID 214155: [-1]
#
#
# Predicted Duplicates for Bug ID 214707: [-1]
# Test Bug ID: 214707
# Training Bug IDs: []
# True Duplicates for Bug ID 214707: [-1]
#
#
# Predicted Duplicates for Bug ID 214471: [-1]
# Test Bug ID: 214471
# Training Bug IDs: []
# True Duplicates for Bug ID 214471: [-1]
#
#
# Predicted Duplicates for Bug ID 214690: [-1]
# Test Bug ID: 214690
# Training Bug IDs: []
# True Duplicates for Bug ID 214690: [-1]
#
#
# Predicted Duplicates for Bug ID 214504: [214497 214500 214498 214501]
# Test Bug ID: 214504
# Training Bug IDs: [214497 214500 214498 214501]
# True Duplicates for Bug ID 214504: [214496, 214497, 214498, 214500, 214501]
#
#
# Precision: 0.9565217391304348
# Recall: 0.9565217391304348
# F1 Score: 0.9565217391304348
# Accuracy Score: 0.9894179894179894
# Confusion Matrix:
# [[165, 1], [1, 22]]
