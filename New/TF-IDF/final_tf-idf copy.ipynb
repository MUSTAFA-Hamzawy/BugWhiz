# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import nltk
from sklearn.model_selection import train_test_split

# %%
# Remove the stop words from the preprocessed_description column using nltk
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Define the directory paths
directories = [
    ("..\\new_dataset\\eclipse", "..\\new_dataset\\eclipse"),
    #("..\\new_dataset\\eclipse_test", "..\\new_dataset\\eclipse_test"),
    #("..\\new_dataset\\firefox", "..\\new_dataset\\firefox"),
    #("..\\new_dataset\\netbeans", "..\\new_dataset\\netbeans"),
    #("..\\new_dataset\\openoffice", "..\\new_dataset\\openoffice")
]

# %%
# Read the file eclipse_new_updated.csv
df = pd.read_csv("..\\new_dataset\\eclipse\\eclipse_small_new_updated.csv")

# Print the first 5 rows of the dataframe (preprocessed_description column only)
print(df['preprocessed_description'].head())
# Out:
# 0    description regression group toc are created a...
# 1    output column page in data set editor used res...
# 2    description regression failed to preview chart...
# 3    description exception is thrown out when link ...
# 4    build id m step to reproduce start eclipse cli...
# Name: preprocessed_description, dtype: object

# %%
import numpy as np

# Check for NaN values and replace them with an empty string
df['preprocessed_description'] = df['preprocessed_description'].fillna('')

# Apply the lambda function only to non-NaN values
df['preprocessed_description'] = df['preprocessed_description'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stop_words)]))

# %%
# Split the data into training and testing data
X_train, X_test = train_test_split(df, test_size=0.2, random_state=42)

# print the first 1 rows of the training data
print(X_train.head(1))

# print the first 1 rows of the testing data
print(X_test.head(1))

# Drop rows where bug_id is not numeric in X_train
X_train = X_train[X_train['bug_id'].apply(lambda x: str(x).isdigit())]

# Drop rows where bug_id is not numeric in X_test
X_test = X_test[X_test['bug_id'].apply(lambda x: str(x).isdigit())]
# Out:
#       bug_id bug_severity                                        description  \
# 2279    2540       normal  The contents of the Open>Perspective menu depe...
#
#      dup_id priority                                         short_desc  \
# 2279     []       P3  Contents of Perspective>Open menu should not c...
#
#                                preprocessed_description
# 2279  content open perspective menu depend current p...
#       bug_id bug_severity                                        description  \
# 3500    3781  enhancement  0) On J platform, save a method with J charact...
#
#      dup_id priority                                         short_desc  \
# 3500     []       P4  J - LOW PRIORITY - Eclipse methods saved with ...
#
#                                preprocessed_description
# 3500  j platform , save method j character invoke e ...

# %%
# Use TF-IDF as a feature extraction technique
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train['preprocessed_description'])
X_test_tfidf = vectorizer.transform(X_test['preprocessed_description'])

# %%
# print the size of X_train_tfidf
print(X_train_tfidf.shape)

# print the size of X_test_tfidf
print(X_test_tfidf.shape)
# Out:
# (3246, 14231)
# (812, 14231)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import re

# make a dictionary to store the test example bug_id as a key and the predicted duplicates as values
predicted_duplicates_dict = {}
# make a dictionary to store the test example bug_id as a key and the corrected duplicates as values
true_duplicates_dict = {}

# Loop through the test examples
for i in range(X_test_tfidf.shape[0]):
    print("Processing test example", i)
    
    # Check if X_test['bug_id'].values is empty
    if len(X_test['bug_id'].values) == 0:
        continue
    
    predicted_duplicates_dict[X_test['bug_id'].values[i]] = []
    true_duplicates_dict[X_test['bug_id'].values[i]] = []
    
    # Calculate the cosine similarity between the test example and all the training examples
    similarity = cosine_similarity(X_test_tfidf[i], X_train_tfidf)

    # Get the bug_ids of the training examples that have similarity greater than or equal to 0.9
    bug_ids = X_train['bug_id'].values[np.where(similarity >= 0.9)[1]]
    # if bug_ids is empty, replace it with -1
    if len(bug_ids) == 0:
        bug_ids = [-1]

    # Append the bug_ids to the predicted_duplicates list
    predicted_duplicates_dict[X_test['bug_id'].values[i]].extend(bug_ids)

    # Get the dup_id of the test example
    dup_id_value = X_test['dup_id'].values[i]
    if not pd.isnull(dup_id_value):  # Check if the value is not NaN
        # split it by semicolons
        dup_ids = dup_id_value.split(';')
        # after splitting check if there is an empty string in the list and remove it
        dup_ids = [dup_id for dup_id in dup_ids if dup_id]  # Filter out empty strings
        # if the dup_ids list is ['[]'], replace it with -1
        if dup_ids == ['[]']:
            dup_ids = [-1]
        # make the dup_ids list as integers
        dup_ids = [int(dup_id) for dup_id in dup_ids]
    else:
        dup_ids = [-1]  # Assign -1 if the value is NaN
        
    # Append the dup_ids to the true_duplicates list
    true_duplicates_dict[X_test['bug_id'].values[i]].extend(dup_ids)
# Out:
# Processing test example 0
# Processing test example 1
# Processing test example 2
# Processing test example 3
# Processing test example 4
# Processing test example 5
# Processing test example 6
# Processing test example 7
# Processing test example 8
# Processing test example 9
# Processing test example 10
# Processing test example 11
# Processing test example 12
# Processing test example 13
# Processing test example 14
# Processing test example 15
# Processing test example 16
# Processing test example 17
# Processing test example 18
# Processing test example 19
# Processing test example 20
# Processing test example 21
# Processing test example 22
# Processing test example 23
# Processing test example 24
# Processing test example 25
# Processing test example 26
# Processing test example 27
# Processing test example 28
# Processing test example 29
# Processing test example 30
# Processing test example 31
# Processing test example 32
# Processing test example 33
# Processing test example 34
# Processing test example 35
# Processing test example 36
# Processing test example 37
# Processing test example 38
# Processing test example 39
# Processing test example 40
# Processing test example 41
# Processing test example 42
# Processing test example 43
# Processing test example 44
# Processing test example 45
# Processing test example 46
# Processing test example 47
# Processing test example 48
# Processing test example 49
# Processing test example 50
# Processing test example 51
# Processing test example 52
# Processing test example 53
# Processing test example 54
# Processing test example 55
# Processing test example 56
# Processing test example 57
# Processing test example 58
# Processing test example 59
# Processing test example 60
# Processing test example 61
# Processing test example 62
# Processing test example 63
# Processing test example 64
# Processing test example 65
# Processing test example 66
# Processing test example 67
# Processing test example 68
# Processing test example 69
# Processing test example 70
# Processing test example 71
# Processing test example 72
# Processing test example 73
# Processing test example 74
# Processing test example 75
# Processing test example 76
# Processing test example 77
# Processing test example 78
# Processing test example 79
# Processing test example 80
# Processing test example 81
# Processing test example 82
# Processing test example 83
# Processing test example 84
# Processing test example 85
# Processing test example 86
# Processing test example 87
# Processing test example 88
# Processing test example 89
# Processing test example 90
# Processing test example 91
# Processing test example 92
# Processing test example 93
# Processing test example 94
# Processing test example 95
# Processing test example 96
# Processing test example 97
# Processing test example 98
# Processing test example 99
# Processing test example 100
# Processing test example 101
# Processing test example 102
# Processing test example 103
# Processing test example 104
# Processing test example 105
# Processing test example 106
# Processing test example 107
# Processing test example 108
# Processing test example 109
# Processing test example 110
# Processing test example 111
# Processing test example 112
# Processing test example 113
# Processing test example 114
# Processing test example 115
# Processing test example 116
# Processing test example 117
# Processing test example 118
# Processing test example 119
# Processing test example 120
# Processing test example 121
# Processing test example 122
# Processing test example 123
# Processing test example 124
# Processing test example 125
# Processing test example 126
# Processing test example 127
# Processing test example 128
# Processing test example 129
# Processing test example 130
# Processing test example 131
# Processing test example 132
# Processing test example 133
# Processing test example 134
# Processing test example 135
# Processing test example 136
# Processing test example 137
# Processing test example 138
# Processing test example 139
# Processing test example 140
# Processing test example 141
# Processing test example 142
# Processing test example 143
# Processing test example 144
# Processing test example 145
# Processing test example 146
# Processing test example 147
# Processing test example 148
# Processing test example 149
# Processing test example 150
# Processing test example 151
# Processing test example 152
# Processing test example 153
# Processing test example 154
# Processing test example 155
# Processing test example 156
# Processing test example 157
# Processing test example 158
# Processing test example 159
# Processing test example 160
# Processing test example 161
# Processing test example 162
# Processing test example 163
# Processing test example 164
# Processing test example 165
# Processing test example 166
# Processing test example 167
# Processing test example 168
# Processing test example 169
# Processing test example 170
# Processing test example 171
# Processing test example 172
# Processing test example 173
# Processing test example 174
# Processing test example 175
# Processing test example 176
# Processing test example 177
# Processing test example 178
# Processing test example 179
# Processing test example 180
# Processing test example 181
# Processing test example 182
# Processing test example 183
# Processing test example 184
# Processing test example 185
# Processing test example 186
# Processing test example 187
# Processing test example 188
# Processing test example 189
# Processing test example 190
# Processing test example 191
# Processing test example 192
# Processing test example 193
# Processing test example 194
# Processing test example 195
# Processing test example 196
# Processing test example 197
# Processing test example 198
# Processing test example 199
# Processing test example 200
# Processing test example 201
# Processing test example 202
# Processing test example 203
# Processing test example 204
# Processing test example 205
# Processing test example 206
# Processing test example 207
# Processing test example 208
# Processing test example 209
# Processing test example 210
# Processing test example 211
# Processing test example 212
# Processing test example 213
# Processing test example 214
# Processing test example 215
# Processing test example 216
# Processing test example 217
# Processing test example 218
# Processing test example 219
# Processing test example 220
# Processing test example 221
# Processing test example 222
# Processing test example 223
# Processing test example 224
# Processing test example 225
# Processing test example 226
# Processing test example 227
# Processing test example 228
# Processing test example 229
# Processing test example 230
# Processing test example 231
# Processing test example 232
# Processing test example 233
# Processing test example 234
# Processing test example 235
# Processing test example 236
# Processing test example 237
# Processing test example 238
# Processing test example 239
# Processing test example 240
# Processing test example 241
# Processing test example 242
# Processing test example 243
# Processing test example 244
# Processing test example 245
# Processing test example 246
# Processing test example 247
# Processing test example 248
# Processing test example 249
# Processing test example 250
# Processing test example 251
# Processing test example 252
# Processing test example 253
# Processing test example 254
# Processing test example 255
# Processing test example 256
# Processing test example 257
# Processing test example 258
# Processing test example 259
# Processing test example 260
# Processing test example 261
# Processing test example 262
# Processing test example 263
# Processing test example 264
# Processing test example 265
# Processing test example 266
# Processing test example 267
# Processing test example 268
# Processing test example 269
# Processing test example 270
# Processing test example 271
# Processing test example 272
# Processing test example 273
# Processing test example 274
# Processing test example 275
# Processing test example 276
# Processing test example 277
# Processing test example 278
# Processing test example 279
# Processing test example 280
# Processing test example 281
# Processing test example 282
# Processing test example 283
# Processing test example 284
# Processing test example 285
# Processing test example 286
# Processing test example 287
# Processing test example 288
# Processing test example 289
# Processing test example 290
# Processing test example 291
# Processing test example 292
# Processing test example 293
# Processing test example 294
# Processing test example 295
# Processing test example 296
# Processing test example 297
# Processing test example 298
# Processing test example 299
# Processing test example 300
# Processing test example 301
# Processing test example 302
# Processing test example 303
# Processing test example 304
# Processing test example 305
# Processing test example 306
# Processing test example 307
# Processing test example 308
# Processing test example 309
# Processing test example 310
# Processing test example 311
# Processing test example 312
# Processing test example 313
# Processing test example 314
# Processing test example 315
# Processing test example 316
# Processing test example 317
# Processing test example 318
# Processing test example 319
# Processing test example 320
# Processing test example 321
# Processing test example 322
# Processing test example 323
# Processing test example 324
# Processing test example 325
# Processing test example 326
# Processing test example 327
# Processing test example 328
# Processing test example 329
# Processing test example 330
# Processing test example 331
# Processing test example 332
# Processing test example 333
# Processing test example 334
# Processing test example 335
# Processing test example 336
# Processing test example 337
# Processing test example 338
# Processing test example 339
# Processing test example 340
# Processing test example 341
# Processing test example 342
# Processing test example 343
# Processing test example 344
# Processing test example 345
# Processing test example 346
# Processing test example 347
# Processing test example 348
# Processing test example 349
# Processing test example 350
# Processing test example 351
# Processing test example 352
# Processing test example 353
# Processing test example 354
# Processing test example 355
# Processing test example 356
# Processing test example 357
# Processing test example 358
# Processing test example 359
# Processing test example 360
# Processing test example 361
# Processing test example 362
# Processing test example 363
# Processing test example 364
# Processing test example 365
# Processing test example 366
# Processing test example 367
# Processing test example 368
# Processing test example 369
# Processing test example 370
# Processing test example 371
# Processing test example 372
# Processing test example 373
# Processing test example 374
# Processing test example 375
# Processing test example 376
# Processing test example 377
# Processing test example 378
# Processing test example 379
# Processing test example 380
# Processing test example 381
# Processing test example 382
# Processing test example 383
# Processing test example 384
# Processing test example 385
# Processing test example 386
# Processing test example 387
# Processing test example 388
# Processing test example 389
# Processing test example 390
# Processing test example 391
# Processing test example 392
# Processing test example 393
# Processing test example 394
# Processing test example 395
# Processing test example 396
# Processing test example 397
# Processing test example 398
# Processing test example 399
# Processing test example 400
# Processing test example 401
# Processing test example 402
# Processing test example 403
# Processing test example 404
# Processing test example 405
# Processing test example 406
# Processing test example 407
# Processing test example 408
# Processing test example 409
# Processing test example 410
# Processing test example 411
# Processing test example 412
# Processing test example 413
# Processing test example 414
# Processing test example 415
# Processing test example 416
# Processing test example 417
# Processing test example 418
# Processing test example 419
# Processing test example 420
# Processing test example 421
# Processing test example 422
# Processing test example 423
# Processing test example 424
# Processing test example 425
# Processing test example 426
# Processing test example 427
# Processing test example 428
# Processing test example 429
# Processing test example 430
# Processing test example 431
# Processing test example 432
# Processing test example 433
# Processing test example 434
# Processing test example 435
# Processing test example 436
# Processing test example 437
# Processing test example 438
# Processing test example 439
# Processing test example 440
# Processing test example 441
# Processing test example 442
# Processing test example 443
# Processing test example 444
# Processing test example 445
# Processing test example 446
# Processing test example 447
# Processing test example 448
# Processing test example 449
# Processing test example 450
# Processing test example 451
# Processing test example 452
# Processing test example 453
# Processing test example 454
# Processing test example 455
# Processing test example 456
# Processing test example 457
# Processing test example 458
# Processing test example 459
# Processing test example 460
# Processing test example 461
# Processing test example 462
# Processing test example 463
# Processing test example 464
# Processing test example 465
# Processing test example 466
# Processing test example 467
# Processing test example 468
# Processing test example 469
# Processing test example 470
# Processing test example 471
# Processing test example 472
# Processing test example 473
# Processing test example 474
# Processing test example 475
# Processing test example 476
# Processing test example 477
# Processing test example 478
# Processing test example 479
# Processing test example 480
# Processing test example 481
# Processing test example 482
# Processing test example 483
# Processing test example 484
# Processing test example 485
# Processing test example 486
# Processing test example 487
# Processing test example 488
# Processing test example 489
# Processing test example 490
# Processing test example 491
# Processing test example 492
# Processing test example 493
# Processing test example 494
# Processing test example 495
# Processing test example 496
# Processing test example 497
# Processing test example 498
# Processing test example 499
# Processing test example 500
# Processing test example 501
# Processing test example 502
# Processing test example 503
# Processing test example 504
# Processing test example 505
# Processing test example 506
# Processing test example 507
# Processing test example 508
# Processing test example 509
# Processing test example 510
# Processing test example 511
# Processing test example 512
# Processing test example 513
# Processing test example 514
# Processing test example 515
# Processing test example 516
# Processing test example 517
# Processing test example 518
# Processing test example 519
# Processing test example 520
# Processing test example 521
# Processing test example 522
# Processing test example 523
# Processing test example 524
# Processing test example 525
# Processing test example 526
# Processing test example 527
# Processing test example 528
# Processing test example 529
# Processing test example 530
# Processing test example 531
# Processing test example 532
# Processing test example 533
# Processing test example 534
# Processing test example 535
# Processing test example 536
# Processing test example 537
# Processing test example 538
# Processing test example 539
# Processing test example 540
# Processing test example 541
# Processing test example 542
# Processing test example 543
# Processing test example 544
# Processing test example 545
# Processing test example 546
# Processing test example 547
# Processing test example 548
# Processing test example 549
# Processing test example 550
# Processing test example 551
# Processing test example 552
# Processing test example 553
# Processing test example 554
# Processing test example 555
# Processing test example 556
# Processing test example 557
# Processing test example 558
# Processing test example 559
# Processing test example 560
# Processing test example 561
# Processing test example 562
# Processing test example 563
# Processing test example 564
# Processing test example 565
# Processing test example 566
# Processing test example 567
# Processing test example 568
# Processing test example 569
# Processing test example 570
# Processing test example 571
# Processing test example 572
# Processing test example 573
# Processing test example 574
# Processing test example 575
# Processing test example 576
# Processing test example 577
# Processing test example 578
# Processing test example 579
# Processing test example 580
# Processing test example 581
# Processing test example 582
# Processing test example 583
# Processing test example 584
# Processing test example 585
# Processing test example 586
# Processing test example 587
# Processing test example 588
# Processing test example 589
# Processing test example 590
# Processing test example 591
# Processing test example 592
# Processing test example 593
# Processing test example 594
# Processing test example 595
# Processing test example 596
# Processing test example 597
# Processing test example 598
# Processing test example 599
# Processing test example 600
# Processing test example 601
# Processing test example 602
# Processing test example 603
# Processing test example 604
# Processing test example 605
# Processing test example 606
# Processing test example 607
# Processing test example 608
# Processing test example 609
# Processing test example 610
# Processing test example 611
# Processing test example 612
# Processing test example 613
# Processing test example 614
# Processing test example 615
# Processing test example 616
# Processing test example 617
# Processing test example 618
# Processing test example 619
# Processing test example 620
# Processing test example 621
# Processing test example 622
# Processing test example 623
# Processing test example 624
# Processing test example 625
# Processing test example 626
# Processing test example 627
# Processing test example 628
# Processing test example 629
# Processing test example 630
# Processing test example 631
# Processing test example 632
# Processing test example 633
# Processing test example 634
# Processing test example 635
# Processing test example 636
# Processing test example 637
# Processing test example 638
# Processing test example 639
# Processing test example 640
# Processing test example 641
# Processing test example 642
# Processing test example 643
# Processing test example 644
# Processing test example 645
# Processing test example 646
# Processing test example 647
# Processing test example 648
# Processing test example 649
# Processing test example 650
# Processing test example 651
# Processing test example 652
# Processing test example 653
# Processing test example 654
# Processing test example 655
# Processing test example 656
# Processing test example 657
# Processing test example 658
# Processing test example 659
# Processing test example 660
# Processing test example 661
# Processing test example 662
# Processing test example 663
# Processing test example 664
# Processing test example 665
# Processing test example 666
# Processing test example 667
# Processing test example 668
# Processing test example 669
# Processing test example 670
# Processing test example 671
# Processing test example 672
# Processing test example 673
# Processing test example 674
# Processing test example 675
# Processing test example 676
# Processing test example 677
# Processing test example 678
# Processing test example 679
# Processing test example 680
# Processing test example 681
# Processing test example 682
# Processing test example 683
# Processing test example 684
# Processing test example 685
# Processing test example 686
# Processing test example 687
# Processing test example 688
# Processing test example 689
# Processing test example 690
# Processing test example 691
# Processing test example 692
# Processing test example 693
# Processing test example 694
# Processing test example 695
# Processing test example 696
# Processing test example 697
# Processing test example 698
# Processing test example 699
# Processing test example 700
# Processing test example 701
# Processing test example 702
# Processing test example 703
# Processing test example 704
# Processing test example 705
# Processing test example 706
# Processing test example 707
# Processing test example 708
# Processing test example 709
# Processing test example 710
# Processing test example 711
# Processing test example 712
# Processing test example 713
# Processing test example 714
# Processing test example 715
# Processing test example 716
# Processing test example 717
# Processing test example 718
# Processing test example 719
# Processing test example 720
# Processing test example 721
# Processing test example 722
# Processing test example 723
# Processing test example 724
# Processing test example 725
# Processing test example 726
# Processing test example 727
# Processing test example 728
# Processing test example 729
# Processing test example 730
# Processing test example 731
# Processing test example 732
# Processing test example 733
# Processing test example 734
# Processing test example 735
# Processing test example 736
# Processing test example 737
# Processing test example 738
# Processing test example 739
# Processing test example 740
# Processing test example 741
# Processing test example 742
# Processing test example 743
# Processing test example 744
# Processing test example 745
# Processing test example 746
# Processing test example 747
# Processing test example 748
# Processing test example 749
# Processing test example 750
# Processing test example 751
# Processing test example 752
# Processing test example 753
# Processing test example 754
# Processing test example 755
# Processing test example 756
# Processing test example 757
# Processing test example 758
# Processing test example 759
# Processing test example 760
# Processing test example 761
# Processing test example 762
# Processing test example 763
# Processing test example 764
# Processing test example 765
# Processing test example 766
# Processing test example 767
# Processing test example 768
# Processing test example 769
# Processing test example 770
# Processing test example 771
# Processing test example 772
# Processing test example 773
# Processing test example 774
# Processing test example 775
# Processing test example 776
# Processing test example 777
# Processing test example 778
# Processing test example 779
# Processing test example 780
# Processing test example 781
# Processing test example 782
# Processing test example 783
# Processing test example 784
# Processing test example 785
# Processing test example 786
# Processing test example 787
# Processing test example 788
# Processing test example 789
# Processing test example 790
# Processing test example 791
# Processing test example 792
# Processing test example 793
# Processing test example 794
# Processing test example 795
# Processing test example 796
# Processing test example 797
# Processing test example 798
# Processing test example 799
# Processing test example 800
# Processing test example 801
# Processing test example 802
# Processing test example 803
# Processing test example 804
# Processing test example 805
# Processing test example 806
# Processing test example 807
# Processing test example 808
# Processing test example 809
# Processing test example 810
# Processing test example 811

# %%
# calculate the true_positive, false_positive, true_negative, false_negative
true_positive = 0
false_positive = 0
true_negative = 0
false_negative = 0

# There are 4 cases to consider:
# 1. The predicted duplicate is in the true duplicates list (true positive)
# 2. The predicted duplicate is not in the true duplicates list (false positive)
# 3. The true duplicate is not predicted as a duplicate (false negative)
# 4. The true duplicate is predicted as a duplicate (true negative)

# Note: if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains -1, and true_duplicates_dict[X_test['bug_id'].values[i]] contains -1, then it is a true negative
# if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains -1, and true_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, then it is a false negative
# if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, and true_duplicates_dict[X_test['bug_id'].values[i]] contains -1, then it is a false positive
# if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, and true_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, then it is a true positive

for key in predicted_duplicates_dict.keys():
    if -1 in predicted_duplicates_dict[key] and -1 in true_duplicates_dict[key]:
        true_negative += 1
    elif -1 in predicted_duplicates_dict[key] and -1 not in true_duplicates_dict[key]:
        false_negative += 1
    elif -1 not in predicted_duplicates_dict[key] and -1 in true_duplicates_dict[key]:
        false_positive += 1
    elif -1 not in predicted_duplicates_dict[key] and -1 not in true_duplicates_dict[key]:
        for bug_id in predicted_duplicates_dict[key]:
            if bug_id in true_duplicates_dict[key]:
                true_positive += 1

# print the true_positive, false_positive, true_negative, false_negative
print("True Positive:", true_positive)
print("False Positive:", false_positive)
print("True Negative:", true_negative)
print("False Negative:", false_negative)
# Out:
# True Positive: 20
# False Positive: 24
# True Negative: 778
# False Negative: 2

# %%
# calculate the precision, recall, and f1 score
precision = true_positive / (true_positive + false_positive)
recall = true_positive / (true_positive + false_negative)
f1 = 2 * precision * recall / (precision + recall)
accuracy_score = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy Score:", accuracy_score)

# confusion matrix
conf_matrix = [[true_negative, false_positive],
               [false_negative, true_positive]]
# Out:
# Precision: 0.45454545454545453
# Recall: 0.9090909090909091
# F1 Score: 0.6060606060606061
# Accuracy Score: 0.9684466019417476

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

# Define the range of n-grams to iterate through
# (1,1) , (1,2) , (1,3) , (1,4) , (1,5) , (1,6) , (1,7)
# (2,2) , (2,3) , (2,4) , (2,5) , (2,6) , (2,7)
# (3,3) , (3,4) , (3,5) , (3,6) , (3,7)
# (4,4) , (4,5) , (4,6) , (4,7)
# (5,5) , (5,6) , (5,7)
# (6,6) , (6,7)
# (7,7)
ngram_ranges = [(i, j) for i in range(1, 8) for j in range(i, 8)]

# Iterate through each n-gram range
for ngram_range in ngram_ranges:
    print("Processing n-gram range:", ngram_range)

    # Use TF-IDF as a feature extraction technique with the current n-gram range
    vectorizer = TfidfVectorizer(ngram_range=ngram_range)
    X_train_tfidf = vectorizer.fit_transform(X_train['preprocessed_description'])
    X_test_tfidf = vectorizer.transform(X_test['preprocessed_description'])

    # make a dictionary to store the test example bug_id as a key and the predicted duplicates as values
    predicted_duplicates_dict = {}
    # make a dictionary to store the test example bug_id as a key and the corrected duplicates as values
    true_duplicates_dict = {}

    # Loop through the test examples
    for i in range(X_test_tfidf.shape[0]):
        print("Processing test example", i)

        # Check if X_test['bug_id'].values is empty
        if len(X_test['bug_id'].values) == 0:
            continue

        predicted_duplicates_dict[X_test['bug_id'].values[i]] = []
        true_duplicates_dict[X_test['bug_id'].values[i]] = []

        # Calculate the cosine similarity between the test example and all the training examples
        similarity = cosine_similarity(X_test_tfidf[i], X_train_tfidf)

        # Get the bug_ids of the training examples that have similarity greater than or equal to 0.9
        bug_ids = X_train['bug_id'].values[np.where(similarity >= 0.9)[1]]
        # if bug_ids is empty, replace it with -1
        if len(bug_ids) == 0:
            bug_ids = [-1]

        # Append the bug_ids to the predicted_duplicates list
        predicted_duplicates_dict[X_test['bug_id'].values[i]].extend(bug_ids)

        # Get the dup_id of the test example
        dup_id_value = X_test['dup_id'].values[i]
        if not pd.isnull(dup_id_value):  # Check if the value is not NaN
            # split it by semicolons
            dup_ids = dup_id_value.split(';')
            # after splitting check if there is an empty string in the list and remove it
            dup_ids = [dup_id for dup_id in dup_ids if dup_id]  # Filter out empty strings
            # if the dup_ids list is ['[]'], replace it with -1
            if dup_ids == ['[]']:
                dup_ids = [-1]
            # make the dup_ids list as integers
            dup_ids = [int(dup_id) for dup_id in dup_ids]
        else:
            dup_ids = [-1]  # Assign -1 if the value is NaN

        # Append the dup_ids to the true_duplicates list
        true_duplicates_dict[X_test['bug_id'].values[i]].extend(dup_ids)

    # calculate the true_positive, false_positive, true_negative, false_negative
    true_positive = 0
    false_positive = 0
    true_negative = 0
    false_negative = 0

    # There are 4 cases to consider:
    # 1. The predicted duplicate is in the true duplicates list (true positive)
    # 2. The predicted duplicate is not in the true duplicates list (false positive)
    # 3. The true duplicate is not predicted as a duplicate (false negative)
    # 4. The true duplicate is predicted as a duplicate (true negative)

    # Note: if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains -1, and true_duplicates_dict[X_test['bug_id'].values[i]] contains -1, then it is a true negative
    # if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains -1, and true_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, then it is a false negative
    # if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, and true_duplicates_dict[X_test['bug_id'].values[i]] contains -1, then it is a false positive
    # if predicted_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, and true_duplicates_dict[X_test['bug_id'].values[i]] contains a bug_id, then it is a true positive

    for key in predicted_duplicates_dict.keys():
        if -1 in predicted_duplicates_dict[key] and -1 in true_duplicates_dict[key]:
            true_negative += 1
        elif -1 in predicted_duplicates_dict[key] and -1 not in true_duplicates_dict[key]:
            false_negative += 1
        elif -1 not in predicted_duplicates_dict[key] and -1 in true_duplicates_dict[key]:
            false_positive += 1
        elif -1 not in predicted_duplicates_dict[key] and -1 not in true_duplicates_dict[key]:
            for bug_id in predicted_duplicates_dict[key]:
                if bug_id in true_duplicates_dict[key]:
                    true_positive += 1

    # print the true_positive, false_positive, true_negative, false_negative
    print("True Positive:", true_positive)
    print("False Positive:", false_positive)
    print("True Negative:", true_negative)
    print("False Negative:", false_negative)

    # calculate the precision, recall, and f1 score
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / (true_positive + false_negative)
    f1 = 2 * precision * recall / (precision + recall)
    accuracy_score = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)

    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Accuracy Score:", accuracy_score)

    # confusion matrix
    conf_matrix = [[true_negative, false_positive],
                   [false_negative, true_positive]]

    # Print the confusion matrix
    print("Confusion Matrix:")
    print(conf_matrix)
# Out:
# Processing n-gram range: (1, 1)
# Processing test example 0
# Processing test example 1
# Processing test example 2
# Processing test example 3
# Processing test example 4
# Processing test example 5
# Processing test example 6
# Processing test example 7
# Processing test example 8
# Processing test example 9
# Processing test example 10
# Processing test example 11
# Processing test example 12
# Processing test example 13
# Processing test example 14
# Processing test example 15
# Processing test example 16
# Processing test example 17
# Processing test example 18
# Processing test example 19
# Processing test example 20
# Processing test example 21
# Processing test example 22
# Processing test example 23
# Processing test example 24
# Processing test example 25
# Processing test example 26
# Processing test example 27
# Processing test example 28
# Processing test example 29
# Processing test example 30
# Processing test example 31
# Processing test example 32
# Processing test example 33
# Processing test example 34
# Processing test example 35
# Processing test example 36
# Processing test example 37
# Processing test example 38
# Processing test example 39
# Processing test example 40
# Processing test example 41
# Processing test example 42
# Processing test example 43
# Processing test example 44
# Processing test example 45
# Processing test example 46
# Processing test example 47
# Processing test example 48
# Processing test example 49
# Processing test example 50
# Processing test example 51
# Processing test example 52
# Processing test example 53
# Processing test example 54
# Processing test example 55
# Processing test example 56
# Processing test example 57
# Processing test example 58
# Processing test example 59
# Processing test example 60
# Processing test example 61
# Processing test example 62
# Processing test example 63
# Processing test example 64
# Processing test example 65
# Processing test example 66
# Processing test example 67
# Processing test example 68
# Processing test example 69
# Processing test example 70
# Processing test example 71
# Processing test example 72
# Processing test example 73
# Processing test example 74
# Processing test example 75
# Processing test example 76
# Processing test example 77
# Processing test example 78
# Processing test example 79
# Processing test example 80
# Processing test example 81
# Processing test example 82
# Processing test example 83
# Processing test example 84
# Processing test example 85
# Processing test example 86
# Processing test example 87
# Processing test example 88
# Processing test example 89
# Processing test example 90
# Processing test example 91
# Processing test example 92
# Processing test example 93
# Processing test example 94
# Processing test example 95
# Processing test example 96
# Processing test example 97
# Processing test example 98
# Processing test example 99
# Processing test example 100
# Processing test example 101
# Processing test example 102
# Processing test example 103
# Processing test example 104
# Processing test example 105
# Processing test example 106
# Processing test example 107
# Processing test example 108
# Processing test example 109
# Processing test example 110
# Processing test example 111
# Processing test example 112
# Processing test example 113
# Processing test example 114
# Processing test example 115
# Processing test example 116
# Processing test example 117
# Processing test example 118
# Processing test example 119
# Processing test example 120
# Processing test example 121
# Processing test example 122
# Processing test example 123
# Processing test example 124
# Processing test example 125
# Processing test example 126
# Processing test example 127
# Processing test example 128
# Processing test example 129
# Processing test example 130
# Processing test example 131
# Processing test example 132
# Processing test example 133
# Processing test example 134
# Processing test example 135
# Processing test example 136
# Processing test example 137
# Processing test example 138
# Processing test example 139
# Processing test example 140
# Processing test example 141
# Processing test example 142
# Processing test example 143
# Processing test example 144
# Processing test example 145
# Processing test example 146
# Processing test example 147
# Processing test example 148
# Processing test example 149
# Processing test example 150
# Processing test example 151
# Processing test example 152
# Processing test example 153
# Processing test example 154
# Processing test example 155
# Processing test example 156
# Processing test example 157
# Processing test example 158
# Processing test example 159
# Processing test example 160
# Processing test example 161
# Processing test example 162
# Processing test example 163
# Processing test example 164
# Processing test example 165
# Processing test example 166
# Processing test example 167
# Processing test example 168
# Processing test example 169
# Processing test example 170
# Processing test example 171
# Processing test example 172
# Processing test example 173
# Processing test example 174
# Processing test example 175
# Processing test example 176
# Processing test example 177
# Processing test example 178
# Processing test example 179
# Processing test example 180
# Processing test example 181
# Processing test example 182
# Processing test example 183
# Processing test example 184
# Processing test example 185
# Processing test example 186
# Processing test example 187
# Processing test example 188
# Processing test example 189
# Processing test example 190
# Processing test example 191
# Processing test example 192
# Processing test example 193
# Processing test example 194
# Processing test example 195
# Processing test example 196
# Processing test example 197
# Processing test example 198
# Processing test example 199
# Processing test example 200
# Processing test example 201
# Processing test example 202
# Processing test example 203
# Processing test example 204
# Processing test example 205
# Processing test example 206
# Processing test example 207
# Processing test example 208
# Processing test example 209
# Processing test example 210
# Processing test example 211
# Processing test example 212
# Processing test example 213
# Processing test example 214
# Processing test example 215
# Processing test example 216
# Processing test example 217
# Processing test example 218
# Processing test example 219
# Processing test example 220
# Processing test example 221
# Processing test example 222
# Processing test example 223
# Processing test example 224
# Processing test example 225
# Processing test example 226
# Processing test example 227
# Processing test example 228
# Processing test example 229
# Processing test example 230
# Processing test example 231
# Processing test example 232
# Processing test example 233
# Processing test example 234
# Processing test example 235
# Processing test example 236
# Processing test example 237
# Processing test example 238
# Processing test example 239
# Processing test example 240
# Processing test example 241
# Processing test example 242
# Processing test example 243
# Processing test example 244
# Processing test example 245
# Processing test example 246
# Processing test example 247
# Processing test example 248
# Processing test example 249
# Processing test example 250
# Processing test example 251
# Processing test example 252
# Processing test example 253
# Processing test example 254
# Processing test example 255
# Processing test example 256
# Processing test example 257
# Processing test example 258
# Processing test example 259
# Processing test example 260
# Processing test example 261
# Processing test example 262
# Processing test example 263
# Processing test example 264
# Processing test example 265
# Processing test example 266
# Processing test example 267
# Processing test example 268
# Processing test example 269
# Processing test example 270
# Processing test example 271
# Processing test example 272
# Processing test example 273
# Processing test example 274
# Processing test example 275
# Processing test example 276
# Processing test example 277
# Processing test example 278
# Processing test example 279
# Processing test example 280
# Processing test example 281
# Processing test example 282
# Processing test example 283
# Processing test example 284
# Processing test example 285
# Processing test example 286
# Processing test example 287
# Processing test example 288
# Processing test example 289
# Processing test example 290
# Processing test example 291
# Processing test example 292
# Processing test example 293
# Processing test example 294
# Processing test example 295
# Processing test example 296
# Processing test example 297
# Processing test example 298
# Processing test example 299
# Processing test example 300
# Processing test example 301
# Processing test example 302
# Processing test example 303
# Processing test example 304
# Processing test example 305
# Processing test example 306
# Processing test example 307
# Processing test example 308
# Processing test example 309
# Processing test example 310
# Processing test example 311
# Processing test example 312
# Processing test example 313
# Processing test example 314
# Processing test example 315
# Processing test example 316
# Processing test example 317
# Processing test example 318
# Processing test example 319
# Processing test example 320
# Processing test example 321
# Processing test example 322
# Processing test example 323
# Processing test example 324
# Processing test example 325
# Processing test example 326
# Processing test example 327
# Processing test example 328
# Processing test example 329
# Processing test example 330
# Processing test example 331
# Processing test example 332
# Processing test example 333
# Processing test example 334
# Processing test example 335
# Processing test example 336
# Processing test example 337
# Processing test example 338
# Processing test example 339
# Processing test example 340
# Processing test example 341
# Processing test example 342
# Processing test example 343
# Processing test example 344
# Processing test example 345
# Processing test example 346
# Processing test example 347
# Processing test example 348
# Processing test example 349
# Processing test example 350
# Processing test example 351
# Processing test example 352
# Processing test example 353
# Processing test example 354
# Processing test example 355
# Processing test example 356
# Processing test example 357
# Processing test example 358
# Processing test example 359
# Processing test example 360
# Processing test example 361
# Processing test example 362
# Processing test example 363
# Processing test example 364
# Processing test example 365
# Processing test example 366
# Processing test example 367
# Processing test example 368
# Processing test example 369
# Processing test example 370
# Processing test example 371
# Processing test example 372
# Processing test example 373
# Processing test example 374
# Processing test example 375
# Processing test example 376
# Processing test example 377
# Processing test example 378
# Processing test example 379
# Processing test example 380
# Processing test example 381
# Processing test example 382
# Processing test example 383
# Processing test example 384
# Processing test example 385
# Processing test example 386
# Processing test example 387
# Processing test example 388
# Processing test example 389
# Processing test example 390
# Processing test example 391
# Processing test example 392
# Processing test example 393
# Processing test example 394
# Processing test example 395
# Processing test example 396
# Processing test example 397
# Processing test example 398
# Processing test example 399
# Processing test example 400
# Processing test example 401
# Processing test example 402
# Processing test example 403
# Processing test example 404
# Processing test example 405
# Processing test example 406
# Processing test example 407
# Processing test example 408
# Processing test example 409
# Processing test example 410
# Processing test example 411
# Processing test example 412
# Processing test example 413
# Processing test example 414
# Processing test example 415
# Processing test example 416
# Processing test example 417
# Processing test example 418
# Processing test example 419
# Processing test example 420
# Processing test example 421
# Processing test example 422
# Processing test example 423
# Processing test example 424
# Processing test example 425
# Processing test example 426
# Processing test example 427
# Processing test example 428
# Processing test example 429
# Processing test example 430
# Processing test example 431
# Processing test example 432
# Processing test example 433
# Processing test example 434
# Processing test example 435
# Processing test example 436
# Processing test example 437
# Processing test example 438
# Processing test example 439
# Processing test example 440
# Processing test example 441
# Processing test example 442
# Processing test example 443
# Processing test example 444
# Processing test example 445
# Processing test example 446
# Processing test example 447
# Processing test example 448
# Processing test example 449
# Processing test example 450
# Processing test example 451
# Processing test example 452
# Processing test example 453
# Processing test example 454
# Processing test example 455
# Processing test example 456
# Processing test example 457
# Processing test example 458
# Processing test example 459
# Processing test example 460
# Processing test example 461
# Processing test example 462
# Processing test example 463
# Processing test example 464
# Processing test example 465
# Processing test example 466
# Processing test example 467
# Processing test example 468
# Processing test example 469
# Processing test example 470
# Processing test example 471
# Processing test example 472
# Processing test example 473
# Processing test example 474
# Processing test example 475
# Processing test example 476
# Processing test example 477
# Processing test example 478
# Processing test example 479
# Processing test example 480
# Processing test example 481
# Processing test example 482
# Processing test example 483
# Processing test example 484
# Processing test example 485
# Processing test example 486
# Processing test example 487
# Processing test example 488
# Processing test example 489
# Processing test example 490
# Processing test example 491
# Processing test example 492
# Processing test example 493
# Processing test example 494
# Processing test example 495
# Processing test example 496
# Processing test example 497
# Processing test example 498
# Processing test example 499
# Processing test example 500
# Processing test example 501
# Processing test example 502
# Processing test example 503
# Processing test example 504
# Processing test example 505
# Processing test example 506
# Processing test example 507
# Processing test example 508
# Processing test example 509
# Processing test example 510
# Processing test example 511
# Processing test example 512
# Processing test example 513
# Processing test example 514
# Processing test example 515
# Processing test example 516
# Processing test example 517
# Processing test example 518
# Processing test example 519
# Processing test example 520
# Processing test example 521
# Processing test example 522
# Processing test example 523
# Processing test example 524
# Processing test example 525
# Processing test example 526
# Processing test example 527
# Processing test example 528
# Processing test example 529
# Processing test example 530
# Processing test example 531
# Processing test example 532
# Processing test example 533
# Processing test example 534
# Processing test example 535
# Processing test example 536
# Processing test example 537
# Processing test example 538
# Processing test example 539
# Processing test example 540
# Processing test example 541
# Processing test example 542
# Processing test example 543
# Processing test example 544
# Processing test example 545
# Processing test example 546
# Processing test example 547
# Processing test example 548
# Processing test example 549
# Processing test example 550
# Processing test example 551
# Processing test example 552
# Processing test example 553
# Processing test example 554
# Processing test example 555
# Processing test example 556
# Processing test example 557
# Processing test example 558
# Processing test example 559
# Processing test example 560
# Processing test example 561
# Processing test example 562
# Processing test example 563
# Processing test example 564
# Processing test example 565
# Processing test example 566
# Processing test example 567
# Processing test example 568
# Processing test example 569
# Processing test example 570
# Processing test example 571
# Processing test example 572
# Processing test example 573
# Processing test example 574
# Processing test example 575
# Processing test example 576
# Processing test example 577
# Processing test example 578
# Processing test example 579
# Processing test example 580
# Processing test example 581
# Processing test example 582
# Processing test example 583
# Processing test example 584
# Processing test example 585
# Processing test example 586
# Processing test example 587
# Processing test example 588
# Processing test example 589
# Processing test example 590
# Processing test example 591
# Processing test example 592
# Processing test example 593
# Processing test example 594
# Processing test example 595
# Processing test example 596
# Processing test example 597
# Processing test example 598
# Processing test example 599
# Processing test example 600
# Processing test example 601
# Processing test example 602
# Processing test example 603
# Processing test example 604
# Processing test example 605
# Processing test example 606
# Processing test example 607
# Processing test example 608
# Processing test example 609
# Processing test example 610
# Processing test example 611
# Processing test example 612
# Processing test example 613
# Processing test example 614
# Processing test example 615
# Processing test example 616
# Processing test example 617
# Processing test example 618
# Processing test example 619
# Processing test example 620
# Processing test example 621
# Processing test example 622
# Processing test example 623
# Processing test example 624
# Processing test example 625
# Processing test example 626
# Processing test example 627
# Processing test example 628
# Processing test example 629
# Processing test example 630
# Processing test example 631
# Processing test example 632
# Processing test example 633
# Processing test example 634
# Processing test example 635
# Processing test example 636
# Processing test example 637
# Processing test example 638
# Processing test example 639
# Processing test example 640
# Processing test example 641
# Processing test example 642
# Processing test example 643
# Processing test example 644
# Processing test example 645
# Processing test example 646
# Processing test example 647
# Processing test example 648
# Processing test example 649
# Processing test example 650
# Processing test example 651
# Processing test example 652
# Processing test example 653
# Processing test example 654
# Processing test example 655
# Processing test example 656
# Processing test example 657
# Processing test example 658
# Processing test example 659
# Processing test example 660
# Processing test example 661
# Processing test example 662
# Processing test example 663
# Processing test example 664
# Processing test example 665
# Processing test example 666
# Processing test example 667
# Processing test example 668
# Processing test example 669
# Processing test example 670
# Processing test example 671
# Processing test example 672
# Processing test example 673
# Processing test example 674
# Processing test example 675
# Processing test example 676
# Processing test example 677
# Processing test example 678
# Processing test example 679
# Processing test example 680
# Processing test example 681
# Processing test example 682
# Processing test example 683
# Processing test example 684
# Processing test example 685
# Processing test example 686
# Processing test example 687
# Processing test example 688
# Processing test example 689
# Processing test example 690
# Processing test example 691
# Processing test example 692
# Processing test example 693
# Processing test example 694
# Processing test example 695
# Processing test example 696
# Processing test example 697
# Processing test example 698
# Processing test example 699
# Processing test example 700
# Processing test example 701
# Processing test example 702
# Processing test example 703
# Processing test example 704
# Processing test example 705
# Processing test example 706
# Processing test example 707
# Processing test example 708
# Processing test example 709
# Processing test example 710
# Processing test example 711
# Processing test example 712
# Processing test example 713
# Processing test example 714
# Processing test example 715
# Processing test example 716
# Processing test example 717
# Processing test example 718
# Processing test example 719
# Processing test example 720
# Processing test example 721
# Processing test example 722
# Processing test example 723
# Processing test example 724
# Processing test example 725
# Processing test example 726
# Processing test example 727
# Processing test example 728
# Processing test example 729
# Processing test example 730
# Processing test example 731
# Processing test example 732
# Processing test example 733
# Processing test example 734
# Processing test example 735
# Processing test example 736
# Processing test example 737
# Processing test example 738
# Processing test example 739
# Processing test example 740
# Processing test example 741
# Processing test example 742
# Processing test example 743
# Processing test example 744
# Processing test example 745
# Processing test example 746
# Processing test example 747
# Processing test example 748
# Processing test example 749
# Processing test example 750
# Processing test example 751
# Processing test example 752
# Processing test example 753
# Processing test example 754
# Processing test example 755
# Processing test example 756
# Processing test example 757
# Processing test example 758
# Processing test example 759
# Processing test example 760
# Processing test example 761
# Processing test example 762
# Processing test example 763
# Processing test example 764
# Processing test example 765
# Processing test example 766
# Processing test example 767
# Processing test example 768
# Processing test example 769
# Processing test example 770
# Processing test example 771
# Processing test example 772
# Processing test example 773
# Processing test example 774
# Processing test example 775
# Processing test example 776
# Processing test example 777
# Processing test example 778
# Processing test example 779
# Processing test example 780
# Processing test example 781
# Processing test example 782
# Processing test example 783
# Processing test example 784
# Processing test example 785
# Processing test example 786
# Processing test example 787
# Processing test example 788
# Processing test example 789
# Processing test example 790
# Processing test example 791
# Processing test example 792
# Processing test example 793
# Processing test example 794
# Processing test example 795
# Processing test example 796
# Processing test example 797
# Processing test example 798
# Processing test example 799
# Processing test example 800
# Processing test example 801
# Processing test example 802
# Processing test example 803
# Processing test example 804
# Processing test example 805
# Processing test example 806
# Processing test example 807
# Processing test example 808
# Processing test example 809
# Processing test example 810
# Processing test example 811
# True Positive: 20
# False Positive: 24
# True Negative: 778
# False Negative: 2
# Precision: 0.45454545454545453
# Recall: 0.9090909090909091
# F1 Score: 0.6060606060606061
# Accuracy Score: 0.9684466019417476
# Confusion Matrix:
# [[778, 24], [2, 20]]
# Processing n-gram range: (1, 2)
# Processing test example 0
# Processing test example 1
# Processing test example 2
# Processing test example 3
# Processing test example 4
# Processing test example 5
# Processing test example 6
# Processing test example 7
# Processing test example 8
# Processing test example 9
# Processing test example 10
# Processing test example 11
# Processing test example 12
# Processing test example 13
# Processing test example 14
# Processing test example 15
# Processing test example 16
# Processing test example 17
# Processing test example 18
# Processing test example 19
# Processing test example 20
# Processing test example 21
# Processing test example 22
# Processing test example 23
# Processing test example 24
# Processing test example 25
# Processing test example 26
# Processing test example 27
# Processing test example 28
# Processing test example 29
# Processing test example 30
# Processing test example 31
# Processing test example 32
# Processing test example 33
# Processing test example 34
# Processing test example 35
# Processing test example 36
# Processing test example 37
# Processing test example 38
# Processing test example 39
# Processing test example 40
# Processing test example 41
# Processing test example 42
# Processing test example 43
# Processing test example 44
# Processing test example 45
# Processing test example 46
# Processing test example 47
# Processing test example 48
# Processing test example 49
# Processing test example 50
# Processing test example 51
# Processing test example 52
# Processing test example 53
# Processing test example 54
# Processing test example 55
# Processing test example 56
# Processing test example 57
# Processing test example 58
# Processing test example 59
# Processing test example 60
# Processing test example 61
# Processing test example 62
# Processing test example 63
# Processing test example 64
# Processing test example 65
# Processing test example 66
# Processing test example 67
# Processing test example 68
# Processing test example 69
# Processing test example 70
# Processing test example 71
# Processing test example 72
# Processing test example 73
# Processing test example 74
# Processing test example 75
# Processing test example 76
# Processing test example 77
# Processing test example 78
# Processing test example 79
# Processing test example 80
# Processing test example 81
# Processing test example 82
# Processing test example 83
# Processing test example 84
# Processing test example 85
# Processing test example 86
# Processing test example 87
# Processing test example 88
# Processing test example 89
# Processing test example 90
# Processing test example 91
# Processing test example 92
# Processing test example 93
# Processing test example 94
# Processing test example 95
# Processing test example 96
# Processing test example 97
# Processing test example 98
# Processing test example 99
# Processing test example 100
# Processing test example 101
# Processing test example 102
# Processing test example 103
# Processing test example 104
# Processing test example 105
# Processing test example 106
# Processing test example 107
# Processing test example 108
# Processing test example 109
# Processing test example 110
# Processing test example 111
# Processing test example 112
# Processing test example 113
# Processing test example 114
# Processing test example 115
# Processing test example 116
# Processing test example 117
# Processing test example 118
# Processing test example 119
# Processing test example 120
# Processing test example 121
# Processing test example 122
# Processing test example 123
# Processing test example 124
# Processing test example 125
# Processing test example 126
# Processing test example 127
# Processing test example 128
# Processing test example 129
# Processing test example 130
# Processing test example 131
# Processing test example 132
# Processing test example 133
# Processing test example 134
# Processing test example 135
# Processing test example 136
# Processing test example 137
# Processing test example 138
# Processing test example 139
# Processing test example 140
# Processing test example 141
# Processing test example 142
# Processing test example 143
# Processing test example 144
# Processing test example 145
# Processing test example 146
# Processing test example 147
# Processing test example 148
# Processing test example 149
# Processing test example 150
# Processing test example 151
# Processing test example 152
# Processing test example 153
# Processing test example 154
# Processing test example 155
# Processing test example 156
# Processing test example 157
# Processing test example 158
# Processing test example 159
# Processing test example 160
# Processing test example 161
# Processing test example 162
# Processing test example 163
# Processing test example 164
# Processing test example 165
# Processing test example 166
# Processing test example 167
# Processing test example 168
# Processing test example 169
# Processing test example 170
# Processing test example 171
# Processing test example 172
# Processing test example 173
# Processing test example 174
# Processing test example 175
# Processing test example 176
# Processing test example 177
# Processing test example 178
# Processing test example 179
# Processing test example 180
# Processing test example 181
# Processing test example 182
# Processing test example 183
# Processing test example 184
# Processing test example 185
# Processing test example 186
# Processing test example 187
# Processing test example 188
# Processing test example 189
# Processing test example 190
# Processing test example 191
# Processing test example 192
# Processing test example 193
# Processing test example 194
# Processing test example 195
# Processing test example 196
# Processing test example 197
# Processing test example 198
# Processing test example 199
# Processing test example 200
# Processing test example 201
# Processing test example 202
# Processing test example 203
# Processing test example 204
# Processing test example 205
# Processing test example 206
# Processing test example 207
# Processing test example 208
# Processing test example 209
# Processing test example 210
# Processing test example 211
# Processing test example 212
# Processing test example 213
# Processing test example 214
# Processing test example 215
# Processing test example 216
# Processing test example 217
# Processing test example 218
# Processing test example 219
# Processing test example 220
# Processing test example 221
# Processing test example 222
# Processing test example 223
# Processing test example 224
# Processing test example 225
# Processing test example 226
# Processing test example 227
# Processing test example 228
# Processing test example 229
# Processing test example 230
# Processing test example 231
# Processing test example 232
# Processing test example 233
# Processing test example 234
# Processing test example 235
# Processing test example 236
# Processing test example 237
# Processing test example 238
# Processing test example 239
# Processing test example 240
# Processing test example 241
# Processing test example 242
# Processing test example 243
# Processing test example 244
# Processing test example 245
# Processing test example 246
# Processing test example 247
# Processing test example 248
# Processing test example 249
# Processing test example 250
# Processing test example 251
# Processing test example 252
# Processing test example 253
# Processing test example 254
# Processing test example 255
# Processing test example 256
# Processing test example 257
# Processing test example 258
# Processing test example 259
# Processing test example 260
# Processing test example 261
# Processing test example 262
# Processing test example 263
# Processing test example 264
# Processing test example 265
# Processing test example 266
# Processing test example 267
# Processing test example 268
# Processing test example 269
# Processing test example 270
# Processing test example 271
# Processing test example 272
# Processing test example 273
# Processing test example 274
# Processing test example 275
# Processing test example 276
# Processing test example 277
# Processing test example 278
# Processing test example 279
# Processing test example 280
# Processing test example 281
# Processing test example 282
# Processing test example 283
# Processing test example 284
# Processing test example 285
# Processing test example 286
# Processing test example 287
# Processing test example 288
# Processing test example 289
# Processing test example 290
# Processing test example 291
# Processing test example 292
# Processing test example 293
# Processing test example 294
# Processing test example 295
# Processing test example 296
# Processing test example 297
# Processing test example 298
# Processing test example 299
# Processing test example 300
# Processing test example 301
# Processing test example 302
# Processing test example 303
# Processing test example 304
# Processing test example 305
# Processing test example 306
# Processing test example 307
# Processing test example 308
# Processing test example 309
# Processing test example 310
# Processing test example 311
# Processing test example 312
# Processing test example 313
# Processing test example 314
# Processing test example 315
# Processing test example 316
# Processing test example 317
# Processing test example 318
# Processing test example 319
# Processing test example 320
# Processing test example 321
# Processing test example 322
# Processing test example 323
# Processing test example 324
# Processing test example 325
# Processing test example 326
# Processing test example 327
# Processing test example 328
# Processing test example 329
# Processing test example 330
# Processing test example 331
# Processing test example 332
# Processing test example 333
# Processing test example 334
# Processing test example 335
# Processing test example 336
# Processing test example 337
# Processing test example 338
# Processing test example 339
# Processing test example 340
# Processing test example 341
# Processing test example 342
# Processing test example 343
# Processing test example 344
# Processing test example 345
# Processing test example 346
# Processing test example 347
# Processing test example 348
# Processing test example 349
# Processing test example 350
# Processing test example 351
# Processing test example 352
# Processing test example 353
# Processing test example 354
# Processing test example 355
# Processing test example 356
# Processing test example 357
# Processing test example 358
# Processing test example 359
# Processing test example 360
# Processing test example 361
# Processing test example 362
# Processing test example 363
# Processing test example 364
# Processing test example 365
# Processing test example 366
# Processing test example 367
# Processing test example 368
# Processing test example 369
# Processing test example 370
# Processing test example 371
# Processing test example 372
# Processing test example 373
# Processing test example 374
# Processing test example 375
# Processing test example 376
# Processing test example 377
# Processing test example 378
# Processing test example 379
# Processing test example 380
# Processing test example 381
# Processing test example 382
# Processing test example 383
# Processing test example 384
# Processing test example 385
# Processing test example 386
# Processing test example 387
# Processing test example 388
# Processing test example 389
# Processing test example 390
# Processing test example 391
# Processing test example 392
# Processing test example 393
# Processing test example 394
# Processing test example 395
# Processing test example 396
# Processing test example 397
# Processing test example 398
# Processing test example 399
# Processing test example 400
# Processing test example 401
# Processing test example 402
# Processing test example 403
# Processing test example 404
# Processing test example 405
# Processing test example 406
# Processing test example 407
# Processing test example 408
# Processing test example 409
# Processing test example 410
# Processing test example 411
# Processing test example 412
# Processing test example 413
# Processing test example 414
# Processing test example 415
# Processing test example 416
# Processing test example 417
# Processing test example 418
# Processing test example 419
# Processing test example 420
# Processing test example 421
# Processing test example 422
# Processing test example 423
# Processing test example 424
# Processing test example 425
# Processing test example 426
# Processing test example 427
# Processing test example 428
# Processing test example 429
# Processing test example 430
# Processing test example 431
# Processing test example 432
# Processing test example 433
# Processing test example 434
# Processing test example 435
# Processing test example 436
# Processing test example 437
# Processing test example 438
# Processing test example 439
# Processing test example 440
# Processing test example 441
# Processing test example 442
# Processing test example 443
# Processing test example 444
# Processing test example 445
# Processing test example 446
# Processing test example 447
# Processing test example 448
# Processing test example 449
# Processing test example 450
# Processing test example 451
# Processing test example 452
# Processing test example 453
# Processing test example 454
# Processing test example 455
# Processing test example 456
# Processing test example 457
# Processing test example 458
# Processing test example 459
# Processing test example 460
# Processing test example 461
# Processing test example 462
# Processing test example 463
# Processing test example 464
# Processing test example 465
# Processing test example 466
# Processing test example 467
# Processing test example 468
# Processing test example 469
# Processing test example 470
# Processing test example 471
# Processing test example 472
# Processing test example 473
# Processing test example 474
# Processing test example 475
# Processing test example 476
# Processing test example 477
# Processing test example 478
# Processing test example 479
# Processing test example 480
# Processing test example 481
# Processing test example 482
# Processing test example 483
# Processing test example 484
# Processing test example 485
# Processing test example 486
# Processing test example 487
# Processing test example 488
# Processing test example 489
# Processing test example 490
# Processing test example 491
# Processing test example 492
# Processing test example 493
# Processing test example 494
# Processing test example 495
# Processing test example 496
# Processing test example 497
# Processing test example 498
# Processing test example 499
# Processing test example 500
# Processing test example 501
# Processing test example 502
# Processing test example 503
# Processing test example 504
# Processing test example 505
# Processing test example 506
# Processing test example 507
# Processing test example 508
# Processing test example 509
# Processing test example 510
# Processing test example 511
# Processing test example 512
# Processing test example 513
# Processing test example 514
# Processing test example 515
# Processing test example 516
# Processing test example 517
# Processing test example 518
# Processing test example 519
# Processing test example 520
# Processing test example 521
# Processing test example 522
# Processing test example 523
# Processing test example 524
# Processing test example 525
# Processing test example 526
# Processing test example 527
# Processing test example 528
# Processing test example 529
# Processing test example 530
# Processing test example 531
# Processing test example 532
# Processing test example 533
# Processing test example 534
# Processing test example 535
# Processing test example 536
# Processing test example 537
# Processing test example 538
# Processing test example 539
# Processing test example 540
# Processing test example 541
# Processing test example 542
# Processing test example 543
# Processing test example 544
# Processing test example 545
# Processing test example 546
# Processing test example 547
# Processing test example 548
# Processing test example 549
# Processing test example 550
# Processing test example 551
# Processing test example 552
# Processing test example 553
# Processing test example 554
# Processing test example 555
# Processing test example 556
# Processing test example 557
# Processing test example 558
# Processing test example 559
# Processing test example 560
# Processing test example 561
# Processing test example 562
# Processing test example 563
# Processing test example 564
# Processing test example 565
# Processing test example 566
# Processing test example 567
# Processing test example 568
# Processing test example 569
# Processing test example 570
# Processing test example 571
# Processing test example 572
# Processing test example 573
# Processing test example 574
# Processing test example 575
# Processing test example 576
# Processing test example 577
# Processing test example 578
# Processing test example 579
# Processing test example 580
# Processing test example 581
# Processing test example 582
# Processing test example 583
# Processing test example 584
# Processing test example 585
# Processing test example 586
# Processing test example 587
# Processing test example 588
# Processing test example 589
# Processing test example 590
# Processing test example 591
# Processing test example 592
# Processing test example 593
# Processing test example 594
# Processing test example 595
# Processing test example 596
# Processing test example 597
# Processing test example 598
# Processing test example 599
# Processing test example 600
# Processing test example 601
# Processing test example 602
# Processing test example 603
# Processing test example 604
# Processing test example 605
# Processing test example 606
# Processing test example 607
# Processing test example 608
# Processing test example 609
# Processing test example 610
# Processing test example 611
# Processing test example 612
# Processing test example 613
# Processing test example 614
# Processing test example 615
# Processing test example 616
# Processing test example 617
# Processing test example 618
# Processing test example 619
# Processing test example 620
# Processing test example 621
# Processing test example 622
# Processing test example 623
# Processing test example 624
# Processing test example 625
# Processing test example 626
# Processing test example 627
# Processing test example 628
# Processing test example 629
# Processing test example 630
# Processing test example 631
# Processing test example 632
# Processing test example 633
# Processing test example 634
# Processing test example 635
# Processing test example 636
# Processing test example 637
# Processing test example 638
# Processing test example 639
# Processing test example 640
# Processing test example 641
# Processing test example 642
# Processing test example 643
# Processing test example 644
# Processing test example 645
# Processing test example 646
# Processing test example 647
# Processing test example 648
# Processing test example 649
# Processing test example 650
# Processing test example 651
# Processing test example 652
# Processing test example 653
# Processing test example 654
# Processing test example 655
# Processing test example 656
# Processing test example 657
# Processing test example 658
# Processing test example 659
# Processing test example 660
# Processing test example 661
# Processing test example 662
# Processing test example 663
# Processing test example 664
# Processing test example 665
# Processing test example 666
# Processing test example 667
# Processing test example 668
# Processing test example 669
# Processing test example 670
# Processing test example 671
# Processing test example 672
# Processing test example 673
# Processing test example 674
# Processing test example 675
# Processing test example 676
# Processing test example 677
# Processing test example 678
# Processing test example 679
# Processing test example 680
# Processing test example 681
# Processing test example 682
# Processing test example 683
# Processing test example 684
# Processing test example 685
# Processing test example 686
# Processing test example 687
# Processing test example 688
# Processing test example 689
# Processing test example 690
# Processing test example 691
# Processing test example 692
# Processing test example 693
# Processing test example 694
# Processing test example 695
# Processing test example 696
# Processing test example 697
# Processing test example 698
# Processing test example 699
# Processing test example 700
# Processing test example 701
# Processing test example 702
# Processing test example 703
# Processing test example 704
# Processing test example 705
# Processing test example 706
# Processing test example 707
# Processing test example 708
# Processing test example 709
# Processing test example 710
# Processing test example 711
# Processing test example 712
# Processing test example 713
# Processing test example 714
# Processing test example 715
# Processing test example 716
# Processing test example 717
# Processing test example 718
# Processing test example 719
# Processing test example 720
# Processing test example 721
# Processing test example 722
# Processing test example 723
# Processing test example 724
# Processing test example 725
# Processing test example 726
# Processing test example 727
# Processing test example 728
# Processing test example 729
# Processing test example 730
# Processing test example 731
# Processing test example 732
# Processing test example 733
# Processing test example 734
# Processing test example 735
# Processing test example 736
# Processing test example 737
# Processing test example 738
# Processing test example 739
# Processing test example 740
# Processing test example 741
# Processing test example 742
# Processing test example 743
# Processing test example 744
# Processing test example 745
# Processing test example 746
# Processing test example 747
# Processing test example 748
# Processing test example 749
# Processing test example 750
# Processing test example 751
# Processing test example 752
# Processing test example 753
# Processing test example 754
# Processing test example 755
# Processing test example 756
# Processing test example 757
# Processing test example 758
# Processing test example 759
# Processing test example 760
# Processing test example 761
# Processing test example 762
# Processing test example 763
# Processing test example 764
# Processing test example 765
# Processing test example 766
# Processing test example 767
# Processing test example 768
# Processing test example 769
# Processing test example 770
# Processing test example 771
# Processing test example 772
# Processing test example 773
# Processing test example 774
# Processing test example 775
# Processing test example 776
# Processing test example 777
# Processing test example 778
# Processing test example 779
# Processing test example 780
# Processing test example 781
# Processing test example 782
# Processing test example 783
# Processing test example 784
# Processing test example 785
# Processing test example 786
# Processing test example 787
# Processing test example 788
# Processing test example 789
# Processing test example 790
# Processing test example 791
# Processing test example 792
# Processing test example 793
# Processing test example 794
# Processing test example 795
# Processing test example 796
# Processing test example 797
# Processing test example 798
# Processing test example 799
# Processing test example 800
# Processing test example 801
# Processing test example 802
# Processing test example 803
# Processing test example 804
# Processing test example 805
# Processing test example 806
# Processing test example 807
# Processing test example 808
# Processing test example 809
# Processing test example 810
# Processing test example 811
# True Positive: 18
# False Positive: 19
# True Negative: 783
# False Negative: 4
# Precision: 0.4864864864864865
# Recall: 0.8181818181818182
# F1 Score: 0.6101694915254238
# Accuracy Score: 0.9720873786407767
# Confusion Matrix:
# [[783, 19], [4, 18]]
# Processing n-gram range: (1, 3)
# Processing test example 0
# Processing test example 1
# Processing test example 2
# Processing test example 3
# Processing test example 4
# Processing test example 5
# Processing test example 6
# Processing test example 7
# Processing test example 8
# Processing test example 9
# Processing test example 10
# Processing test example 11
# Processing test example 12
# Processing test example 13
# Processing test example 14
# Processing test example 15
# Processing test example 16
# Processing test example 17
# Processing test example 18
# Processing test example 19
# Processing test example 20
# Processing test example 21
# Processing test example 22
# Processing test example 23
# Processing test example 24
# Processing test example 25
# Processing test example 26
# Processing test example 27
# Processing test example 28
# Processing test example 29
# Processing test example 30
# Processing test example 31
# Processing test example 32
# Processing test example 33
# Processing test example 34
# Processing test example 35
# Processing test example 36
# Processing test example 37
# Processing test example 38
# Processing test example 39
# Processing test example 40
# Processing test example 41
# Processing test example 42
# Processing test example 43
# Processing test example 44
# Processing test example 45
# Processing test example 46
# Processing test example 47
# Processing test example 48
# Processing test example 49
# Processing test example 50
# Processing test example 51
# Processing test example 52
# Processing test example 53
# Processing test example 54
# Processing test example 55
# Processing test example 56
# Processing test example 57
# Processing test example 58
# Processing test example 59
# Processing test example 60
# Processing test example 61
# Processing test example 62
# Processing test example 63
# Processing test example 64
# Processing test example 65
# Processing test example 66
# Processing test example 67
# Processing test example 68
# Processing test example 69
# Processing test example 70
# Processing test example 71
# Processing test example 72
# Processing test example 73
# Processing test example 74
# Processing test example 75
# Processing test example 76
# Processing test example 77
# Processing test example 78
# Processing test example 79
# Processing test example 80
# ...
# Processing test example 249
# Processing test example 250
# Processing test example 251
# Processing test example 252
# Processing test example 253
# Processing test example 254
# Processing test example 255
# Processing test example 256
# Processing test example 257
# Processing test example 258
# Processing test example 259
# Processing test example 260
# Processing test example 261
# Processing test example 262
# Processing test example 263
# Processing test example 264
# Processing test example 265
# Processing test example 266
# Processing test example 267
# Processing test example 268
# Processing test example 269
# Processing test example 270
# Processing test example 271
# Processing test example 272
# Processing test example 273
# Processing test example 274
# Processing test example 275
# Processing test example 276
# Processing test example 277
# Processing test example 278
# Processing test example 279
# Processing test example 280
# Processing test example 281
# Processing test example 282
# Processing test example 283
# Processing test example 284
# Processing test example 285
# Processing test example 286
# Processing test example 287
# Processing test example 288
# Processing test example 289
# Processing test example 290
# Processing test example 291
# Processing test example 292
# Processing test example 293
# Processing test example 294
# Processing test example 295
# Processing test example 296
# Processing test example 297
# Processing test example 298
# Processing test example 299
# Processing test example 300
# Processing test example 301
# Processing test example 302
# Processing test example 303
# Processing test example 304
# Processing test example 305
# Processing test example 306
# Processing test example 307
# Processing test example 308
# Processing test example 309
# Processing test example 310
# Processing test example 311
# Processing test example 312
# Processing test example 313
# Processing test example 314
# Processing test example 315
# Processing test example 316
# Processing test example 317
# Processing test example 318
# Processing test example 319
# Processing test example 320
# Processing test example 321
# Processing test example 322
# Processing test example 323
# Processing test example 324
# Processing test example 325
# Processing test example 326
# Processing test example 327
# Processing test example 328
# Processing test example 329
# Processing test example 330
# Processing test example 331
# Processing test example 332
# Processing test example 333
# Processing test example 334
# Processing test example 335
# Processing test example 336
# Processing test example 337
# Processing test example 338
# Processing test example 339
# Processing test example 340
# Processing test example 341
# Processing test example 342
# Processing test example 343
# Processing test example 344
# Processing test example 345
# Processing test example 346
# Processing test example 347
# Processing test example 348
# Processing test example 349
# Processing test example 350
# Processing test example 351
# Processing test example 352
# Processing test example 353
# Processing test example 354
# Processing test example 355
# Processing test example 356
# Processing test example 357
# Processing test example 358
# Processing test example 359
# Processing test example 360
# Processing test example 361
# Processing test example 362
# Processing test example 363
# Processing test example 364
# Processing test example 365
# Processing test example 366
# Processing test example 367
# Processing test example 368
# Processing test example 369
# Processing test example 370
# Processing test example 371
# Processing test example 372
# Processing test example 373
# Processing test example 374
# Processing test example 375
# Processing test example 376
# Processing test example 377
# Processing test example 378
# Processing test example 379
# Processing test example 380
# Processing test example 381
# Processing test example 382
# Processing test example 383
# Processing test example 384
# Processing test example 385
# Processing test example 386
# Processing test example 387
# Processing test example 388
# Processing test example 389
# Processing test example 390
# Processing test example 391
# Processing test example 392
# Processing test example 393
# Processing test example 394
# Processing test example 395
# Processing test example 396
# Processing test example 397
# Processing test example 398
# Processing test example 399
# Processing test example 400
# Processing test example 401
# Processing test example 402
# Processing test example 403
# Processing test example 404
# Processing test example 405
# Processing test example 406
# Processing test example 407
# Processing test example 408
# Processing test example 409
# Processing test example 410
# Processing test example 411
# Processing test example 412
# Processing test example 413
# Processing test example 414
# Processing test example 415
# Processing test example 416
# Processing test example 417
# Processing test example 418
# Processing test example 419
# Processing test example 420
# Processing test example 421
# Processing test example 422
# Processing test example 423
# Processing test example 424
# Processing test example 425
# Processing test example 426
# Processing test example 427
# Processing test example 428
# Processing test example 429
# Processing test example 430
# Processing test example 431
# Processing test example 432
# Processing test example 433
# Processing test example 434
# Processing test example 435
# Processing test example 436
# Processing test example 437
# Processing test example 438
# Processing test example 439
# Processing test example 440
# Processing test example 441
# Processing test example 442
# Processing test example 443
# Processing test example 444
# Processing test example 445
# Processing test example 446
# Processing test example 447
# Processing test example 448
# Processing test example 449
# Processing test example 450
# Processing test example 451
# Processing test example 452
# Processing test example 453
# Processing test example 454
# Processing test example 455
# Processing test example 456
# Processing test example 457
# Processing test example 458
# Processing test example 459
# Processing test example 460
# Processing test example 461
# Processing test example 462
# Processing test example 463
# Processing test example 464
# Processing test example 465
# Processing test example 466
# Processing test example 467
# Processing test example 468
# Processing test example 469
# Processing test example 470
# Processing test example 471
# Processing test example 472
# Processing test example 473
# Processing test example 474
# Processing test example 475
# Processing test example 476
# Processing test example 477
# Processing test example 478
# Processing test example 479
# Processing test example 480
# Processing test example 481
# Processing test example 482
# Processing test example 483
# Processing test example 484
# Processing test example 485
# Processing test example 486
# Processing test example 487
# Processing test example 488
# Processing test example 489
# Processing test example 490
# Processing test example 491
# Processing test example 492
# Processing test example 493
# Processing test example 494
# Processing test example 495
# Processing test example 496
# Processing test example 497
# Processing test example 498
# Processing test example 499
# Processing test example 500
# Processing test example 501
# Processing test example 502
# Processing test example 503
# Processing test example 504
# Processing test example 505
# Processing test example 506
# Processing test example 507
# Processing test example 508
# Processing test example 509
# Processing test example 510
# Processing test example 511
# Processing test example 512
# Processing test example 513
# Processing test example 514
# Processing test example 515
# Processing test example 516
# Processing test example 517
# Processing test example 518
# Processing test example 519
# Processing test example 520
# Processing test example 521
# Processing test example 522
# Processing test example 523
# Processing test example 524
# Processing test example 525
# Processing test example 526
# Processing test example 527
# Processing test example 528
# Processing test example 529
# Processing test example 530
# Processing test example 531
# Processing test example 532
# Processing test example 533
# Processing test example 534
# Processing test example 535
# Processing test example 536
# Processing test example 537
# Processing test example 538
# Processing test example 539
# Processing test example 540
# Processing test example 541
# Processing test example 542
# Processing test example 543
# Processing test example 544
# Processing test example 545
# Processing test example 546
# Processing test example 547
# Processing test example 548
# Processing test example 549
# Processing test example 550
# Processing test example 551
# Processing test example 552
# Processing test example 553
# Processing test example 554
# Processing test example 555
# Processing test example 556
# Processing test example 557
# Processing test example 558
# Processing test example 559
# Processing test example 560
# Processing test example 561
# Processing test example 562
# Processing test example 563
# Processing test example 564
# Processing test example 565
# Processing test example 566
# Processing test example 567
# Processing test example 568
# Processing test example 569
# Processing test example 570
# Processing test example 571
# Processing test example 572
# Processing test example 573
# Processing test example 574
# Processing test example 575
# Processing test example 576
# Processing test example 577
# Processing test example 578
# Processing test example 579
# Processing test example 580
# Processing test example 581
# Processing test example 582
# Processing test example 583
# Processing test example 584
# Processing test example 585
# Processing test example 586
# Processing test example 587
# Processing test example 588
# Processing test example 589
# Processing test example 590
# Processing test example 591
# Processing test example 592
# Processing test example 593
# Processing test example 594
# Processing test example 595
# Processing test example 596
# Processing test example 597
# Processing test example 598
# Processing test example 599
# Processing test example 600
# Processing test example 601
# Processing test example 602
# Processing test example 603
# Processing test example 604
# Processing test example 605
# Processing test example 606
# Processing test example 607
# Processing test example 608
# Processing test example 609
# Processing test example 610
# Processing test example 611
# Processing test example 612
# Processing test example 613
# Processing test example 614
# Processing test example 615
# Processing test example 616
# Processing test example 617
# Processing test example 618
# Processing test example 619
# Processing test example 620
# Processing test example 621
# Processing test example 622
# Processing test example 623
# Processing test example 624
# Processing test example 625
# Processing test example 626
# Processing test example 627
# Processing test example 628
# Processing test example 629
# Processing test example 630
# Processing test example 631
# Processing test example 632
# Processing test example 633
# Processing test example 634
# Processing test example 635
# Processing test example 636
# Processing test example 637
# Processing test example 638
# Processing test example 639
# Processing test example 640
# Processing test example 641
# Processing test example 642
# Processing test example 643
# Processing test example 644
# Processing test example 645
# Processing test example 646
# Processing test example 647
# Processing test example 648
# Processing test example 649
# Processing test example 650
# Processing test example 651
# Processing test example 652
# Processing test example 653
# Processing test example 654
# Processing test example 655
# Processing test example 656
# Processing test example 657
# Processing test example 658
# Processing test example 659
# Processing test example 660
# Processing test example 661
# Processing test example 662
# Processing test example 663
# Processing test example 664
# Processing test example 665
# Processing test example 666
# Processing test example 667
# Processing test example 668
# Processing test example 669
# Processing test example 670
# Processing test example 671
# Processing test example 672
# Processing test example 673
# Processing test example 674
# Processing test example 675
# Processing test example 676
# Processing test example 677
# Processing test example 678
# Processing test example 679
# Processing test example 680
# Processing test example 681
# Processing test example 682
# Processing test example 683
# Processing test example 684
# Processing test example 685
# Processing test example 686
# Processing test example 687
# Processing test example 688
# Processing test example 689
# Processing test example 690
# Processing test example 691
# Processing test example 692
# Processing test example 693
# Processing test example 694
# Processing test example 695
# Processing test example 696
# Processing test example 697
# Processing test example 698
# Processing test example 699
# Processing test example 700
# Processing test example 701
# Processing test example 702
# Processing test example 703
# Processing test example 704
# Processing test example 705
# Processing test example 706
# Processing test example 707
# Processing test example 708
# Processing test example 709
# Processing test example 710
# Processing test example 711
# Processing test example 712
# Processing test example 713
# Processing test example 714
# Processing test example 715
# Processing test example 716
# Processing test example 717
# Processing test example 718
# Processing test example 719
# Processing test example 720
# Processing test example 721
# Processing test example 722
# Processing test example 723
# Processing test example 724
# Processing test example 725
# Processing test example 726
# Processing test example 727
# Processing test example 728
# Processing test example 729
# Processing test example 730
# Processing test example 731
# Processing test example 732
# Processing test example 733
# Processing test example 734
# Processing test example 735
# Processing test example 736
# Processing test example 737
# Processing test example 738
# Processing test example 739
# Processing test example 740
# Processing test example 741
# Processing test example 742
# Processing test example 743
# Processing test example 744
# Processing test example 745
# Processing test example 746
# Processing test example 747
# Processing test example 748
# Processing test example 749
# Processing test example 750
# Processing test example 751
# Processing test example 752
# Processing test example 753
# Processing test example 754
# Processing test example 755
# Processing test example 756
# Processing test example 757
# Processing test example 758
# Processing test example 759
# Processing test example 760
# Processing test example 761
# Processing test example 762
# Processing test example 763
# Processing test example 764
# Processing test example 765
# Processing test example 766
# Processing test example 767
# Processing test example 768
# Processing test example 769
# Processing test example 770
# Processing test example 771
# Processing test example 772
# Processing test example 773
# Processing test example 774
# Processing test example 775
# Processing test example 776
# Processing test example 777
# Processing test example 778
# Processing test example 779
# Processing test example 780
# Processing test example 781
# Processing test example 782
# Processing test example 783
# Processing test example 784
# Processing test example 785
# Processing test example 786
# Processing test example 787
# Processing test example 788
# Processing test example 789
# Processing test example 790
# Processing test example 791
# Processing test example 792
# Processing test example 793
# Processing test example 794
# Processing test example 795
# Processing test example 796
# Processing test example 797
# Processing test example 798
# Processing test example 799
# Processing test example 800
# Processing test example 801
# Processing test example 802
# Processing test example 803
# Processing test example 804
# Processing test example 805
# Processing test example 806
# Processing test example 807
# Processing test example 808
# Processing test example 809
# Processing test example 810
# Processing test example 811
# True Positive: 17
# False Positive: 8
# True Negative: 794
# False Negative: 5
# Precision: 0.68
# Recall: 0.7727272727272727
# F1 Score: 0.7234042553191491
# Accuracy Score: 0.9842233009708737
# Confusion Matrix:
# [[794, 8], [5, 17]]
