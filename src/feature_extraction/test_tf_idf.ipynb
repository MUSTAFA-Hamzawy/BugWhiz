# %%
from Preprocessing import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [25], in <module>
# ----> 1 from Preprocessing import preprocessing
#
# ModuleNotFoundError: No module named 'Preprocessing'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample bug report data
bug_reports = [
    """Bug report 1: UnknownHostException is not caught when the host name is invalid

1. in the Repositories view, New->CVS repository location
2. put a garbage host name( e.g. eh? )
3. complete the wizard.
4. expand the ""Project Version""
	UHE is thrown.

Log: Wed Jun 06 12:51:50 EDT 2001
4 org.eclipse.vcm.core 4 Cannot locate host eh?
java.net.UnknownHostException: eh?
	at java.net.InetAddress.getAllByName0(InetAddress.java:585)
	at java.net.InetAddress.getAllByName0(InetAddress.java:554)
	at java.net.InetAddress.getByName(InetAddress.java:463)
	at java.net.Socket.<init>(Socket.java:112)
	at 
org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.createSocket
(PServerConnection.java:140)
	at org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.open
(PServerConnection.java:190)
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.open
(Connection.java:224)
	at org.eclipse.vcm.internal.core.ccvs.client.Client.<init>
(Client.java:226)
	at 
org.eclipse.vcm.internal.core.ccvs.CVSAdapter.internalFetchMemberNames
(CVSAdapter.java:768)
	at 
org.eclipse.vcm.internal.core.ccvs.CVSAdapter.fetchTeamStreamProjectNames
(CVSAdapter.java:591)
	at org.eclipse.vcm.internal.core.TeamStream.fetchProjects
(TeamStream.java:58)
	at 
org.eclipse.vcm.internal.ui.model.TeamStreamElement.internalGetChildren
(TeamStreamElement.java:82)
	at org.eclipse.vcm.internal.ui.model.TeamStreamElement$1.run
(TeamStreamElement.java:39)
	at org.eclipse.swt.custom.BusyIndicator.showWhile(BusyIndicator.java:97)
	at org.eclipse.vcm.internal.ui.model.TeamStreamElement.getChildren
(TeamStreamElement.java:37)
	at org.eclipse.ui.model.WorkbenchContentProvider.getChildren
(WorkbenchContentProvider.java:53)
	at org.eclipse.jface.viewers.AbstractTreeViewer.getRawChildren
(AbstractTreeViewer.java:568)
	at org.eclipse.jface.viewers.StructuredViewer.getFilteredChildren
(StructuredViewer.java:281)
	at org.eclipse.jface.viewers.StructuredViewer.getSortedChildren
(StructuredViewer.java:378)
	at org.eclipse.jface.viewers.AbstractTreeViewer.createChildren
(AbstractTreeViewer.java:238)
	at org.eclipse.jface.viewers.AbstractTreeViewer.handleTreeExpand
(AbstractTreeViewer.java:611)
	at org.eclipse.jface.viewers.AbstractTreeViewer$2.treeExpanded
(AbstractTreeViewer.java:631)
	at org.eclipse.swt.widgets.TypedListener.handleEvent(TypedListener.java
(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.wmNotifyChild(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled 
Code))
	at org.eclipse.swt.internal.win32.OS.CallWindowProc(Native Method)
	at org.eclipse.swt.widgets.Tree.callWindowProc(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.WM_LBUTTONDOWN(Tree.java:1043)
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled 
Code))
	at org.eclipse.swt.internal.win32.OS.DispatchMessage(Native Method)
	at org.eclipse.swt.widgets.Display.readAndDispatch(Display.java
(Compiled Code))
	at org.eclipse.ui.internal.Workbench.runEventLoop(Workbench.java
(Compiled Code))
	at org.eclipse.ui.internal.Workbench.run(Workbench.java:620)
	at org.eclipse.core.internal.boot.InternalBootLoader.run
(InternalBootLoader.java:815)
	at org.eclipse.core.boot.BootLoader.run(BootLoader.java:285)
	at java.lang.reflect.Method.invoke(Native Method)
	at org.eclipse.core.launcher.Main.basicRun(Main.java:69)
	at org.eclipse.core.launcher.Main.run(Main.java:311)
	at org.eclipse.core.launcher.Main.main(Main.java:198)

NOTES:

KM (6/7/01 2:50:06 PM)
	Recommend we catch at level of TeamStreamElement.internalGetChildren() 
and do
			ErrorDialog.openError(...)
	Recommend that class because its only UI place we can catch, and its 
already catching CoreExceptions there anyway.

	There are other places you could get this error since we lazy verify 
connections but this is the most common.

	Also, noticed that in VCMModelElement.handle() (where this IS being 
caught)
	we should not be loging info messages, only errors.

KH (6/8/2001 5:47:05 PM)
	Yes """,
    
    """Bug report 2: After having synchronized and released successfully with teamstream (on zrhcvs), I attempted to version the project org.eclipse.jdt.core
and got a dialog saying ""CVS communication error"", following stack trace was in the log:

Log: Sat Jun 02 00:45:55 CEST 2001
4 org.eclipse.vcm.core 4 CVS communication error
java.io.InterruptedIOException: Read timed out
	at java.net.SocketInputStream.socketRead(Native Method)
	at java.net.SocketInputStream.read(SocketInputStream.java(Compiled Code))
	at java.io.BufferedInputStream.fill(BufferedInputStream.java(Compiled Code))
	at java.io.BufferedInputStream.read(BufferedInputStream.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.readLineOrUntil(Connection.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.readToken(Connection.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Client.processResponses(Client.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Client.processResponses(Client.java:397)
	at org.eclipse.vcm.internal.core.ccvs.client.Client.execute(Client.java:257)
	at org.eclipse.vcm.internal.core.ccvs.CVSAdapter.createProjectVersion(CVSAdapter.java:313)
	at org.eclipse.vcm.internal.core.SharingManager.createProjectVersion(SharingManager.java:71)
	at org.eclipse.vcm.internal.ui.actions.VersionAction$VersionLocalOperation.version(VersionAction.java:121)
	at org.eclipse.vcm.internal.ui.VersionResourcesOperation.run(VersionResourcesOperation.java:45)
	at org.eclipse.jface.operation.ModalContext$ModalContextThread.run(ModalContext.java:98)

NOTES:

PM (6/2/2001 12:48:47 AM)
	My network connection did not drop. I am connected over VPN from home to OTT.
	Next versioning attempt worked fine""",
    
    """Bug report 3: When the connection to the repositories fails, InterruptedIOException is not caught.

Log: Wed Jun 13 12:13:40 EDT 2001
4 org.eclipse.vcm.core 4 Cannot connect to host cvslnxtest
java.io.InterruptedIOException: Operation timed out: no further information
	at java.net.PlainSocketImpl.socketConnect(Native Method)
	at java.net.PlainSocketImpl.doConnect(PlainSocketImpl.java:329)
	at java.net.PlainSocketImpl.connectToAddress(PlainSocketImpl.java:141)
	at java.net.PlainSocketImpl.connect(PlainSocketImpl.java:128)
	at java.net.Socket.<init>(Socket.java:285)
	at java.net.Socket.<init>(Socket.java:112)
	at org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.createSocket(PServerConnection.java:140)
	at org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.open(PServerConnection.java:190)
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.open(Connection.java:224)
	at org.eclipse.vcm.internal.core.ccvs.client.Client.<init>(Client.java:227)
	at org.eclipse.vcm.internal.core.ccvs.CVSAdapter.internalFetchMemberNames(CVSAdapter.java:778)
	at org.eclipse.vcm.internal.core.ccvs.CVSAdapter.fetchProjectNames(CVSAdapter.java:485)
	at org.eclipse.vcm.internal.core.Repository.fetchProjectList(Repository.java:128)
	at org.eclipse.vcm.internal.ui.model.ProjectVersionsCategory.internalGetChildren(ProjectVersionsCategory.java:92)
	at org.eclipse.vcm.internal.ui.model.ProjectVersionsCategory$1.run(ProjectVersionsCategory.java:48)
	at org.eclipse.swt.custom.BusyIndicator.showWhile(BusyIndicator.java(Compiled Code))
	at org.eclipse.vcm.internal.ui.model.ProjectVersionsCategory.getChildren(ProjectVersionsCategory.java:46)
	at org.eclipse.ui.model.WorkbenchContentProvider.getChildren(WorkbenchContentProvider.java:51)
	at org.eclipse.jface.viewers.AbstractTreeViewer.getRawChildren(AbstractTreeViewer.java:568)
	at org.eclipse.jface.viewers.StructuredViewer.getFilteredChildren(StructuredViewer.java(Compiled Code))
	at org.eclipse.jface.viewers.StructuredViewer.getSortedChildren(StructuredViewer.java(Compiled Code))
	at org.eclipse.jface.viewers.AbstractTreeViewer.createChildren(AbstractTreeViewer.java(Compiled Code))
	at org.eclipse.jface.viewers.AbstractTreeViewer.handleTreeExpand(AbstractTreeViewer.java:611)
	at org.eclipse.jface.viewers.AbstractTreeViewer$2.treeExpanded(AbstractTreeViewer.java:631)
	at org.eclipse.swt.widgets.TypedListener.handleEvent(TypedListener.java(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.wmNotifyChild(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled Code))
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled Code))
	at org.eclipse.swt.internal.win32.OS.CallWindowProc(Native Method)
	at org.eclipse.swt.widgets.Tree.WM_LBUTTONDOWN(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.WM_LBUTTONDOWN(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled Code))
	at org.eclipse.swt.internal.win32.OS.DispatchMessage(Native Method)
	at org.eclipse.swt.widgets.Display.readAndDispatch(Display.java(Compiled Code))
	at org.eclipse.ui.internal.Workbench.runEventLoop(Workbench.java(Compiled Code))
	at org.eclipse.ui.internal.Workbench.run(Workbench.java:620)
	at org.eclipse.core.internal.boot.InternalBootLoader.run(InternalBootLoader.java:815)
	at org.eclipse.core.boot.BootLoader.run(BootLoader.java:285)
	at java.lang.reflect.Method.invoke(Native Method)
	at org.eclipse.core.launcher.Main.basicRun(Main.java:126)
	at org.eclipse.core.launcher.Main.run(Main.java:408)
	at org.eclipse.core.launcher.Main.main(Main.java:281)""",
]

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Preprocess and apply TF-IDF to each bug report
for bug_report in bug_reports:
    # Preprocess the bug report description
    preprocessed_description = preprocess_bug_description(bug_report)
    # Apply TF-IDF
    tfidf_vectors = tfidf_vectorizer.fit_transform([preprocessed_description])
    # Get the feature names (words)
    feature_names = tfidf_vectorizer.get_feature_names_out()
    # Print the TF-IDF vectors with corresponding words
    print("\nPreprocessed Bug Report:", preprocessed_description)
    tfidf_array = tfidf_vectors.toarray()[0]
    for word_index, tfidf_value in enumerate(tfidf_array):
        if tfidf_value != 0:
            print("Word:", feature_names[word_index], "- TF-IDF Value:", tfidf_value)
# Out:
# Preprocessed Bug Report: bug report unknownhostexception is not_caught when the host name is invalid in the repository view newcvs repository location put a garbage host name eg eh complete the wizard expand the project version uhe is thrown log wed jun edt orgeclipsevcmcore can not_locate host eh javanetunknownhostexception eh at javanetinetaddressgetallbynameinetaddressjava at javanetinetaddressgetallbynameinetaddressjava at javanetinetaddressgetbynameinetaddressjava at javanetsocketinitsocketjava at orgeclipsevcminternalcoreccvsclientpserverconnectioncreatesocket pserverconnectionjava at orgeclipsevcminternalcoreccvsclientpserverconnectionopen pserverconnectionjava at orgeclipsevcminternalcoreccvsclientconnectionopen connectionjava at orgeclipsevcminternalcoreccvsclientclientinit clientjava at orgeclipsevcminternalcoreccvscvsadapterinternalfetchmembernames cvsadapterjava at orgeclipsevcminternalcoreccvscvsadapterfetchteamstreamprojectnames cvsadapterjava at orgeclipsevcminternalcoreteamstreamfetchprojects teamstreamjava at orgeclipsevcminternaluimodelteamstreamelementinternalgetchildren teamstreamelementjava at orgeclipsevcminternaluimodelteamstreamelementrun teamstreamelementjava at orgeclipseswtcustombusyindicatorshowwhilebusyindicatorjava at orgeclipsevcminternaluimodelteamstreamelementgetchildren teamstreamelementjava at orgeclipseuimodelworkbenchcontentprovidergetchildren workbenchcontentproviderjava at orgeclipsejfaceviewersabstracttreeviewergetrawchildren abstracttreeviewerjava at orgeclipsejfaceviewersstructuredviewergetfilteredchildren structuredviewerjava at orgeclipsejfaceviewersstructuredviewergetsortedchildren structuredviewerjava at orgeclipsejfaceviewersabstracttreeviewercreatechildren abstracttreeviewerjava at orgeclipsejfaceviewersabstracttreeviewerhandletreeexpand abstracttreeviewerjava at orgeclipsejfaceviewersabstracttreeviewertreeexpanded abstracttreeviewerjava at orgeclipseswtwidgetstypedlistenerhandleeventtypedlistenerjava compiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetstreewmnotifychildtreejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwinoscallwindowprocnative method at orgeclipseswtwidgetstreecallwindowproctreejavacompiled code at orgeclipseswtwidgetstreewmlbuttondowntreejava at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwinosdispatchmessagenative method at orgeclipseswtwidgetsdisplayreadanddispatchdisplayjava compiled code at orgeclipseuiinternalworkbenchruneventloopworkbenchjava compiled code at orgeclipseuiinternalworkbenchrunworkbenchjava at orgeclipsecoreinternalbootinternalbootloaderrun internalbootloaderjava at orgeclipsecorebootbootloaderrunbootloaderjava at javalangreflectmethodinvokenative method at orgeclipsecorelaunchermainbasicrunmainjava at orgeclipsecorelaunchermainrunmainjava at orgeclipsecorelaunchermainmainmainjava note km pm recommend we catch at level of teamstreamelementinternalgetchildren and do errordialogopenerror recommend that class because it only ui place we can catch and it already catching coreexceptions there anyway there are other place you could get this error since we lazy verify connection but this is the most common also noticed that in vcmmodelelementhandle where this is being caught we should not_be loging info message only error kh pm yes
# Word: abstracttreeviewerjava - TF-IDF Value: 0.07823610118539688
# Word: already - TF-IDF Value: 0.01955902529634922
# Word: also - TF-IDF Value: 0.01955902529634922
# Word: and - TF-IDF Value: 0.03911805059269844
# Word: anyway - TF-IDF Value: 0.01955902529634922
# Word: are - TF-IDF Value: 0.01955902529634922
# Word: at - TF-IDF Value: 0.8997151636320642
# Word: because - TF-IDF Value: 0.01955902529634922
# Word: being - TF-IDF Value: 0.01955902529634922
# Word: bug - TF-IDF Value: 0.01955902529634922
# Word: but - TF-IDF Value: 0.01955902529634922
# Word: can - TF-IDF Value: 0.03911805059269844
# Word: catch - TF-IDF Value: 0.03911805059269844
# Word: catching - TF-IDF Value: 0.01955902529634922
# Word: caught - TF-IDF Value: 0.01955902529634922
# Word: class - TF-IDF Value: 0.01955902529634922
# Word: clientjava - TF-IDF Value: 0.01955902529634922
# Word: code - TF-IDF Value: 0.2542673288525399
# Word: common - TF-IDF Value: 0.01955902529634922
# Word: compiled - TF-IDF Value: 0.058677075889047664
# Word: complete - TF-IDF Value: 0.01955902529634922
# Word: connection - TF-IDF Value: 0.01955902529634922
# Word: connectionjava - TF-IDF Value: 0.01955902529634922
# Word: coreexceptions - TF-IDF Value: 0.01955902529634922
# Word: could - TF-IDF Value: 0.01955902529634922
# Word: cvsadapterjava - TF-IDF Value: 0.03911805059269844
# Word: do - TF-IDF Value: 0.01955902529634922
# Word: edt - TF-IDF Value: 0.01955902529634922
# Word: eg - TF-IDF Value: 0.01955902529634922
# Word: eh - TF-IDF Value: 0.058677075889047664
# Word: error - TF-IDF Value: 0.03911805059269844
# Word: errordialogopenerror - TF-IDF Value: 0.01955902529634922
# Word: expand - TF-IDF Value: 0.01955902529634922
# Word: garbage - TF-IDF Value: 0.01955902529634922
# Word: get - TF-IDF Value: 0.01955902529634922
# Word: host - TF-IDF Value: 0.058677075889047664
# Word: in - TF-IDF Value: 0.03911805059269844
# Word: info - TF-IDF Value: 0.01955902529634922
# Word: internalbootloaderjava - TF-IDF Value: 0.01955902529634922
# Word: invalid - TF-IDF Value: 0.01955902529634922
# Word: is - TF-IDF Value: 0.09779512648174611
# Word: it - TF-IDF Value: 0.03911805059269844
# Word: javalangreflectmethodinvokenative - TF-IDF Value: 0.01955902529634922
# Word: javanetinetaddressgetallbynameinetaddressjava - TF-IDF Value: 0.03911805059269844
# Word: javanetinetaddressgetbynameinetaddressjava - TF-IDF Value: 0.01955902529634922
# Word: javanetsocketinitsocketjava - TF-IDF Value: 0.01955902529634922
# Word: javanetunknownhostexception - TF-IDF Value: 0.01955902529634922
# Word: jun - TF-IDF Value: 0.01955902529634922
# Word: kh - TF-IDF Value: 0.01955902529634922
# Word: km - TF-IDF Value: 0.01955902529634922
# Word: lazy - TF-IDF Value: 0.01955902529634922
# Word: level - TF-IDF Value: 0.01955902529634922
# Word: location - TF-IDF Value: 0.01955902529634922
# Word: log - TF-IDF Value: 0.01955902529634922
# Word: loging - TF-IDF Value: 0.01955902529634922
# Word: message - TF-IDF Value: 0.01955902529634922
# Word: method - TF-IDF Value: 0.058677075889047664
# Word: most - TF-IDF Value: 0.01955902529634922
# Word: name - TF-IDF Value: 0.03911805059269844
# Word: newcvs - TF-IDF Value: 0.01955902529634922
# Word: not_be - TF-IDF Value: 0.01955902529634922
# Word: not_caught - TF-IDF Value: 0.01955902529634922
# Word: not_locate - TF-IDF Value: 0.01955902529634922
# Word: note - TF-IDF Value: 0.01955902529634922
# Word: noticed - TF-IDF Value: 0.01955902529634922
# Word: of - TF-IDF Value: 0.01955902529634922
# Word: only - TF-IDF Value: 0.03911805059269844
# Word: orgeclipsecorebootbootloaderrunbootloaderjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsecoreinternalbootinternalbootloaderrun - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsecorelaunchermainbasicrunmainjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsecorelaunchermainmainmainjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsecorelaunchermainrunmainjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsejfaceviewersabstracttreeviewercreatechildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsejfaceviewersabstracttreeviewergetrawchildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsejfaceviewersabstracttreeviewerhandletreeexpand - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsejfaceviewersabstracttreeviewertreeexpanded - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsejfaceviewersstructuredviewergetfilteredchildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsejfaceviewersstructuredviewergetsortedchildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtcustombusyindicatorshowwhilebusyindicatorjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtinternalwinoscallwindowprocnative - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtinternalwinosdispatchmessagenative - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtwidgetscompositewmnotifycompositejavacompiled - TF-IDF Value: 0.03911805059269844
# Word: orgeclipseswtwidgetscontrolwindowproccontroljavacompiled - TF-IDF Value: 0.03911805059269844
# Word: orgeclipseswtwidgetsdisplayreadanddispatchdisplayjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled - TF-IDF Value: 0.03911805059269844
# Word: orgeclipseswtwidgetstreecallwindowproctreejavacompiled - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtwidgetstreewmlbuttondowntreejava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtwidgetstreewmnotifychildtreejavacompiled - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtwidgetstypedlistenerhandleeventtypedlistenerjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled - TF-IDF Value: 0.03911805059269844
# Word: orgeclipseuiinternalworkbenchruneventloopworkbenchjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseuiinternalworkbenchrunworkbenchjava - TF-IDF Value: 0.01955902529634922
# Word: orgeclipseuimodelworkbenchcontentprovidergetchildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcmcore - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreccvsclientclientinit - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreccvsclientconnectionopen - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreccvsclientpserverconnectioncreatesocket - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreccvsclientpserverconnectionopen - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreccvscvsadapterfetchteamstreamprojectnames - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreccvscvsadapterinternalfetchmembernames - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternalcoreteamstreamfetchprojects - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternaluimodelteamstreamelementgetchildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternaluimodelteamstreamelementinternalgetchildren - TF-IDF Value: 0.01955902529634922
# Word: orgeclipsevcminternaluimodelteamstreamelementrun - TF-IDF Value: 0.01955902529634922
# Word: other - TF-IDF Value: 0.01955902529634922
# Word: place - TF-IDF Value: 0.03911805059269844
# Word: pm - TF-IDF Value: 0.03911805059269844
# Word: project - TF-IDF Value: 0.01955902529634922
# Word: pserverconnectionjava - TF-IDF Value: 0.03911805059269844
# Word: put - TF-IDF Value: 0.01955902529634922
# Word: recommend - TF-IDF Value: 0.03911805059269844
# Word: report - TF-IDF Value: 0.01955902529634922
# Word: repository - TF-IDF Value: 0.03911805059269844
# Word: should - TF-IDF Value: 0.01955902529634922
# Word: since - TF-IDF Value: 0.01955902529634922
# Word: structuredviewerjava - TF-IDF Value: 0.03911805059269844
# Word: teamstreamelementinternalgetchildren - TF-IDF Value: 0.01955902529634922
# Word: teamstreamelementjava - TF-IDF Value: 0.058677075889047664
# Word: teamstreamjava - TF-IDF Value: 0.01955902529634922
# Word: that - TF-IDF Value: 0.03911805059269844
# Word: the - TF-IDF Value: 0.09779512648174611
# Word: there - TF-IDF Value: 0.03911805059269844
# Word: this - TF-IDF Value: 0.058677075889047664
# Word: thrown - TF-IDF Value: 0.01955902529634922
# Word: uhe - TF-IDF Value: 0.01955902529634922
# Word: ui - TF-IDF Value: 0.01955902529634922
# Word: unknownhostexception - TF-IDF Value: 0.01955902529634922
# Word: vcmmodelelementhandle - TF-IDF Value: 0.01955902529634922
# Word: verify - TF-IDF Value: 0.01955902529634922
# Word: version - TF-IDF Value: 0.01955902529634922
# Word: view - TF-IDF Value: 0.01955902529634922
# Word: we - TF-IDF Value: 0.07823610118539688
# Word: wed - TF-IDF Value: 0.01955902529634922
# Word: when - TF-IDF Value: 0.01955902529634922
# Word: where - TF-IDF Value: 0.01955902529634922
# Word: wizard - TF-IDF Value: 0.01955902529634922
# Word: workbenchcontentproviderjava - TF-IDF Value: 0.01955902529634922
# Word: yes - TF-IDF Value: 0.01955902529634922
# Word: you - TF-IDF Value: 0.01955902529634922
#
# Preprocessed Bug Report: bug report after having synchronized and released successfully with teamstream on zrhcvs i attempted to version the project orgeclipsejdtcore and got a dialog saying cv communication error following stack trace wa in the log log sat jun cest orgeclipsevcmcore cv communication error javaiointerruptedioexception read timed out at javanetsocketinputstreamsocketreadnative method at javanetsocketinputstreamreadsocketinputstreamjavacompiled code at javaiobufferedinputstreamfillbufferedinputstreamjavacompiled code at javaiobufferedinputstreamreadbufferedinputstreamjavacompiled code at orgeclipsevcminternalcoreccvsclientconnectionreadlineoruntilconnectionjavacompiled code at orgeclipsevcminternalcoreccvsclientconnectionreadtokenconnectionjavacompiled code at orgeclipsevcminternalcoreccvsclientclientprocessresponsesclientjavacompiled code at orgeclipsevcminternalcoreccvsclientclientprocessresponsesclientjava at orgeclipsevcminternalcoreccvsclientclientexecuteclientjava at orgeclipsevcminternalcoreccvscvsadaptercreateprojectversioncvsadapterjava at orgeclipsevcminternalcoresharingmanagercreateprojectversionsharingmanagerjava at orgeclipsevcminternaluiactionsversionactionversionlocaloperationversionversionactionjava at orgeclipsevcminternaluiversionresourcesoperationrunversionresourcesoperationjava at orgeclipsejfaceoperationmodalcontextmodalcontextthreadrunmodalcontextjava note pm am my network connection did not_drop i am connected over vpn from home to ott next versioning attempt worked fine
# Word: after - TF-IDF Value: 0.05521576303742327
# Word: am - TF-IDF Value: 0.11043152607484653
# Word: and - TF-IDF Value: 0.11043152607484653
# Word: at - TF-IDF Value: 0.7730206825239258
# Word: attempt - TF-IDF Value: 0.05521576303742327
# Word: attempted - TF-IDF Value: 0.05521576303742327
# Word: bug - TF-IDF Value: 0.05521576303742327
# Word: cest - TF-IDF Value: 0.05521576303742327
# Word: code - TF-IDF Value: 0.3312945782245396
# Word: communication - TF-IDF Value: 0.11043152607484653
# Word: connected - TF-IDF Value: 0.05521576303742327
# Word: connection - TF-IDF Value: 0.05521576303742327
# Word: cv - TF-IDF Value: 0.11043152607484653
# Word: dialog - TF-IDF Value: 0.05521576303742327
# Word: did - TF-IDF Value: 0.05521576303742327
# Word: error - TF-IDF Value: 0.11043152607484653
# Word: fine - TF-IDF Value: 0.05521576303742327
# Word: following - TF-IDF Value: 0.05521576303742327
# Word: from - TF-IDF Value: 0.05521576303742327
# Word: got - TF-IDF Value: 0.05521576303742327
# Word: having - TF-IDF Value: 0.05521576303742327
# Word: home - TF-IDF Value: 0.05521576303742327
# Word: in - TF-IDF Value: 0.05521576303742327
# Word: javaiobufferedinputstreamfillbufferedinputstreamjavacompiled - TF-IDF Value: 0.05521576303742327
# Word: javaiobufferedinputstreamreadbufferedinputstreamjavacompiled - TF-IDF Value: 0.05521576303742327
# Word: javaiointerruptedioexception - TF-IDF Value: 0.05521576303742327
# Word: javanetsocketinputstreamreadsocketinputstreamjavacompiled - TF-IDF Value: 0.05521576303742327
# Word: javanetsocketinputstreamsocketreadnative - TF-IDF Value: 0.05521576303742327
# Word: jun - TF-IDF Value: 0.05521576303742327
# Word: log - TF-IDF Value: 0.11043152607484653
# Word: method - TF-IDF Value: 0.05521576303742327
# Word: my - TF-IDF Value: 0.05521576303742327
# Word: network - TF-IDF Value: 0.05521576303742327
# Word: next - TF-IDF Value: 0.05521576303742327
# Word: not_drop - TF-IDF Value: 0.05521576303742327
# Word: note - TF-IDF Value: 0.05521576303742327
# Word: on - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsejdtcore - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsejfaceoperationmodalcontextmodalcontextthreadrunmodalcontextjava - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcmcore - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoreccvsclientclientexecuteclientjava - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoreccvsclientclientprocessresponsesclientjava - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoreccvsclientclientprocessresponsesclientjavacompiled - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoreccvsclientconnectionreadlineoruntilconnectionjavacompiled - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoreccvsclientconnectionreadtokenconnectionjavacompiled - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoreccvscvsadaptercreateprojectversioncvsadapterjava - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternalcoresharingmanagercreateprojectversionsharingmanagerjava - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternaluiactionsversionactionversionlocaloperationversionversionactionjava - TF-IDF Value: 0.05521576303742327
# Word: orgeclipsevcminternaluiversionresourcesoperationrunversionresourcesoperationjava - TF-IDF Value: 0.05521576303742327
# Word: ott - TF-IDF Value: 0.05521576303742327
# Word: out - TF-IDF Value: 0.05521576303742327
# Word: over - TF-IDF Value: 0.05521576303742327
# Word: pm - TF-IDF Value: 0.05521576303742327
# Word: project - TF-IDF Value: 0.05521576303742327
# Word: read - TF-IDF Value: 0.05521576303742327
# Word: released - TF-IDF Value: 0.05521576303742327
# Word: report - TF-IDF Value: 0.05521576303742327
# Word: sat - TF-IDF Value: 0.05521576303742327
# Word: saying - TF-IDF Value: 0.05521576303742327
# Word: stack - TF-IDF Value: 0.05521576303742327
# Word: successfully - TF-IDF Value: 0.05521576303742327
# Word: synchronized - TF-IDF Value: 0.05521576303742327
# Word: teamstream - TF-IDF Value: 0.05521576303742327
# Word: the - TF-IDF Value: 0.11043152607484653
# Word: timed - TF-IDF Value: 0.05521576303742327
# Word: to - TF-IDF Value: 0.11043152607484653
# Word: trace - TF-IDF Value: 0.05521576303742327
# Word: version - TF-IDF Value: 0.05521576303742327
# Word: versioning - TF-IDF Value: 0.05521576303742327
# Word: vpn - TF-IDF Value: 0.05521576303742327
# Word: wa - TF-IDF Value: 0.05521576303742327
# Word: with - TF-IDF Value: 0.05521576303742327
# Word: worked - TF-IDF Value: 0.05521576303742327
# Word: zrhcvs - TF-IDF Value: 0.05521576303742327
#
# Preprocessed Bug Report: bug report when the connection to the repository fails interruptedioexception is not_caught log wed jun edt orgeclipsevcmcore can not_connect to host cvslnxtest javaiointerruptedioexception operation timed out not_further information at javanetplainsocketimplsocketconnectnative method at javanetplainsocketimpldoconnectplainsocketimpljava at javanetplainsocketimplconnecttoaddressplainsocketimpljava at javanetplainsocketimplconnectplainsocketimpljava at javanetsocketinitsocketjava at javanetsocketinitsocketjava at orgeclipsevcminternalcoreccvsclientpserverconnectioncreatesocketpserverconnectionjava at orgeclipsevcminternalcoreccvsclientpserverconnectionopenpserverconnectionjava at orgeclipsevcminternalcoreccvsclientconnectionopenconnectionjava at orgeclipsevcminternalcoreccvsclientclientinitclientjava at orgeclipsevcminternalcoreccvscvsadapterinternalfetchmembernamescvsadapterjava at orgeclipsevcminternalcoreccvscvsadapterfetchprojectnamescvsadapterjava at orgeclipsevcminternalcorerepositoryfetchprojectlistrepositoryjava at orgeclipsevcminternaluimodelprojectversionscategoryinternalgetchildrenprojectversionscategoryjava at orgeclipsevcminternaluimodelprojectversionscategoryrunprojectversionscategoryjava at orgeclipseswtcustombusyindicatorshowwhilebusyindicatorjavacompiled code at orgeclipsevcminternaluimodelprojectversionscategorygetchildrenprojectversionscategoryjava at orgeclipseuimodelworkbenchcontentprovidergetchildrenworkbenchcontentproviderjava at orgeclipsejfaceviewersabstracttreeviewergetrawchildrenabstracttreeviewerjava at orgeclipsejfaceviewersstructuredviewergetfilteredchildrenstructuredviewerjavacompiled code at orgeclipsejfaceviewersstructuredviewergetsortedchildrenstructuredviewerjavacompiled code at orgeclipsejfaceviewersabstracttreeviewercreatechildrenabstracttreeviewerjavacompiled code at orgeclipsejfaceviewersabstracttreeviewerhandletreeexpandabstracttreeviewerjava at orgeclipsejfaceviewersabstracttreeviewertreeexpandedabstracttreeviewerjava at orgeclipseswtwidgetstypedlistenerhandleeventtypedlistenerjavacompiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetstreewmnotifychildtreejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwinoscallwindowprocnative method at orgeclipseswtwidgetstreewmlbuttondowntreejavacompiled code at orgeclipseswtwidgetstreewmlbuttondowntreejavacompiled code at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwinosdispatchmessagenative method at orgeclipseswtwidgetsdisplayreadanddispatchdisplayjavacompiled code at orgeclipseuiinternalworkbenchruneventloopworkbenchjavacompiled code at orgeclipseuiinternalworkbenchrunworkbenchjava at orgeclipsecoreinternalbootinternalbootloaderruninternalbootloaderjava at orgeclipsecorebootbootloaderrunbootloaderjava at javalangreflectmethodinvokenative method at orgeclipsecorelaunchermainbasicrunmainjava at orgeclipsecorelaunchermainrunmainjava at orgeclipsecorelaunchermainmainmainjava
# Word: at - TF-IDF Value: 0.9147362593897894
# Word: bug - TF-IDF Value: 0.019462473604038074
# Word: can - TF-IDF Value: 0.019462473604038074
# Word: code - TF-IDF Value: 0.35032452487268534
# Word: connection - TF-IDF Value: 0.019462473604038074
# Word: cvslnxtest - TF-IDF Value: 0.019462473604038074
# Word: edt - TF-IDF Value: 0.019462473604038074
# Word: fails - TF-IDF Value: 0.019462473604038074
# Word: host - TF-IDF Value: 0.019462473604038074
# Word: information - TF-IDF Value: 0.019462473604038074
# Word: interruptedioexception - TF-IDF Value: 0.019462473604038074
# Word: is - TF-IDF Value: 0.019462473604038074
# Word: javaiointerruptedioexception - TF-IDF Value: 0.019462473604038074
# Word: javalangreflectmethodinvokenative - TF-IDF Value: 0.019462473604038074
# Word: javanetplainsocketimplconnectplainsocketimpljava - TF-IDF Value: 0.019462473604038074
# Word: javanetplainsocketimplconnecttoaddressplainsocketimpljava - TF-IDF Value: 0.019462473604038074
# Word: javanetplainsocketimpldoconnectplainsocketimpljava - TF-IDF Value: 0.019462473604038074
# Word: javanetplainsocketimplsocketconnectnative - TF-IDF Value: 0.019462473604038074
# Word: javanetsocketinitsocketjava - TF-IDF Value: 0.03892494720807615
# Word: jun - TF-IDF Value: 0.019462473604038074
# Word: log - TF-IDF Value: 0.019462473604038074
# Word: method - TF-IDF Value: 0.0778498944161523
# Word: not_caught - TF-IDF Value: 0.019462473604038074
# Word: not_connect - TF-IDF Value: 0.019462473604038074
# Word: not_further - TF-IDF Value: 0.019462473604038074
# Word: operation - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsecorebootbootloaderrunbootloaderjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsecoreinternalbootinternalbootloaderruninternalbootloaderjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsecorelaunchermainbasicrunmainjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsecorelaunchermainmainmainjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsecorelaunchermainrunmainjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsejfaceviewersabstracttreeviewercreatechildrenabstracttreeviewerjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsejfaceviewersabstracttreeviewergetrawchildrenabstracttreeviewerjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsejfaceviewersabstracttreeviewerhandletreeexpandabstracttreeviewerjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsejfaceviewersabstracttreeviewertreeexpandedabstracttreeviewerjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsejfaceviewersstructuredviewergetfilteredchildrenstructuredviewerjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsejfaceviewersstructuredviewergetsortedchildrenstructuredviewerjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtcustombusyindicatorshowwhilebusyindicatorjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtinternalwinoscallwindowprocnative - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtinternalwinosdispatchmessagenative - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtwidgetscompositewmnotifycompositejavacompiled - TF-IDF Value: 0.03892494720807615
# Word: orgeclipseswtwidgetscontrolwindowproccontroljavacompiled - TF-IDF Value: 0.03892494720807615
# Word: orgeclipseswtwidgetsdisplayreadanddispatchdisplayjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled - TF-IDF Value: 0.03892494720807615
# Word: orgeclipseswtwidgetstreewmlbuttondowntreejavacompiled - TF-IDF Value: 0.03892494720807615
# Word: orgeclipseswtwidgetstreewmnotifychildtreejavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtwidgetstypedlistenerhandleeventtypedlistenerjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled - TF-IDF Value: 0.03892494720807615
# Word: orgeclipseuiinternalworkbenchruneventloopworkbenchjavacompiled - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseuiinternalworkbenchrunworkbenchjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipseuimodelworkbenchcontentprovidergetchildrenworkbenchcontentproviderjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcmcore - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcoreccvsclientclientinitclientjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcoreccvsclientconnectionopenconnectionjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcoreccvsclientpserverconnectioncreatesocketpserverconnectionjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcoreccvsclientpserverconnectionopenpserverconnectionjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcoreccvscvsadapterfetchprojectnamescvsadapterjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcoreccvscvsadapterinternalfetchmembernamescvsadapterjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternalcorerepositoryfetchprojectlistrepositoryjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternaluimodelprojectversionscategorygetchildrenprojectversionscategoryjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternaluimodelprojectversionscategoryinternalgetchildrenprojectversionscategoryjava - TF-IDF Value: 0.019462473604038074
# Word: orgeclipsevcminternaluimodelprojectversionscategoryrunprojectversionscategoryjava - TF-IDF Value: 0.019462473604038074
# Word: out - TF-IDF Value: 0.019462473604038074
# Word: report - TF-IDF Value: 0.019462473604038074
# Word: repository - TF-IDF Value: 0.019462473604038074
# Word: the - TF-IDF Value: 0.03892494720807615
# Word: timed - TF-IDF Value: 0.019462473604038074
# Word: to - TF-IDF Value: 0.03892494720807615
# Word: wed - TF-IDF Value: 0.019462473604038074
# Word: when - TF-IDF Value: 0.019462473604038074

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_bug_description(description):

    # Convert to lowercase
    description = description.lower()

    # Remove punctuation and special characters
    description = re.sub(r'[^a-zA-Z0-9\s]', '', description)

    # Remove numbers
    description = re.sub(r'\b\d+\b', '', description)

    # Remove extra whitespace
    description = re.sub(r'\s+', ' ', description)

    return description

# Sample bug report data
bug_reports = [
    """Bug report 1: UnknownHostException is not caught when the host name is invalid

1. in the Repositories view, New->CVS repository location
2. put a garbage host name( e.g. eh? )
3. complete the wizard.
4. expand the ""Project Version""
	UHE is thrown.

Log: Wed Jun 06 12:51:50 EDT 2001
4 org.eclipse.vcm.core 4 Cannot locate host eh?
java.net.UnknownHostException: eh?
	at java.net.InetAddress.getAllByName0(InetAddress.java:585)
	at java.net.InetAddress.getAllByName0(InetAddress.java:554)
	at java.net.InetAddress.getByName(InetAddress.java:463)
	at java.net.Socket.<init>(Socket.java:112)
	at 
org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.createSocket
(PServerConnection.java:140)
	at org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.open
(PServerConnection.java:190)
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.open
(Connection.java:224)
	at org.eclipse.vcm.internal.core.ccvs.client.Client.<init>
(Client.java:226)
	at 
org.eclipse.vcm.internal.core.ccvs.CVSAdapter.internalFetchMemberNames
(CVSAdapter.java:768)
	at 
org.eclipse.vcm.internal.core.ccvs.CVSAdapter.fetchTeamStreamProjectNames
(CVSAdapter.java:591)
	at org.eclipse.vcm.internal.core.TeamStream.fetchProjects
(TeamStream.java:58)
	at 
org.eclipse.vcm.internal.ui.model.TeamStreamElement.internalGetChildren
(TeamStreamElement.java:82)
	at org.eclipse.vcm.internal.ui.model.TeamStreamElement$1.run
(TeamStreamElement.java:39)
	at org.eclipse.swt.custom.BusyIndicator.showWhile(BusyIndicator.java:97)
	at org.eclipse.vcm.internal.ui.model.TeamStreamElement.getChildren
(TeamStreamElement.java:37)
	at org.eclipse.ui.model.WorkbenchContentProvider.getChildren
(WorkbenchContentProvider.java:53)
	at org.eclipse.jface.viewers.AbstractTreeViewer.getRawChildren
(AbstractTreeViewer.java:568)
	at org.eclipse.jface.viewers.StructuredViewer.getFilteredChildren
(StructuredViewer.java:281)
	at org.eclipse.jface.viewers.StructuredViewer.getSortedChildren
(StructuredViewer.java:378)
	at org.eclipse.jface.viewers.AbstractTreeViewer.createChildren
(AbstractTreeViewer.java:238)
	at org.eclipse.jface.viewers.AbstractTreeViewer.handleTreeExpand
(AbstractTreeViewer.java:611)
	at org.eclipse.jface.viewers.AbstractTreeViewer$2.treeExpanded
(AbstractTreeViewer.java:631)
	at org.eclipse.swt.widgets.TypedListener.handleEvent(TypedListener.java
(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.wmNotifyChild(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled 
Code))
	at org.eclipse.swt.internal.win32.OS.CallWindowProc(Native Method)
	at org.eclipse.swt.widgets.Tree.callWindowProc(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.WM_LBUTTONDOWN(Tree.java:1043)
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled 
Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled 
Code))
	at org.eclipse.swt.internal.win32.OS.DispatchMessage(Native Method)
	at org.eclipse.swt.widgets.Display.readAndDispatch(Display.java
(Compiled Code))
	at org.eclipse.ui.internal.Workbench.runEventLoop(Workbench.java
(Compiled Code))
	at org.eclipse.ui.internal.Workbench.run(Workbench.java:620)
	at org.eclipse.core.internal.boot.InternalBootLoader.run
(InternalBootLoader.java:815)
	at org.eclipse.core.boot.BootLoader.run(BootLoader.java:285)
	at java.lang.reflect.Method.invoke(Native Method)
	at org.eclipse.core.launcher.Main.basicRun(Main.java:69)
	at org.eclipse.core.launcher.Main.run(Main.java:311)
	at org.eclipse.core.launcher.Main.main(Main.java:198)

NOTES:

KM (6/7/01 2:50:06 PM)
	Recommend we catch at level of TeamStreamElement.internalGetChildren() 
and do
			ErrorDialog.openError(...)
	Recommend that class because its only UI place we can catch, and its 
already catching CoreExceptions there anyway.

	There are other places you could get this error since we lazy verify 
connections but this is the most common.

	Also, noticed that in VCMModelElement.handle() (where this IS being 
caught)
	we should not be loging info messages, only errors.

KH (6/8/2001 5:47:05 PM)
	Yes """,
    
    """Bug report 2: After having synchronized and released successfully with teamstream (on zrhcvs), I attempted to version the project org.eclipse.jdt.core
and got a dialog saying ""CVS communication error"", following stack trace was in the log:

Log: Sat Jun 02 00:45:55 CEST 2001
4 org.eclipse.vcm.core 4 CVS communication error
java.io.InterruptedIOException: Read timed out
	at java.net.SocketInputStream.socketRead(Native Method)
	at java.net.SocketInputStream.read(SocketInputStream.java(Compiled Code))
	at java.io.BufferedInputStream.fill(BufferedInputStream.java(Compiled Code))
	at java.io.BufferedInputStream.read(BufferedInputStream.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.readLineOrUntil(Connection.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.readToken(Connection.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Client.processResponses(Client.java(Compiled Code))
	at org.eclipse.vcm.internal.core.ccvs.client.Client.processResponses(Client.java:397)
	at org.eclipse.vcm.internal.core.ccvs.client.Client.execute(Client.java:257)
	at org.eclipse.vcm.internal.core.ccvs.CVSAdapter.createProjectVersion(CVSAdapter.java:313)
	at org.eclipse.vcm.internal.core.SharingManager.createProjectVersion(SharingManager.java:71)
	at org.eclipse.vcm.internal.ui.actions.VersionAction$VersionLocalOperation.version(VersionAction.java:121)
	at org.eclipse.vcm.internal.ui.VersionResourcesOperation.run(VersionResourcesOperation.java:45)
	at org.eclipse.jface.operation.ModalContext$ModalContextThread.run(ModalContext.java:98)

NOTES:

PM (6/2/2001 12:48:47 AM)
	My network connection did not drop. I am connected over VPN from home to OTT.
	Next versioning attempt worked fine""",
    
    """Bug report 3: When the connection to the repositories fails, InterruptedIOException is not caught.

Log: Wed Jun 13 12:13:40 EDT 2001
4 org.eclipse.vcm.core 4 Cannot connect to host cvslnxtest
java.io.InterruptedIOException: Operation timed out: no further information
	at java.net.PlainSocketImpl.socketConnect(Native Method)
	at java.net.PlainSocketImpl.doConnect(PlainSocketImpl.java:329)
	at java.net.PlainSocketImpl.connectToAddress(PlainSocketImpl.java:141)
	at java.net.PlainSocketImpl.connect(PlainSocketImpl.java:128)
	at java.net.Socket.<init>(Socket.java:285)
	at java.net.Socket.<init>(Socket.java:112)
	at org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.createSocket(PServerConnection.java:140)
	at org.eclipse.vcm.internal.core.ccvs.client.PServerConnection.open(PServerConnection.java:190)
	at org.eclipse.vcm.internal.core.ccvs.client.Connection.open(Connection.java:224)
	at org.eclipse.vcm.internal.core.ccvs.client.Client.<init>(Client.java:227)
	at org.eclipse.vcm.internal.core.ccvs.CVSAdapter.internalFetchMemberNames(CVSAdapter.java:778)
	at org.eclipse.vcm.internal.core.ccvs.CVSAdapter.fetchProjectNames(CVSAdapter.java:485)
	at org.eclipse.vcm.internal.core.Repository.fetchProjectList(Repository.java:128)
	at org.eclipse.vcm.internal.ui.model.ProjectVersionsCategory.internalGetChildren(ProjectVersionsCategory.java:92)
	at org.eclipse.vcm.internal.ui.model.ProjectVersionsCategory$1.run(ProjectVersionsCategory.java:48)
	at org.eclipse.swt.custom.BusyIndicator.showWhile(BusyIndicator.java(Compiled Code))
	at org.eclipse.vcm.internal.ui.model.ProjectVersionsCategory.getChildren(ProjectVersionsCategory.java:46)
	at org.eclipse.ui.model.WorkbenchContentProvider.getChildren(WorkbenchContentProvider.java:51)
	at org.eclipse.jface.viewers.AbstractTreeViewer.getRawChildren(AbstractTreeViewer.java:568)
	at org.eclipse.jface.viewers.StructuredViewer.getFilteredChildren(StructuredViewer.java(Compiled Code))
	at org.eclipse.jface.viewers.StructuredViewer.getSortedChildren(StructuredViewer.java(Compiled Code))
	at org.eclipse.jface.viewers.AbstractTreeViewer.createChildren(AbstractTreeViewer.java(Compiled Code))
	at org.eclipse.jface.viewers.AbstractTreeViewer.handleTreeExpand(AbstractTreeViewer.java:611)
	at org.eclipse.jface.viewers.AbstractTreeViewer$2.treeExpanded(AbstractTreeViewer.java:631)
	at org.eclipse.swt.widgets.TypedListener.handleEvent(TypedListener.java(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Widget.sendEvent(Widget.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.wmNotifyChild(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled Code))
	at org.eclipse.swt.widgets.Composite.WM_NOTIFY(Composite.java(Compiled Code))
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled Code))
	at org.eclipse.swt.internal.win32.OS.CallWindowProc(Native Method)
	at org.eclipse.swt.widgets.Tree.WM_LBUTTONDOWN(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Tree.WM_LBUTTONDOWN(Tree.java(Compiled Code))
	at org.eclipse.swt.widgets.Control.windowProc(Control.java(Compiled Code))
	at org.eclipse.swt.widgets.Display.windowProc(Display.java(Compiled Code))
	at org.eclipse.swt.internal.win32.OS.DispatchMessage(Native Method)
	at org.eclipse.swt.widgets.Display.readAndDispatch(Display.java(Compiled Code))
	at org.eclipse.ui.internal.Workbench.runEventLoop(Workbench.java(Compiled Code))
	at org.eclipse.ui.internal.Workbench.run(Workbench.java:620)
	at org.eclipse.core.internal.boot.InternalBootLoader.run(InternalBootLoader.java:815)
	at org.eclipse.core.boot.BootLoader.run(BootLoader.java:285)
	at java.lang.reflect.Method.invoke(Native Method)
	at org.eclipse.core.launcher.Main.basicRun(Main.java:126)
	at org.eclipse.core.launcher.Main.run(Main.java:408)
	at org.eclipse.core.launcher.Main.main(Main.java:281)""",
     """Bug report 4: "Since refresh() is called before the catchup/release view opens, it should be as fast as possible.

NOTES:

BB (12/04/2001 11:32:05 AM)
	The most promising optimization idea is: Don't return an IServerResourceTree from fetchRemoteTree
	but instead use a call-back to interleave the server communication with updating the sync info.

BB (12/04/2001 11:30:31 AM)
	See this PR for other performance tuning opportunities: 1GAT2V2: ITPVCM:WINNT - Releasing very slow

MichaelV (19/09/2001 2:14:23 PM)

	Here are some percentages on a refresh from OTT to Paris with auto-build turned OFF

		Total Time: 97776 ms

		(57026) 58.3% in Subscriber.refresh()
			(40704) 41.6% CVSAdapter.fetchRemoteTree()
			(14918) 15.3% Subscriber.recursiveRefresh()
		(13242) 13.5% in SharingManager.manage() from  org.eclipse.vcm.ui.sync.Repository.autoManage()
			What is autoManage?
		 (12234) 12.5% in org.eclipse.vcm.ui.sync.Repository.collectResourceChanges() (recursive)
		11% in JavaModelManager.resourceChanged()
		4.3% in ResourceDeltaFactory.computeDelta()

	Hot-spots are
		14% socket read
		13% socket write
		12% String#substring
		4.6% String#indexOf
		3.6% Path#segments
		3.2% String#compareTo
		3.2% AccumulatingProgressMonitor#subtask
		3% Path#append
		3.2% String#concat

	Auto manage time (13.5%) seems to be spent determining what is ignored. There seems to be many ways to improve this!
	
MichaelV (20/09/2001 8:51:55 AM)

	There seems to be a lot of room for improvement in Subscriber#recursiveRefresh
	However, the general approach used by VCM to determine what changes there are seems to be
	inherently ineficient.

	In CVS clients, the following steps take place on an update
	1. Client sends information about all loaded files (versions and what has changed locally)
	2. Server makes one pass through to determine update reponse.
	3. Client uses response to update only as necessary
	This results in 2 to 3 passes through the project

	In VCM, the following occurs
	1. client sends information about known directories
	2. Server responds with information about new directories and files
	3. client requests file information (status)
	4. server responds + client must place file in resulting tree
	5. resulting tree + local structure traversed to update sync info
	6. local structure traversed to determine if their are changes
	My guess is that this is roughly equivalent to 5 passes

	Considering that some projects may be very large, this leads to slow syncing 
	which takes the same time whether there are changes or not.
	
MichaelV (21/09/2001 2:06:02 PM)

	I have optimized the recursive refresh itself but this has bought little (13000). The problem is
	that we do a get and write of the sync info at each node and this is costly. Furthermore,
	getting and setting get slower as the distance from the root increases. This is probably due
	to the fact that there are lots of files at the leaves. 

	Within getWorkspaces, getSharing and getProject are the main culprits. Can these be passed in?
	The project should be OK but I'm unsure of the sharing. getRepository also does a getProject.

	I have optimized SharingManager.manage to avoid internalGetSyncInfo and getProject. (from 13000 to 9000)
	However, we should not need a separate traversal to ensure that all non-ignored resources are managed!

	I have included change collection as part of the refresh. 
	(Much speed improvement!! from 12000 to virtualy 0)

MichaelV (24/09/2001 12:49:57 PM)
	
	Timings of local sync with auto-manage refresh and collection in same pass.

	100% = 30290 ms
	82.73% (25059) in Subscriber.refresh
		49.95% (15130) in CVSAdapter.fetchRemoteTree
		27.25% (8257) in Subscriber.refreshChildren
		5% (1512) in Policy.countResources
	15.34% (4649) in NotificationManager.getDelta()

	This is a savings of over 75% on VCM operations but no improvement in fetchRemoteTree. 
	Also, getDelta timings result from all the storeSyncInfo calls. One solution is
	to request only the delta information from the server as the CVS command-line
	client does.
 
Test Cases

	Sync for first time
	- on unshared project
	- on folder/file of unshared project
	- on folder/file of shared project

	Sync with outgoing, incomming and both

	Merges with outgoing, incomming and both"
""",
]

# Preprocess bug report descriptions
preprocessed_bug_reports = [preprocess_bug_description(description) for description in bug_reports]

# print preprocessed_bug_reports one by one
for i in range(len(preprocessed_bug_reports)):
	print(f"Preprocessed Bug Report {i+1}:", preprocessed_bug_reports[i])

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit the vectorizer to the preprocessed bug report data and transform it into TF-IDF vectors
tfidf_vectors = tfidf_vectorizer.fit_transform(preprocessed_bug_reports)

# Compute cosine similarity between each pair of bug reports
num_reports = len(bug_reports)
for i in range(num_reports):
    for j in range(i+1, num_reports):
        similarity_score = cosine_similarity(tfidf_vectors[i], tfidf_vectors[j])[0][0]
        print(f"Similarity between Bug Report {i+1} and Bug Report {j+1}: {similarity_score:.4f}")
# Out:
# Preprocessed Bug Report 1: bug report unknownhostexception is not caught when the host name is invalid in the repositories view newcvs repository location put a garbage host name eg eh complete the wizard expand the project version uhe is thrown log wed jun edt orgeclipsevcmcore cannot locate host eh javanetunknownhostexception eh at javanetinetaddressgetallbyname0inetaddressjava585 at javanetinetaddressgetallbyname0inetaddressjava554 at javanetinetaddressgetbynameinetaddressjava463 at javanetsocketinitsocketjava112 at orgeclipsevcminternalcoreccvsclientpserverconnectioncreatesocket pserverconnectionjava140 at orgeclipsevcminternalcoreccvsclientpserverconnectionopen pserverconnectionjava190 at orgeclipsevcminternalcoreccvsclientconnectionopen connectionjava224 at orgeclipsevcminternalcoreccvsclientclientinit clientjava226 at orgeclipsevcminternalcoreccvscvsadapterinternalfetchmembernames cvsadapterjava768 at orgeclipsevcminternalcoreccvscvsadapterfetchteamstreamprojectnames cvsadapterjava591 at orgeclipsevcminternalcoreteamstreamfetchprojects teamstreamjava58 at orgeclipsevcminternaluimodelteamstreamelementinternalgetchildren teamstreamelementjava82 at orgeclipsevcminternaluimodelteamstreamelement1run teamstreamelementjava39 at orgeclipseswtcustombusyindicatorshowwhilebusyindicatorjava97 at orgeclipsevcminternaluimodelteamstreamelementgetchildren teamstreamelementjava37 at orgeclipseuimodelworkbenchcontentprovidergetchildren workbenchcontentproviderjava53 at orgeclipsejfaceviewersabstracttreeviewergetrawchildren abstracttreeviewerjava568 at orgeclipsejfaceviewersstructuredviewergetfilteredchildren structuredviewerjava281 at orgeclipsejfaceviewersstructuredviewergetsortedchildren structuredviewerjava378 at orgeclipsejfaceviewersabstracttreeviewercreatechildren abstracttreeviewerjava238 at orgeclipsejfaceviewersabstracttreeviewerhandletreeexpand abstracttreeviewerjava611 at orgeclipsejfaceviewersabstracttreeviewer2treeexpanded abstracttreeviewerjava631 at orgeclipseswtwidgetstypedlistenerhandleeventtypedlistenerjava compiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetstreewmnotifychildtreejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwin32oscallwindowprocnative method at orgeclipseswtwidgetstreecallwindowproctreejavacompiled code at orgeclipseswtwidgetstreewmlbuttondowntreejava1043 at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwin32osdispatchmessagenative method at orgeclipseswtwidgetsdisplayreadanddispatchdisplayjava compiled code at orgeclipseuiinternalworkbenchruneventloopworkbenchjava compiled code at orgeclipseuiinternalworkbenchrunworkbenchjava620 at orgeclipsecoreinternalbootinternalbootloaderrun internalbootloaderjava815 at orgeclipsecorebootbootloaderrunbootloaderjava285 at javalangreflectmethodinvokenative method at orgeclipsecorelaunchermainbasicrunmainjava69 at orgeclipsecorelaunchermainrunmainjava311 at orgeclipsecorelaunchermainmainmainjava198 notes km pm recommend we catch at level of teamstreamelementinternalgetchildren and do errordialogopenerror recommend that class because its only ui place we can catch and its already catching coreexceptions there anyway there are other places you could get this error since we lazy verify connections but this is the most common also noticed that in vcmmodelelementhandle where this is being caught we should not be loging info messages only errors kh pm yes
# Preprocessed Bug Report 2: bug report after having synchronized and released successfully with teamstream on zrhcvs i attempted to version the project orgeclipsejdtcore and got a dialog saying cvs communication error following stack trace was in the log log sat jun cest orgeclipsevcmcore cvs communication error javaiointerruptedioexception read timed out at javanetsocketinputstreamsocketreadnative method at javanetsocketinputstreamreadsocketinputstreamjavacompiled code at javaiobufferedinputstreamfillbufferedinputstreamjavacompiled code at javaiobufferedinputstreamreadbufferedinputstreamjavacompiled code at orgeclipsevcminternalcoreccvsclientconnectionreadlineoruntilconnectionjavacompiled code at orgeclipsevcminternalcoreccvsclientconnectionreadtokenconnectionjavacompiled code at orgeclipsevcminternalcoreccvsclientclientprocessresponsesclientjavacompiled code at orgeclipsevcminternalcoreccvsclientclientprocessresponsesclientjava397 at orgeclipsevcminternalcoreccvsclientclientexecuteclientjava257 at orgeclipsevcminternalcoreccvscvsadaptercreateprojectversioncvsadapterjava313 at orgeclipsevcminternalcoresharingmanagercreateprojectversionsharingmanagerjava71 at orgeclipsevcminternaluiactionsversionactionversionlocaloperationversionversionactionjava121 at orgeclipsevcminternaluiversionresourcesoperationrunversionresourcesoperationjava45 at orgeclipsejfaceoperationmodalcontextmodalcontextthreadrunmodalcontextjava98 notes pm am my network connection did not drop i am connected over vpn from home to ott next versioning attempt worked fine
# Preprocessed Bug Report 3: bug report when the connection to the repositories fails interruptedioexception is not caught log wed jun edt orgeclipsevcmcore cannot connect to host cvslnxtest javaiointerruptedioexception operation timed out no further information at javanetplainsocketimplsocketconnectnative method at javanetplainsocketimpldoconnectplainsocketimpljava329 at javanetplainsocketimplconnecttoaddressplainsocketimpljava141 at javanetplainsocketimplconnectplainsocketimpljava128 at javanetsocketinitsocketjava285 at javanetsocketinitsocketjava112 at orgeclipsevcminternalcoreccvsclientpserverconnectioncreatesocketpserverconnectionjava140 at orgeclipsevcminternalcoreccvsclientpserverconnectionopenpserverconnectionjava190 at orgeclipsevcminternalcoreccvsclientconnectionopenconnectionjava224 at orgeclipsevcminternalcoreccvsclientclientinitclientjava227 at orgeclipsevcminternalcoreccvscvsadapterinternalfetchmembernamescvsadapterjava778 at orgeclipsevcminternalcoreccvscvsadapterfetchprojectnamescvsadapterjava485 at orgeclipsevcminternalcorerepositoryfetchprojectlistrepositoryjava128 at orgeclipsevcminternaluimodelprojectversionscategoryinternalgetchildrenprojectversionscategoryjava92 at orgeclipsevcminternaluimodelprojectversionscategory1runprojectversionscategoryjava48 at orgeclipseswtcustombusyindicatorshowwhilebusyindicatorjavacompiled code at orgeclipsevcminternaluimodelprojectversionscategorygetchildrenprojectversionscategoryjava46 at orgeclipseuimodelworkbenchcontentprovidergetchildrenworkbenchcontentproviderjava51 at orgeclipsejfaceviewersabstracttreeviewergetrawchildrenabstracttreeviewerjava568 at orgeclipsejfaceviewersstructuredviewergetfilteredchildrenstructuredviewerjavacompiled code at orgeclipsejfaceviewersstructuredviewergetsortedchildrenstructuredviewerjavacompiled code at orgeclipsejfaceviewersabstracttreeviewercreatechildrenabstracttreeviewerjavacompiled code at orgeclipsejfaceviewersabstracttreeviewerhandletreeexpandabstracttreeviewerjava611 at orgeclipsejfaceviewersabstracttreeviewer2treeexpandedabstracttreeviewerjava631 at orgeclipseswtwidgetstypedlistenerhandleeventtypedlistenerjavacompiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetswidgetsendeventwidgetjavacompiled code at orgeclipseswtwidgetstreewmnotifychildtreejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscompositewmnotifycompositejavacompiled code at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwin32oscallwindowprocnative method at orgeclipseswtwidgetstreewmlbuttondowntreejavacompiled code at orgeclipseswtwidgetstreewmlbuttondowntreejavacompiled code at orgeclipseswtwidgetscontrolwindowproccontroljavacompiled code at orgeclipseswtwidgetsdisplaywindowprocdisplayjavacompiled code at orgeclipseswtinternalwin32osdispatchmessagenative method at orgeclipseswtwidgetsdisplayreadanddispatchdisplayjavacompiled code at orgeclipseuiinternalworkbenchruneventloopworkbenchjavacompiled code at orgeclipseuiinternalworkbenchrunworkbenchjava620 at orgeclipsecoreinternalbootinternalbootloaderruninternalbootloaderjava815 at orgeclipsecorebootbootloaderrunbootloaderjava285 at javalangreflectmethodinvokenative method at orgeclipsecorelaunchermainbasicrunmainjava126 at orgeclipsecorelaunchermainrunmainjava408 at orgeclipsecorelaunchermainmainmainjava281
# Preprocessed Bug Report 4: bug report since refresh is called before the catchuprelease view opens it should be as fast as possible notes bb am the most promising optimization idea is dont return an iserverresourcetree from fetchremotetree but instead use a callback to interleave the server communication with updating the sync info bb am see this pr for other performance tuning opportunities 1gat2v2 itpvcmwinnt releasing very slow michaelv pm here are some percentages on a refresh from ott to paris with autobuild turned off total time ms in subscriberrefresh cvsadapterfetchremotetree subscriberrecursiverefresh in sharingmanagermanage from orgeclipsevcmuisyncrepositoryautomanage what is automanage in orgeclipsevcmuisyncrepositorycollectresourcechanges recursive in javamodelmanagerresourcechanged in resourcedeltafactorycomputedelta hotspots are socket read socket write stringsubstring stringindexof pathsegments stringcompareto accumulatingprogressmonitorsubtask pathappend stringconcat auto manage time seems to be spent determining what is ignored there seems to be many ways to improve this michaelv am there seems to be a lot of room for improvement in subscriberrecursiverefresh however the general approach used by vcm to determine what changes there are seems to be inherently ineficient in cvs clients the following steps take place on an update client sends information about all loaded files versions and what has changed locally server makes one pass through to determine update reponse client uses response to update only as necessary this results in to passes through the project in vcm the following occurs client sends information about known directories server responds with information about new directories and files client requests file information status server responds client must place file in resulting tree resulting tree local structure traversed to update sync info local structure traversed to determine if their are changes my guess is that this is roughly equivalent to passes considering that some projects may be very large this leads to slow syncing which takes the same time whether there are changes or not michaelv pm i have optimized the recursive refresh itself but this has bought little the problem is that we do a get and write of the sync info at each node and this is costly furthermore getting and setting get slower as the distance from the root increases this is probably due to the fact that there are lots of files at the leaves within getworkspaces getsharing and getproject are the main culprits can these be passed in the project should be ok but im unsure of the sharing getrepository also does a getproject i have optimized sharingmanagermanage to avoid internalgetsyncinfo and getproject from to however we should not need a separate traversal to ensure that all nonignored resources are managed i have included change collection as part of the refresh much speed improvement from to virtualy michaelv pm timings of local sync with automanage refresh and collection in same pass ms in subscriberrefresh in cvsadapterfetchremotetree in subscriberrefreshchildren in policycountresources in notificationmanagergetdelta this is a savings of over on vcm operations but no improvement in fetchremotetree also getdelta timings result from all the storesyncinfo calls one solution is to request only the delta information from the server as the cvs commandline client does test cases sync for first time on unshared project on folderfile of unshared project on folderfile of shared project sync with outgoing incomming and both merges with outgoing incomming and both
# Similarity between Bug Report 1 and Bug Report 2: 0.6395
# Similarity between Bug Report 1 and Bug Report 3: 0.8611
# Similarity between Bug Report 1 and Bug Report 4: 0.1502
# Similarity between Bug Report 2 and Bug Report 3: 0.6971
# Similarity between Bug Report 2 and Bug Report 4: 0.1745
# Similarity between Bug Report 3 and Bug Report 4: 0.0574

# %%
# Function to expand contractions
def expand_contractions(text):
    contractions_dict = {
        "don't": "do not",
        "doesn't": "does not",
        "can't": "cannot",
        "won't": "will not",
        "wouldn't": "would not",
        "shouldn't": "should not",
        "couldn't": "could not",
        "isn't": "is not",
        "aren't": "are not",
        "wasn't": "was not",
        "weren't": "were not",
        "haven't": "have not",
        "hasn't": "has not",
        "hadn't": "had not",
        "it's": "it is",
        "he's": "he is",
        "she's": "she is",
        "i'm": "i am",
        "you're": "you are",
        "they're": "they are",
        "we're": "we are",
        "that's": "that is",
        "who's": "who is",
        "what's": "what is",
        "where's": "where is",
        "when's": "when is",
        "why's": "why is",
        "how's": "how is"
    }
    for contraction, expansion in contractions_dict.items():
        text = re.sub(r'\b' + contraction + r'\b', expansion, text)
    return text

# Function to preprocess bug description text
def preprocess_bug_description(text):
    # Remove unnecessary sections (timestamps, log messages, stack traces, notes)
    text = re.sub(r'Log:.*$', '', text, flags=re.MULTILINE)
    text = re.sub(r'NOTES:.*$', '', text, flags=re.MULTILINE)
    
    # Lowercase the text
    text = text.lower()
    
    # Remove punctuation and numbers
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Expand contractions
    text = expand_contractions(text)
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Lemmatization and stemming
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    
    # Normalize whitespace
    text = ' '.join(tokens)
    
    return text
