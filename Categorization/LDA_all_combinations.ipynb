# %%
import pandas as pd
import os
import numpy as np
import string
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# path of training data
train_path = 'train.xlsx'

# path of testing data
test_path = 'test.xlsx'

# %%
# show the first 5 rows of the training data
train_df = pd.read_excel(train_path)
print(train_df.head())

# show the first 5 rows of the testing data
test_df = pd.read_excel(test_path)
print(test_df.head())
# Out:
#                                               report class_name  class_index
# 0  "For any event on my bookmarked projects" opti...    Backend            1
# 1           Switch to using full l10n id's in urlbar   Frontend            2
# 2  Consider removing hasicon property to simplify...   Frontend            2
# 3  Method to obtain current URL from WebBrowserEd...   Frontend            2
# 4              Fix: migration fails in MS SQL-Server    Backend            1
#                                               report class_name  class_index
# 0  REST API - ability to list sub projects for a ...    Backend            1
# 1  support selective text on right if set in GNOM...   Frontend            2
# 2  [meta][userstory] Ship v1 of Pre-populated top...   Frontend            2
# 3  Include updated_on and passwd_changed_on colum...    Backend            1
# 4    Problem with email integration to MS Office 365    Backend            1

# %%
def convert_lower_case(data):
    return str(data).lower()

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in symbols:
        data = np.char.replace(data, i, ' ')

    return str(data)

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def remove_numbers(data):
    return re.sub(r'\d+', '', str(data))

# %%
def remove_single_characters(tokens):
    new_text = ""
    for w in tokens:
        if len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def lemmatization(data):
    lemmatizer = WordNetLemmatizer()
    tokens = word_tokenize(data)
    data = remove_single_characters(tokens)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(word) for word in tokens])
    return lemmatized_output

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data)
    data = remove_apostrophe(data)
    data = remove_numbers(data)
    data = lemmatization(data)
    return data

# %%
# print the first report of the training data
print(train_df['report'][0])
# Out:
# "For any event on my bookmarked projects" option not sending notifications for non-member bookmarked projects

# %%
# preprocess the first report of the training data
print(preprocess(train_df['report'][0]))
# Out:
# for any event on my bookmarked project option not sending notification for non member bookmarked project

# %%
import pandas as pd

# Assuming train_df is your DataFrame containing training data
# Assuming train_df has columns 'id', 'report', and 'class_name'

# Initialize counter
counter = 1

# Iterate over each row in the DataFrame
with open('preprocessed_train_data.csv', 'w', encoding='utf-8') as f:
    f.write('bug_description , class_name\n')  # Write header

    for _, row in train_df.iterrows():
        # Preprocess the 'report' column
        preprocessed_report = preprocess(row['report'])

        # Write data to the file with incremented counter
        f.write(f"{preprocessed_report},{row['class_name']}\n")

# Print the first preprocessed report
print(train_df['report'][0])
# Out:
# "For any event on my bookmarked projects" option not sending notifications for non-member bookmarked projects

# %%
# FOR TESTING DATA

# Iterate over each row in the DataFrame
with open('preprocessed_test_data.csv', 'w', encoding='utf-8') as f:
    f.write('bug_description , class_name\n')  # Write header

    for _, row in test_df.iterrows():
        # Preprocess the 'report' column
        preprocessed_report = preprocess(row['report'])

        # Write data to the file with incremented counter
        f.write(f"{preprocessed_report},{row['class_name']}\n")

# Print the first preprocessed report
print(test_df['report'][0])
# Out:
# REST API - ability to list sub projects for a project

# %%
# Open the preprocessed data file for reading
with open('preprocessed_train_data.csv', 'r', encoding='utf-8') as f:
    # Open the new file for writing preprocessed data with 2 columns
    with open('preprocessed_train_data2.csv', 'w', encoding='utf-8') as f_out:
        # Iterate over each line in the file
        for i, line in enumerate(f):
            # Skip the header
            if i == 0:
                continue
            
            # Split the line into columns based on comma delimiter
            columns = line.strip().split(',')
            
            # Check the number of columns
            if len(columns) == 2:
                # Get the preprocessed report and class name
                preprocessed_report = columns[0]
                class_name = columns[1]
                
                # Write the preprocessed report and class name to the new file
                f_out.write(f"{preprocessed_report},{class_name}\n")
            else:
                # Skip the line if it doesn't have exactly 2 columns
                continue

# %%
# FOR TESTING DATA

# Open the preprocessed data file for reading
with open('preprocessed_test_data.csv', 'r', encoding='utf-8') as f:
    # Open the new file for writing preprocessed data with 2 columns
    with open('preprocessed_test_data2.csv', 'w', encoding='utf-8') as f_out:
        # Iterate over each line in the file
        for i, line in enumerate(f):
            # Skip the header
            if i == 0:
                continue
            
            # Split the line into columns based on comma delimiter
            columns = line.strip().split(',')
            
            # Check the number of columns
            if len(columns) == 2:
                # Get the preprocessed report and class name
                preprocessed_report = columns[0]
                class_name = columns[1]
                
                # Write the preprocessed report and class name to the new file
                f_out.write(f"{preprocessed_report},{class_name}\n")
            else:
                # Skip the line if it doesn't have exactly 2 columns
                continue

# %%
# read the preprocessed data from the new file
preprocessed_train_df = pd.read_csv('preprocessed_train_data2.csv')

# show the first 5 rows of the preprocessed training data
print(preprocessed_train_df.head())
# Out:
#                                      bug_description class_name
# 0  for any event on my bookmarked project option ...    Backend
# 1               switch to using full ln id in urlbar   Frontend
# 2  consider removing hasicon property to simplify...   Frontend
# 3  method to obtain current url from webbrowsered...   Frontend
# 4                fix migration fails in m sql server    Backend

# %%
# read the preprocessed data from the new file
preprocessed_test_df = pd.read_csv('preprocessed_test_data2.csv')

# show the first 5 rows of the preprocessed training data
print(preprocessed_test_df.head())
# Out:
#                                      bug_description class_name
# 0  rest api ability to list sub project for a pro...    Backend
# 1  support selective text on right if set in gnom...   Frontend
# 2  meta userstory ship v of pre populated topsite...   Frontend
# 3  include updated on and passwd changed on colum...    Backend
# 4         problem with email integration to m office    Backend

# %%
# remove the stop words from the preprocessed data using nltk
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

def remove_stop_words(data):
    tokens = word_tokenize(data)
    data = ' '.join([i for i in tokens if not i in stop_words])
    return data

# preprocess the first report of the training data
print(preprocess(train_df['report'][0]))

# remove the stop words from the preprocessed data
print(remove_stop_words(preprocess(train_df['report'][0])))

# preprocess the first report of the testing data
print(preprocess(test_df['report'][0]))
# Out:
# for any event on my bookmarked project option not sending notification for non member bookmarked project
# event bookmarked project option sending notification non member bookmarked project
# rest api ability to list sub project for a project
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Convert non-string values to strings in 'bug_description' column
preprocessed_train_df['bug_description'] = preprocessed_train_df['bug_description'].apply(lambda x: str(x))
preprocessed_test_df['bug_description'] = preprocessed_test_df['bug_description'].apply(lambda x: str(x))

# Remove stop words from 'bug_description' column
preprocessed_train_df['bug_description'] = preprocessed_train_df['bug_description'].apply(lambda x: remove_stop_words(x))
preprocessed_test_df['bug_description'] = preprocessed_test_df['bug_description'].apply(lambda x: remove_stop_words(x))

# Show the first 5 rows of the preprocessed training data
print(preprocessed_train_df.head())

# Show the first 5 rows of the preprocessed testing data
print(preprocessed_test_df.head())
# Out:
#                                      bug_description class_name
# 0  event bookmarked project option sending notifi...    Backend
# 1                     switch using full ln id urlbar   Frontend
# 2  consider removing hasicon property simplify st...   Frontend
# 3         method obtain current url webbrowsereditor   Frontend
# 4                     fix migration fails sql server    Backend
#                                      bug_description class_name
# 0          rest api ability list sub project project    Backend
# 1     support selective text right set gnome setting   Frontend
# 2  meta userstory ship v pre populated topsites a...   Frontend
# 3  include updated passwd changed column user api...    Backend
# 4                   problem email integration office    Backend

# %%
# keep only the reports that has class_name of Frontend, Backend
# Filter the training data
filtered_train_df = preprocessed_train_df[
    (preprocessed_train_df['class_name'] == 'Frontend') | 
    (preprocessed_train_df['class_name'] == 'Backend')
]

# Filter the testing data
filtered_test_df = preprocessed_test_df[
    (preprocessed_test_df['class_name'] == 'Frontend') | 
    (preprocessed_test_df['class_name'] == 'Backend')
]

# Show the first 5 rows of the filtered training data
print("Filtered Training Data:")
print(filtered_train_df.head())

# Show the first 5 rows of the filtered testing data
print("\nFiltered Testing Data:")
print(filtered_test_df.head())
# Out:
# Filtered Training Data:
#                                      bug_description class_name
# 0  event bookmarked project option sending notifi...    Backend
# 1                     switch using full ln id urlbar   Frontend
# 2  consider removing hasicon property simplify st...   Frontend
# 3         method obtain current url webbrowsereditor   Frontend
# 4                     fix migration fails sql server    Backend
#
# Filtered Testing Data:
#                                      bug_description class_name
# 0          rest api ability list sub project project    Backend
# 1     support selective text right set gnome setting   Frontend
# 2  meta userstory ship v pre populated topsites a...   Frontend
# 3  include updated passwd changed column user api...    Backend
# 4                   problem email integration office    Backend

# %%
# print the unique class names in the training data
print(filtered_train_df['class_name'].unique())

# print the unique class names in the testing data
print(filtered_test_df['class_name'].unique())
# Out:
# ['Backend' 'Frontend']
# ['Backend' 'Frontend']

# %% [markdown]
# ## Feature Exraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Replace NaN values with an empty string
preprocessed_train_df['bug_description'].fillna('', inplace=True)

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the preprocessed data
X_train = vectorizer.fit_transform(filtered_train_df['bug_description'])

# Print the shape of X_train
print(X_train.shape)
# Out:
# (13236, 7304)

# %%
# print the vector representation of the first report
print(X_train[0])
# Out:
#   (0, 3814)	0.28841526302990617
#   (0, 4128)	0.25104918788961694
#   (0, 4158)	0.18214347162409292
#   (0, 5630)	0.30509756351985684
#   (0, 4346)	0.21058799657286695
#   (0, 4849)	0.3799346246464815
#   (0, 651)	0.6803204047615824
#   (0, 2087)	0.2756749849905213

# %%
# Print the number of unique class_name in the training data
print(filtered_train_df['class_name'].nunique())

# print their unique values
print(filtered_train_df['class_name'].unique())

# print the number of reports in each class
print(filtered_train_df['class_name'].value_counts())
# Out:
# 2
# ['Backend' 'Frontend']
# Backend     7437
# Frontend    5799
# Name: class_name, dtype: int64

# %%
# Create a mapping between cluster labels and class names
cluster_class_mapping = {
    1: 'Backend',  # Example mapping, adjust based on your actual clusters
    0: 'Frontend',
}

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

def lda_topic_modeling(data, class_name, n_components=2, ngram_range=(1, 2), random_state=42):
    """
    Perform Latent Dirichlet Allocation (LDA) topic modeling on the given data and evaluate on test data.

    Parameters:
    - data: DataFrame containing the text data to be modeled.
    - class_name: Series containing the class names corresponding to the data.
    - n_components: Number of topics to be generated (default is 2).
    - ngram_range: Tuple specifying the range of n-grams to consider (default is (1, 2)).
    - random_state: Random seed for reproducibility (default is 42).

    Returns:
    - None
    """
    # Initialize the TfidfVectorizer
    vectorizer = TfidfVectorizer(ngram_range=ngram_range)

    # Fit and transform the data
    X_train = vectorizer.fit_transform(data)

    # Initialize the LDA model
    lda_model = LatentDirichletAllocation(n_components=n_components, random_state=random_state)

    # Fit the LDA model
    lda_model.fit(X_train)

    # Print the top words for each topic
    for i, topic in enumerate(lda_model.components_):
        print(f"Top words for topic #{i}:")
        print([vectorizer.get_feature_names_out()[index] for index in topic.argsort()[-10:]])
        print("\n")

    # Transform the preprocessed test data
    X_test = vectorizer.transform(filtered_test_df['bug_description'])

    # Predict the topics for the test data
    topic_predictions = lda_model.transform(X_test)

    # Map numerical indices to class names
    predicted_class_names = [cluster_class_mapping[prediction] for prediction in np.argmax(topic_predictions, axis=1)]

    # Print the classification report
    print("Classification Report:")
    print(classification_report(class_name, predicted_class_names))

    # Print the confusion matrix
    print("Confusion Matrix:")
    print(confusion_matrix(class_name, predicted_class_names))

    # Calculate and print the accuracy
    accuracy = np.mean(class_name == predicted_class_names)
    print("Accuracy:", accuracy)

    # precision
    precision = np.mean(class_name == predicted_class_names)
    print("Precision:", precision)

    # recall
    recall = np.mean(class_name == predicted_class_names)
    print("Recall:", recall)

    # f1-score
    f1_score = np.mean(class_name == predicted_class_names)
    print("F1-Score:", f1_score)

# Usage example:
lda_topic_modeling(filtered_train_df['bug_description'], filtered_test_df['class_name'])
# Out:
# Top words for topic #0:
# ['file', 'type', 'work', 'rest', 'issue', 'redmine', 'search', 'user', 'api', 'tab']
#
#
# Top words for topic #1:
# ['tab', 'error', 'user', 'api', 'add', 'project', 'email notification', 'issue', 'email', 'notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.55      0.51      0.53      1345
#     Frontend       0.40      0.44      0.42       987
#
#     accuracy                           0.48      2332
#    macro avg       0.47      0.47      0.47      2332
# weighted avg       0.49      0.48      0.48      2332
#
# Confusion Matrix:
# [[686 659]
#  [555 432]]
# Accuracy: 0.4794168096054888
# Precision: 0.4794168096054888
# Recall: 0.4794168096054888
# F1-Score: 0.4794168096054888

# %%
# iterate to cover all possible combinations of ngram_range:
# 1- (1, 1) , (1, 2) , (1, 3)and so on till (1,15)
# 2- (2, 2) , (2, 3) , (2, 4)and so on till (2,15)
# 3- (3, 3) , (3, 4) , (3, 5)and so on till (3,15)
# and so on till (15, 15)

# Create a list of tuples containing the range of n-grams to consider
ngram_ranges = [(i, j) for i in range(1, 16) for j in range(i, 16)]

# Iterate over each n-gram range
for ngram_range in ngram_ranges:
    print(f"Processing ngram_range: {ngram_range}")
    lda_topic_modeling(filtered_train_df['bug_description'], filtered_test_df['class_name'], ngram_range=ngram_range)
    print("------------------------------------------------------------------")
# Out:
# Processing ngram_range: (1, 1)
# Top words for topic #0:
# ['type', 'option', 'window', 'file', 'menu', 'notification', 'redmine', 'error', 'email', 'tab']
#
#
# Top words for topic #1:
# ['email', 'rest', 'field', 'project', 'page', 'user', 'search', 'add', 'issue', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.58      0.47      0.52      1345
#     Frontend       0.43      0.54      0.48       987
#
#     accuracy                           0.50      2332
#    macro avg       0.51      0.51      0.50      2332
# weighted avg       0.52      0.50      0.50      2332
#
# Confusion Matrix:
# [[638 707]
#  [453 534]]
# Accuracy: 0.5025728987993139
# Precision: 0.5025728987993139
# Recall: 0.5025728987993139
# F1-Score: 0.5025728987993139
# ------------------------------------------------------------------
# Processing ngram_range: (1, 2)
# Top words for topic #0:
# ['file', 'type', 'work', 'rest', 'issue', 'redmine', 'search', 'user', 'api', 'tab']
#
#
# Top words for topic #1:
# ['tab', 'error', 'user', 'api', 'add', 'project', 'email notification', 'issue', 'email', 'notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.55      0.51      0.53      1345
#     Frontend       0.40      0.44      0.42       987
#
#     accuracy                           0.48      2332
#    macro avg       0.47      0.47      0.47      2332
# weighted avg       0.49      0.48      0.48      2332
#
# Confusion Matrix:
# [[686 659]
#  [555 432]]
# Accuracy: 0.4794168096054888
# Precision: 0.4794168096054888
# Recall: 0.4794168096054888
# F1-Score: 0.4794168096054888
# ------------------------------------------------------------------
# Processing ngram_range: (1, 3)
# Top words for topic #0:
# ['rest', 'add', 'issue', 'email notification', 'project', 'notification', 'email', 'user', 'tab', 'api']
#
#
# Top words for topic #1:
# ['page', 'api', 'tab', 'redmine', 'add', 'notification', 'error', 'search', 'issue', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.60      0.50      0.55      1345
#     Frontend       0.44      0.55      0.49       987
#
#     accuracy                           0.52      2332
#    macro avg       0.52      0.52      0.52      2332
# weighted avg       0.53      0.52      0.52      2332
#
# Confusion Matrix:
# [[672 673]
#  [449 538]]
# Accuracy: 0.5188679245283019
# Precision: 0.5188679245283019
# Recall: 0.5188679245283019
# F1-Score: 0.5188679245283019
# ------------------------------------------------------------------
# Processing ngram_range: (1, 4)
# Top words for topic #0:
# ['new', 'search', 'error', 'redmine', 'add', 'user', 'project', 'api', 'issue', 'tab']
#
#
# Top words for topic #1:
# ['error', 'search', 'tab', 'add', 'issue', 'user', 'api', 'email notification', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.67      0.50      0.57      1345
#     Frontend       0.49      0.66      0.56       987
#
#     accuracy                           0.57      2332
#    macro avg       0.58      0.58      0.57      2332
# weighted avg       0.59      0.57      0.57      2332
#
# Confusion Matrix:
# [[668 677]
#  [335 652]]
# Accuracy: 0.5660377358490566
# Precision: 0.5660377358490566
# Recall: 0.5660377358490566
# F1-Score: 0.5660377358490566
# ------------------------------------------------------------------
# Processing ngram_range: (1, 5)
# Top words for topic #0:
# ['error', 'project', 'add', 'issue', 'email notification', 'redmine', 'api', 'user', 'email', 'notification']
#
#
# Top words for topic #1:
# ['new', 'user', 'project', 'add', 'error', 'search', 'api', 'issue', 'email', 'tab']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.53      0.49      0.51      1345
#     Frontend       0.37      0.41      0.39       987
#
#     accuracy                           0.46      2332
#    macro avg       0.45      0.45      0.45      2332
# weighted avg       0.46      0.46      0.46      2332
#
# Confusion Matrix:
# [[654 691]
#  [579 408]]
# Accuracy: 0.4554030874785592
# Precision: 0.4554030874785592
# Recall: 0.4554030874785592
# F1-Score: 0.4554030874785592
# ------------------------------------------------------------------
# Processing ngram_range: (1, 6)
# Top words for topic #0:
# ['file', 'page', 'error', 'project', 'email', 'api', 'user', 'search', 'tab', 'add']
#
#
# Top words for topic #1:
# ['project', 'error', 'user', 'tab', 'email notification', 'redmine', 'api', 'issue', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.57      0.58      1345
#     Frontend       0.44      0.46      0.45       987
#
#     accuracy                           0.52      2332
#    macro avg       0.51      0.51      0.51      2332
# weighted avg       0.53      0.52      0.52      2332
#
# Confusion Matrix:
# [[769 576]
#  [537 450]]
# Accuracy: 0.5227272727272727
# Precision: 0.5227272727272727
# Recall: 0.5227272727272727
# F1-Score: 0.5227272727272727
# ------------------------------------------------------------------
# Processing ngram_range: (1, 7)
# Top words for topic #0:
# ['email notification', 'redmine', 'project', 'user', 'tab', 'error', 'search', 'issue', 'notification', 'email']
#
#
# Top words for topic #1:
# ['project', 'rest', 'redmine', 'issue', 'add', 'user', 'notification', 'tab', 'email', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.61      0.57      0.59      1345
#     Frontend       0.46      0.50      0.48       987
#
#     accuracy                           0.54      2332
#    macro avg       0.53      0.53      0.53      2332
# weighted avg       0.55      0.54      0.54      2332
#
# Confusion Matrix:
# [[763 582]
#  [492 495]]
# Accuracy: 0.5394511149228131
# Precision: 0.5394511149228131
# Recall: 0.5394511149228131
# F1-Score: 0.5394511149228131
# ------------------------------------------------------------------
# Processing ngram_range: (1, 8)
# Top words for topic #0:
# ['project', 'search', 'rest', 'error', 'add', 'tab', 'redmine', 'issue', 'user', 'api']
#
#
# Top words for topic #1:
# ['user', 'search', 'add', 'error', 'project', 'issue', 'tab', 'email notification', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.56      0.49      0.52      1345
#     Frontend       0.40      0.47      0.43       987
#
#     accuracy                           0.48      2332
#    macro avg       0.48      0.48      0.48      2332
# weighted avg       0.49      0.48      0.48      2332
#
# Confusion Matrix:
# [[661 684]
#  [527 460]]
# Accuracy: 0.4807032590051458
# Precision: 0.4807032590051458
# Recall: 0.4807032590051458
# F1-Score: 0.4807032590051458
# ------------------------------------------------------------------
# Processing ngram_range: (1, 9)
# Top words for topic #0:
# ['support', 'notification', 'error', 'email', 'tab', 'user', 'add', 'issue', 'redmine', 'api']
#
#
# Top words for topic #1:
# ['error', 'issue', 'search', 'api', 'email notification', 'project', 'user', 'tab', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.54      0.54      1345
#     Frontend       0.38      0.38      0.38       987
#
#     accuracy                           0.47      2332
#    macro avg       0.46      0.46      0.46      2332
# weighted avg       0.47      0.47      0.47      2332
#
# Confusion Matrix:
# [[725 620]
#  [614 373]]
# Accuracy: 0.47084048027444253
# Precision: 0.47084048027444253
# Recall: 0.47084048027444253
# F1-Score: 0.47084048027444253
# ------------------------------------------------------------------
# Processing ngram_range: (1, 10)
# Top words for topic #0:
# ['redmine', 'search', 'error', 'issue', 'email', 'tab', 'user', 'add', 'api', 'project']
#
#
# Top words for topic #1:
# ['error', 'search', 'redmine', 'user', 'api', 'tab', 'issue', 'email notification', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.57      0.49      0.53      1345
#     Frontend       0.42      0.51      0.46       987
#
#     accuracy                           0.50      2332
#    macro avg       0.50      0.50      0.49      2332
# weighted avg       0.51      0.50      0.50      2332
#
# Confusion Matrix:
# [[653 692]
#  [483 504]]
# Accuracy: 0.4961406518010292
# Precision: 0.4961406518010292
# Recall: 0.4961406518010292
# F1-Score: 0.4961406518010292
# ------------------------------------------------------------------
# Processing ngram_range: (1, 11)
# Top words for topic #0:
# ['add', 'search', 'email', 'project', 'page', 'api', 'error', 'user', 'issue', 'tab']
#
#
# Top words for topic #1:
# ['search', 'tab', 'add', 'user', 'issue', 'redmine', 'email notification', 'api', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.57      0.49      0.53      1345
#     Frontend       0.42      0.50      0.46       987
#
#     accuracy                           0.50      2332
#    macro avg       0.50      0.50      0.49      2332
# weighted avg       0.51      0.50      0.50      2332
#
# Confusion Matrix:
# [[658 687]
#  [490 497]]
# Accuracy: 0.49528301886792453
# Precision: 0.49528301886792453
# Recall: 0.49528301886792453
# F1-Score: 0.49528301886792453
# ------------------------------------------------------------------
# Processing ngram_range: (1, 12)
# Top words for topic #0:
# ['page', 'notification', 'api', 'new', 'issue', 'redmine', 'email', 'user', 'add', 'tab']
#
#
# Top words for topic #1:
# ['redmine', 'search', 'project', 'error', 'user', 'email notification', 'issue', 'api', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.63      0.59      0.61      1345
#     Frontend       0.49      0.54      0.51       987
#
#     accuracy                           0.57      2332
#    macro avg       0.56      0.56      0.56      2332
# weighted avg       0.57      0.57      0.57      2332
#
# Confusion Matrix:
# [[787 558]
#  [454 533]]
# Accuracy: 0.5660377358490566
# Precision: 0.5660377358490566
# Recall: 0.5660377358490566
# F1-Score: 0.5660377358490566
# ------------------------------------------------------------------
# Processing ngram_range: (1, 13)
# Top words for topic #0:
# ['notification', 'file', 'search', 'issue', 'page', 'project', 'add', 'api', 'tab', 'user']
#
#
# Top words for topic #1:
# ['add', 'search', 'tab', 'error', 'redmine', 'api', 'email notification', 'issue', 'notification', 'email']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.58      0.49      0.53      1345
#     Frontend       0.42      0.51      0.46       987
#
#     accuracy                           0.50      2332
#    macro avg       0.50      0.50      0.50      2332
# weighted avg       0.51      0.50      0.50      2332
#
# Confusion Matrix:
# [[658 687]
#  [484 503]]
# Accuracy: 0.4978559176672384
# Precision: 0.4978559176672384
# Recall: 0.4978559176672384
# F1-Score: 0.4978559176672384
# ------------------------------------------------------------------
# Processing ngram_range: (1, 14)
# Top words for topic #0:
# ['tab', 'error', 'user', 'project', 'api', 'redmine', 'email notification', 'issue', 'notification', 'email']
#
#
# Top words for topic #1:
# ['project', 'page', 'issue', 'new', 'error', 'search', 'add', 'user', 'api', 'tab']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.57      0.50      0.53      1345
#     Frontend       0.42      0.48      0.45       987
#
#     accuracy                           0.49      2332
#    macro avg       0.49      0.49      0.49      2332
# weighted avg       0.50      0.49      0.50      2332
#
# Confusion Matrix:
# [[677 668]
#  [513 474]]
# Accuracy: 0.4935677530017153
# Precision: 0.4935677530017153
# Recall: 0.4935677530017153
# F1-Score: 0.4935677530017153
# ------------------------------------------------------------------
# Processing ngram_range: (1, 15)
# Top words for topic #0:
# ['project', 'add', 'api', 'user', 'search', 'email notification', 'tab', 'issue', 'notification', 'email']
#
#
# Top words for topic #1:
# ['notification', 'project', 'add', 'issue', 'email', 'tab', 'user', 'error', 'redmine', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.50      0.54      1345
#     Frontend       0.43      0.52      0.47       987
#
#     accuracy                           0.51      2332
#    macro avg       0.51      0.51      0.51      2332
# weighted avg       0.52      0.51      0.51      2332
#
# Confusion Matrix:
# [[670 675]
#  [470 517]]
# Accuracy: 0.5090051457975986
# Precision: 0.5090051457975986
# Recall: 0.5090051457975986
# F1-Score: 0.5090051457975986
# ------------------------------------------------------------------
# Processing ngram_range: (2, 2)
# Top words for topic #0:
# ['working set', 'doe work', 'address bar', 'context menu', 'send email', 'search engine', 'custom field', 'new tab', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['content assist', 'error message', 'doesnt work', 'internal error', 'via rest', 'new tab', 'due date', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.63      0.45      0.52      1345
#     Frontend       0.46      0.64      0.54       987
#
#     accuracy                           0.53      2332
#    macro avg       0.55      0.55      0.53      2332
# weighted avg       0.56      0.53      0.53      2332
#
# Confusion Matrix:
# [[604 741]
#  [353 634]]
# Accuracy: 0.5308747855917667
# Precision: 0.5308747855917667
# Recall: 0.5308747855917667
# F1-Score: 0.5308747855917667
# ------------------------------------------------------------------
# Processing ngram_range: (2, 3)
# Top words for topic #0:
# ['send email notification', 'doesnt work', 'doe work', 'context menu', 'org eclipse', 'content assist', 'new tab', 'rest api', 'custom field', 'email notification']
#
#
# Top words for topic #1:
# ['email template', 'custom field', 'context menu', 'working set', 'send notification', 'redmine api', 'new tab', 'due date', 'email notification', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.61      0.45      0.52      1345
#     Frontend       0.45      0.61      0.52       987
#
#     accuracy                           0.52      2332
#    macro avg       0.53      0.53      0.52      2332
# weighted avg       0.54      0.52      0.52      2332
#
# Confusion Matrix:
# [[606 739]
#  [386 601]]
# Accuracy: 0.5175814751286449
# Precision: 0.5175814751286449
# Recall: 0.5175814751286449
# F1-Score: 0.5175814751286449
# ------------------------------------------------------------------
# Processing ngram_range: (2, 4)
# Top words for topic #0:
# ['issue status', 'internal error', 'context menu', 'address bar', 'redmine api', 'doesnt work', 'custom field', 'new tab', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['internal server error', 'internal server', 'server error', 'api response', 'due date', 'context menu', 'doe work', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.42      0.49      1345
#     Frontend       0.43      0.59      0.50       987
#
#     accuracy                           0.49      2332
#    macro avg       0.51      0.51      0.49      2332
# weighted avg       0.52      0.49      0.49      2332
#
# Confusion Matrix:
# [[570 775]
#  [403 584]]
# Accuracy: 0.49485420240137223
# Precision: 0.49485420240137223
# Recall: 0.49485420240137223
# F1-Score: 0.49485420240137223
# ------------------------------------------------------------------
# Processing ngram_range: (2, 5)
# Top words for topic #0:
# ['notification setting', 'search engine', 'email configuration', 'via rest', 'via rest api', 'email template', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['send mail', 'server error', 'error message', 'content assist', 'context menu', 'redmine api', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.61      0.45      0.52      1345
#     Frontend       0.45      0.61      0.52       987
#
#     accuracy                           0.52      2332
#    macro avg       0.53      0.53      0.52      2332
# weighted avg       0.54      0.52      0.52      2332
#
# Confusion Matrix:
# [[602 743]
#  [384 603]]
# Accuracy: 0.5167238421955404
# Precision: 0.5167238421955404
# Recall: 0.5167238421955404
# F1-Score: 0.5167238421955404
# ------------------------------------------------------------------
# Processing ngram_range: (2, 6)
# Top words for topic #0:
# ['api key', 'address bar', 'context menu', 'email configuration', 'send email', 'send email notification', 'send mail', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['notification email', 'context menu', 'content assist', 'doesnt work', 'redmine api', 'doe work', 'custom field', 'rest api', 'new tab', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.61      0.47      0.53      1345
#     Frontend       0.45      0.59      0.51       987
#
#     accuracy                           0.52      2332
#    macro avg       0.53      0.53      0.52      2332
# weighted avg       0.54      0.52      0.52      2332
#
# Confusion Matrix:
# [[628 717]
#  [403 584]]
# Accuracy: 0.5197255574614065
# Precision: 0.5197255574614065
# Recall: 0.5197255574614065
# F1-Score: 0.5197255574614065
# ------------------------------------------------------------------
# Processing ngram_range: (2, 7)
# Top words for topic #0:
# ['internal server error', 'server error', 'send mail', 'send email notification', 'redmine api', 'send email', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['address bar', 'doe work', 'email configuration', 'new tab', 'email template', 'due date', 'context menu', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.62      0.46      0.53      1345
#     Frontend       0.46      0.62      0.52       987
#
#     accuracy                           0.53      2332
#    macro avg       0.54      0.54      0.53      2332
# weighted avg       0.55      0.53      0.53      2332
#
# Confusion Matrix:
# [[618 727]
#  [378 609]]
# Accuracy: 0.5261578044596913
# Precision: 0.5261578044596913
# Recall: 0.5261578044596913
# F1-Score: 0.5261578044596913
# ------------------------------------------------------------------
# Processing ngram_range: (2, 8)
# Top words for topic #0:
# ['content assist', 'notification setting', 'context menu', 'error message', 'send notification', 'notification email', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['internal server error', 'internal server', 'email configuration', 'context menu', 'send email', 'send mail', 'redmine api', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.60      0.45      0.52      1345
#     Frontend       0.44      0.59      0.50       987
#
#     accuracy                           0.51      2332
#    macro avg       0.52      0.52      0.51      2332
# weighted avg       0.53      0.51      0.51      2332
#
# Confusion Matrix:
# [[609 736]
#  [408 579]]
# Accuracy: 0.5094339622641509
# Precision: 0.5094339622641509
# Recall: 0.5094339622641509
# F1-Score: 0.5094339622641509
# ------------------------------------------------------------------
# Processing ngram_range: (2, 9)
# Top words for topic #0:
# ['internal server', 'doe work', 'custom field', 'send email', 'server error', 'context menu', 'new tab', 'send notification', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['user api', 'content assist', 'doesnt work', 'context menu', 'redmine api', 'due date', 'new tab', 'custom field', 'email notification', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.61      0.45      0.52      1345
#     Frontend       0.45      0.60      0.51       987
#
#     accuracy                           0.52      2332
#    macro avg       0.53      0.53      0.51      2332
# weighted avg       0.54      0.52      0.52      2332
#
# Confusion Matrix:
# [[610 735]
#  [396 591]]
# Accuracy: 0.5150085763293311
# Precision: 0.5150085763293311
# Recall: 0.5150085763293311
# F1-Score: 0.5150085763293311
# ------------------------------------------------------------------
# Processing ngram_range: (2, 10)
# Top words for topic #0:
# ['error message', 'mention user', 'mention user username', 'user username', 'doe work', 'new tab', 'redmine api', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['doesnt work', 'internal error', 'content assist', 'context menu', 'send email', 'due date', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.60      0.43      0.50      1345
#     Frontend       0.44      0.60      0.51       987
#
#     accuracy                           0.50      2332
#    macro avg       0.52      0.52      0.50      2332
# weighted avg       0.53      0.50      0.50      2332
#
# Confusion Matrix:
# [[581 764]
#  [392 595]]
# Accuracy: 0.5042881646655232
# Precision: 0.5042881646655232
# Recall: 0.5042881646655232
# F1-Score: 0.5042881646655232
# ------------------------------------------------------------------
# Processing ngram_range: (2, 11)
# Top words for topic #0:
# ['via rest api', 'via rest', 'send email notification', 'send email', 'redmine api', 'due date', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['doesnt work', 'email configuration', 'doe work', 'new tab', 'context menu', 'error message', 'email template', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.44      0.51      1345
#     Frontend       0.44      0.59      0.50       987
#
#     accuracy                           0.50      2332
#    macro avg       0.52      0.52      0.50      2332
# weighted avg       0.53      0.50      0.50      2332
#
# Confusion Matrix:
# [[592 753]
#  [404 583]]
# Accuracy: 0.5038593481989708
# Precision: 0.5038593481989708
# Recall: 0.5038593481989708
# F1-Score: 0.5038593481989708
# ------------------------------------------------------------------
# Processing ngram_range: (2, 12)
# Top words for topic #0:
# ['send notification', 'send email notification', 'send mail', 'redmine api', 'send email', 'content assist', 'custom field', 'new tab', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['notification email', 'email configuration', 'context menu', 'error message', 'email template', 'due date', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.43      0.50      1345
#     Frontend       0.43      0.58      0.50       987
#
#     accuracy                           0.50      2332
#    macro avg       0.51      0.51      0.50      2332
# weighted avg       0.52      0.50      0.50      2332
#
# Confusion Matrix:
# [[580 765]
#  [410 577]]
# Accuracy: 0.4961406518010292
# Precision: 0.4961406518010292
# Recall: 0.4961406518010292
# F1-Score: 0.4961406518010292
# ------------------------------------------------------------------
# Processing ngram_range: (2, 13)
# Top words for topic #0:
# ['user api', 'doe work', 'internal error', 'due date', 'content assist', 'new tab', 'email template', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['server error', 'send email notification', 'send mail', 'context menu', 'send notification', 'send email', 'redmine api', 'new tab', 'email notification', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.45      0.51      1345
#     Frontend       0.44      0.57      0.49       987
#
#     accuracy                           0.50      2332
#    macro avg       0.51      0.51      0.50      2332
# weighted avg       0.53      0.50      0.51      2332
#
# Confusion Matrix:
# [[610 735]
#  [421 566]]
# Accuracy: 0.5042881646655232
# Precision: 0.5042881646655232
# Recall: 0.5042881646655232
# F1-Score: 0.5042881646655232
# ------------------------------------------------------------------
# Processing ngram_range: (2, 14)
# Top words for topic #0:
# ['notification setting', 'send email notification', 'content assist', 'send email', 'send mail', 'context menu', 'custom field', 'new tab', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['internal server', 'internal server error', 'email configuration', 'org eclipse', 'new tab', 'send notification', 'redmine api', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.62      0.44      0.51      1345
#     Frontend       0.45      0.63      0.53       987
#
#     accuracy                           0.52      2332
#    macro avg       0.53      0.53      0.52      2332
# weighted avg       0.55      0.52      0.52      2332
#
# Confusion Matrix:
# [[587 758]
#  [365 622]]
# Accuracy: 0.5184391080617495
# Precision: 0.5184391080617495
# Recall: 0.5184391080617495
# F1-Score: 0.5184391080617495
# ------------------------------------------------------------------
# Processing ngram_range: (2, 15)
# Top words for topic #0:
# ['server error', 'address bar', 'db migrate', 'notification email', 'context menu', 'new tab', 'due date', 'custom field', 'email notification', 'rest api']
#
#
# Top words for topic #1:
# ['user username', 'mention user username', 'mention user', 'error message', 'content assist', 'doe work', 'new tab', 'redmine api', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.63      0.47      0.54      1345
#     Frontend       0.47      0.63      0.54       987
#
#     accuracy                           0.54      2332
#    macro avg       0.55      0.55      0.54      2332
# weighted avg       0.56      0.54      0.54      2332
#
# Confusion Matrix:
# [[630 715]
#  [363 624]]
# Accuracy: 0.5377358490566038
# Precision: 0.5377358490566038
# Recall: 0.5377358490566038
# F1-Score: 0.5377358490566038
# ------------------------------------------------------------------
# Processing ngram_range: (3, 3)
# Top words for topic #0:
# ['cant delete account', 'unify email notification', 'due date redmine', 'email dropped timeout', 'email configuration error', 'email notification error', 'org eclipse ui', 'attachment rest api', 'mention user username', 'send email notification']
#
#
# Top words for topic #1:
# ['optional email header', 'smtp authentication failed', 'abstraction layer notification', 'new tab page', 'value custom field', 'issue assigned group', 'add automated test', 'single tracking bug', 'internal server error', 'via rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.79      0.31      0.45      1345
#     Frontend       0.49      0.89      0.63       987
#
#     accuracy                           0.56      2332
#    macro avg       0.64      0.60      0.54      2332
# weighted avg       0.66      0.56      0.52      2332
#
# Confusion Matrix:
# [[421 924]
#  [112 875]]
# Accuracy: 0.5557461406518011
# Precision: 0.5557461406518011
# Recall: 0.5557461406518011
# F1-Score: 0.5557461406518011
# ------------------------------------------------------------------
# Processing ngram_range: (3, 4)
# Top words for topic #0:
# ['changed email template', 'modify email template', 'picture email notification', 'author name mail', 'via rest api', 'optional email header', 'unify email notification', 'email configuration error', 'email notification error', 'send email notification']
#
#
# Top words for topic #1:
# ['email notification setting', 'option project manager', 'due date redmine', 'email dropped timeout', 'notification removing assignment', 'cant delete account', 'abstraction layer notification', 'smtp authentication failed', 'internal server error', 'mention user username']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.82      0.30      0.44      1345
#     Frontend       0.49      0.91      0.64       987
#
#     accuracy                           0.56      2332
#    macro avg       0.65      0.61      0.54      2332
# weighted avg       0.68      0.56      0.52      2332
#
# Confusion Matrix:
# [[405 940]
#  [ 89 898]]
# Accuracy: 0.5587478559176673
# Precision: 0.5587478559176673
# Recall: 0.5587478559176673
# F1-Score: 0.5587478559176673
# ------------------------------------------------------------------
# Processing ngram_range: (3, 5)
# Top words for topic #0:
# ['modify email template', 'set value reminder', 'problem smtp setup', 'attachment rest api', 'option project manager', 'notification removing assignment', 'abstraction layer notification', 'optional email header', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['changed email template', 'issue assigned group', 'cant delete account', 'smtp authentication failed', 'email configuration error', 'unify email notification', 'email dropped timeout', 'due date redmine', 'email notification error', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.82      0.34      0.48      1345
#     Frontend       0.50      0.90      0.64       987
#
#     accuracy                           0.58      2332
#    macro avg       0.66      0.62      0.56      2332
# weighted avg       0.69      0.58      0.55      2332
#
# Confusion Matrix:
# [[454 891]
#  [ 98 889]]
# Accuracy: 0.5759005145797599
# Precision: 0.5759005145797599
# Recall: 0.5759005145797599
# F1-Score: 0.5759005145797599
# ------------------------------------------------------------------
# Processing ngram_range: (3, 6)
# Top words for topic #0:
# ['associated revision api', 'issue assigned group', 'send mail option', 'mail ssl working', 'smtp authentication failed', 'option project manager', 'cant delete account', 'optional email header', 'internal server error', 'send email notification']
#
#
# Top words for topic #1:
# ['set value reminder', 'issue email notification', 'abstraction layer notification', 'email configuration error', 'unify email notification', 'due date redmine', 'notification removing assignment', 'email dropped timeout', 'email notification error', 'mention user username']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.81      0.32      0.46      1345
#     Frontend       0.49      0.90      0.64       987
#
#     accuracy                           0.56      2332
#    macro avg       0.65      0.61      0.55      2332
# weighted avg       0.67      0.56      0.53      2332
#
# Confusion Matrix:
# [[431 914]
#  [102 885]]
# Accuracy: 0.5643224699828473
# Precision: 0.5643224699828473
# Recall: 0.5643224699828473
# F1-Score: 0.5643224699828473
# ------------------------------------------------------------------
# Processing ngram_range: (3, 7)
# Top words for topic #0:
# ['private issue notification', 'problem smtp setup', 'author name mail', 'email configuration error', 'smtp authentication failed', 'abstraction layer notification', 'option project manager', 'cant delete account', 'internal server error', 'send email notification']
#
#
# Top words for topic #1:
# ['picture email notification', 'modify email template', 'email notification setting', 'attachment rest api', 'unify email notification', 'due date redmine', 'optional email header', 'email dropped timeout', 'notification removing assignment', 'mention user username']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.81      0.31      0.45      1345
#     Frontend       0.49      0.90      0.63       987
#
#     accuracy                           0.56      2332
#    macro avg       0.65      0.61      0.54      2332
# weighted avg       0.68      0.56      0.53      2332
#
# Confusion Matrix:
# [[416 929]
#  [ 96 891]]
# Accuracy: 0.5604631217838765
# Precision: 0.5604631217838765
# Recall: 0.5604631217838765
# F1-Score: 0.5604631217838765
# ------------------------------------------------------------------
# Processing ngram_range: (3, 8)
# Top words for topic #0:
# ['set value reminder', 'send mail option', 'email notification setting', 'email configuration error', 'cant delete account', 'email dropped timeout', 'due date redmine', 'email notification error', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['picture email notification', 'private issue notification', 'problem smtp setup', 'option project manager', 'optional email header', 'unify email notification', 'notification removing assignment', 'abstraction layer notification', 'smtp authentication failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.30      0.43      1345
#     Frontend       0.48      0.90      0.63       987
#
#     accuracy                           0.55      2332
#    macro avg       0.64      0.60      0.53      2332
# weighted avg       0.67      0.55      0.52      2332
#
# Confusion Matrix:
# [[399 946]
#  [ 99 888]]
# Accuracy: 0.5518867924528302
# Precision: 0.5518867924528302
# Recall: 0.5518867924528302
# F1-Score: 0.5518867924528302
# ------------------------------------------------------------------
# Processing ngram_range: (3, 9)
# Top words for topic #0:
# ['send mail option', 'problem smtp setup', 'email dropped timeout', 'due date redmine', 'abstraction layer notification', 'notification removing assignment', 'option project manager', 'unify email notification', 'optional email header', 'send email notification']
#
#
# Top words for topic #1:
# ['notification setting group', 'private issue notification', 'picture email notification', 'mail ssl working', 'email configuration error', 'smtp authentication failed', 'cant delete account', 'email notification error', 'internal server error', 'mention user username']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.79      0.33      0.47      1345
#     Frontend       0.49      0.88      0.63       987
#
#     accuracy                           0.56      2332
#    macro avg       0.64      0.61      0.55      2332
# weighted avg       0.67      0.56      0.54      2332
#
# Confusion Matrix:
# [[447 898]
#  [117 870]]
# Accuracy: 0.5647512864493996
# Precision: 0.5647512864493996
# Recall: 0.5647512864493996
# F1-Score: 0.5647512864493996
# ------------------------------------------------------------------
# Processing ngram_range: (3, 10)
# Top words for topic #0:
# ['send mail option', 'set value reminder', 'unify email notification', 'email configuration error', 'optional email header', 'notification removing assignment', 'option project manager', 'due date redmine', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['picture email notification', 'private issue notification', 'changed email template', 'mail ssl working', 'email dropped timeout', 'abstraction layer notification', 'cant delete account', 'smtp authentication failed', 'internal server error', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.81      0.32      0.46      1345
#     Frontend       0.49      0.90      0.64       987
#
#     accuracy                           0.57      2332
#    macro avg       0.65      0.61      0.55      2332
# weighted avg       0.68      0.57      0.54      2332
#
# Confusion Matrix:
# [[437 908]
#  [101 886]]
# Accuracy: 0.5673241852487135
# Precision: 0.5673241852487135
# Recall: 0.5673241852487135
# F1-Score: 0.5673241852487135
# ------------------------------------------------------------------
# Processing ngram_range: (3, 11)
# Top words for topic #0:
# ['problem smtp setup', 'changed email template', 'email notification setting', 'send mail option', 'email dropped timeout', 'abstraction layer notification', 'option project manager', 'optional email header', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['modify email template', 'set value reminder', 'attachment rest api', 'due date redmine', 'cant delete account', 'email configuration error', 'notification removing assignment', 'unify email notification', 'smtp authentication failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.31      0.44      1345
#     Frontend       0.49      0.89      0.63       987
#
#     accuracy                           0.55      2332
#    macro avg       0.64      0.60      0.54      2332
# weighted avg       0.67      0.55      0.52      2332
#
# Confusion Matrix:
# [[412 933]
#  [105 882]]
# Accuracy: 0.5548885077186964
# Precision: 0.5548885077186964
# Recall: 0.5548885077186964
# F1-Score: 0.5548885077186964
# ------------------------------------------------------------------
# Processing ngram_range: (3, 12)
# Top words for topic #0:
# ['notification removing assignment', 'due date redmine', 'unify email notification', 'option project manager', 'abstraction layer notification', 'email dropped timeout', 'cant delete account', 'optional email header', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['set value reminder', 'private issue notification', 'picture email notification', 'email notification setting', 'mail ssl working', 'smtp authentication failed', 'email configuration error', 'attachment rest api', 'email notification error', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.82      0.32      0.46      1345
#     Frontend       0.49      0.90      0.64       987
#
#     accuracy                           0.57      2332
#    macro avg       0.66      0.61      0.55      2332
# weighted avg       0.68      0.57      0.54      2332
#
# Confusion Matrix:
# [[430 915]
#  [ 96 891]]
# Accuracy: 0.5664665523156089
# Precision: 0.5664665523156089
# Recall: 0.5664665523156089
# F1-Score: 0.5664665523156089
# ------------------------------------------------------------------
# Processing ngram_range: (3, 13)
# Top words for topic #0:
# ['send mail option', 'picture email notification', 'private issue notification', 'abstraction layer notification', 'notification removing assignment', 'smtp authentication failed', 'unify email notification', 'attachment rest api', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['changed email template', 'author name mail', 'mail ssl working', 'optional email header', 'option project manager', 'cant delete account', 'email configuration error', 'due date redmine', 'email dropped timeout', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.31      0.45      1345
#     Frontend       0.49      0.89      0.63       987
#
#     accuracy                           0.56      2332
#    macro avg       0.64      0.60      0.54      2332
# weighted avg       0.67      0.56      0.53      2332
#
# Confusion Matrix:
# [[422 923]
#  [106 881]]
# Accuracy: 0.5587478559176673
# Precision: 0.5587478559176673
# Recall: 0.5587478559176673
# F1-Score: 0.5587478559176673
# ------------------------------------------------------------------
# Processing ngram_range: (3, 14)
# Top words for topic #0:
# ['notification removing assignment', 'due date redmine', 'email dropped timeout', 'cant delete account', 'optional email header', 'abstraction layer notification', 'email configuration error', 'attachment rest api', 'send email notification', 'mention user username']
#
#
# Top words for topic #1:
# ['picture email notification', 'mail ssl working', 'changed email template', 'send mail option', 'via rest api', 'unify email notification', 'option project manager', 'smtp authentication failed', 'email notification error', 'internal server error']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.30      0.43      1345
#     Frontend       0.48      0.90      0.63       987
#
#     accuracy                           0.55      2332
#    macro avg       0.64      0.60      0.53      2332
# weighted avg       0.67      0.55      0.51      2332
#
# Confusion Matrix:
# [[397 948]
#  [100 887]]
# Accuracy: 0.5506003430531733
# Precision: 0.5506003430531733
# Recall: 0.5506003430531733
# F1-Score: 0.5506003430531733
# ------------------------------------------------------------------
# Processing ngram_range: (3, 15)
# Top words for topic #0:
# ['private issue notification', 'set value reminder', 'due date redmine', 'optional email header', 'cant delete account', 'smtp authentication failed', 'abstraction layer notification', 'option project manager', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['send mail option', 'changed email template', 'email notification setting', 'attachment rest api', 'send email notification', 'email dropped timeout', 'unify email notification', 'notification removing assignment', 'email configuration error', 'email notification error']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.81      0.32      0.46      1345
#     Frontend       0.49      0.90      0.64       987
#
#     accuracy                           0.56      2332
#    macro avg       0.65      0.61      0.55      2332
# weighted avg       0.68      0.56      0.53      2332
#
# Confusion Matrix:
# [[429 916]
#  [100 887]]
# Accuracy: 0.5643224699828473
# Precision: 0.5643224699828473
# Recall: 0.5643224699828473
# F1-Score: 0.5643224699828473
# ------------------------------------------------------------------
# Processing ngram_range: (4, 4)
# Top words for topic #0:
# ['change url automatic mail', 'time send email long', 'issue email notification setup', 'added formatting email notification', 'email notification specified filter', 'redmine send reminder work', 'email notification involved clarification', 'hiding field email notification', 'notify user high issue', 'need email configuration redmine']
#
#
# Top words for topic #1:
# ['warning comment go nowhere', 'reporter watcher receiving mail', 'add button send notification', 'problem email integration office', 'dont want notified change', 'want notified change make', 'custom template email notification', 'mention working status changed', 'issue via rest api', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.94      0.26      0.41      1345
#     Frontend       0.49      0.98      0.65       987
#
#     accuracy                           0.56      2332
#    macro avg       0.72      0.62      0.53      2332
# weighted avg       0.75      0.56      0.51      2332
#
# Confusion Matrix:
# [[348 997]
#  [ 21 966]]
# Accuracy: 0.5634648370497427
# Precision: 0.5634648370497427
# Recall: 0.5634648370497427
# F1-Score: 0.5634648370497427
# ------------------------------------------------------------------
# Processing ngram_range: (4, 5)
# Top words for topic #0:
# ['time send email long', 'add button send notification', 'larger font email notification', 'email notification involved clarification', 'mention working status changed', 'redmine send reminder work', 'notify user high issue', 'custom template email notification', 'hiding field email notification', 'need email configuration redmine']
#
#
# Top words for topic #1:
# ['extended watcher notification feature', 'get tag via api', 'warning comment go nowhere', 'send reminder working redmine', 'api archive unarchive project', 'issue email notification setup', 'change url automatic mail', 'problem email integration office', 'added formatting email notification', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.93      0.26      0.40      1345
#     Frontend       0.49      0.98      0.65       987
#
#     accuracy                           0.56      2332
#    macro avg       0.71      0.62      0.53      2332
# weighted avg       0.75      0.56      0.51      2332
#
# Confusion Matrix:
# [[ 345 1000]
#  [  24  963]]
# Accuracy: 0.5608919382504288
# Precision: 0.5608919382504288
# Recall: 0.5608919382504288
# F1-Score: 0.5608919382504288
# ------------------------------------------------------------------
# Processing ngram_range: (4, 6)
# Top words for topic #0:
# ['added formatting email notification', 'issue email notification setup', 'add button send notification', 'reporter watcher receiving mail', 'larger font email notification', 'email notification involved clarification', 'notify user high issue', 'hiding field email notification', 'custom template email notification', 'delete attachment rest api']
#
#
# Top words for topic #1:
# ['extended watcher notification feature', 'send reminder working redmine', 'email notification create ticket', 'problem email integration office', 'change url automatic mail', 'time send email long', 'email notification specified filter', 'need email configuration redmine', 'mention working status changed', 'redmine send reminder work']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.93      0.26      0.40      1345
#     Frontend       0.49      0.97      0.65       987
#
#     accuracy                           0.56      2332
#    macro avg       0.71      0.61      0.53      2332
# weighted avg       0.74      0.56      0.51      2332
#
# Confusion Matrix:
# [[ 344 1001]
#  [  26  961]]
# Accuracy: 0.5596054888507719
# Precision: 0.5596054888507719
# Recall: 0.5596054888507719
# F1-Score: 0.5596054888507719
# ------------------------------------------------------------------
# Processing ngram_range: (4, 7)
# Top words for topic #0:
# ['email truncated use deleted', 'api key user page', 'issue via rest api', 'get tag via api', 'email notification create ticket', 'add button send notification', 'added formatting email notification', 'issue email notification setup', 'email notification specified filter', 'mention working status changed']
#
#
# Top words for topic #1:
# ['time send email long', 'reporter watcher receiving mail', 'larger font email notification', 'redmine send reminder work', 'hiding field email notification', 'custom template email notification', 'email notification involved clarification', 'need email configuration redmine', 'notify user high issue', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.95      0.25      0.40      1345
#     Frontend       0.49      0.98      0.65       987
#
#     accuracy                           0.56      2332
#    macro avg       0.72      0.62      0.53      2332
# weighted avg       0.75      0.56      0.51      2332
#
# Confusion Matrix:
# [[ 340 1005]
#  [  19  968]]
# Accuracy: 0.5608919382504288
# Precision: 0.5608919382504288
# Recall: 0.5608919382504288
# F1-Score: 0.5608919382504288
# ------------------------------------------------------------------
# Processing ngram_range: (4, 8)
# Top words for topic #0:
# ['api key user page', 'api redmine configuration information', 'warning comment go nowhere', 'wiki watch option working', 'get tag via api', 'reporter watcher receiving mail', 'added formatting email notification', 'hiding field email notification', 'need email configuration redmine', 'custom template email notification']
#
#
# Top words for topic #1:
# ['problem email integration office', 'add button send notification', 'larger font email notification', 'change url automatic mail', 'time send email long', 'redmine send reminder work', 'email notification involved clarification', 'mention working status changed', 'notify user high issue', 'delete attachment rest api']
#
#
# Classification Report:
# ...
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.43      0.26      2332
#
# Confusion Matrix:
# [[   8 1337]
#  [   0  987]]
# Accuracy: 0.42667238421955406
# Precision: 0.42667238421955406
# Recall: 0.42667238421955406
# F1-Score: 0.42667238421955406
# ------------------------------------------------------------------
# Processing ngram_range: (13, 13)
# Top words for topic #0:
# ['request adding tracker id name rest time entry response like already project info', 'anymore yaml db rake task db data dump db data load update redmine', 'workflow status transition header column header row pan scroll view numerous issue status', 'email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping', 'outgoing email address per project email alias different incoming email alias mapping specific', 'updating issue via rest api cause internal server error invalid project id specified', 'rest api show wiki page html format contains wrong link another wiki project', 'view issue link email reminder point issue list doe include issue assigned group', 'project copy always send email notification ignoring send email notification project copy option']
#
#
# Top words for topic #1:
# ['request access cookie incorrect message console content blocking disabled enhanced tracking protection enabled', 'address bar arrow button go button ha misleading tooltip pointing url may searching', 'byte downloads downloading http file http site dom block download insecure set default', 'querycolumn sql field assumes operator issue opened closed deal field named status id', 'sql field assumes operator issue opened closed deal field named status id extendable', 'setting host name instead setting app title totp issuer avoid name collision instance', 'host name instead setting app title totp issuer avoid name collision instance apps', 'use setting host name instead setting app title totp issuer avoid name collision', 'api create issue relation method return undefined method split issue id sent integer', 'creating rest api new issue project without tracker enabled return misleading error message']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   2 1343]
#  [   0  987]]
# Accuracy: 0.4240994854202401
# Precision: 0.4240994854202401
# Recall: 0.4240994854202401
# F1-Score: 0.4240994854202401
# ------------------------------------------------------------------
# Processing ngram_range: (13, 14)
# Top words for topic #0:
# ['customize mode entering disabled chromeless window window open without toolbars etc doesnt work', 'secondary undocked window revert default position positioned edge primary monitor dual monitor setup', 'sql field assumes operator issue opened closed deal field named status id extendable', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'querycolumn sql field assumes operator issue opened closed deal field named status id', 'workflow status transition header column header row pan scroll view numerous issue status', 'anymore yaml db rake task db data dump db data load update redmine', 'api create issue relation method return undefined method split issue id sent integer', 'view issue link email reminder point issue list doe include issue assigned group', 'project copy always send email notification ignoring send email notification project copy option']
#
#
# Top words for topic #1:
# ['adding tracker id name rest time entry response like already project info response', 'request adding tracker id name rest time entry response like already project info', 'outgoing email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping', 'outgoing email address per project email alias different incoming email alias mapping specific', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'email address per project email alias different incoming email alias mapping specific project', 'updating issue via rest api cause internal server error invalid project id specified', 'rest api show wiki page html format contains wrong link another wiki project', 'creating rest api new issue project without tracker enabled return misleading error message']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.01      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.43      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.43      0.26      2332
#
# Confusion Matrix:
# [[   5 1340]
#  [   0  987]]
# Accuracy: 0.42538593481989706
# Precision: 0.42538593481989706
# Recall: 0.42538593481989706
# F1-Score: 0.42538593481989706
# ------------------------------------------------------------------
# Processing ngram_range: (13, 15)
# Top words for topic #0:
# ['outgoing email address per project email alias different incoming email alias mapping specific', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'different outgoing email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping', 'email address per project email alias different incoming email alias mapping specific project', 'anymore yaml db rake task db data dump db data load update redmine', 'api create issue relation method return undefined method split issue id sent integer', 'rest api show wiki page html format contains wrong link another wiki project', 'view issue link email reminder point issue list doe include issue assigned group', 'project copy always send email notification ignoring send email notification project copy option']
#
#
# Top words for topic #1:
# ['window last top site wrongly displayed second row horizontally resizing browser exactly px', 'searching text via context menu text includes exclamation mark activate duckduckgos bang action', 'newtab linting script rely top level mach lint arent working window dev environment', 'save action add missing override annotation implementation interface method always executed generic interface', 'sql field assumes operator issue opened closed deal field named status id extendable', 'querycolumn sql field assumes operator issue opened closed deal field named status id', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'workflow status transition header column header row pan scroll view numerous issue status', 'updating issue via rest api cause internal server error invalid project id specified', 'creating rest api new issue project without tracker enabled return misleading error message']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   3 1342]
#  [   0  987]]
# Accuracy: 0.42452830188679247
# Precision: 0.42452830188679247
# Recall: 0.42452830188679247
# F1-Score: 0.42452830188679247
# ------------------------------------------------------------------
# Processing ngram_range: (14, 14)
# Top words for topic #0:
# ['imported bookmark html placed inside bookmark menu bookmark toolbar imported file stated spec doc', 'request denied downloading temporary file browser download start downloads tmp dir enabled snap build', 'entering customize menu using context menu edge overflow menu show another incomplete overflow menu', 'firefox account menu display name email manage account fxa panel use default font colour', 'firefox running window admin account still asks admin privilege running downloaded unsigned exe file', 'œpersonalizeâ button ha blue œfocus visibleâ border button clicked state right address bar focused', 'œtry import againâ œcancelâ button œimport errorâ modal exceed modalâ area specific language russian', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'use setting host name instead setting app title totp issuer avoid name collision instance', 'setting host name instead setting app title totp issuer avoid name collision instance apps']
#
#
# Top words for topic #1:
# ['project copy failed copy issue category set required project copy issue issue xxx could', 'failed copy issue category set required project copy issue issue xxx could copied category', 'copy failed copy issue category set required project copy issue issue xxx could copied', 'copy issue category set required project copy issue issue xxx could copied category blank', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'design tracker selection ui custom field editing screen project setting screen aligned create sense', 'selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'request adding tracker id name rest time entry response like already project info response', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.01      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.26      2332
#
# Confusion Matrix:
# [[   4 1341]
#  [   0  987]]
# Accuracy: 0.42495711835334476
# Precision: 0.42495711835334476
# Recall: 0.42495711835334476
# F1-Score: 0.42495711835334476
# ------------------------------------------------------------------
# Processing ngram_range: (14, 15)
# Top words for topic #0:
# ['window tweak svgs caption button match native color thickness precisely different dpi scaling setting', 'entering help menuitem mainmenu first time session display help instead firefox nightly help header', 'contribution contribution run menu item seems linger even though debug context doesnt seem active', 'checkout maven project svn stuck resolve plugin dependency using annotation processor maven compiler plugin', 'progress updating progress view lot job block ui main thread make ui sluggish minute', 'incorrect reporting page size rt click pg view pg info sv ondisk pg larger', 'investigate sync failure caused error encountered statement execution database disk image malformed self repair', 'firefox account ha right arrow sub panel view placed inside overflow menu user signed', 'new sync option encrypt data secret thats used anything else never entered web page', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable']
#
#
# Top words for topic #1:
# ['tracker selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'design tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'use setting host name instead setting app title totp issuer avoid name collision instance', 'setting host name instead setting app title totp issuer avoid name collision instance apps', 'use setting host name instead setting app title totp issuer avoid name collision instance apps', 'request adding tracker id name rest time entry response like already project info response', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'outgoing email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.01      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.26      2332
#
# Confusion Matrix:
# [[   4 1341]
#  [   0  987]]
# Accuracy: 0.42495711835334476
# Precision: 0.42495711835334476
# Recall: 0.42495711835334476
# F1-Score: 0.42495711835334476
# ------------------------------------------------------------------
# Processing ngram_range: (15, 15)
# Top words for topic #0:
# ['organize import add unnecessary static import creating anonymous class enclosing interface calling static method within', 'meta ascertain whether new gui toolkit needed firefox due gtk abstraction potential gtk lack support', 'closing gmail tab opening email another tab exit firefox even browser tab closewindowwithlasttab set false', 'potential origin spoofing address bar truncates facebook com evil com facebook com instead evil com', 'pin promo still displayed private window user chooses pin shortcut taskbar existing user onboarding modal', 'blocklisted addons cause sync create error log failed apply incoming record error add found install', 'recently closed tab menu slow due giant several mb data uris stored closed tab favicons', 'window icon context menu button recommended pocket card barely visible system high contrast mode turned', 'navigator possible bug org eclipse ui ide src org eclipse ui view navigator stringmatcher java', 'undo close tab window reopens previously loaded page even though user specifically asked remember history']
#
#
# Top words for topic #1:
# ['pdf date input box auto corrects dd mm yyyy format american format mm dd yyyy', 'move lightweight theme cs browser base content browser cs browser theme shared browser inc cs', 'downloadssummary file downloading bottom downloads panel includes finished downloads lead wrong size progress number shown', 'project copy failed copy issue category set required project copy issue issue xxx could copied', 'copy failed copy issue category set required project copy issue issue xxx could copied category', 'failed copy issue category set required project copy issue issue xxx could copied category blank', 'design tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'use setting host name instead setting app title totp issuer avoid name collision instance apps', 'different outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   2 1343]
#  [   0  987]]
# Accuracy: 0.4240994854202401
# Precision: 0.4240994854202401
# Recall: 0.4240994854202401
# F1-Score: 0.4240994854202401
# ------------------------------------------------------------------
