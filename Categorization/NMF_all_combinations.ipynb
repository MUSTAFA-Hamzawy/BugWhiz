# %%
import pandas as pd
import os
import numpy as np
import string
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# path of training data
train_path = 'train.xlsx'

# path of testing data
test_path = 'test.xlsx'

# %%
# show the first 5 rows of the training data
train_df = pd.read_excel(train_path)
print(train_df.head())

# show the first 5 rows of the testing data
test_df = pd.read_excel(test_path)
print(test_df.head())
# Out:
#                                               report class_name  class_index
# 0  "For any event on my bookmarked projects" opti...    Backend            1
# 1           Switch to using full l10n id's in urlbar   Frontend            2
# 2  Consider removing hasicon property to simplify...   Frontend            2
# 3  Method to obtain current URL from WebBrowserEd...   Frontend            2
# 4              Fix: migration fails in MS SQL-Server    Backend            1
#                                               report class_name  class_index
# 0  REST API - ability to list sub projects for a ...    Backend            1
# 1  support selective text on right if set in GNOM...   Frontend            2
# 2  [meta][userstory] Ship v1 of Pre-populated top...   Frontend            2
# 3  Include updated_on and passwd_changed_on colum...    Backend            1
# 4    Problem with email integration to MS Office 365    Backend            1

# %%
def convert_lower_case(data):
    return str(data).lower()

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in symbols:
        data = np.char.replace(data, i, ' ')

    return str(data)

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def remove_numbers(data):
    return re.sub(r'\d+', '', str(data))

# %%
def remove_single_characters(tokens):
    new_text = ""
    for w in tokens:
        if len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def lemmatization(data):
    lemmatizer = WordNetLemmatizer()
    tokens = word_tokenize(data)
    data = remove_single_characters(tokens)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(word) for word in tokens])
    return lemmatized_output

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data)
    data = remove_apostrophe(data)
    data = remove_numbers(data)
    data = lemmatization(data)
    return data

# %%
# print the first report of the training data
print(train_df['report'][0])
# Out:
# "For any event on my bookmarked projects" option not sending notifications for non-member bookmarked projects

# %%
# preprocess the first report of the training data
print(preprocess(train_df['report'][0]))
# Out:
# for any event on my bookmarked project option not sending notification for non member bookmarked project

# %%
import pandas as pd

# Assuming train_df is your DataFrame containing training data
# Assuming train_df has columns 'id', 'report', and 'class_name'

# Initialize counter
counter = 1

# Iterate over each row in the DataFrame
with open('preprocessed_train_data.csv', 'w', encoding='utf-8') as f:
    f.write('bug_description , class_name\n')  # Write header

    for _, row in train_df.iterrows():
        # Preprocess the 'report' column
        preprocessed_report = preprocess(row['report'])

        # Write data to the file with incremented counter
        f.write(f"{preprocessed_report},{row['class_name']}\n")

# Print the first preprocessed report
print(train_df['report'][0])
# Out:
# "For any event on my bookmarked projects" option not sending notifications for non-member bookmarked projects

# %%
# FOR TESTING DATA

# Iterate over each row in the DataFrame
with open('preprocessed_test_data.csv', 'w', encoding='utf-8') as f:
    f.write('bug_description , class_name\n')  # Write header

    for _, row in test_df.iterrows():
        # Preprocess the 'report' column
        preprocessed_report = preprocess(row['report'])

        # Write data to the file with incremented counter
        f.write(f"{preprocessed_report},{row['class_name']}\n")

# Print the first preprocessed report
print(test_df['report'][0])
# Out:
# REST API - ability to list sub projects for a project

# %%
# Open the preprocessed data file for reading
with open('preprocessed_train_data.csv', 'r', encoding='utf-8') as f:
    # Open the new file for writing preprocessed data with 2 columns
    with open('preprocessed_train_data2.csv', 'w', encoding='utf-8') as f_out:
        # Iterate over each line in the file
        for i, line in enumerate(f):
            # Skip the header
            if i == 0:
                continue
            
            # Split the line into columns based on comma delimiter
            columns = line.strip().split(',')
            
            # Check the number of columns
            if len(columns) == 2:
                # Get the preprocessed report and class name
                preprocessed_report = columns[0]
                class_name = columns[1]
                
                # Write the preprocessed report and class name to the new file
                f_out.write(f"{preprocessed_report},{class_name}\n")
            else:
                # Skip the line if it doesn't have exactly 2 columns
                continue

# %%
# FOR TESTING DATA

# Open the preprocessed data file for reading
with open('preprocessed_test_data.csv', 'r', encoding='utf-8') as f:
    # Open the new file for writing preprocessed data with 2 columns
    with open('preprocessed_test_data2.csv', 'w', encoding='utf-8') as f_out:
        # Iterate over each line in the file
        for i, line in enumerate(f):
            # Skip the header
            if i == 0:
                continue
            
            # Split the line into columns based on comma delimiter
            columns = line.strip().split(',')
            
            # Check the number of columns
            if len(columns) == 2:
                # Get the preprocessed report and class name
                preprocessed_report = columns[0]
                class_name = columns[1]
                
                # Write the preprocessed report and class name to the new file
                f_out.write(f"{preprocessed_report},{class_name}\n")
            else:
                # Skip the line if it doesn't have exactly 2 columns
                continue

# %%
# read the preprocessed data from the new file
preprocessed_train_df = pd.read_csv('preprocessed_train_data2.csv')

# show the first 5 rows of the preprocessed training data
print(preprocessed_train_df.head())
# Out:
#                                      bug_description class_name
# 0  for any event on my bookmarked project option ...    Backend
# 1               switch to using full ln id in urlbar   Frontend
# 2  consider removing hasicon property to simplify...   Frontend
# 3  method to obtain current url from webbrowsered...   Frontend
# 4                fix migration fails in m sql server    Backend

# %%
# read the preprocessed data from the new file
preprocessed_test_df = pd.read_csv('preprocessed_test_data2.csv')

# show the first 5 rows of the preprocessed training data
print(preprocessed_test_df.head())
# Out:
#                                      bug_description class_name
# 0  rest api ability to list sub project for a pro...    Backend
# 1  support selective text on right if set in gnom...   Frontend
# 2  meta userstory ship v of pre populated topsite...   Frontend
# 3  include updated on and passwd changed on colum...    Backend
# 4         problem with email integration to m office    Backend

# %%
# remove the stop words from the preprocessed data using nltk
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

def remove_stop_words(data):
    tokens = word_tokenize(data)
    data = ' '.join([i for i in tokens if not i in stop_words])
    return data

# preprocess the first report of the training data
print(preprocess(train_df['report'][0]))

# remove the stop words from the preprocessed data
print(remove_stop_words(preprocess(train_df['report'][0])))

# preprocess the first report of the testing data
print(preprocess(test_df['report'][0]))
# Out:
# for any event on my bookmarked project option not sending notification for non member bookmarked project
# event bookmarked project option sending notification non member bookmarked project
# rest api ability to list sub project for a project
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Convert non-string values to strings in 'bug_description' column
preprocessed_train_df['bug_description'] = preprocessed_train_df['bug_description'].apply(lambda x: str(x))
preprocessed_test_df['bug_description'] = preprocessed_test_df['bug_description'].apply(lambda x: str(x))

# Remove stop words from 'bug_description' column
preprocessed_train_df['bug_description'] = preprocessed_train_df['bug_description'].apply(lambda x: remove_stop_words(x))
preprocessed_test_df['bug_description'] = preprocessed_test_df['bug_description'].apply(lambda x: remove_stop_words(x))

# Show the first 5 rows of the preprocessed training data
print(preprocessed_train_df.head())

# Show the first 5 rows of the preprocessed testing data
print(preprocessed_test_df.head())
# Out:
#                                      bug_description class_name
# 0  event bookmarked project option sending notifi...    Backend
# 1                     switch using full ln id urlbar   Frontend
# 2  consider removing hasicon property simplify st...   Frontend
# 3         method obtain current url webbrowsereditor   Frontend
# 4                     fix migration fails sql server    Backend
#                                      bug_description class_name
# 0          rest api ability list sub project project    Backend
# 1     support selective text right set gnome setting   Frontend
# 2  meta userstory ship v pre populated topsites a...   Frontend
# 3  include updated passwd changed column user api...    Backend
# 4                   problem email integration office    Backend

# %%
# keep only the reports that has class_name of Frontend, Backend
# Filter the training data
filtered_train_df = preprocessed_train_df[
    (preprocessed_train_df['class_name'] == 'Frontend') | 
    (preprocessed_train_df['class_name'] == 'Backend')
]

# Filter the testing data
filtered_test_df = preprocessed_test_df[
    (preprocessed_test_df['class_name'] == 'Frontend') | 
    (preprocessed_test_df['class_name'] == 'Backend')
]

# Show the first 5 rows of the filtered training data
print("Filtered Training Data:")
print(filtered_train_df.head())

# Show the first 5 rows of the filtered testing data
print("\nFiltered Testing Data:")
print(filtered_test_df.head())
# Out:
# Filtered Training Data:
#                                      bug_description class_name
# 0  event bookmarked project option sending notifi...    Backend
# 1                     switch using full ln id urlbar   Frontend
# 2  consider removing hasicon property simplify st...   Frontend
# 3         method obtain current url webbrowsereditor   Frontend
# 4                     fix migration fails sql server    Backend
#
# Filtered Testing Data:
#                                      bug_description class_name
# 0          rest api ability list sub project project    Backend
# 1     support selective text right set gnome setting   Frontend
# 2  meta userstory ship v pre populated topsites a...   Frontend
# 3  include updated passwd changed column user api...    Backend
# 4                   problem email integration office    Backend

# %%
# print the unique class names in the training data
print(filtered_train_df['class_name'].unique())

# print the unique class names in the testing data
print(filtered_test_df['class_name'].unique())
# Out:
# ['Backend' 'Frontend']
# ['Backend' 'Frontend']

# %% [markdown]
# ## Feature Exraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Replace NaN values with an empty string
preprocessed_train_df['bug_description'].fillna('', inplace=True)

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the preprocessed data
X_train = vectorizer.fit_transform(filtered_train_df['bug_description'])

# Print the shape of X_train
print(X_train.shape)
# Out:
# (13236, 7304)

# %%
# print the vector representation of the first report
print(X_train[0])
# Out:
#   (0, 3814)	0.28841526302990617
#   (0, 4128)	0.25104918788961694
#   (0, 4158)	0.18214347162409292
#   (0, 5630)	0.30509756351985684
#   (0, 4346)	0.21058799657286695
#   (0, 4849)	0.3799346246464815
#   (0, 651)	0.6803204047615824
#   (0, 2087)	0.2756749849905213

# %%
# Print the number of unique class_name in the training data
print(filtered_train_df['class_name'].nunique())

# print their unique values
print(filtered_train_df['class_name'].unique())

# print the number of reports in each class
print(filtered_train_df['class_name'].value_counts())
# Out:
# 2
# ['Backend' 'Frontend']
# Backend     7437
# Frontend    5799
# Name: class_name, dtype: int64

# %%
# Create a mapping between cluster labels and class names
cluster_class_mapping = {
    1: 'Backend',  # Example mapping, adjust based on your actual clusters
    0: 'Frontend',
}

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

import numpy as np

def nmf_topic_modeling(data, class_name, n_components=2, ngram_range=(1, 2), random_state=42):
    """
    Perform Non-negative Matrix Factorization (NMF) topic modeling on the given data and evaluate on test data.

    Parameters:
    - data: DataFrame containing the text data to be modeled.
    - class_name: Series containing the class names corresponding to the data.
    - n_components: Number of topics to be generated (default is 2).
    - ngram_range: Tuple specifying the range of n-grams to consider (default is (1, 2)).
    - random_state: Random seed for reproducibility (default is 42).

    Returns:
    - None
    """
    # Initialize the TfidfVectorizer
    vectorizer = TfidfVectorizer(ngram_range=ngram_range)

    # Fit and transform the data
    X_train = vectorizer.fit_transform(data)

    # Initialize the NMF model
    nmf_model = NMF(n_components=n_components, random_state=random_state)

    # Fit the NMF model
    nmf_model.fit(X_train)

    # Print the top words for each topic
    for i, topic in enumerate(nmf_model.components_):
        print(f"Top words for topic #{i}:")
        print([vectorizer.get_feature_names_out()[index] for index in topic.argsort()[-10:]])
        print("\n")

    # Transform the preprocessed test data
    X_test = vectorizer.transform(filtered_test_df['bug_description'])

    # Predict the topics for the test data
    topic_predictions = nmf_model.transform(X_test)

    # Map numerical indices to class names
    predicted_class_names = [cluster_class_mapping[prediction] for prediction in np.argmax(topic_predictions, axis=1)]

    # Print the classification report
    print("Classification Report:")
    print(classification_report(class_name, predicted_class_names))

    # Print the confusion matrix
    print("Confusion Matrix:")
    print(confusion_matrix(class_name, predicted_class_names))

    # Calculate and print the accuracy
    accuracy = np.mean(class_name == predicted_class_names)
    print("Accuracy:", accuracy)

    # Calculate and print the precision, recall, and F1-score
    precision, recall, f1_score, _ = precision_recall_fscore_support(class_name, predicted_class_names, average='weighted')
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1_score)

# Usage example:
nmf_topic_modeling(filtered_train_df['bug_description'], filtered_test_df['class_name'])
# Out:
# Top words for topic #0:
# ['notification error', 'option', 'due', 'redmine', 'send email', 'issue', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom field', 'custom', 'field', 'project', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.84      0.66      1345
#     Frontend       0.07      0.02      0.02       987
#
#     accuracy                           0.49      2332
#    macro avg       0.30      0.43      0.34      2332
# weighted avg       0.34      0.49      0.39      2332
#
# Confusion Matrix:
# [[1130  215]
#  [ 972   15]]
# Accuracy: 0.49099485420240135
# Precision: 0.3376582512462517
# Recall: 0.49099485420240135
# F1 Score: 0.38858044639534545

# %%
# iterate to cover all possible combinations of ngram_range:
# 1- (1, 1) , (1, 2) , (1, 3)and so on till (1,15)
# 2- (2, 2) , (2, 3) , (2, 4)and so on till (2,15)
# 3- (3, 3) , (3, 4) , (3, 5)and so on till (3,15)
# and so on till (15, 15)

# Create a list of tuples containing the range of n-grams to consider
ngram_ranges = [(i, j) for i in range(1, 16) for j in range(i, 16)]

# Iterate over each n-gram range
for ngram_range in ngram_ranges:
    print(f"Processing ngram_range: {ngram_range}")
    nmf_topic_modeling(filtered_train_df['bug_description'], filtered_test_df['class_name'], ngram_range=ngram_range)
    print("------------------------------------------------------------------")
# Out:
# Processing ngram_range: (1, 1)
# Top words for topic #0:
# ['error', 'due', 'show', 'option', 'mail', 'redmine', 'issue', 'send', 'notification', 'email']
#
#
# Top words for topic #1:
# ['new', 'custom', 'tab', 'add', 'field', 'project', 'user', 'rest', 'issue', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.85      0.66      1345
#     Frontend       0.05      0.01      0.02       987
#
#     accuracy                           0.49      2332
#    macro avg       0.29      0.43      0.34      2332
# weighted avg       0.33      0.49      0.39      2332
#
# Confusion Matrix:
# [[1139  206]
#  [ 976   11]]
# Accuracy: 0.49313893653516294
# Precision: 0.33205868922189613
# Recall: 0.49313893653516294
# F1 Score: 0.38746055107556326
# ------------------------------------------------------------------
# Processing ngram_range: (1, 2)
# Top words for topic #0:
# ['notification error', 'option', 'due', 'redmine', 'send email', 'issue', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom field', 'custom', 'field', 'project', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.84      0.66      1345
#     Frontend       0.07      0.02      0.02       987
#
#     accuracy                           0.49      2332
#    macro avg       0.30      0.43      0.34      2332
# weighted avg       0.34      0.49      0.39      2332
#
# Confusion Matrix:
# [[1130  215]
#  [ 972   15]]
# Accuracy: 0.49099485420240135
# Precision: 0.3376582512462517
# Recall: 0.49099485420240135
# F1 Score: 0.38858044639534545
# ------------------------------------------------------------------
# Processing ngram_range: (1, 3)
# Top words for topic #0:
# ['email notification error', 'notification error', 'redmine', 'send email notification', 'issue', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['redmine', 'custom field', 'custom', 'field', 'project', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.85      0.66      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.43      0.34      2332
# weighted avg       0.34      0.50      0.39      2332
#
# Confusion Matrix:
# [[1138  207]
#  [ 970   17]]
# Accuracy: 0.49528301886792453
# Precision: 0.3434828796856539
# Recall: 0.49528301886792453
# F1 Score: 0.3920455505568016
# ------------------------------------------------------------------
# Processing ngram_range: (1, 4)
# Top words for topic #0:
# ['redmine', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['custom field', 'custom', 'redmine', 'field', 'project', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.66      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1152  193]
#  [ 970   17]]
# Accuracy: 0.5012864493996569
# Precision: 0.34737524714539986
# Recall: 0.5012864493996569
# F1 Score: 0.3953073909211634
# ------------------------------------------------------------------
# Processing ngram_range: (1, 5)
# Top words for topic #0:
# ['notification setting', 'email notification error', 'notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1156  189]
#  [ 970   17]]
# Accuracy: 0.5030017152658662
# Precision: 0.348536577301632
# Recall: 0.5030017152658662
# F1 Score: 0.3962353174125933
# ------------------------------------------------------------------
# Processing ngram_range: (1, 6)
# Top words for topic #0:
# ['notification setting', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1159  186]
#  [ 971   16]]
# Accuracy: 0.5038593481989708
# Precision: 0.34735635734713516
# Recall: 0.5038593481989708
# F1 Score: 0.3961175954336986
# ------------------------------------------------------------------
# Processing ngram_range: (1, 7)
# Top words for topic #0:
# ['notification setting', 'email notification error', 'notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1159  186]
#  [ 970   17]]
# Accuracy: 0.5042881646655232
# Precision: 0.34942355748657666
# Recall: 0.5042881646655232
# F1 Score: 0.3969300987191299
# ------------------------------------------------------------------
# Processing ngram_range: (1, 8)
# Top words for topic #0:
# ['notification setting', 'email notification error', 'notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1158  187]
#  [ 970   17]]
# Accuracy: 0.5038593481989708
# Precision: 0.34912632675169913
# Recall: 0.5038593481989708
# F1 Score: 0.3966986154596901
# ------------------------------------------------------------------
# Processing ngram_range: (1, 9)
# Top words for topic #0:
# ['notification setting', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1157  188]
#  [ 970   17]]
# Accuracy: 0.5034305317324185
# Precision: 0.3488306749731584
# Recall: 0.5034305317324185
# F1 Score: 0.3964670217418556
# ------------------------------------------------------------------
# Processing ngram_range: (1, 10)
# Top words for topic #0:
# ['notification setting', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1156  189]
#  [ 970   17]]
# Accuracy: 0.5030017152658662
# Precision: 0.348536577301632
# Recall: 0.5030017152658662
# F1 Score: 0.3962353174125933
# ------------------------------------------------------------------
# Processing ngram_range: (1, 11)
# Top words for topic #0:
# ['notification setting', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1156  189]
#  [ 970   17]]
# Accuracy: 0.5030017152658662
# Precision: 0.348536577301632
# Recall: 0.5030017152658662
# F1 Score: 0.3962353174125933
# ------------------------------------------------------------------
# Processing ngram_range: (1, 12)
# Top words for topic #0:
# ['notification setting', 'email notification error', 'notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1155  190]
#  [ 970   17]]
# Accuracy: 0.5025728987993139
# Precision: 0.3482440093645035
# Recall: 0.5025728987993139
# F1 Score: 0.3960035023188866
# ------------------------------------------------------------------
# Processing ngram_range: (1, 13)
# Top words for topic #0:
# ['notification setting', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1155  190]
#  [ 970   17]]
# Accuracy: 0.5025728987993139
# Precision: 0.3482440093645035
# Recall: 0.5025728987993139
# F1 Score: 0.3960035023188866
# ------------------------------------------------------------------
# Processing ngram_range: (1, 14)
# Top words for topic #0:
# ['notification setting', 'notification error', 'email notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1155  190]
#  [ 970   17]]
# Accuracy: 0.5025728987993139
# Precision: 0.3482440093645035
# Recall: 0.5025728987993139
# F1 Score: 0.3960035023188866
# ------------------------------------------------------------------
# Processing ngram_range: (1, 15)
# Top words for topic #0:
# ['notification setting', 'email notification error', 'notification error', 'issue', 'send email notification', 'send email', 'send', 'email notification', 'notification', 'email']
#
#
# Top words for topic #1:
# ['add', 'custom', 'field', 'project', 'redmine', 'user', 'issue', 'rest api', 'rest', 'api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.54      0.86      0.67      1345
#     Frontend       0.08      0.02      0.03       987
#
#     accuracy                           0.50      2332
#    macro avg       0.31      0.44      0.35      2332
# weighted avg       0.35      0.50      0.40      2332
#
# Confusion Matrix:
# [[1155  190]
#  [ 970   17]]
# Accuracy: 0.5025728987993139
# Precision: 0.3482440093645035
# Recall: 0.5025728987993139
# F1 Score: 0.3960035023188866
# ------------------------------------------------------------------
# Processing ngram_range: (2, 2)
# Top words for topic #0:
# ['add style', 'due date', 'notification redmine', 'picture email', 'notification setting', 'unify email', 'issue email', 'notification error', 'send email', 'email notification']
#
#
# Top words for topic #1:
# ['expose repository', 'api user', 'using rest', 'issue via', 'delete attachment', 'custom field', 'create issue', 'attachment rest', 'via rest', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.47      0.23      0.31       987
#
#     accuracy                           0.56      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.56      0.52      2332
#
# Confusion Matrix:
# [[1086  259]
#  [ 758  229]]
# Accuracy: 0.5638936535162951
# Precision: 0.5382857099920382
# Recall: 0.5638936535162951
# F1 Score: 0.5242451103080568
# ------------------------------------------------------------------
# Processing ngram_range: (2, 3)
# Top words for topic #0:
# ['email notification setting', 'issue email', 'issue email notification', 'unify email', 'unify email notification', 'notification error', 'email notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['issue via rest', 'issue via', 'create issue', 'delete attachment', 'delete attachment rest', 'attachment rest api', 'attachment rest', 'via rest api', 'via rest', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.47      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.52      2332
#
# Confusion Matrix:
# [[1093  252]
#  [ 761  226]]
# Accuracy: 0.5656089193825042
# Precision: 0.5401299354558569
# Recall: 0.5656089193825042
# F1 Score: 0.5247049067058162
# ------------------------------------------------------------------
# Processing ngram_range: (2, 4)
# Top words for topic #0:
# ['picture email notification', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['issue via rest api', 'issue via', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest', 'attachment rest api', 'via rest api', 'via rest', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.82      0.69      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.54      0.52      0.50      2332
# weighted avg       0.55      0.57      0.53      2332
#
# Confusion Matrix:
# [[1105  240]
#  [ 762  225]]
# Accuracy: 0.5703259005145798
# Precision: 0.5461537125620782
# Recall: 0.5703259005145798
# F1 Score: 0.5280054582466849
# ------------------------------------------------------------------
# Processing ngram_range: (2, 5)
# Top words for topic #0:
# ['picture email', 'notification setting', 'email notification setting', 'unify email notification', 'unify email', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['issue via', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest', 'delete attachment rest api', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.82      0.69      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.54      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1103  242]
#  [ 764  223]]
# Accuracy: 0.5686106346483705
# Precision: 0.5437154726690016
# Recall: 0.5686106346483705
# F1 Score: 0.5261212484991666
# ------------------------------------------------------------------
# Processing ngram_range: (2, 6)
# Top words for topic #0:
# ['picture email', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'notification error', 'email notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['issue via', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.82      0.69      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1102  243]
#  [ 764  223]]
# Accuracy: 0.5681818181818182
# Precision: 0.5431534233353782
# Recall: 0.5681818181818182
# F1 Score: 0.5257958992672318
# ------------------------------------------------------------------
# Processing ngram_range: (2, 7)
# Top words for topic #0:
# ['picture email', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['issue via', 'create issue', 'via rest api', 'via rest', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.82      0.69      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1101  244]
#  [ 764  223]]
# Accuracy: 0.5677530017152659
# Precision: 0.5425931037451812
# Recall: 0.5677530017152659
# F1 Score: 0.5254705261431245
# ------------------------------------------------------------------
# Processing ngram_range: (2, 8)
# Top words for topic #0:
# ['picture email', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['issue via', 'create issue', 'via rest api', 'via rest', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'attachment rest', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.82      0.69      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1099  246]
#  [ 763  224]]
# Accuracy: 0.5673241852487135
# Precision: 0.5421326687215465
# Recall: 0.5673241852487135
# F1 Score: 0.5254349236839799
# ------------------------------------------------------------------
# Processing ngram_range: (2, 9)
# Top words for topic #0:
# ['picture email notification', 'notification setting', 'email notification setting', 'unify email notification', 'unify email', 'notification error', 'email notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest', 'create issue', 'via rest api', 'via rest', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.47      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.52      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 763  224]]
# Accuracy: 0.5660377358490566
# Precision: 0.5404718909108333
# Recall: 0.5660377358490566
# F1 Score: 0.5244575709672807
# ------------------------------------------------------------------
# Processing ngram_range: (2, 10)
# Top words for topic #0:
# ['picture email', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest', 'delete attachment rest api', 'attachment rest api', 'attachment rest', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 761  226]]
# Accuracy: 0.5668953687821612
# Precision: 0.5417762420777181
# Recall: 0.5668953687821612
# F1 Score: 0.5256843509312981
# ------------------------------------------------------------------
# Processing ngram_range: (2, 11)
# Top words for topic #0:
# ['picture email notification', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'notification error', 'email notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest api', 'create issue', 'via rest api', 'via rest', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'attachment rest', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 760  227]]
# Accuracy: 0.5673241852487135
# Precision: 0.5424257573438083
# Recall: 0.5673241852487135
# F1 Score: 0.5262968512959905
# ------------------------------------------------------------------
# Processing ngram_range: (2, 12)
# Top words for topic #0:
# ['picture email notification', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'notification error', 'email notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest api', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 760  227]]
# Accuracy: 0.5673241852487135
# Precision: 0.5424257573438083
# Recall: 0.5673241852487135
# F1 Score: 0.5262968512959905
# ------------------------------------------------------------------
# Processing ngram_range: (2, 13)
# Top words for topic #0:
# ['picture email notification', 'notification setting', 'email notification setting', 'unify email notification', 'unify email', 'notification error', 'email notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest api', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest api', 'delete attachment rest', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 760  227]]
# Accuracy: 0.5673241852487135
# Precision: 0.5424257573438083
# Recall: 0.5673241852487135
# F1 Score: 0.5262968512959905
# ------------------------------------------------------------------
# Processing ngram_range: (2, 14)
# Top words for topic #0:
# ['picture email', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest api', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest', 'delete attachment rest api', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 760  227]]
# Accuracy: 0.5673241852487135
# Precision: 0.5424257573438083
# Recall: 0.5673241852487135
# F1 Score: 0.5262968512959905
# ------------------------------------------------------------------
# Processing ngram_range: (2, 15)
# Top words for topic #0:
# ['picture email notification', 'notification setting', 'email notification setting', 'unify email', 'unify email notification', 'email notification error', 'notification error', 'send email', 'send email notification', 'email notification']
#
#
# Top words for topic #1:
# ['extension rest api', 'create issue', 'via rest', 'via rest api', 'delete attachment', 'delete attachment rest', 'delete attachment rest api', 'attachment rest', 'attachment rest api', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.81      0.68      1345
#     Frontend       0.48      0.23      0.31       987
#
#     accuracy                           0.57      2332
#    macro avg       0.53      0.52      0.50      2332
# weighted avg       0.54      0.57      0.53      2332
#
# Confusion Matrix:
# [[1096  249]
#  [ 760  227]]
# Accuracy: 0.5673241852487135
# Precision: 0.5424257573438083
# Recall: 0.5673241852487135
# F1 Score: 0.5262968512959905
# ------------------------------------------------------------------
# Processing ngram_range: (3, 3)
# Top words for topic #0:
# ['email notification project', 'project copy always', 'notification ignoring send', 'project copy option', 'copy always send', 'always send email', 'ignoring send email', 'email notification failed', 'try send email', 'send email notification']
#
#
# Top words for topic #1:
# ['option decide default', 'decide default value', 'ability set default', 'set default value', 'default value dont', 'value dont want', 'dont want notified', 'want notified change', 'notified change make', 'mention user username']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.69      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.70      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[810 535]
#  [203 784]]
# Accuracy: 0.6835334476843911
# Precision: 0.7127493685438298
# Recall: 0.6835334476843911
# F1 Score: 0.6840358320825772
# ------------------------------------------------------------------
# Processing ngram_range: (3, 4)
# Top words for topic #0:
# ['value dont want', 'default value dont', 'default value dont want', 'value dont want notified', 'notified change make', 'dont want notified', 'dont want notified change', 'want notified change make', 'want notified change', 'mention user username']
#
#
# Top words for topic #1:
# ['always send email', 'email notification project copy', 'email notification project', 'send email notification project', 'email notification ignoring', 'send email notification failed', 'email notification failed', 'try send email', 'try send email notification', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.79      0.58      0.67      1345
#     Frontend       0.58      0.79      0.67       987
#
#     accuracy                           0.67      2332
#    macro avg       0.69      0.68      0.67      2332
# weighted avg       0.70      0.67      0.67      2332
#
# Confusion Matrix:
# [[774 571]
#  [203 784]]
# Accuracy: 0.6680960548885078
# Precision: 0.701806764160891
# Recall: 0.6680960548885078
# F1 Score: 0.6678714541773048
# ------------------------------------------------------------------
# Processing ngram_range: (3, 5)
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# Top words for topic #0:
# ['add support updating attachment', 'updating attachment rest', 'add support updating attachment rest', 'updating attachment rest api', 'support updating attachment', 'add support updating', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['always send email notification ignoring', 'send email notification project', 'send email notification ignoring', 'send email notification ignoring send', 'try send email', 'try send email notification failed', 'email notification failed', 'send email notification failed', 'try send email notification', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.59      0.68      1345
#     Frontend       0.59      0.79      0.67       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.69      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[793 552]
#  [203 784]]
# Accuracy: 0.6762435677530018
# Precision: 0.7075755054399664
# Recall: 0.6762435677530018
# F1 Score: 0.6764305652177038
# ------------------------------------------------------------------
# Processing ngram_range: (3, 6)
# Top words for topic #0:
# ['add support updating', 'updating attachment rest api', 'support updating attachment rest api', 'support updating attachment rest', 'support updating attachment', 'updating attachment rest', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['email notification ignoring send', 'email notification project copy', 'notification project copy', 'ignoring send email', 'email notification failed', 'try send email notification failed', 'try send email notification', 'try send email', 'send email notification failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.59      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.69      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[796 549]
#  [203 784]]
# Accuracy: 0.6775300171526587
# Precision: 0.7084874858374837
# Recall: 0.6775300171526587
# F1 Score: 0.6777762245215797
# ------------------------------------------------------------------
# Processing ngram_range: (3, 7)
# Top words for topic #0:
# ['updating attachment rest api', 'support updating attachment rest', 'add support updating attachment', 'support updating attachment rest api', 'add support updating attachment rest api', 'updating attachment rest', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['notification project copy option', 'email notification ignoring send email notification project', 'email notification ignoring send', 'email notification ignoring send email', 'email notification failed', 'try send email notification', 'send email notification failed', 'try send email notification failed', 'try send email', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.68      1345
#     Frontend       0.59      0.80      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[801 544]
#  [202 785]]
# Accuracy: 0.6801029159519726
# Precision: 0.7105975998105988
# Recall: 0.6801029159519726
# F1 Score: 0.6804248150223442
# ------------------------------------------------------------------
# Processing ngram_range: (3, 8)
# Top words for topic #0:
# ['add support updating attachment', 'support updating attachment', 'updating attachment rest', 'updating attachment rest api', 'add support updating attachment rest', 'support updating attachment rest', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['send email notification ignoring send email notification', 'ignoring send email notification project', 'ignoring send email notification', 'ignoring send email', 'try send email', 'try send email notification failed', 'email notification failed', 'send email notification failed', 'try send email notification', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.68      1345
#     Frontend       0.59      0.80      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[801 544]
#  [202 785]]
# Accuracy: 0.6801029159519726
# Precision: 0.7105975998105988
# Recall: 0.6801029159519726
# F1 Score: 0.6804248150223442
# ------------------------------------------------------------------
# Processing ngram_range: (3, 9)
# Top words for topic #0:
# ['updating attachment rest', 'updating attachment rest api', 'add support updating attachment', 'add support updating attachment rest', 'add support updating attachment rest api', 'add support updating', 'delete attachment rest', 'delete attachment rest api', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['project copy always send email notification ignoring send', 'project copy always send email notification ignoring', 'copy always send email notification ignoring send email notification', 'email notification project copy option', 'send email notification failed', 'try send email notification', 'try send email', 'email notification failed', 'try send email notification failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.59      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.69      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[798 547]
#  [203 784]]
# Accuracy: 0.6783876500857633
# Precision: 0.7090956971242753
# Recall: 0.6783876500857633
# F1 Score: 0.6786724748562842
# ------------------------------------------------------------------
# Processing ngram_range: (3, 10)
# Top words for topic #0:
# ['add support updating attachment', 'support updating attachment rest api', 'support updating attachment rest', 'support updating attachment', 'updating attachment rest api', 'add support updating', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['issue csv file', 'notification importing issue', 'option send email notification', 'option send email', 'try send email notification failed', 'try send email notification', 'try send email', 'send email notification failed', 'email notification failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.59      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.69      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[800 545]
#  [203 784]]
# Accuracy: 0.6792452830188679
# Precision: 0.7097041003570489
# Recall: 0.6792452830188679
# F1 Score: 0.6795680450894283
# ------------------------------------------------------------------
# Processing ngram_range: (3, 11)
# Top words for topic #0:
# ['add support updating', 'add support updating attachment', 'add support updating attachment rest', 'support updating attachment rest api', 'support updating attachment rest', 'add support updating attachment rest api', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['send email notification importing issue csv file', 'notification importing issue csv', 'notification importing issue', 'send email notification importing issue csv', 'try send email notification', 'email notification failed', 'try send email notification failed', 'try send email', 'send email notification failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.59      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.69      0.69      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[799 546]
#  [203 784]]
# Accuracy: 0.6788164665523156
# Precision: 0.7093998740804929
# Recall: 0.6788164665523156
# F1 Score: 0.6791203447397864
# ------------------------------------------------------------------
# Processing ngram_range: (3, 12)
# Top words for topic #0:
# ['support updating attachment rest api', 'support updating attachment rest', 'support updating attachment', 'add support updating attachment rest', 'add support updating', 'updating attachment rest api', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['option send email', 'importing issue csv', 'importing issue csv file', 'notification importing issue csv', 'try send email notification failed', 'try send email notification', 'send email notification failed', 'try send email', 'email notification failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.70      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[805 540]
#  [203 784]]
# Accuracy: 0.6813893653516295
# Precision: 0.7112260181620111
# Recall: 0.6813893653516295
# F1 Score: 0.6818040210047526
# ------------------------------------------------------------------
# Processing ngram_range: (3, 13)
# Top words for topic #0:
# ['add support updating attachment', 'add support updating', 'support updating attachment rest', 'support updating attachment rest api', 'updating attachment rest api', 'updating attachment rest', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['email notification importing', 'send email notification importing issue', 'issue csv file', 'send email notification importing issue csv file', 'email notification failed', 'try send email notification', 'send email notification failed', 'try send email notification failed', 'try send email', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.69      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.70      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[807 538]
#  [203 784]]
# Accuracy: 0.6822469982847341
# Precision: 0.7118351771094672
# Recall: 0.6822469982847341
# F1 Score: 0.6826972417938343
# ------------------------------------------------------------------
# Processing ngram_range: (3, 14)
# Top words for topic #0:
# ['add support updating attachment rest', 'add support updating attachment rest api', 'support updating attachment', 'support updating attachment rest', 'updating attachment rest', 'updating attachment rest api', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['notification importing issue', 'email notification importing issue csv', 'email notification importing issue', 'email notification importing issue csv file', 'try send email notification failed', 'try send email', 'email notification failed', 'send email notification failed', 'try send email notification', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.70      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[805 540]
#  [203 784]]
# Accuracy: 0.6813893653516295
# Precision: 0.7112260181620111
# Recall: 0.6813893653516295
# F1 Score: 0.6818040210047526
# ------------------------------------------------------------------
# Processing ngram_range: (3, 15)
# Top words for topic #0:
# ['add support updating attachment rest api', 'add support updating attachment rest', 'add support updating', 'add support updating attachment', 'support updating attachment rest api', 'updating attachment rest', 'delete attachment rest api', 'delete attachment rest', 'attachment rest api', 'mention user username']
#
#
# Top words for topic #1:
# ['notification importing issue csv file', 'issue csv file', 'option send email notification importing issue csv file', 'send email notification importing issue csv', 'try send email notification', 'try send email', 'send email notification failed', 'email notification failed', 'try send email notification failed', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.80      0.60      0.68      1345
#     Frontend       0.59      0.79      0.68       987
#
#     accuracy                           0.68      2332
#    macro avg       0.70      0.70      0.68      2332
# weighted avg       0.71      0.68      0.68      2332
#
# Confusion Matrix:
# [[805 540]
#  [203 784]]
# Accuracy: 0.6813893653516295
# Precision: 0.7112260181620111
# Recall: 0.6813893653516295
# F1 Score: 0.6818040210047526
# ------------------------------------------------------------------
# Processing ngram_range: (4, 4)
# Top words for topic #0:
# ['notified change make default', 'option decide default value', 'add option decide default', 'decide default value dont', 'ability set default value', 'set default value dont', 'default value dont want', 'value dont want notified', 'dont want notified change', 'want notified change make']
#
#
# Top words for topic #1:
# ['email notification option event', 'notification option event bookmarked', 'option event bookmarked project', 'email notification option thing', 'option thing watch assigned', 'default notification option thing', 'change default notification option', 'new email notification option', 'notification option thing watch', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.92      0.43      0.59      1345
#     Frontend       0.55      0.95      0.70       987
#
#     accuracy                           0.65      2332
#    macro avg       0.74      0.69      0.64      2332
# weighted avg       0.77      0.65      0.63      2332
#
# Confusion Matrix:
# [[578 767]
#  [ 47 940]]
# Accuracy: 0.6509433962264151
# Precision: 0.7664540902609677
# Recall: 0.6509433962264151
# F1 Score: 0.6338009376688483
# ------------------------------------------------------------------
# Processing ngram_range: (4, 5)
# Top words for topic #0:
# ['set default value dont want', 'set default value dont', 'ability set default value dont', 'default value dont want notified', 'value dont want notified', 'value dont want notified change', 'default value dont want', 'dont want notified change', 'dont want notified change make', 'want notified change make']
#
#
# Top words for topic #1:
# ['character enclosed removed email', 'character enclosed removed email notification', 'enclosed removed email notification', 'fullwidth character enclosed removed', 'redmine send reminder work', 'add table border email', 'table border email notification', 'add table border email notification', 'email notification involved clarification', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
# ...
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.43      0.26      2332
#
# Confusion Matrix:
# [[   7 1338]
#  [   0  987]]
# Accuracy: 0.4262435677530017
# Precision: 0.7564311403751453
# Recall: 0.4262435677530017
# F1 Score: 0.25823062570357014
# ------------------------------------------------------------------
# Processing ngram_range: (13, 13)
# Top words for topic #0:
# ['updating issue via rest api cause internal server error invalid project id specified', 'rest api show wiki page html format contains wrong link another wiki project', 'api create issue relation method return undefined method split issue id sent integer', 'request adding tracker id name rest time entry response like already project info', 'adding tracker id name rest time entry response like already project info response', 'use setting host name instead setting app title totp issuer avoid name collision', 'host name instead setting app title totp issuer avoid name collision instance apps', 'setting host name instead setting app title totp issuer avoid name collision instance', 'creating rest api new issue project without tracker enabled return misleading error message', 'project copy always send email notification ignoring send email notification project copy option']
#
#
# Top words for topic #1:
# ['host name instead setting app title totp issuer avoid name collision instance apps', 'setting host name instead setting app title totp issuer avoid name collision instance', 'use setting host name instead setting app title totp issuer avoid name collision', 'updating issue via rest api cause internal server error invalid project id specified', 'creating rest api new issue project without tracker enabled return misleading error message', 'rest api show wiki page html format contains wrong link another wiki project', 'outgoing email address per project email alias different incoming email alias mapping specific', 'different outgoing email address per project email alias different incoming email alias mapping', 'email address per project email alias different incoming email alias mapping specific project', 'view issue link email reminder point issue list doe include issue assigned group']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   3 1342]
#  [   0  987]]
# Accuracy: 0.42452830188679247
# Precision: 0.7561225564457983
# Recall: 0.42452830188679247
# F1 Score: 0.25452115853229024
# ------------------------------------------------------------------
# Processing ngram_range: (13, 14)
# Top words for topic #0:
# ['querycolumn sql field assumes operator issue opened closed deal field named status id', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'sql field assumes operator issue opened closed deal field named status id extendable', 'workflow status transition header column header row pan scroll view numerous issue status', 'creating rest api new issue project without tracker enabled return misleading error message', 'anymore yaml db rake task db data dump db data load update redmine', 'rest api show wiki page html format contains wrong link another wiki project', 'updating issue via rest api cause internal server error invalid project id specified', 'view issue link email reminder point issue list doe include issue assigned group', 'project copy always send email notification ignoring send email notification project copy option']
#
#
# Top words for topic #1:
# ['use setting host name instead setting app title totp issuer avoid name collision instance', 'host name instead setting app title totp issuer avoid name collision instance apps', 'rest api show wiki page html format contains wrong link another wiki project', 'creating rest api new issue project without tracker enabled return misleading error message', 'view issue link email reminder point issue list doe include issue assigned group', 'email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'different outgoing email address per project email alias different incoming email alias mapping', 'outgoing email address per project email alias different incoming email alias mapping specific', 'outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.01      0.01      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.43      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.43      0.26      2332
#
# Confusion Matrix:
# [[   7 1338]
#  [   0  987]]
# Accuracy: 0.4262435677530017
# Precision: 0.7564311403751453
# Recall: 0.4262435677530017
# F1 Score: 0.25823062570357014
# ------------------------------------------------------------------
# Processing ngram_range: (13, 15)
# Top words for topic #0:
# ['request adding tracker id name rest time entry response like already project info', 'querycolumn sql field assumes operator issue opened closed deal field named status id', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'sql field assumes operator issue opened closed deal field named status id extendable', 'api create issue relation method return undefined method split issue id sent integer', 'workflow status transition header column header row pan scroll view numerous issue status', 'rest api show wiki page html format contains wrong link another wiki project', 'updating issue via rest api cause internal server error invalid project id specified', 'creating rest api new issue project without tracker enabled return misleading error message', 'project copy always send email notification ignoring send email notification project copy option']
#
#
# Top words for topic #1:
# ['api create issue relation method return undefined method split issue id sent integer', 'creating rest api new issue project without tracker enabled return misleading error message', 'rest api show wiki page html format contains wrong link another wiki project', 'different outgoing email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'different outgoing email address per project email alias different incoming email alias mapping', 'outgoing email address per project email alias different incoming email alias mapping specific', 'outgoing email address per project email alias different incoming email alias mapping specific project', 'email address per project email alias different incoming email alias mapping specific project', 'view issue link email reminder point issue list doe include issue assigned group']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.01      0.01      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.43      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.43      0.26      2332
#
# Confusion Matrix:
# [[   9 1336]
#  [   0  987]]
# Accuracy: 0.42710120068610635
# Precision: 0.75658583085544
# Recall: 0.42710120068610635
# F1 Score: 0.26007809038208873
# ------------------------------------------------------------------
# Processing ngram_range: (14, 14)
# Top words for topic #0:
# ['project copy failed copy issue category set required project copy issue issue xxx could', 'failed copy issue category set required project copy issue issue xxx could copied category', 'copy issue category set required project copy issue issue xxx could copied category blank', 'copy failed copy issue category set required project copy issue issue xxx could copied', 'request adding tracker id name rest time entry response like already project info response', 'design tracker selection ui custom field editing screen project setting screen aligned create sense', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Top words for topic #1:
# ['failed copy issue category set required project copy issue issue xxx could copied category', 'project copy failed copy issue category set required project copy issue issue xxx could', 'copy failed copy issue category set required project copy issue issue xxx could copied', 'querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'design tracker selection ui custom field editing screen project setting screen aligned create sense', 'request adding tracker id name rest time entry response like already project info response', 'use setting host name instead setting app title totp issuer avoid name collision instance', 'setting host name instead setting app title totp issuer avoid name collision instance apps']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   3 1342]
#  [   0  987]]
# Accuracy: 0.42452830188679247
# Precision: 0.7561225564457983
# Recall: 0.42452830188679247
# F1 Score: 0.25452115853229024
# ------------------------------------------------------------------
# Processing ngram_range: (14, 15)
# Top words for topic #0:
# ['copy failed copy issue category set required project copy issue issue xxx could copied category', 'request adding tracker id name rest time entry response like already project info response', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'design tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'design tracker selection ui custom field editing screen project setting screen aligned create sense', 'different outgoing email address per project email alias different incoming email alias mapping specific project', 'different outgoing email address per project email alias different incoming email alias mapping specific', 'outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Top words for topic #1:
# ['querycolumn sql field assumes operator issue opened closed deal field named status id extendable', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'design tracker selection ui custom field editing screen project setting screen aligned create sense', 'selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'design tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'request adding tracker id name rest time entry response like already project info response', 'use setting host name instead setting app title totp issuer avoid name collision instance', 'use setting host name instead setting app title totp issuer avoid name collision instance apps', 'setting host name instead setting app title totp issuer avoid name collision instance apps']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.60       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   3 1342]
#  [   0  987]]
# Accuracy: 0.42452830188679247
# Precision: 0.7561225564457983
# Recall: 0.42452830188679247
# F1 Score: 0.25452115853229024
# ------------------------------------------------------------------
# Processing ngram_range: (15, 15)
# Top words for topic #0:
# ['open new tab ff already open additional testing seems indicate occurs last opened site wa', 'fails restore quiting browser via ctrl standalone window manager arch linux session restores manually pressing', 'restore quiting browser via ctrl standalone window manager arch linux session restores manually pressing button', 'session fails restore quiting browser via ctrl standalone window manager arch linux session restores manually', 'copy failed copy issue category set required project copy issue issue xxx could copied category', 'project copy failed copy issue category set required project copy issue issue xxx could copied', 'failed copy issue category set required project copy issue issue xxx could copied category blank', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'design tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'different outgoing email address per project email alias different incoming email alias mapping specific project']
#
#
# Top words for topic #1:
# ['org eclipse jst jee webapplication internal impl webappimpl cast org eclipse jst javaee web webapp', 'organize import add unnecessary static import creating anonymous class enclosing interface calling static method within', 'pdf date input box auto corrects dd mm yyyy format american format mm dd yyyy', 'pdf download new tab steal focus even user switch different tab download start download end', 'project copy failed copy issue category set required project copy issue issue xxx could copied', 'failed copy issue category set required project copy issue issue xxx could copied category blank', 'copy failed copy issue category set required project copy issue issue xxx could copied category', 'design tracker selection ui custom field editing screen project setting screen aligned create sense coherence', 'tracker selection ui custom field editing screen project setting screen aligned create sense coherence unity', 'use setting host name instead setting app title totp issuer avoid name collision instance apps']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       1.00      0.00      0.00      1345
#     Frontend       0.42      1.00      0.59       987
#
#     accuracy                           0.42      2332
#    macro avg       0.71      0.50      0.30      2332
# weighted avg       0.76      0.42      0.25      2332
#
# Confusion Matrix:
# [[   1 1344]
#  [   0  987]]
# Accuracy: 0.4236706689536878
# Precision: 0.755968661629039
# Recall: 0.4236706689536878
# F1 Score: 0.2526591105323622
# ------------------------------------------------------------------
