# %%
import pandas as pd
import os
import numpy as np
import string
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# path of training data
train_path = 'train.xlsx'

# path of testing data
test_path = 'test.xlsx'

# %%
# show the first 5 rows of the training data
train_df = pd.read_excel(train_path)
print(train_df.head())

# show the first 5 rows of the testing data
test_df = pd.read_excel(test_path)
print(test_df.head())
# Out:
#                                               report class_name  class_index
# 0  "For any event on my bookmarked projects" opti...    Backend            1
# 1           Switch to using full l10n id's in urlbar   Frontend            2
# 2  Consider removing hasicon property to simplify...   Frontend            2
# 3  Method to obtain current URL from WebBrowserEd...   Frontend            2
# 4              Fix: migration fails in MS SQL-Server    Backend            1
#                                               report class_name  class_index
# 0  REST API - ability to list sub projects for a ...    Backend            1
# 1  support selective text on right if set in GNOM...   Frontend            2
# 2  [meta][userstory] Ship v1 of Pre-populated top...   Frontend            2
# 3  Include updated_on and passwd_changed_on colum...    Backend            1
# 4    Problem with email integration to MS Office 365    Backend            1

# %%
def convert_lower_case(data):
    return str(data).lower()

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in symbols:
        data = np.char.replace(data, i, ' ')

    return str(data)

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def remove_numbers(data):
    return re.sub(r'\d+', '', str(data))

# %%
def remove_single_characters(tokens):
    new_text = ""
    for w in tokens:
        if len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def lemmatization(data):
    lemmatizer = WordNetLemmatizer()
    tokens = word_tokenize(data)
    data = remove_single_characters(tokens)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(word) for word in tokens])
    return lemmatized_output

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data)
    data = remove_apostrophe(data)
    data = remove_numbers(data)
    data = lemmatization(data)
    return data

# %%
# print the first report of the training data
print(train_df['report'][0])
# Out:
# "For any event on my bookmarked projects" option not sending notifications for non-member bookmarked projects

# %%
# preprocess the first report of the training data
print(preprocess(train_df['report'][0]))
# Out:
# for any event on my bookmarked project option not sending notification for non member bookmarked project

# %%
import pandas as pd

# Assuming train_df is your DataFrame containing training data
# Assuming train_df has columns 'id', 'report', and 'class_name'

# Initialize counter
counter = 1

# Iterate over each row in the DataFrame
with open('preprocessed_train_data.csv', 'w', encoding='utf-8') as f:
    f.write('bug_description , class_name\n')  # Write header

    for _, row in train_df.iterrows():
        # Preprocess the 'report' column
        preprocessed_report = preprocess(row['report'])

        # Write data to the file with incremented counter
        f.write(f"{preprocessed_report},{row['class_name']}\n")

# Print the first preprocessed report
print(train_df['report'][0])
# Out:
# "For any event on my bookmarked projects" option not sending notifications for non-member bookmarked projects

# %%
# FOR TESTING DATA

# Iterate over each row in the DataFrame
with open('preprocessed_test_data.csv', 'w', encoding='utf-8') as f:
    f.write('bug_description , class_name\n')  # Write header

    for _, row in test_df.iterrows():
        # Preprocess the 'report' column
        preprocessed_report = preprocess(row['report'])

        # Write data to the file with incremented counter
        f.write(f"{preprocessed_report},{row['class_name']}\n")

# Print the first preprocessed report
print(test_df['report'][0])
# Out:
# REST API - ability to list sub projects for a project

# %%
# Open the preprocessed data file for reading
with open('preprocessed_train_data.csv', 'r', encoding='utf-8') as f:
    # Open the new file for writing preprocessed data with 2 columns
    with open('preprocessed_train_data2.csv', 'w', encoding='utf-8') as f_out:
        # Iterate over each line in the file
        for i, line in enumerate(f):
            # Skip the header
            if i == 0:
                continue
            
            # Split the line into columns based on comma delimiter
            columns = line.strip().split(',')
            
            # Check the number of columns
            if len(columns) == 2:
                # Get the preprocessed report and class name
                preprocessed_report = columns[0]
                class_name = columns[1]
                
                # Write the preprocessed report and class name to the new file
                f_out.write(f"{preprocessed_report},{class_name}\n")
            else:
                # Skip the line if it doesn't have exactly 2 columns
                continue

# %%
# FOR TESTING DATA

# Open the preprocessed data file for reading
with open('preprocessed_test_data.csv', 'r', encoding='utf-8') as f:
    # Open the new file for writing preprocessed data with 2 columns
    with open('preprocessed_test_data2.csv', 'w', encoding='utf-8') as f_out:
        # Iterate over each line in the file
        for i, line in enumerate(f):
            # Skip the header
            if i == 0:
                continue
            
            # Split the line into columns based on comma delimiter
            columns = line.strip().split(',')
            
            # Check the number of columns
            if len(columns) == 2:
                # Get the preprocessed report and class name
                preprocessed_report = columns[0]
                class_name = columns[1]
                
                # Write the preprocessed report and class name to the new file
                f_out.write(f"{preprocessed_report},{class_name}\n")
            else:
                # Skip the line if it doesn't have exactly 2 columns
                continue

# %%
# read the preprocessed data from the new file
preprocessed_train_df = pd.read_csv('preprocessed_train_data2.csv')

# show the first 5 rows of the preprocessed training data
print(preprocessed_train_df.head())
# Out:
#                                      bug_description class_name
# 0  for any event on my bookmarked project option ...    Backend
# 1               switch to using full ln id in urlbar   Frontend
# 2  consider removing hasicon property to simplify...   Frontend
# 3  method to obtain current url from webbrowsered...   Frontend
# 4                fix migration fails in m sql server    Backend

# %%
# read the preprocessed data from the new file
preprocessed_test_df = pd.read_csv('preprocessed_test_data2.csv')

# show the first 5 rows of the preprocessed training data
print(preprocessed_test_df.head())
# Out:
#                                      bug_description class_name
# 0  rest api ability to list sub project for a pro...    Backend
# 1  support selective text on right if set in gnom...   Frontend
# 2  meta userstory ship v of pre populated topsite...   Frontend
# 3  include updated on and passwd changed on colum...    Backend
# 4         problem with email integration to m office    Backend

# %%
# remove the stop words from the preprocessed data using nltk
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

def remove_stop_words(data):
    tokens = word_tokenize(data)
    data = ' '.join([i for i in tokens if not i in stop_words])
    return data

# preprocess the first report of the training data
print(preprocess(train_df['report'][0]))

# remove the stop words from the preprocessed data
print(remove_stop_words(preprocess(train_df['report'][0])))

# preprocess the first report of the testing data
print(preprocess(test_df['report'][0]))
# Out:
# for any event on my bookmarked project option not sending notification for non member bookmarked project
# event bookmarked project option sending notification non member bookmarked project
# rest api ability to list sub project for a project
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Convert non-string values to strings in 'bug_description' column
preprocessed_train_df['bug_description'] = preprocessed_train_df['bug_description'].apply(lambda x: str(x))
preprocessed_test_df['bug_description'] = preprocessed_test_df['bug_description'].apply(lambda x: str(x))

# Remove stop words from 'bug_description' column
preprocessed_train_df['bug_description'] = preprocessed_train_df['bug_description'].apply(lambda x: remove_stop_words(x))
preprocessed_test_df['bug_description'] = preprocessed_test_df['bug_description'].apply(lambda x: remove_stop_words(x))

# Show the first 5 rows of the preprocessed training data
print(preprocessed_train_df.head())

# Show the first 5 rows of the preprocessed testing data
print(preprocessed_test_df.head())
# Out:
#                                      bug_description class_name
# 0  event bookmarked project option sending notifi...    Backend
# 1                     switch using full ln id urlbar   Frontend
# 2  consider removing hasicon property simplify st...   Frontend
# 3         method obtain current url webbrowsereditor   Frontend
# 4                     fix migration fails sql server    Backend
#                                      bug_description class_name
# 0          rest api ability list sub project project    Backend
# 1     support selective text right set gnome setting   Frontend
# 2  meta userstory ship v pre populated topsites a...   Frontend
# 3  include updated passwd changed column user api...    Backend
# 4                   problem email integration office    Backend

# %%
# keep only the reports that has class_name of Frontend, Backend, Security, Documentation
# Filter the training data
filtered_train_df = preprocessed_train_df[
    (preprocessed_train_df['class_name'] == 'Frontend') | 
    (preprocessed_train_df['class_name'] == 'Backend') |
    (preprocessed_train_df['class_name'] == 'Security') 
]

# Filter the testing data
filtered_test_df = preprocessed_test_df[
    (preprocessed_test_df['class_name'] == 'Frontend') | 
    (preprocessed_test_df['class_name'] == 'Backend') |
    (preprocessed_test_df['class_name'] == 'Security') 
]

# Show the first 5 rows of the filtered training data
print("Filtered Training Data:")
print(filtered_train_df.head())

# Show the first 5 rows of the filtered testing data
print("\nFiltered Testing Data:")
print(filtered_test_df.head())
# Out:
# Filtered Training Data:
#                                      bug_description class_name
# 0  event bookmarked project option sending notifi...    Backend
# 1                     switch using full ln id urlbar   Frontend
# 2  consider removing hasicon property simplify st...   Frontend
# 3         method obtain current url webbrowsereditor   Frontend
# 4                     fix migration fails sql server    Backend
#
# Filtered Testing Data:
#                                      bug_description class_name
# 0          rest api ability list sub project project    Backend
# 1     support selective text right set gnome setting   Frontend
# 2  meta userstory ship v pre populated topsites a...   Frontend
# 3  include updated passwd changed column user api...    Backend
# 4                   problem email integration office    Backend

# %%
# Define the mapping of class names to the desired order
class_name_mapping = {
    'Backend': 1,
    'Frontend': 0,
    'Security': 2
}

# Map class names in both training and testing data to the desired order
filtered_train_df['class_label'] = filtered_train_df['class_name'].map(class_name_mapping)
filtered_test_df['class_label'] = filtered_test_df['class_name'].map(class_name_mapping)

# order them based on the number of class_label
filtered_train_df = filtered_train_df.sort_values(by=['class_label'])
filtered_test_df = filtered_test_df.sort_values(by=['class_label'])

# Print the unique class names in the training data
print(filtered_train_df['class_name'].unique())

# Print the unique class names in the testing data
print(filtered_test_df['class_name'].unique())
# Out:
# ['Frontend' 'Backend' 'Security']
# ['Frontend' 'Backend' 'Security']
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21728\1289288455.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_train_df['class_label'] = filtered_train_df['class_name'].map(class_name_mapping)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21728\1289288455.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_test_df['class_label'] = filtered_test_df['class_name'].map(class_name_mapping)

# %% [markdown]
# ## Feature Exraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Replace NaN values with an empty string
preprocessed_train_df['bug_description'].fillna('', inplace=True)

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the preprocessed data
X_train = vectorizer.fit_transform(filtered_train_df['bug_description'])

# Print the shape of X_train
print(X_train.shape)
# Out:
# (13603, 7483)

# %%
# print the vector representation of the first report
print(X_train[0])
# Out:
#   (0, 6321)	0.39810213343122414
#   (0, 1005)	0.48891468317581693
#   (0, 6672)	0.5876471675976369
#   (0, 3503)	0.507097555059254

# %%
# Print the number of unique class_name in the training data
print(filtered_train_df['class_name'].nunique())

# print their unique values
print(filtered_train_df['class_name'].unique())

# print the number of reports in each class
print(filtered_train_df['class_name'].value_counts())
# Out:
# 3
# ['Frontend' 'Backend' 'Security']
# Backend     7437
# Frontend    5799
# Security     367
# Name: class_name, dtype: int64

# %%
# Create a mapping between cluster labels and class names
cluster_class_mapping = {
    1: 'Backend',  # Example mapping, adjust based on your actual clusters
    0: 'Frontend',
    2: 'Security'
}

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

def lda_topic_modeling(data, class_name, n_components=2, ngram_range=(3, 5), random_state=42):
    """
    Perform Latent Dirichlet Allocation (LDA) topic modeling on the given data and evaluate on test data.

    Parameters:
    - data: DataFrame containing the text data to be modeled.
    - class_name: Series containing the class names corresponding to the data.
    - n_components: Number of topics to be generated (default is 2).
    - ngram_range: Tuple specifying the range of n-grams to consider (default is (1, 2)).
    - random_state: Random seed for reproducibility (default is 42).

    Returns:
    - None
    """
    # Initialize the TfidfVectorizer
    vectorizer = TfidfVectorizer(ngram_range=ngram_range)

    # Fit and transform the data
    X_train = vectorizer.fit_transform(data)

    # Initialize the LDA model
    lda_model = LatentDirichletAllocation(n_components=n_components, random_state=random_state)

    # Fit the LDA model
    lda_model.fit(X_train)

    # Print the top words for each topic
    for i, topic in enumerate(lda_model.components_):
        print(f"Top words for topic #{i}:")
        print([vectorizer.get_feature_names_out()[index] for index in topic.argsort()[-10:]])
        print("\n")

    # Transform the preprocessed test data
    X_test = vectorizer.transform(filtered_test_df['bug_description'])

    # Predict the topics for the test data
    topic_predictions = lda_model.transform(X_test)

    # Map numerical indices to class names
    predicted_class_names = [cluster_class_mapping[prediction] for prediction in np.argmax(topic_predictions, axis=1)]

    # Print the classification report
    print("Classification Report:")
    print(classification_report(class_name, predicted_class_names))

    # Print the confusion matrix
    print("Confusion Matrix:")
    print(confusion_matrix(class_name, predicted_class_names))

    # Calculate and print the accuracy
    accuracy = np.mean(class_name == predicted_class_names)
    print("Accuracy:", accuracy)

    # precision
    precision = np.mean(class_name == predicted_class_names)
    print("Precision:", precision)

    # recall
    recall = np.mean(class_name == predicted_class_names)
    print("Recall:", recall)

    # f1-score
    f1_score = np.mean(class_name == predicted_class_names)
    print("F1-Score:", f1_score)

# Usage example:
lda_topic_modeling(filtered_train_df['bug_description'], filtered_test_df['class_name'])
# Out:
# Top words for topic #0:
# ['issue email notification', 'due date redmine', 'email configuration error', 'cant delete account', 'unify email notification', 'smtp authentication failed', 'optional email header', 'abstraction layer notification', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['author name mail', 'picture email notification', 'modify email template', 'changed email template', 'issue assigned group', 'notification removing assignment', 'option project manager', 'email dropped timeout', 'email notification error', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.78      0.32      0.46      1345
#     Frontend       0.47      0.89      0.62       987
#     Security       0.00      0.00      0.00        70
#
#     accuracy                           0.55      2402
#    macro avg       0.42      0.40      0.36      2402
# weighted avg       0.63      0.55      0.51      2402
#
# Confusion Matrix:
# [[433 912   0]
#  [109 878   0]
#  [ 11  59   0]]
# Accuracy: 0.5457951706910907
# Precision: 0.5457951706910907
# Recall: 0.5457951706910907
# F1-Score: 0.5457951706910907
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# iterate to cover all possible combinations of ngram_range:
# 1- (2, 2) , (2, 3) , (2, 4)and so on till (2,8)
# 2- (3, 3) , (3, 4) , (3, 5)and so on till (3,8)
# and so on till (5, 8)

# Define the n-gram ranges to be considered
ngram_ranges = [(2, i) for i in range(2, 9)] + [(3, i) for i in range(3, 9)] + [(4, i) for i in range(4, 9)] + [(5, i) for i in range(5, 9)]

# Iterate over each n-gram range
for ngram_range in ngram_ranges:
    print(f"Processing ngram_range: {ngram_range}")
    lda_topic_modeling(filtered_train_df['bug_description'], filtered_test_df['class_name'], ngram_range=ngram_range)
    print("------------------------------------------------------------------")
# Out:
# Processing ngram_range: (2, 2)
# Top words for topic #0:
# ['search engine', 'via rest', 'content assist', 'user api', 'internal server', 'custom field', 'server error', 'email notification', 'new tab', 'rest api']
#
#
# Top words for topic #1:
# ['doesnt work', 'user group', 'attachment rest', 'wiki page', 'address bar', 'org eclipse', 'intermittent browser', 'send email', 'email notification', 'rest api']
#
#
# Top words for topic #2:
# ['doe work', 'due date', 'send notification', 'error message', 'context menu', 'notification email', 'new tab', 'rest api', 'custom field', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.32      0.42      1345
#     Frontend       0.43      0.43      0.43       987
#     Security       0.03      0.30      0.06        70
#
#     accuracy                           0.37      2402
#    macro avg       0.35      0.35      0.30      2402
# weighted avg       0.51      0.37      0.41      2402
#
# Confusion Matrix:
# [[432 535 378]
#  [278 428 281]
#  [ 23  26  21]]
# Accuracy: 0.36677768526228144
# Precision: 0.36677768526228144
# Recall: 0.36677768526228144
# F1-Score: 0.36677768526228144
# ------------------------------------------------------------------
# Processing ngram_range: (2, 3)
# Top words for topic #0:
# ['email footer', 'redmine api', 'user api', 'search engine', 'content assist', 'address bar', 'new tab', 'context menu', 'email notification', 'rest api']
#
#
# Top words for topic #1:
# ['mention user username', 'mention user', 'user group', 'internal server error', 'internal server', 'new tab', 'server error', 'custom field', 'email notification', 'rest api']
#
#
# Top words for topic #2:
# ['issue email notification', 'email template', 'issue email', 'db migrate', 'doe work', 'send email', 'custom field', 'new tab', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.31      0.41      1345
#     Frontend       0.45      0.46      0.45       987
#     Security       0.03      0.30      0.06        70
#
#     accuracy                           0.37      2402
#    macro avg       0.36      0.36      0.31      2402
# weighted avg       0.52      0.37      0.42      2402
#
# Confusion Matrix:
# [[420 537 388]
#  [265 454 268]
#  [ 22  27  21]]
# Accuracy: 0.3726061615320566
# Precision: 0.3726061615320566
# Recall: 0.3726061615320566
# F1-Score: 0.3726061615320566
# ------------------------------------------------------------------
# Processing ngram_range: (2, 4)
# Top words for topic #0:
# ['notification email', 'email notification error', 'notification error', 'new tab', 'send email', 'custom field', 'context menu', 'redmine api', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['issue notification', 'error message', 'doe work', 'email footer', 'api key', 'notification setting', 'new tab', 'rest api', 'custom field', 'email notification']
#
#
# Top words for topic #2:
# ['mention user', 'mention user username', 'user username', 'due date', 'email configuration', 'new tab', 'content assist', 'custom field', 'email notification', 'rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.59      0.28      0.38      1345
#     Frontend       0.44      0.46      0.45       987
#     Security       0.03      0.27      0.05        70
#
#     accuracy                           0.35      2402
#    macro avg       0.35      0.34      0.29      2402
# weighted avg       0.51      0.35      0.40      2402
#
# Confusion Matrix:
# [[377 549 419]
#  [250 452 285]
#  [ 17  34  19]]
# Accuracy: 0.3530391340549542
# Precision: 0.3530391340549542
# Recall: 0.3530391340549542
# F1-Score: 0.3530391340549542
# ------------------------------------------------------------------
# Processing ngram_range: (2, 5)
# Top words for topic #0:
# ['send mail', 'doe work', 'send email', 'new tab', 'send email notification', 'email template', 'custom field', 'redmine api', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['mention user', 'user username', 'notification setting', 'due date', 'internal server', 'internal server error', 'server error', 'email notification', 'custom field', 'rest api']
#
#
# Top words for topic #2:
# ['send notification', 'email notification error', 'notification error', 'doesnt work', 'custom field', 'content assist', 'context menu', 'new tab', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.60      0.29      0.39      1345
#     Frontend       0.45      0.46      0.46       987
#     Security       0.03      0.27      0.05        70
#
#     accuracy                           0.36      2402
#    macro avg       0.36      0.34      0.30      2402
# weighted avg       0.52      0.36      0.41      2402
#
# Confusion Matrix:
# [[393 527 425]
#  [246 457 284]
#  [ 14  37  19]]
# Accuracy: 0.361781848459617
# Precision: 0.361781848459617
# Recall: 0.361781848459617
# F1-Score: 0.361781848459617
# ------------------------------------------------------------------
# Processing ngram_range: (2, 6)
# Top words for topic #0:
# ['authentification oauth', 'content assist', 'address bar', 'send email', 'notification setting', 'send email notification', 'new tab', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['send notification', 'due date', 'email configuration', 'user username', 'mention user', 'mention user username', 'new tab', 'email notification', 'custom field', 'rest api']
#
#
# Top words for topic #2:
# ['error message', 'email notification error', 'notification error', 'internal server error', 'internal server', 'server error', 'context menu', 'redmine api', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.58      0.29      0.39      1345
#     Frontend       0.43      0.44      0.43       987
#     Security       0.03      0.34      0.06        70
#
#     accuracy                           0.36      2402
#    macro avg       0.35      0.36      0.30      2402
# weighted avg       0.50      0.36      0.40      2402
#
# Confusion Matrix:
# [[396 552 397]
#  [267 435 285]
#  [ 14  32  24]]
# Accuracy: 0.3559533721898418
# Precision: 0.3559533721898418
# Recall: 0.3559533721898418
# F1-Score: 0.3559533721898418
# ------------------------------------------------------------------
# Processing ngram_range: (2, 7)
# Top words for topic #0:
# ['context menu', 'content assist', 'internal server error', 'internal server', 'error message', 'server error', 'new tab', 'email notification', 'redmine api', 'rest api']
#
#
# Top words for topic #1:
# ['email delivery', 'email header', 'email template', 'new tab', 'email configuration', 'send email', 'send email notification', 'custom field', 'rest api', 'email notification']
#
#
# Top words for topic #2:
# ['email notification error', 'notification error', 'mention user', 'mention user username', 'user username', 'doesnt work', 'due date', 'custom field', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.62      0.32      0.42      1345
#     Frontend       0.47      0.50      0.48       987
#     Security       0.02      0.20      0.04        70
#
#     accuracy                           0.39      2402
#    macro avg       0.37      0.34      0.31      2402
# weighted avg       0.54      0.39      0.43      2402
#
# Confusion Matrix:
# [[430 529 386]
#  [241 489 257]
#  [ 25  31  14]]
# Accuracy: 0.3884263114071607
# Precision: 0.3884263114071607
# Recall: 0.3884263114071607
# F1-Score: 0.3884263114071607
# ------------------------------------------------------------------
# Processing ngram_range: (2, 8)
# Top words for topic #0:
# ['send email', 'new tab', 'mention user', 'mention user username', 'user username', 'server error', 'internal server', 'internal server error', 'rest api', 'email notification']
#
#
# Top words for topic #1:
# ['due date', 'email footer', 'internal error', 'new tab', 'content assist', 'doesnt work', 'redmine api', 'rest api', 'custom field', 'email notification']
#
#
# Top words for topic #2:
# ['unify email', 'unify email notification', 'notification redmine', 'send reminder', 'context menu', 'send notification', 'custom field', 'new tab', 'rest api', 'email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.58      0.28      0.37      1345
#     Frontend       0.44      0.47      0.46       987
#     Security       0.04      0.36      0.06        70
#
#     accuracy                           0.36      2402
#    macro avg       0.35      0.37      0.30      2402
# weighted avg       0.51      0.36      0.40      2402
#
# Confusion Matrix:
# [[371 553 421]
#  [262 467 258]
#  [  9  36  25]]
# Accuracy: 0.35928393005828474
# Precision: 0.35928393005828474
# Recall: 0.35928393005828474
# F1-Score: 0.35928393005828474
# ------------------------------------------------------------------
# Processing ngram_range: (3, 3)
# Top words for topic #0:
# ['picture email notification', 'create edit user', 'abstraction layer notification', 'unify email notification', 'cant delete account', 'notification removing assignment', 'email configuration error', 'email notification error', 'mention user username', 'internal server error']
#
#
# Top words for topic #1:
# ['changed email template', 'set value reminder', 'private issue notification', 'modify email template', 'delete attachment rest', 'changing subject line', 'email dropped timeout', 'option project manager', 'due date redmine', 'via rest api']
#
#
# Top words for topic #2:
# ['using rest api', 'org eclipse ui', 'intermittent browser component', 'send mail option', 'mail ssl working', 'add automated test', 'optional email header', 'smtp authentication failed', 'single tracking bug', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.79      0.21      0.33      1345
#     Frontend       0.51      0.85      0.64       987
#     Security       0.02      0.14      0.04        70
#
#     accuracy                           0.47      2402
#    macro avg       0.44      0.40      0.34      2402
# weighted avg       0.65      0.47      0.45      2402
#
# Confusion Matrix:
# [[278 753 314]
#  [ 67 842  78]
#  [  6  54  10]]
# Accuracy: 0.4704412989175687
# Precision: 0.4704412989175687
# Recall: 0.4704412989175687
# F1-Score: 0.4704412989175687
# ------------------------------------------------------------------
# Processing ngram_range: (3, 4)
# Top words for topic #0:
# ['notification setting group', 'font small version', 'redmine api key', 'email notification setting', 'author name mail', 'picture email notification', 'modify email template', 'due date redmine', 'notification removing assignment', 'mention user username']
#
#
# Top words for topic #1:
# ['set value reminder', 'changed email template', 'mail ssl working', 'problem smtp setup', 'issue assigned group', 'smtp authentication failed', 'abstraction layer notification', 'email configuration error', 'internal server error', 'email notification error']
#
#
# Top words for topic #2:
# ['email send notification', 'email notification redmine', 'send mail option', 'private issue notification', 'cant delete account', 'optional email header', 'email dropped timeout', 'option project manager', 'unify email notification', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.76      0.20      0.32      1345
#     Frontend       0.50      0.85      0.63       987
#     Security       0.01      0.07      0.02        70
#
#     accuracy                           0.47      2402
#    macro avg       0.42      0.38      0.32      2402
# weighted avg       0.63      0.47      0.44      2402
#
# Confusion Matrix:
# [[275 800 270]
#  [ 77 841  69]
#  [  8  57   5]]
# Accuracy: 0.4666944213155704
# Precision: 0.4666944213155704
# Recall: 0.4666944213155704
# F1-Score: 0.4666944213155704
# ------------------------------------------------------------------
# Processing ngram_range: (3, 5)
# Top words for topic #0:
# ['email send notification', 'font small version', 'problem smtp setup', 'abstraction layer notification', 'cant delete account', 'due date redmine', 'optional email header', 'smtp authentication failed', 'internal server error', 'mention user username']
#
#
# Top words for topic #1:
# ['via rest api', 'picture email notification', 'private issue notification', 'changed email template', 'mail ssl working', 'author name mail', 'email dropped timeout', 'notification removing assignment', 'email notification error', 'send email notification']
#
#
# Top words for topic #2:
# ['email getting triggered', 'feedback email delivery', 'attachment rest api', 'send mail option', 'set value reminder', 'modify email template', 'email notification setting', 'unify email notification', 'option project manager', 'email configuration error']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.79      0.20      0.32      1345
#     Frontend       0.50      0.85      0.63       987
#     Security       0.02      0.09      0.03        70
#
#     accuracy                           0.47      2402
#    macro avg       0.43      0.38      0.33      2402
# weighted avg       0.65      0.47      0.44      2402
#
# Confusion Matrix:
# [[274 782 289]
#  [ 68 842  77]
#  [  7  57   6]]
# Accuracy: 0.46711074104912575
# Precision: 0.46711074104912575
# Recall: 0.46711074104912575
# F1-Score: 0.46711074104912575
# ------------------------------------------------------------------
# Processing ngram_range: (3, 6)
# Top words for topic #0:
# ['paging miss entry', 'email notification redmine', 'email send notification', 'create edit user', 'changed email template', 'send mail option', 'cant delete account', 'smtp authentication failed', 'abstraction layer notification', 'internal server error']
#
#
# Top words for topic #1:
# ['mail ssl working', 'email notification setting', 'option project manager', 'due date redmine', 'email dropped timeout', 'optional email header', 'notification removing assignment', 'unify email notification', 'email notification error', 'mention user username']
#
#
# Top words for topic #2:
# ['feedback email delivery', 'email getting triggered', 'font small version', 'attachment rest api', 'private issue notification', 'author name mail', 'problem smtp setup', 'picture email notification', 'email configuration error', 'send email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.82      0.22      0.35      1345
#     Frontend       0.50      0.86      0.64       987
#     Security       0.02      0.09      0.03        70
#
#     accuracy                           0.48      2402
#    macro avg       0.45      0.39      0.34      2402
# weighted avg       0.66      0.48      0.46      2402
#
# Confusion Matrix:
# [[296 779 270]
#  [ 61 850  76]
#  [  6  58   6]]
# Accuracy: 0.47960033305578686
# Precision: 0.47960033305578686
# Recall: 0.47960033305578686
# F1-Score: 0.47960033305578686
# ------------------------------------------------------------------
# Processing ngram_range: (3, 7)
# Top words for topic #0:
# ['extension rest api', 'problem smtp setup', 'modify email template', 'mail ssl working', 'cant delete account', 'notification removing assignment', 'abstraction layer notification', 'option project manager', 'smtp authentication failed', 'send email notification']
#
#
# Top words for topic #1:
# ['changed email template', 'send mail option', 'private issue notification', 'author name mail', 'picture email notification', 'email notification setting', 'email dropped timeout', 'due date redmine', 'internal server error', 'mention user username']
#
#
# Top words for topic #2:
# ['delete attachment rest api', 'notification setting group', 'email getting triggered', 'associated revision api', 'attachment rest api', 'set value reminder', 'unify email notification', 'optional email header', 'email configuration error', 'email notification error']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.82      0.20      0.32      1345
#     Frontend       0.51      0.87      0.64       987
#     Security       0.01      0.06      0.02        70
#
#     accuracy                           0.47      2402
#    macro avg       0.45      0.38      0.33      2402
# weighted avg       0.67      0.47      0.45      2402
#
# Confusion Matrix:
# [[272 763 310]
#  [ 50 856  81]
#  [ 11  55   4]]
# Accuracy: 0.47127393838467946
# Precision: 0.47127393838467946
# Recall: 0.47127393838467946
# F1-Score: 0.47127393838467946
# ------------------------------------------------------------------
# Processing ngram_range: (3, 8)
# Top words for topic #0:
# ['notification setting group', 'feedback email delivery', 'send mail option', 'author name mail', 'smtp authentication failed', 'due date redmine', 'notification removing assignment', 'optional email header', 'abstraction layer notification', 'email dropped timeout']
#
#
# Top words for topic #1:
# ['delete attachment rest', 'delete attachment rest api', 'redmine api key', 'picture email notification', 'problem smtp setup', 'email notification setting', 'changed email template', 'set value reminder', 'cant delete account', 'email configuration error']
#
#
# Top words for topic #2:
# ['create edit user', 'email notification error', 'modify email template', 'private issue notification', 'mail ssl working', 'option project manager', 'unify email notification', 'send email notification', 'internal server error', 'mention user username']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.77      0.21      0.33      1345
#     Frontend       0.51      0.86      0.64       987
#     Security       0.02      0.10      0.03        70
#
#     accuracy                           0.47      2402
#    macro avg       0.43      0.39      0.33      2402
# weighted avg       0.64      0.47      0.45      2402
#
# Confusion Matrix:
# [[287 768 290]
#  [ 77 846  64]
#  [ 10  53   7]]
# Accuracy: 0.4746044962531224
# Precision: 0.4746044962531224
# Recall: 0.4746044962531224
# F1-Score: 0.4746044962531224
# ------------------------------------------------------------------
# Processing ngram_range: (4, 4)
# Top words for topic #0:
# ['date alert email notification', 'rake ignore blank parameter', 'reminder rake ignore blank', 'send email notification failed', 'try send email notification', 'send reminder working redmine', 'dont want notified change', 'want notified change make', 'email notification involved clarification', 'notify user high issue']
#
#
# Top words for topic #1:
# ['wiki watch option working', 'extended watcher notification feature', 'new email notification option', 'add button send notification', 'time send email long', 'email notification specified filter', 'issue email notification setup', 'larger font email notification', 'mention working status changed', 'need email configuration redmine']
#
#
# Top words for topic #2:
# ['mail full name commenter', 'email notification create ticket', 'problem email integration office', 'change url automatic mail', 'reporter watcher receiving mail', 'added formatting email notification', 'hiding field email notification', 'redmine send reminder work', 'custom template email notification', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.93      0.15      0.26      1345
#     Frontend       0.50      0.97      0.66       987
#     Security       0.01      0.04      0.02        70
#
#     accuracy                           0.49      2402
#    macro avg       0.48      0.39      0.31      2402
# weighted avg       0.72      0.49      0.42      2402
#
# Confusion Matrix:
# [[205 895 245]
#  [ 15 959  13]
#  [  1  66   3]]
# Accuracy: 0.4858451290591174
# Precision: 0.4858451290591174
# Recall: 0.4858451290591174
# F1-Score: 0.4858451290591174
# ------------------------------------------------------------------
# Processing ngram_range: (4, 5)
# Top words for topic #0:
# ['popup message session timeout', 'api key user page', 'api redmine configuration information', 'hide favourite project mypage', 'access control allow origin', 'get tag via api', 'email notification create ticket', 'added formatting email notification', 'email notification specified filter', 'delete attachment rest api']
#
#
# Top words for topic #1:
# ['unable view login page localhost', 'unable view login page', 'email truncated use deleted', 'activation email rejected gmail', 'login password transmission srp', 'rest api group permissoins', 'larger font email notification', 'reporter watcher receiving mail', 'custom template email notification', 'notify user high issue']
#
#
# Top words for topic #2:
# ['change url automatic mail', 'add button send notification', 'problem email integration office', 'time send email long', 'issue email notification setup', 'email notification involved clarification', 'hiding field email notification', 'mention working status changed', 'redmine send reminder work', 'need email configuration redmine']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.90      0.17      0.29      1345
#     Frontend       0.50      0.97      0.66       987
#     Security       0.00      0.00      0.00        70
#
#     accuracy                           0.50      2402
#    macro avg       0.47      0.38      0.32      2402
# weighted avg       0.71      0.50      0.43      2402
#
# Confusion Matrix:
# [[235 896 214]
#  [ 22 954  11]
#  [  4  66   0]]
# Accuracy: 0.49500416319733553
# Precision: 0.49500416319733553
# Recall: 0.49500416319733553
# F1-Score: 0.49500416319733553
# ------------------------------------------------------------------
# Processing ngram_range: (4, 6)
# Top words for topic #0:
# ['activation email rejected gmail', 'send reminder working redmine', 'get tag via api', 'problem email integration office', 'time send email long', 'added formatting email notification', 'change url automatic mail', 'larger font email notification', 'email notification involved clarification', 'notify user high issue']
#
#
# Top words for topic #1:
# ['api redmine configuration information', 'wiki watch option working', 'extended watcher notification feature', 'issue via rest api', 'reporter watcher receiving mail', 'issue email notification setup', 'redmine send reminder work', 'custom template email notification', 'mention working status changed', 'hiding field email notification']
#
#
# Top words for topic #2:
# ['hide favourite project mypage', 'popup message session timeout', 'access control allow origin', 'warning comment go nowhere', 'email notification create ticket', 'api archive unarchive project', 'add button send notification', 'email notification specified filter', 'need email configuration redmine', 'delete attachment rest api']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.94      0.17      0.28      1345
#     Frontend       0.50      0.97      0.66       987
#     Security       0.01      0.03      0.01        70
#
#     accuracy                           0.49      2402
#    macro avg       0.48      0.39      0.32      2402
# weighted avg       0.74      0.49      0.43      2402
#
# Confusion Matrix:
# [[222 885 238]
#  [  9 953  25]
#  [  4  64   2]]
# Accuracy: 0.4900083263946711
# Precision: 0.4900083263946711
# Recall: 0.4900083263946711
# F1-Score: 0.4900083263946711
# ------------------------------------------------------------------
# Processing ngram_range: (4, 7)
# Top words for topic #0:
# ['extended watcher notification feature', 'send reminder working redmine', 'problem email integration office', 'larger font email notification', 'notify user high issue', 'redmine send reminder work', 'email notification involved clarification', 'need email configuration redmine', 'mention working status changed', 'delete attachment rest api']
#
#
# Top words for topic #1:
# ['popup message session timeout', 'search falsy parameter respected', 'access control allow origin', 'api archive unarchive project', 'warning comment go nowhere', 'get tag via api', 'time send email long', 'added formatting email notification', 'email notification specified filter', 'custom template email notification']
#
#
# Top words for topic #2:
# ['block user via api', 'recursive watcher option mode', 'rest api group permissoins', 'expose repository rest api', 'wiki watch option working', 'reporter watcher receiving mail', 'issue email notification setup', 'add button send notification', 'change url automatic mail', 'hiding field email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.92      0.17      0.28      1345
#     Frontend       0.50      0.97      0.66       987
#     Security       0.00      0.01      0.01        70
#
#     accuracy                           0.49      2402
#    macro avg       0.48      0.38      0.32      2402
# weighted avg       0.72      0.49      0.43      2402
#
# Confusion Matrix:
# [[223 883 239]
#  [ 17 955  15]
#  [  2  67   1]]
# Accuracy: 0.49084096586178183
# Precision: 0.49084096586178183
# Recall: 0.49084096586178183
# F1-Score: 0.49084096586178183
# ------------------------------------------------------------------
# Processing ngram_range: (4, 8)
# Top words for topic #0:
# ['expose repository rest api', 'english becomes unavailable redmine', 'warning comment go nowhere', 'wiki watch option working', 'issue email notification setup', 'problem email integration office', 'email notification involved clarification', 'mention working status changed', 'redmine send reminder work', 'notify user high issue']
#
#
# Top words for topic #1:
# ['search falsy parameter respected', 'popup message session timeout', 'email notification create ticket', 'extended watcher notification feature', 'send reminder working redmine', 'api archive unarchive project', 'change url automatic mail', 'add button send notification', 'need email configuration redmine', 'delete attachment rest api']
#
#
# Top words for topic #2:
# ['restore deleted user info', 'access control allow origin', 'get tag via api', 'time send email long', 'larger font email notification', 'reporter watcher receiving mail', 'email notification specified filter', 'added formatting email notification', 'custom template email notification', 'hiding field email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.93      0.18      0.29      1345
#     Frontend       0.51      0.97      0.67       987
#     Security       0.02      0.06      0.02        70
#
#     accuracy                           0.50      2402
#    macro avg       0.48      0.40      0.33      2402
# weighted avg       0.73      0.50      0.44      2402
#
# Confusion Matrix:
# [[236 869 240]
#  [ 17 959  11]
#  [  2  64   4]]
# Accuracy: 0.49916736053288924
# Precision: 0.49916736053288924
# Recall: 0.49916736053288924
# F1-Score: 0.49916736053288924
# ------------------------------------------------------------------
# Processing ngram_range: (5, 5)
# Top words for topic #0:
# ['email due date get elapsed', 'remainder email due date get', 'make assignee prominent email notification', 'longer receiver shown field upgrade', 'restapi set version start date', 'api authentication json web token', 'custom style sheet email notification', 'servidor de correo está configurado', 'notification mail issue creation email', 'redmine doe send notification email']
#
#
# Top words for topic #1:
# ['mailer synched delivery thread safe', 'auto watch issue issue creation', 'edit mail subject form default', 'outgoing email doesnt work upgrade', 'show gravatar icon email notification', 'reminder rake ignore blank parameter', 'send mail full name commenter', 'unable view login page localhost', 'due date alert email notification', 'add table border email notification']
#
#
# Top words for topic #2:
# ['custom email sender per project', 'create issue via rest api', 'add style pre email notification', 'separated email template closed status', 'show due day email notification', 'need patch enable email queue', 'send fa security notification asynchronously', 'try send email notification failed', 'sending email changing subject line', 'change email notification sending time']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.95      0.12      0.21      1345
#     Frontend       0.48      0.98      0.65       987
#     Security       0.00      0.01      0.01        70
#
#     accuracy                           0.47      2402
#    macro avg       0.48      0.37      0.29      2402
# weighted avg       0.73      0.47      0.38      2402
#
# Confusion Matrix:
# [[161 982 202]
#  [  6 970  11]
#  [  2  67   1]]
# Accuracy: 0.47127393838467946
# Precision: 0.47127393838467946
# Recall: 0.47127393838467946
# F1-Score: 0.47127393838467946
# ------------------------------------------------------------------
# Processing ngram_range: (5, 6)
# Top words for topic #0:
# ['make account endpoint accessible api', 'show parent issue notification email', 'api authentication json web token', 'unnecessary encoded cr character mail', 'show gravatar icon email notification', 'outgoing email doesnt work upgrade', 'notification mail issue creation email', 'add table border email notification', 'show due day email notification', 'due date alert email notification']
#
#
# Top words for topic #1:
# ['nomethoderror undefined method description tracker', 'servidor de correo está configurado', 'separated email template closed status', 'show custom field notification email', 'redmine doe send notification email', 'mailer synched delivery thread safe', 'reminder rake ignore blank parameter', 'try send email notification failed', 'send mail full name commenter', 'change email notification sending time']
#
#
# Top words for topic #2:
# ['make assignee prominent email notification', 'url outgoing email get mutilated', 'add style blockquote email notification', 'add style pre email notification', 'edit mail subject form default', 'auto watch issue issue creation', 'sending email changing subject line', 'unable view login page localhost', 'send fa security notification asynchronously', 'need patch enable email queue']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.97      0.13      0.22      1345
#     Frontend       0.48      0.98      0.65       987
#     Security       0.01      0.03      0.01        70
#
#     accuracy                           0.48      2402
#    macro avg       0.49      0.38      0.30      2402
# weighted avg       0.74      0.48      0.39      2402
#
# Confusion Matrix:
# [[170 967 208]
#  [  5 972  10]
#  [  1  67   2]]
# Accuracy: 0.47626977518734387
# Precision: 0.47626977518734387
# Recall: 0.47626977518734387
# F1-Score: 0.47626977518734387
# ------------------------------------------------------------------
# Processing ngram_range: (5, 7)
# Top words for topic #0:
# ['show parent issue notification email', 'unnecessary encoded cr character mail', 'outgoing email doesnt work upgrade', 'add style pre email notification', 'servidor de correo está configurado', 'show gravatar icon email notification', 'redmine doe send notification email', 'reminder rake ignore blank parameter', 'change email notification sending time', 'sending email changing subject line']
#
#
# Top words for topic #1:
# ['restapi set version start date', 'make api paging limit configurable', 'add admin flag user api', 'nomethoderror undefined method description tracker', 'make assignee prominent email notification', 'filter issue status reminder task', 'create issue via rest api', 'separated email template closed status', 'mailer synched delivery thread safe', 'unable view login page localhost']
#
#
# Top words for topic #2:
# ['auto watch issue issue creation', 'edit mail subject form default', 'notification mail issue creation email', 'send fa security notification asynchronously', 'show due day email notification', 'need patch enable email queue', 'add table border email notification', 'try send email notification failed', 'due date alert email notification', 'send mail full name commenter']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.94      0.13      0.23      1345
#     Frontend       0.48      0.98      0.65       987
#     Security       0.00      0.01      0.01        70
#
#     accuracy                           0.48      2402
#    macro avg       0.48      0.38      0.30      2402
# weighted avg       0.72      0.48      0.40      2402
#
# Confusion Matrix:
# [[177 960 208]
#  [ 12 969   6]
#  [  0  69   1]]
# Accuracy: 0.47751873438801
# Precision: 0.47751873438801
# Recall: 0.47751873438801
# F1-Score: 0.47751873438801
# ------------------------------------------------------------------
# Processing ngram_range: (5, 8)
# Top words for topic #0:
# ['api authentication json web token', 'nomethoderror undefined method description tracker', 'include workflow creation rest api', 'show gravatar icon email notification', 'show custom field notification email', 'mailer synched delivery thread safe', 'separated email template closed status', 'add style blockquote email notification', 'redmine doe send notification email', 'need patch enable email queue']
#
#
# Top words for topic #1:
# ['include attachment news post notification', 'restapi set version start date', 'show parent issue notification email', 'unnecessary encoded cr character mail', 'servidor de correo está configurado', 'change email notification sending time', 'reminder rake ignore blank parameter', 'try send email notification failed', 'show due day email notification', 'send mail full name commenter']
#
#
# Top words for topic #2:
# ['notification mail issue creation email', 'outgoing email doesnt work upgrade', 'auto watch issue issue creation', 'add style pre email notification', 'edit mail subject form default', 'unable view login page localhost', 'sending email changing subject line', 'send fa security notification asynchronously', 'add table border email notification', 'due date alert email notification']
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Backend       0.94      0.12      0.21      1345
#     Frontend       0.48      0.99      0.65       987
#     Security       0.00      0.01      0.01        70
#
#     accuracy                           0.47      2402
#    macro avg       0.48      0.37      0.29      2402
# weighted avg       0.73      0.47      0.39      2402
#
# Confusion Matrix:
# [[162 972 211]
#  [  9 975   3]
#  [  1  68   1]]
# Accuracy: 0.47377185678601164
# Precision: 0.47377185678601164
# Recall: 0.47377185678601164
# F1-Score: 0.47377185678601164
# ------------------------------------------------------------------
