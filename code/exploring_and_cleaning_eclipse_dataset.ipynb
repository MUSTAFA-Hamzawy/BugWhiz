# %%
import os
import pandas as pd
import re

# %% [markdown]
# **Loading and merging the data**

# %%
# Define the path to the directory containing the CSV files
directory_path = os.path.join('..', 'data', 'eclipse_dataset', 'dataset_before_merge')

# List all CSV files in the directory
file_paths = [os.path.join(directory_path, file) for file in os.listdir(directory_path) if file.endswith('.csv')]

# Read the CSV files into DataFrames
dataframes = [pd.read_csv(file) for file in file_paths]

# Concatenate all DataFrames into a single DataFrame
eclipse_dataset = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# **Exploring the data**

# %%
print(eclipse_dataset.shape)
# Out:
# (333667, 8)

# %%
print(eclipse_dataset.columns)
# Out:
# Index(['Bug ID', 'Product', 'Component', 'Assignee', 'Status', 'Resolution',
#        'Summary', 'Changed'],
#       dtype='object')

# %%
eclipse_dataset
# Out:
#         Bug ID            Product                   Component  \
# 0       419458             Sphinx                        Core
# 1       430531             Sphinx                        Core
# 2       447379             Sphinx                        Core
# 3       447395             Sphinx                        Core
# 4       448041             Sphinx  Navigator & Editor Sockets
# ...        ...                ...                         ...
# 333662  150112  Target Management                         RSE
# 333663  153629  Target Management                         RSE
# 333664  160778  Target Management                         RSE
# 333665  190930  Target Management                         RSE
# 333666  312320  Target Management                         RSE
#
#                 Assignee       Status Resolution  \
# 0           sphinx-inbox  UNCONFIRMED        ---
# 1           sphinx-inbox  UNCONFIRMED        ---
# 2           sphinx-inbox  UNCONFIRMED        ---
# 3           sphinx-inbox  UNCONFIRMED        ---
# 4           sphinx-inbox  UNCONFIRMED        ---
# ...                  ...          ...        ...
# 333662            kmunir       CLOSED      FIXED
# 333663  mober.at+eclipse       CLOSED      FIXED
# 333664  mober.at+eclipse       CLOSED      FIXED
# 333665  mober.at+eclipse       CLOSED      FIXED
# 333666  mober.at+eclipse       CLOSED      FIXED
#
#                                                   Summary              Changed
# 0       Usage of HashSet and HashMap does not preserve...  2021-08-24 08:47:27
# 1                     ModelLoadManager forces System.gc()  2021-08-24 08:48:08
# 2       Add support for scheduling rules in the dynami...  2021-08-24 08:47:19
# 3       Class loading problem during dynamic workflow ...  2021-08-24 08:47:38
# 4       [BasicTransactionalFormEditor] addPages() meth...  2021-08-24 08:47:56
# ...                                                   ...                  ...
# 333662         [api] Dead code: SystemNewConnectionWizard  2008-08-13 13:16:59
# 333663  RSE Project Filters show up as "%ViewFilter.RS...  2006-11-23 06:53:01
# 333664                  typo on RSE "Tutorials" help page  2008-08-13 13:08:32
# 333665  Need to update the year of copyright in Univer...  2012-05-23 17:32:27
# 333666  TVT36:TCT199: Mnemonics on TestConnection cont...  2010-05-28 11:21:28
#
# [333667 rows x 8 columns]

# %%
print(eclipse_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333667 entries, 0 to 333666
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Bug ID      333667 non-null  int64
#  1   Product     333667 non-null  object
#  2   Component   333667 non-null  object
#  3   Assignee    333667 non-null  object
#  4   Status      333667 non-null  object
#  5   Resolution  333667 non-null  object
#  6   Summary     333664 non-null  object
#  7   Changed     333667 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 20.4+ MB
# None

# %% [markdown]
# **Delete duplicate data [if exist]**

# %%
eclipse_dataset.duplicated().any()
# Out:
# False

# %% [markdown]
# **generates descriptive statistics of the data**

# %%
# generates descriptive statistics of the data
# include="O": This parameter is specifying that you want to include columns with object data type 
eclipse_dataset.describe(include = "O")
# Out:
#        Product Component   Assignee    Status Resolution  \
# count   333667    333667     333667    333667     333667
# unique     222       778       2820         7          8
# top        JDT      Core  webmaster  RESOLVED      FIXED
# freq     63266     54768       9369    171494     201858
#
#                                     Summary              Changed
# count                                333664               333667
# unique                               327017               305148
# top     DVT34: broken link in documentation  2005-09-27 09:12:53
# freq                                    105                  504

# %%
# compute the number of unique values for each column in the DataFrame training_data.
eclipse_dataset.nunique()
# Out:
# Bug ID        333667
# Product          222
# Component        778
# Assignee        2820
# Status             7
# Resolution         8
# Summary       327017
# Changed       305148
# dtype: int64

# %% [markdown]
# **Show the unique values for Status column**

# %%
# Print the unique values for the 'Status' column
status_unique_values = eclipse_dataset['Status'].unique()
print(f"Unique values in the 'Status' column: {status_unique_values}")
# Out:
# Unique values in the 'Status' column: ['UNCONFIRMED' 'NEW' 'ASSIGNED' 'REOPENED' 'RESOLVED' 'VERIFIED' 'CLOSED']

# %% [markdown]
# **Show the unique values for Resolution column**

# %%
# Print the unique values for the 'Resolution' column
resolution_unique_values = eclipse_dataset['Resolution'].unique()
print(f"Unique values in the 'Resolution' column: {resolution_unique_values}")
# Out:
# Unique values in the 'Resolution' column: [' ---' 'FIXED' 'WONTFIX' 'INVALID' 'NOT_ECLIPSE' 'WORKSFORME' 'DUPLICATE'
#  'MOVED']

# %% [markdown]
# **Remove rows with 'Resolution' is 'DUPLICATE' or 'INVALID'**

# %%
# Filter out rows with 'Duplicate' in the 'Resolution' column
eclipse_dataset = eclipse_dataset[eclipse_dataset['Resolution'] != 'DUPLICATE']

# Filter out rows with 'INVALID' in the 'Resolution' column
eclipse_dataset = eclipse_dataset[eclipse_dataset['Resolution'] != 'INVALID']

# %%
'''
Bug ID is unique for each column ==> remove it
Resolution, Status, Product, Component, Changed don't affect our task
'''
# Out:
# "\nBug ID is unique for each column ==> remove it\nResolution, Status, Product, Component, Changed don't affect our task\n"

# %% [markdown]
# **Drop unnecessary columns**

# %%
# Columns to drop
columns_to_drop = ['Bug ID', 'Resolution', 'Status', 'Product', 'Component', 'Changed']

# Drop the specified columns
eclipse_dataset = eclipse_dataset.drop(columns=columns_to_drop)

# %%
print(eclipse_dataset.columns)
# Out:
# Index(['Assignee', 'Summary'], dtype='object')

# %% [markdown]
# **generates descriptive statistics of the data**

# %%
# generates descriptive statistics of the data
# include="O": This parameter is specifying that you want to include columns with object data type 
eclipse_dataset.describe(include = "O")
# Out:
#          Assignee                              Summary
# count      291373                               291371
# unique       2779                               286938
# top     webmaster  DVT34: broken link in documentation
# freq         8603                                   71

# %% [markdown]
# **Show the number of nulls in each column**

# %%
# Print the number of null values in each column in the training data
print(eclipse_dataset.isnull().sum())
# Out:
# Assignee    0
# Summary     2
# dtype: int64

# %% [markdown]
# **Remove rows with null values**

# %%
# remove rows with missing values from the dataset
eclipse_dataset.dropna(inplace=True)
print(eclipse_dataset.isnull().sum())
# Out:
# Assignee    0
# Summary     0
# dtype: int64

# %% [markdown]
# **Print the minimum number of occurance of Assignee column**

# %%
min_occurrences = eclipse_dataset['Assignee'].value_counts().min()
print(f"The minimum number of occurrences in owner column is {min_occurrences}")
# Out:
# The minimum number of occurrences in owner column is 1

# %% [markdown]
# **Filter the dataset do the minimum occurance of each Assignee is 5**

# %%
# Calculate the occurrences of each value in the owner column
value_counts = eclipse_dataset['Assignee'].value_counts()

# Filter the dataset to include only rows where the value in 'owner' has at least 5 occurrences
eclipse_dataset = eclipse_dataset[eclipse_dataset['Assignee'].isin(value_counts[value_counts >= 5].index)]

# %%
min_occurrences = eclipse_dataset['Assignee'].value_counts().min()
print(f"The minimum number of occurrences in owner column after filteration is {min_occurrences}")
# Out:
# The minimum number of occurrences in owner column after filteration is 5

# %%
print(eclipse_dataset.shape)
# Out:
# (289359, 2)

# %%
# compute the number of unique values for each column in the DataFrame training_data.
eclipse_dataset.nunique()
# Out:
# Assignee      1623
# Summary     284967
# dtype: int64

# %% [markdown]
# **Show the values of Assignee column**

# %%
# Print the unique values for the 'Status' column
assignee_unique_values = eclipse_dataset['Assignee'].unique()
print(f"Unique values in the 'Assignee' column:")
for assignee_value in assignee_unique_values:
    print (assignee_value)
# Out:
# Unique values in the 'Assignee' column:
# sphinx-inbox
# a.gurov
# ali.akar82
# cdt-build-inbox
# ddoerr
# KetanPadegaonkar
# khu
# nicolaspeifer
# sedlund
# soa-inbox
# stem.core-inbox
# stem.simulation-inbox
# stem.ui-inbox
# stephaneberle9
# swtbot-inbox
# balazs.grill
# christian.k.2510
# christian.thoens
# jhkauf
# mattadav
# werner.keil
# mariot.chauvin
# igor.burilo
# alexei.goncharov
# aprsac
# apupier
# john.cortell
# laurent.redor
# lorenzo.bettini
# malaperle
# michael.keppler
# mistria
# patrick.tasse
# pierre-charles.david
# sbouchet
# twolf
# wellmann.hannes1
# ymesika
# idydieng
# jthomas119
# webdaford
# alexander.fedorov
# eclipse
# emo
# ohf.stem-inbox
# robert.kiss
# statet-inbox
# sw
# mmt-qvt.operational-inbox
# qvtd-inbox
# adolfosbh
# alexander.igdalov
# arcanefoam
# christopher.gerking
# dvorak.radek
# engine.qvtr-inbox
# ivan
# mknauer
# mmt-atl.web-inbox
# parser.qvtr-inbox
# rap-inbox
# rap.incubator-inbox
# serg.boyko2011
# ui.qvtr-inbox
# austin.riddle
# rsternberg
# b.muskalla
# fr.appel
# ruediger.herrmann
# tbuschto
# a_mergey
# bjorn.freeman-benson
# dominik.ebert
# m2t.core-inbox
# ralf.zahn
# stefan.roeck
# tom.schindl
# webmaster
# PDE-Incubator-Inbox
# apogy-inbox
# app4mc-inbox
# d_a_carver
# milesparker
# AJDT-inbox
# aspectj-inbox
# aclement
# adrian.colyer
# andmore-inbox
# avasseur
# cdtdoug
# equinox.incubator-inbox
# ericc
# jdt-apt-inbox
# jonas.ruettimann
# kaloyan
# matthew_webster
# urs.frei
# disabled
# mik.kersten
# regent.larcheveque
# harald.mackamul
# pierre.allard
# hlhawkins
# jim-aj
# wes
# eh-ajdev
# gharley
# matthew
# mpchapman
# tools.pmc-inbox
# andreas.sailer
# daniel.kunz
# dirk.fauth
# jdt-core-inbox
# zakirhussain.meer
# ldt-inbox
# m2e-wtp.core-inbox
# mdht-inbox
# mdt-bpmn2-inbox
# mdt-uml2-inbox
# microprofile-inbox
# mmt-atl.doc-inbox
# mmt-atl.toolkit-inbox
# modisco.web-inbox
# dsdp.mtj-inbox
# gdupe
# lyo.core-inbox
# mpc.wizard-inbox
# adrian.mos
# andriib
# camle
# cdt-doc-inbox
# dcarlson
# ebaron
# eclipse.e4-inbox
# Ed.Merks
# fiedler.mf
# gustavo.eliano
# hugo.bruneliere
# iw
# jad
# jamsden
# jhelming
# jjohnstn
# kkinfoo
# lukas.ladenberger
# lyo.client-inbox
# lyo.docs-inbox
# lyo.ldp-inbox
# lyo.releng-inbox
# lyo.rio-inbox
# lyo.server-inbox
# lyo.testsuite-inbox
# m2t.xpand-inbox
# mat.core-inbox
# mat.gui-inbox
# mdt-releng-inbox
# mdt-website-inbox
# mfeldman
# michael
# mpc.install-inbox
# nboldt
# ns03ja
# pelder.eclipse
# peter
# ralph.soika
# reckord
# rgrunber
# richard.gronback
# samuel.padgett
# sven.efftinge
# swagiaal
# xraynaud
# yash.s.khatri
# fabien.giquel
# rmf.pror-inbox
# nicolas.bros
# hussein.mhanna
# andreas.buchen
# andrew_johnson
# fbricon
# hheitkoetter
# kevin.grigorenko
# krum.tsvetkov
# mat.doc-inbox
# dwagelaar
# contact
# CDT-Contrib-Inbox
# code
# ffleutot
# greensopinion
# karl.matthias
# lbarthelemy
# marc.aubry42
# mgiang
# mihini-inbox
# rperier
# sasal002
# xavier.raynaud
# xcoulon
# danielhb
# elena.nayashkova
# give.a.damus
# gorkem.ercan
# Kenn.Hussey
# nathan
# steffen.pingel
# a.nehmer
# ahunter.eclipse
# akurtako
# akurtakov
# alcapcom
# angelika.wittek
# anithra
# b.kolb
# bruck.james
# cabernal
# caniszczyk
# charley.wang
# chris.guindon
# elaskavaia.cdt
# erik.brangs
# erwin.margewitsch
# fchouinard
# ian.skerrett
# krzysztof.daniel
# lbullen
# linux.distros-inbox
# linux.packagingtools-inbox
# linux.rpm-inbox
# linuxtools-inbox
# lufimtse
# m.koller
# ma.becker
# marketplace-inbox
# mat.booth
# mdmbl-inbox
# mmt.web-inbox
# obusatto
# overholt
# Platform-UI-Inbox
# platform-ui-triaged
# pmuldoon
# snjezana.peco
# stepper
# thanh.ha
# thomas
# uml2-core-inbox
# wst.server-inbox
# wtv368
# ansgar.radermacher
# cletavernier
# denis.roy
# arto.laurila
# barbier.gabriel
# borlander
# hugo.raniere
# schoenbach
# wds057
# wgp010
# dgterry
# Achim.Loerke
# alex.blewitt
# cdt-core-inbox
# craigsfnet
# darius.jockel
# dennis.huebner
# florian.schmitt
# fnegre
# ganesh.deshvini
# gmt-am3-inbox
# Heiko.Behrens
# jan
# jljlmatu
# jruehlin
# karsten.thoms
# khorowit
# m.fleischer
# melaasar
# mika.hoikkala
# mikael.barbero
# moritz.eysholdt
# phoenix.ui-inbox
# pitschke
# pmcmahan
# ptp-inbox
# pulsar-inbox
# rpastran
# seanpk
# simon.skoczylas
# sspeiche
# tmf.xtext-inbox
# ttsanton
# yyin
# eclemma-inbox
# ecore-inbox
# eef-inbox
# sirius.properties-inbox
# abuzila
# eneufeld
# jfaltermeier
# psuzzi
# bsd
# bugs.eclipse.org
# e4.languages-inbox
# e4.runtime-inbox
# e4.search-inbox
# e4.tools-inbox
# e4.ui-inbox
# ecf.core-inbox
# ecf.doc-inbox
# ecf.examples-inbox
# ecf.test-inbox
# emfcp.common-inbox
# emfcp.editor-inbox
# emfcp.emfforms-inbox
# hoffmann
# lkoehler
# sdirix
# tony.homer
# glenn.plouhinec
# mandrikov
# remy.suen
# rschnekenburger
# stephane.begaudeau
# david.soto.setzke
# emf.edapt-inbox
# wim.jongman
# bokowski
# emueller
# nobody
# pwebster
# aghilesa
# aniefer
# azerr
# ccalli
# codesurgeon
# danail.branekov
# daniel.rolka
# david.eclipse000
# dimitar.georgiev
# e4.resources-inbox
# e4.xwt-inbox
# eclipse.org.list
# eduard.bartsch
# emfcp.validation-inbox
# emft.eef-inbox
# emoffatt
# fabian.pfaff
# gheorghe
# goulwen.lefur
# herrmama
# jacek.pospychala
# john.arthorne
# Kevin_McGuire
# kim.moir
# Lars.Vogel
# marco
# mayworm
# melanie.bats
# Michael_Rennie
# modlost
# nathalie.lepine
# ob1.eclipse
# olivier.prouvost
# Olivier_Thomann
# Patrick.Tessier
# platform-resources-inbox
# pnehrer
# roland
# serge
# sergebeauchamp
# simon.scholz
# simon_kaegi
# sirius.core-inbox
# skanton
# slewis
# steven
# susan
# winston.prakash
# yves.yang
# laurent.fasani
# ease-inbox
# emfcp.modelworkspace-inbox
# mkoegel
# christian.pontesegger
# arthur.daussy
# devnull
# e4.scripting-inbox
# emfcp.navigator-inbox
# franziska.haunolder
# jakub.jurkiewicz
# jean-francois.rolland
# jonah
# mfleck
# mschaefer
# neil
# ottovonwesendonk
# sebastien.revol
# t.s.verhoeven
# planger
# agarcdomi
# antonio.campesino.robles
# dkolovos
# epp.packager-inbox
# equinox.framework-inbox
# gef-inbox
# gendoc-inbox
# mohamed-ali.bachtobji
# cbridgha
# cedric.brun
# epp.installer-inbox
# equinox.compendium-inbox
# equinox.components-inbox
# equinox.launcher-inbox
# equinox.p2-inbox
# equinox.security-inbox
# equinox.server-side-inbox
# equinox.weaving-inbox
# esf-inbox
# gemini.blueprint-inbox
# gemini.dbaccess-inbox
# gemini.management-inbox
# gemini.naming-inbox
# gemini.web-inbox
# geogig-inbox
# geomesa-inbox
# irbull
# jan.celmer
# laeubi
# matthias.wienand
# michael.keith
# nyssen
# polarsys.general-inbox
# sinadoom
# sravankumarl
# tjwatson
# zoltan.ujhelyi
# beth
# hamdan.msheik
# milesg78
# pascal
# sewe
# equinox.website-inbox
# louis
# mn
# aboyko
# arunkumar.thondapu
# david_williams
# ebordeau
# haftsteind
# hudsonr
# jeffmcaffer
# juergen.haug
# mwflaher
# ppshah
# recommenders-inbox
# simon.laffoy
# steveshaw
# unknown1
# wayne.beaton
# agcattle
# crevells
# dj.houghton
# henrik.lindberg
# jfogell
# mgobeil
# mmostafa
# platform-runtime-inbox
# pradeepb
# sorensm
# aldo_eisma
# anjum.eclipse
# anne.haugommard
# bartosz.michalik
# bluesoldier
# cbi.prototype-inbox
# christian.georgi
# christoph.langer
# daniel_megert
# david.dubrow
# dean.t.roberts
# delee
# dstevens
# eclipse.sprigogin
# emf.cdo-inbox
# epp.dpd-inbox
# eric.milles
# eric.poirier
# eric_w_li
# error-reports-inbox
# etrice.core-inbox
# etrice.documentation-inbox
# etrice.generators-inbox
# etrice.releng-inbox
# etrice.runtime-inbox
# etrice.test-inbox
# etrice.userinterface-inbox
# grant_gayed
# gunnar
# hargrave
# hrr
# igor
# jan.belle
# jkubitz-eclipse
# johannes.dorn
# julian.honnen
# jwross
# kane.zhu
# konradk
# konstantin
# l.kirchev
# laurent.goubet
# leberre
# lgrahek
# loskutov
# lshanmug
# marcel.bruch
# markus.kell.r
# maxime.porhel
# miklossy
# mlippert
# mober.at+eclipse
# naci.dai
# niraj.modi
# ogruber
# pascal.rapicault
# paul-eclipse
# pde-build-inbox
# pyvesdev
# raymond.auge
# register.eclipse
# rinsvind
# s.boshev
# sebastian.ratz
# shaun.smith
# Silenio_Quarti
# simeon.danailov.andreev
# sja.eclipse
# sptaszkiewicz
# steeg
# Stefan.Liebig
# stephanie.swart
# sxenos
# syedatif
# t-oberlies
# thatnitind
# timothym
# tj
# tjbishop
# tmacdoug
# Tod_Creasey
# tomasz.zarna
# torbjorn.svensson
# ts
# vasili.gulevich
# Vikas.Chandra
# walther
# wassim.melhem
# wong
# zulus
# kalyan_prasad
# markus.tiede
# noopur_gupta
# zeb.ford-reitz
# accceleo-inbox
# andrey
# cocoakevin
# dmitry
# egit.releng-inbox
# fwaibel
# ganoro
# olaf
# pde-ui-inbox
# tom.ware
# virgo-inbox
# webtools.releng-inbox
# zteve.powell
# aobuchow
# pde-apitools-inbox
# pde-doc-inbox
# rafael.oliveira
# sarika.sinha
# dejan
# pde-core-inbox
# rodrigo
# andre_weinand
# ankur_sharma
# baumanbr
# curtis.windatt.public
# darin.eclipse
# janek.lb
# agarcher
# brockj
# carsten.hammer
# cherie.wong
# Darin_Swanson
# jerome_lanneluc
# kjdoyle
# lesojones
# markus.duft
# mike.pawlowski
# noam.chitayat
# stephan.herrmann
# vincent.lorenzo
# abel.hegedus
# azoff
# christian.dietrich.opensource
# Curtis_Windatt
# jonas.hungershausen
# kitlo
# martin.karpisek
# pragya.g
# stefan
# suag
# Szymon.Brandys
# tmccrary
# vrubezhny
# jdt-ui-inbox
# asma.smaoui
# cedric.dumoulin
# charles
# mdt-papyrus-inbox
# mickael.adam29
# papyrusrt-inbox
# quentin.lemenez
# saadia.dhouib
# tapanta.bhanja
# bmaher
# eposse
# fanch.bonnabesse
# ibtihel.khemir
# jeremie.tatibouet
# mathilde.arnaud
# nifauvergue
# pauline.deville
# sebastien.gerard
# shuai.li
# benoit.maggi
# Celine.janssens
# Chokri.Mraidha
# thanhliem.phan
# arnaud.cuccuru
# kovalsky
# mathieu.velten
# fjcano
# vincent.hemery
# francois.le-fevre
# gery.deloge
# tatiana.fesenko
# tischenko
# axel.richard
# bruno.marques
# David.Servat
# emilien.perico
# faure.tristan
# gabriel.pascual
# jerome.benois
# juan.cadavid
# laurent.wouters
# mauricio.alferez
# patrik
# sebastien.gabel
# shatilov
# t.leouay
# thibault.landre
# yann.tanguy
# yupanqui.munozjulho
# guy.perron
# lucasgabillard
# mdt-uml2tools-inbox
# onder.gurcan
# peter.cigehn
# schafe
# simon.delisle
# ysroh
# jgit.core-inbox
# jsdt.javascript-inbox
# jsdt.debug-inbox
# cameron.bateman
# debajit.adhikary
# gerry.kessler
# ian.trimble
# jubula.core-inbox
# jubula.rc-inbox
# carlin.rogers
# christian.halstrick
# cmjaun
# egit.core-inbox
# egit.ui-inbox
# ibuziuk
# jsdt.web-inbox
# jsf-inbox
# jsf.core-inbox
# jsf.doc-inbox
# jsf.ui-inbox
# jubula.agent-inbox
# jubula.tools-inbox
# jubula.ua-inbox
# jubula.ui-inbox
# marvin_m
# mathias.kinzler
# raghunathan.srinivasan
# wst.javascript-inbox
# Marcel.Hein
# matthias.sohn
# miklos.hartmann
# nsand.dev
# sebastian.jubula
# sop
# berkland
# childsb
# itewksbu
# joakim.erdfelt
# 4diac-inbox
# adalbertolopezv
# adrian.goerler
# athena
# boulay
# ccc
# dariusz.luksza
# david.a.jencks
# esteban.dugueperoux
# gregw
# hmalphettes
# istewart
# janb
# jasonpet
# jdeblen1
# jens.baumgart
# jesse.mcconnell
# jetty-inbox
# kevin
# lbustelo
# leachbj
# mgorovoy
# orlandor
# robin
# robin.rosenberg
# sbryzak
# simone.bordet
# stefan.lay
# tbecker
# samuelwu
# alexandra.schladebeck
# bela.bara
# daniel.toelgyesi
# Maissmaallsmyss.Maulhs
# Oliver.Goetz
# raimar.buehmann
# yung-chang.chen
# elena.pister
# jchoi
# justj-inbox
# philipp.thun
# jst.j2ee-inbox
# jst.jsp-inbox
# wakaama-inbox
# diegosr
# locationtech.wg-inbox
# arvera
# deboer
# dimitar.giormov
# ericdp
# fproj-inbox
# galileo
# jmmunoz
# jst.ws-triaged
# mahutch
# samindaw
# sandakith
# shr31223
# stryker
# wst.common-inbox
# wst.dtd-inbox
# wst.html-inbox
# wst.sse-inbox
# wst.validation-inbox
# wst.wsdl-triaged
# wst.wsi-triaged
# wst.xml-inbox
# wst.xml-triaged
# wst.xsd-triaged
# zalapa
# zina
# adrianpade14
# alina
# atosak
# bkorn
# chavezjc
# dariog
# doug.satchwell
# eyuen7
# hshanka
# iot.wg-inbox
# jakarta.wg-inbox
# jcollier
# jenyoung
# jesper
# jst-inbox
# jst.ejb-inbox
# jst.jsp-triaged
# jst.server-inbox
# jst.servlet-inbox
# jst.ws-inbox
# jst.ws.jaxws-inbox
# katep
# kathy
# keith.chong.ca
# larryisaacs
# lmandel
# lts.infrastructure-inbox
# makandre
# martin.lowe
# mhutchin
# neil.hauge
# petya.sabeva
# rakes123
# rosendo
# sghung
# shane_clarke
# sharon.corbett
# sinan.konya
# webtools.documentation-inbox
# webtools.education-inbox
# webtools.website-inbox
# woolsey-inbox
# wst-inbox
# wst.css-inbox
# wst.html-triaged
# wst.internet-inbox
# wst.json-inbox
# wst.sse-triaged
# wst.web-inbox
# wst.ws-inbox
# wst.ws-triaged
# wst.wsdl-inbox
# wst.wsi-inbox
# wst.xsd-inbox
# wst.xsl-inbox
# wst.xsl-triaged
# wtp.inc.jaxws-inbox
# wtp.inc.xsl-inbox
# vaninder
# bob.fraser
# dpchou
# sengpl
# jsholl
# ktsao
# nagrawal
# valentinbaciu
# amkareh
# for.work.things
# jgwest
# mukul.gandhi
# pmoogk
# rfrost
# richkulp
# tewksbur
# thebravoman
# danny.ju
# eclipse.felipe
# gautier.desaintmartinlacaze
# gilberta
# gindik
# israelgd
# ivanc
# janelle
# jgarms
# karasiuk
# openmdm.wg-inbox
# polarsys.wg-inbox
# ramanday
# shuff
# stefan.dimov
# tranle1
# webdev
# wmmark
# wtp.inc-inbox
# yenlu
# cbrealey
# csalter
# dfholt
# jeffliu
# jialin
# jlanuti
# joan
# kboo
# lauzond
# mdelder
# pavery
# rkklai
# rmah
# rsinha
# vbhadrir
# walkerp
# yavor.vasilev.boyadzhiev
# agarwasa
# andyzhai
# ebelisar
# oetlinge
# tcarroll
# trungha
# blancett
# jayjaybillings
# ledunnel
# nssheth
# platform-text-inbox
# ryman
# syeshin
# wtp-dev
# erdal.karaca.de
# jin.liu
# ice-inbox
# jakartaee-stable-inbox
# jordan.deyton
# amccaskey2223
# bennettar
# smithrw
# jdt-debug-inbox
# maxime_daniel
# wojtowicza
# andypiperuk
# asm
# fpagliughi
# icraggs
# nick.oleary
# ppatierno
# xtend-inbox
# miro.spoenemann
# Holger.Schill
# buildship-inbox
# cf-inbox
# loulloudes.n
# bbrodt
# babel.core-inbox
# babel.server-inbox
# nigelipse
# pleacu
# vulnerability.reports-inbox
# antoine
# basyx-inbox
# flavio.donze
# gabe.obrien
# kai.hudalla
# satoru_yoshida_kawasaki
# csdonat
# etienne
# sirius.diagram-inbox
# sirius.tree-inbox
# narayana.nekkanti
# florian.barbin
# pierre.guilet
# sirius.doc-inbox
# sirius.releng-inbox
# sirius.table-inbox
# skills-inbox
# jessy.mallet
# steve.monnier
# simultaneousrelease-inbox
# sirius.server-inbox
# belqassim.djafer
# alex.lagarde
# arnaud.dieumegard
# benjamin.grouhan
# mathieu.cartaud
# mickael.lanoe
# efm-inbox
# efxclipse-inbox
# egerrit-inbox
# ejb-inbox
# elk-inbox
# ccaks
# egit.gitflow-inbox
# egit.github-inbox
# egit.mylyn-inbox
# zephanya
# elogbook-inbox
# marc.khouzam
# cross-project.inbox
# lmcbout
# tobbaumann
# mdt-ocl-inbox
# nattable.core-inbox
# ogee.core-inbox
# om2m-inbox
# oomph-inbox
# openj9-inbox
# openpass-inbox
# libingw
# oliver.wolf
# orbit.bundles-inbox
# orbit.releng-inbox
# orion.client-inbox
# orion.editor-inbox
# orion.server-inbox
# acceleo-inbox
# benalaya
# Carolyn_MacLeod
# esp1
# masquill
# objectteams.otdt-inbox
# objectteams.otequinox-inbox
# objectteams.otj-inbox
# oisin.hurley
# orion.git-inbox
# orion.releng-inbox
# osee.ats-inbox
# osee.framework-inbox
# osee.website-inbox
# ryan.d.brooks
# Sumy.Joseph
# torkildr
# walter.vorhees
# xinyij
# ryan.schmitt
# Angel.Avila2
# caseyflynn
# julian.enoch
# misinco
# roberto.e.escobar
# derek.toolan
# ed
# fifteenknots505
# mamacdon
# mihai.sucan
# steve_northover
# adrian.aichner
# aidanr
# aissaoui
# alston
# andrew.eisenberg
# andy.jury
# antonm
# bartosz.grabski
# e4.orion-inbox
# edyta.przymus
# elijahe
# felix.dorner
# filip.madej
# gabriel.luong
# henshin.ck
# jainnayna
# jarthana
# jasmsing
# jhan
# jiahaow
# jimfan
# ken_walker
# maciej.bendkowski
# malgorzata.tomczyk
# marco.miller
# maxli
# mmousa
# orion.doc-inbox
# s.t.jahns
# sudol.wojciech
# ubolatov
# wajnberg
# xintong
# christian.campo
# cbmcgee
# cvogt
# david.w.miller6
# donald.g.dunne
# megumi.telles
# openk-usermodules-inbox
# paul.waldfogel
# rflueckiger
# sebastian.zarnekow
# shawn.f.cook
# Theron.W.Virgin
# vramaswa
# shankhba
# aiproulx
# akiezun
# amj87.iitr
# anchakrk
# david
# david_audel
# deepakazad
# gayanper
# jdt-core-triaged
# jdt-doc-inbox
# jdt-text-inbox
# kai-uwe_maetzel
# manoj.palat
# mateusz.matela
# sasikanth.bharadwaj
# satyam.kandula
# srikanth.sankaran
# srikanth_sankaran
# tip
# fabrice.tiercelin
# gzsombor
# het
# jinbwan
# manju656
# t.s.maeder
# dirk_baeumer
# christof_marti
# Claude_Knaus
# erich_gamma
# jared_burns
# kent_johnson
# Markus_Huebscher
# martinae
# philippe_mulet
# Rory_Lucyshyn-Wright
# tobias_widmer
# unknown
# benno.baumgartner
# frederic_fusier
# raksha.vasisht
# rfaust
# rfuhrer
# chanskw
# chris
# eclipsetalk2
# eric_jodet
# erol_koc_OTI
# ferenc.hechler
# jeem
# kenneth
# mkaufman
# nikolaymetchev
# paul.fullbright
# pawel.1.piech
# pisv
# rthakkar
# samrat.dhillon
# silvio_boehler
# teicher-bugzilla
# till_bay
# tyeung
# krzysztof.michalski
# alex.panchenko
# me
# szabta89
# rcptt-inbox
# raphael.faudou
# reqcycle-inbox
# reqcycle.requirement_editor-inbox
# riena.core-inbox
# riena.navigation-inbox
# achilles.sabine
# b-karunamoorthy
# d-russo
# reqcycle.traceability_viewer-inbox
# riena.communication-inbox
# riena.ui-inbox
# sascha
# thorsten.schenkel
# zachary.labaysse
# dfriedland
# jcusano
# karl
# pgingrich
# rowlands
# vikram.adiga
# steffen.kriese
# ademars
# akapania
# cring
# judah
# sg
# ulyana.skorokhodova
# juergen.becker
# elias
# riena.tests-inbox
# ivan.inozemtsev
# mail
# mixail.bobylev
# amitm
# c-mccormick
# titan-inbox
# tracecompass-inbox
# tracecompass.incubator-inbox
# time4sys-inbox
# alexmonthy
# bernd.hufmann
# gbastien+lttng
# aurelien.didier51
# loic.prieurdrevon
# matthew.khouzam
# php.ui-inbox
# tmf.common-inbox
# clay
# emft-mwe-inbox
# mike
# kitalpha-inbox
# kura.core-inbox
# jwt.metamodel-inbox
# faycal.abka
# jwt.desktop-inbox
# jwt.releng-inbox
# jwt.transformations-inbox
# jwt.we-inbox
# thomas.guiu
# lautenbacher
# philippe.dul
# jean.barata
# chr.seitz
# christian.saad
# jaubry
# marc.dutoo
# minhtutonthat
# amalgam.ui-inbox
# yvan.lussaud
# amalgam.releng-inbox
# amalgam.web-inbox
# cabralcochi
# martin.melik
# lolrus
# swhiting
# b.j.dalziel
# fordmat3
# imcgrath
# luzius.meisser
# sjanuary
# alois.zoitl
# monika.wenger
# gmf-runtime-inbox
# graphiti-inbox
# gmp.gmf-tooling-inbox
# gmf.runtime.diagram-inbox
# tikhomirov.artem
# akarjakina
# Alexander.Fedorov
# bobfoster
# boris.blajer
# carson_li
# dimzzy
# duncan.r.mills
# g.hillairet
# gmf.devtools-inbox
# gmf.generation-inbox
# gmf.models-inbox
# gmf.runtime.common-inbox
# gmf.runtime.emf-inbox
# gmf.samples-inbox
# gmf.templates-inbox
# gmf.ui-inbox
# jason
# sgribovsky
# schristou88
# eshaverdova
# michael.wenz
# rovarghe
# gmf.releng-inbox
# gmf.runtime-inbox
# ldamus
# shatalin
# ylulu
# chris.waniek
# dcummin
# etworkow
# gmf-notation-inbox
# gmf.docs-inbox
# hawk-inbox
# wdiu
# christian.brand
# felix.velasco
# matthias.gorning
# tim.kaiser
# elena.parovyshnaya
# nikifor.fedorov
# passage-inbox
# serjiokov
# benoit.langlois
# egf-inbox
# emf.compare-inbox
# emfdiffmerge.core-inbox
# emfparsley-inbox
# emfservices-inbox
# matthieu.helleboid
# adietish
# arendt
# caspar_d
# davidms
# emf.query2-inbox
# emfdiffmerge.ui-inbox
# emfrefactor.refactorings-inbox
# emfrefactor.ui-inbox
# henshin.core-inbox
# henshin.interpreter-inbox
# henshin.ui-inbox
# martin.fluegge
# miguel.garcia
# mtaal
# schulzs
# strueber
# vroldanbet
# laurent.delaigue
# olivier.constant
# vaisegid
# elitani
# frankb
# marcelop
# boris.gruschko
# bhunt
# bportier
# emfservices.query-inbox
# emfservices.transaction-inbox
# emfservices.validation-inbox
# emfstore.clientcore-inbox
# emfstore.clientui-inbox
# emfstore.common-inbox
# emfstore.servercore-inbox
# enrico
# francesco.guidieri
# henshin.stj
# michal.ruza
# vincenzo.caselli
# smcduff
# pascal.lehmann
# lunk.peter
# udig-inbox
# usssdk-inbox
# viatra-inbox
# viatra-query
# viatra-transformation
# aberry
# b.kapukaranov
# bdmetz
# cnethery
# dmarthaler
# gabor.bergmann
# harmath
# istvanrath
# lonnie
# trip
# vertx.core-inbox
# vertx.platform-inbox
# viatra-dse
# vorto-inbox
# shopkins
# leo.dos.santos
# incquery.runtime-inbox
# alexander.edelmann
# davidi
# hsiliev
# incquery.tooling-inbox
# jkobal
# marton.bur
# mgreenawalt
# modeling.gmt.viatra2-inbox
# nasz013
# viatra-cep
# gm.romanato
# istvan.papp
# norman.maurer
# capra-inbox
# cft-inbox
# che-inbox
# chemclipse-inbox
# dirigible-inbox
# dltk.common-inbox
# drupal.projects-inbox
# vparfono
# dtp.sqldevtools-inbox
# bfitzpat
# brian.vosburgh
# cdt-refactoring-inbox
# dltk.tcl-inbox
# nan.n.li
# pascal.filion
# andrei.sobolev
# bpayton
# cdt-arduino-inbox
# cdt-build-managed-inbox
# cdt-codan-inbox
# cdt-debug-cdi-gdb-inbox
# cdt-debug-dsf-gdb-inbox
# cdt-debug-dsf-inbox
# cdt-debug-inbox
# cdt-editor-inbox
# cdt-indexer-inbox
# cdt-launch-inbox
# cdt-parser-inbox
# cdt-releng-inbox
# cdt-source-nav-inbox
# dali.diagrameditor-inbox
# dali.framework-inbox
# dali.general-inbox
# dali.website-inbox
# dash-inbox
# dltk.python-inbox
# dtp.connectivity-inbox
# dtp.enablement-inbox
# dtp.modelbase-inbox
# emily.sybase
# hskolwal
# hui.cao
# juewu
# Jun-Yan.Ren
# karenfbutzke
# linsong
# lzhu
# mwu
# quyon
# rick.sapir
# salomehonest
# spektom
# timur
# ui.guidelines-inbox
# william.riley
# wtu
# xiaofeng.zhang
# xwu
# lchan
# dominic.scharfe
# ec
# g.watson
# kds
# neilwang
# sbrandt
# thomas.corbat
# accounts-inbox
# alain
# b3.aggregator-inbox
# cbi-inbox
# ci.admin-inbox
# cwiebe
# dashboard-inbox
# Dave_Williams
# dinglis
# edouard
# forums-inbox
# foundation.ipzilla-inbox
# hamer
# john.camelon
# ken.ryall
# leftylynn
# lj
# mikekucera
# mikhail.kalugin
# nkurtov
# olivier.fremion
# portal-inbox
# recoskie
# sevoy
# thomasf
# victor.lenet
# vivkong
# weisz
# xli
# andrew.ferguson
# api-inbox
# capella-inbox
# christophe.gatti
# community.blogs-inbox
# damien.filliat
# darrell.armstrong
# dave.daoust
# devinsteffler.lists
# dmcknigh
# drupal.eclipsecon-inbox
# enriquev
# erwan.brottier
# eyasser
# jcamelon
# khapitas
# leo.treggiari
# ling.5.wang
# marco.stornelli
# phoenix.contentmgt-inbox
# Randy.Rohrbach
# roland.bary
# ted
# tm.core-inbox
# turnham
# twolff
# abdullah.dev0
# achapiro
# aleherb+eclipse
# alvaro.sanchez-leon
# amozzhuhin
# andrea.ross
# angvoz.dev
# anna.dushistova
# anne.jacko
# bala.torati
# bryan2233
# cdt-debug-cdi-inbox
# clare
# community.articles-inbox
# ctron
# davmac
# dd.general-inbox
# dltk.ruby-inbox
# donald.smith
# doshiro
# drupal.iwg-inbox
# dyang
# eclipse.org-architecture-council
# eclipselive-inbox
# ed.swartz
# emanuel
# fabrizio.iannetti
# filip.hrbek
# fmorgner
# foe-disbursements-inbox
# frank.turovich
# frederic.gurr
# gabe
# georgi.pavlov
# hannes
# hansruedi.patzen
# jamesblackburn+eclipse
# janet.campbell
# jason.montojo
# jeblen
# Jesse.Weinstein
# jgangemi
# jgreen
# joacquim.esabe
# john
# jwsliu
# les.davis
# license
# linkfang
# marc.dumais
# mike.milinkovich
# mikhail.sennikovskiy
# mkmanishkhurana98
# mkwan
# mschorn.eclipse
# norbert.ploett
# oleg.krasilnikov
# pchuong
# rcernich
# roxanne.joncas
# sebastien
# sharon.macdonald
# simon.marchi
# sonar-inbox
# sunil.k.davasam
# suzy.broto
# teodor.madan
# umair_sair
# ward.cunningham
# warren.paul
# WilliamRSwanson
# woskimi
# wtp.inc.jpaeditor-inbox
# xma
# yi.liu
# yjiang
# zeratul976
# dfiguero
# eromero
# matei-alexandru.stamate
# hung.hsi
# jeremyl
# jgraham
# max
# mparra
# arjan.tijms
# danijoh2
# eugene
# maxim.nesen
# ootsuka
# wolfgang.auer
# zzhu
# com-eclipse-dot-org
# photran-inbox
# amine.ouraiba
# bwatt
# cla.knobloch
# cmnavarr
# marianomendez
# W.Frings
# c.karbach
# wspear
# incongruous
# clement.chu
# khendle2
# tyuvash2
# rsqrd
# ahumphrey
# arossi
# crasmussen
# dfferber
# drwootton
# ndebard
# ronglli
# tuhongj
# donny.kurniawan
# texlipse-inbox
# ddykstal.eclipse
# tm.rse-inbox
# xuanchen
# dbrachet.wr
# dsdp.tm.tcf-inbox
# erdillon
# javier.montalvoorus
# kmunir
# rgerganov
# rupenm
# sheldond
# tcf.agent-inbox
# tcf.core-inbox
# tcf.debug-inbox
# tcf.tm-inbox
# technology.pmc-inbox
# tigerstripe.core-inbox
# tigerstripe.diagram-inbox
# tigerstripe.documentation-inbox
# tigerstripe.plugin-inbox
# tigerstripe.ui-inbox
# yuri
# jistrawn
# nmehrega
# tigerstripe.annotations-inbox
# felix.burton
# uwe.st
# dkeysell
# rcraddoc
# sjerman
# tea-inbox
# tigerstripe.facet-inbox
# william.chen

# %% [markdown]
# **clean the text in the summary column**

# %%
def preprocess_summary(summary):
    # Remove special characters
    summary = re.sub(r'[^\w\s]', '', summary)
    # Remove newlines
    summary = summary.replace('\n', ' ')
    # Remove hyperlinks
    summary = re.sub(r'http\S+', '', summary)
    return summary

# %%
# Preprocess the 'Summary' column
eclipse_dataset['Summary'] = eclipse_dataset['Summary'].apply(preprocess_summary)

# %% [markdown]
# **Filter the dataset by the number of words in Summary column**

# %%
def filter_by_word_count(df, min_word_count):
    return df[df['Summary'].str.split().str.len() >= min_word_count]

# %%
# Define the minimum word count
min_word_count = 5

# Filter rows where the 'Summary' has at least min_word_count words
eclipse_dataset = filter_by_word_count(eclipse_dataset, min_word_count)

# %%
print(eclipse_dataset.shape)
# Out:
# (247997, 2)

# %% [markdown]
# **Save cleaned data**

# %%
current_dir = os.getcwd() 
relative_path = os.path.join('..', 'data','eclipse_dataset','cleaned_eclipse_dataset.csv')
eclipse_dataset.to_csv(os.path.join(current_dir, relative_path), index=False) # exclude the DataFrame index from being saved to the CSV file.
